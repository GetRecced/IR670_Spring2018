# %%
# Imports 
import string
import pandas as pd
import numpy as np
import time
from scipy.stats.stats import pearsonr 
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
# load the data, keep only selected columns
# Read the file using super fast Pandas.read_csv
def load_required_data(path, required_columns):
    dataframe = pd.read_json(path, lines=True)
    dataframe = dataframe[required_columns]
    return dataframe, dataframe.values

# %%
dataframe, values = load_required_data('../train.json', ["asin", "reviewerID", "overall"])

# %%
dataframe[:10]
# Out:
#          asin             reviewerID  overall
# 0  B00AMR1HZ8  A00100742Q4O8VH0YMUBZ        4
# 1  B006C1ZSO4  A00100742Q4O8VH0YMUBZ        5
# 2  B00ANT8OF6  A00100742Q4O8VH0YMUBZ        4
# 3  B008LY1B32  A00100742Q4O8VH0YMUBZ        4
# 4  B0080JJLBW  A00100742Q4O8VH0YMUBZ        5
# 5  B007KPT2N4  A00100742Q4O8VH0YMUBZ        1
# 6  B00EQ2TYMS  A00100742Q4O8VH0YMUBZ        4
# 7  B007PW1BRC  A00100742Q4O8VH0YMUBZ        2
# 8  B009P8EMCK  A00100742Q4O8VH0YMUBZ        5
# 9  B006YUVTK0  A00100742Q4O8VH0YMUBZ        5

# %%
dataframe.shape
# Out:
# (665666, 3)

# %%
# Create user-item matrix given a matrix and mapping from original matrix columns to new matrix rows/columns
def create_user_item_matrix(data, rowMapping, columnMapping):
    # Create table of users to items by taking row and column pivots
    # Rows of user-item table are users
    rows, row_pos = np.unique(data[:, rowMapping], return_inverse=True)
    # Columns of user-item table are movies
    cols, col_pos = np.unique(data[:, columnMapping], return_inverse=True)

    pivot_table = np.zeros((len(rows), len(cols)), dtype=data.dtype)
    pivot_table[row_pos, col_pos] = data[:, 2]
    return pivot_table, rows, cols

# %%
ratings_matrix, rows, cols = create_user_item_matrix(values, rowMapping=1, columnMapping=0)
print (ratings_matrix.shape)
# Out:
# (87271, 13209)

# %%
pd.DataFrame(ratings_matrix[:10], index = rows[:10], columns= cols)
# Out:
#                       B004A9SDD8 B004AFQAUA B004AHBBPW B004ALVL6W B004AMAIZQ  \
# A00100742Q4O8VH0YMUBZ          0          0          0          0          0
# A001619027H9L9EG4UVRB          0          0          0          0          0
# A002359833QJM7OQHCXWY          0          0          0          0          0
# A0037670NPLI11RBWYFA           0          0          0          0          0
# A003841815JTX0JFLR8B1          0          0          0          0          0
# A0038872349TB5N0JHQQW          0          0          0          0          0
# A00455683H6M1GQZMPQPV          0          0          0          0          0
# A0047670XAAJD587LXS7           0          0          0          0          0
# A00501041JRAPWYLPQ4TE          0          0          0          0          0
# A00507662MEMHI1YMGQ15          0          0          0          0          0
#
#                       B004AMDC86 B004ANC00Q B004ANE2WU B004ANMWPY B004AZH4C8  \
# A00100742Q4O8VH0YMUBZ          0          0          0          0          0
# A001619027H9L9EG4UVRB          0          0          0          0          0
# A002359833QJM7OQHCXWY          0          0          0          0          0
# A0037670NPLI11RBWYFA           0          0          0          0          0
# A003841815JTX0JFLR8B1          0          0          0          0          0
# A0038872349TB5N0JHQQW          0          0          0          0          0
# A00455683H6M1GQZMPQPV          0          0          0          0          0
# A0047670XAAJD587LXS7           0          0          0          0          0
# A00501041JRAPWYLPQ4TE          0          0          0          0          0
# A00507662MEMHI1YMGQ15          0          0          0          0          0
#
#                          ...     B00LDNE3FG B00LDNQHJ6 B00LEIT6K2 B00LFLOEYG  \
# A00100742Q4O8VH0YMUBZ    ...              0          0          0          0
# A001619027H9L9EG4UVRB    ...              0          0          0          0
# A002359833QJM7OQHCXWY    ...              0          0          0          0
# A0037670NPLI11RBWYFA     ...              0          0          0          0
# A003841815JTX0JFLR8B1    ...              0          0          0          0
# A0038872349TB5N0JHQQW    ...              0          0          0          0
# A00455683H6M1GQZMPQPV    ...              0          0          0          0
# A0047670XAAJD587LXS7     ...              0          0          0          0
# A00501041JRAPWYLPQ4TE    ...              0          0          0          0
# A00507662MEMHI1YMGQ15    ...              0          0          0          0
#
#                       B00LIAMYCI B00LITLOMK B00LMLW8T2 B00LMLXTJK B00LP1MVSW  \
# A00100742Q4O8VH0YMUBZ          0          0          0          0          0
# A001619027H9L9EG4UVRB          0          0          0          0          0
# A002359833QJM7OQHCXWY          0          0          0          0          0
# A0037670NPLI11RBWYFA           0          0          0          0          0
# A003841815JTX0JFLR8B1          0          0          0          0          0
# A0038872349TB5N0JHQQW          0          0          0          0          0
# A00455683H6M1GQZMPQPV          0          0          0          0          0
# A0047670XAAJD587LXS7           0          0          0          0          0
# A00501041JRAPWYLPQ4TE          0          0          0          0          0
# A00507662MEMHI1YMGQ15          0          0          0          0          0
#
#                       B00LUEMK44
# A00100742Q4O8VH0YMUBZ          0
# A001619027H9L9EG4UVRB          0
# A002359833QJM7OQHCXWY          0
# A0037670NPLI11RBWYFA           0
# A003841815JTX0JFLR8B1          0
# A0038872349TB5N0JHQQW          0
# A00455683H6M1GQZMPQPV          0
# A0047670XAAJD587LXS7           0
# A00501041JRAPWYLPQ4TE          0
# A00507662MEMHI1YMGQ15          0
#
# [10 rows x 13209 columns]

# %%
def get_index_map(arr):
    index_map = {}
    for el in arr:
        index_map[el] = len(index_map)
    return index_map

# %%
def pearson_coeff(target, others):
    return np.corrcoef(matrix[target], matrix[others])[0][1:]

# %%
# Get unique movies and users
unique_items = np.unique(values[:,0])
unique_users = np.unique(values[:,1])

# %%
unique_items.shape
# Out:
# (13209,)

# %%
unique_users.shape
# Out:
# (87271,)

# %%
# Create mapping from unique list to 
item_idx_map = get_index_map(unique_items)
user_idx_map = get_index_map(unique_users)

# %%
mean_ratings = np.true_divide(ratings_matrix.sum(1), (ratings_matrix!=0).sum(1))

# %%
K = 0.1

# %%
def get_users_who_rated_item(item_id):
    return np.where(ratings_matrix[:,item_idx_map[item_id]] > 0)[0]

def get_users_who_rated_item_by_index(item_idx):
    return np.where(ratings_matrix[:,item_idx] > 0)

def predict(user_id, item_id):
    item_idx = item_idx_map[item_id]
    user_idx = user_idx_map[user_id]
    other_users_idx = get_users_who_rated_item(item_id)
    if user_idx in other_users_idx:
        np.delete(other_users_idx, user_idx)
    pearson_correlation = [pearsonr(other_user, ratings_matrix[user_idx])[0] for other_user in ratings_matrix[other_users_idx]]
    mean_others = mean_ratings[other_users_idx]
    rating_others = ratings_matrix[other_users_idx,item_idx]
    prediction = mean_ratings[user_idx] + K * np.sum(pearson_correlation * (rating_others - mean_others))
    return prediction

# %%
predict(u'A0698182HBSA2D2MEX40', 'B004K44R74')
# Out:
# mean user =  3.33333333333
# mean other =  3.58868265059
# pearson =  [0.0167888572734455, -0.0006497015732684542, -0.002077295180652037, -0.001123092923200311, -0.0007796779679517869, -0.0013973590945584792, -0.0008269890243092583, -0.0008588432060162333]
# 3.3358391387334074

# %%
np.mean(mean_ratings)
# Out:
# 4.007764456541003

# %%
test_dataframe, test_values = load_required_data('../test.json', ["asin", "reviewerID", "overall"])

# %%
test_dataframe['reviewerID'].unique().shape
# Out:
# (87271,)

# %%
# Returns DF containing predictions, MAE, RMSE
def get_predictions(dataframe):
    df = dataframe.copy()
    print ("Predicting ratings..")
    start_time = time.time()
    df['Prediction'] = df.apply(lambda row: predict_row(row), axis=1)
    MAE = round(mean_absolute_error(df['overall'], df['Prediction']), 2)
    RMSE = round(np.sqrt(mean_squared_error(df['overall'], df['Prediction'])), 2)
    print "Done Predicting in",  round((time.time() - start_time), 2), "seconds"
    return df, MAE, RMSE

def predict_row(row):
    prediction = predict(row['reviewerID'], row['asin'])
    print ("Actual = ", row['overall'], "Predictioned = ", prediction)
    return prediction

# %%
df, MAE, RMSE = get_predictions(test_dataframe)
# Out:
# Predicting ratings..
# ('Actual = ', 5, 'Predictioned = ', 4.013018801103645)
# ('Actual = ', 5, 'Predictioned = ', 5.084660540080265)
# ('Actual = ', 3, 'Predictioned = ', 4.438249332727059)
# ('Actual = ', 4, 'Predictioned = ', 3.7863946929984795)
# ('Actual = ', 5, 'Predictioned = ', 5.229468196676607)
# ('Actual = ', 5, 'Predictioned = ', 3.179725855269213)
# ('Actual = ', 5, 'Predictioned = ', 5.030768402130499)
# ('Actual = ', 3, 'Predictioned = ', 3.4117098961410965)
# ('Actual = ', 3, 'Predictioned = ', 3.99986259332239)
# ('Actual = ', 4, 'Predictioned = ', 3.971900906608292)
# ('Actual = ', 5, 'Predictioned = ', 5.016487908015378)
# ('Actual = ', 4, 'Predictioned = ', 4.219783278191484)
# ('Actual = ', 5, 'Predictioned = ', 3.9997574877840205)
# ('Actual = ', 5, 'Predictioned = ', 4.378683070387178)
# ('Actual = ', 1, 'Predictioned = ', 4.039080478566658)
# ('Actual = ', 1, 'Predictioned = ', 2.7229137371145704)
# ('Actual = ', 5, 'Predictioned = ', 3.8190208339595357)
# ('Actual = ', 5, 'Predictioned = ', 4.500708359285983)
# ('Actual = ', 5, 'Predictioned = ', 4.356548794093407)
# ('Actual = ', 4, 'Predictioned = ', 4.45948079107103)
# ('Actual = ', 4, 'Predictioned = ', 4.249999747899057)
# ('Actual = ', 5, 'Predictioned = ', 3.8253821910950325)
# ('Actual = ', 5, 'Predictioned = ', 3.9167562524166932)
# ('Actual = ', 5, 'Predictioned = ', 3.0000704749641223)
# ('Actual = ', 4, 'Predictioned = ', 4.077984682806997)
# ('Actual = ', 5, 'Predictioned = ', 4.968498265691547)
# ('Actual = ', 4, 'Predictioned = ', 4.466954692145319)
# ('Actual = ', 5, 'Predictioned = ', 5.150036963960957)
# ('Actual = ', 3, 'Predictioned = ', 2.8470970932769895)
# ('Actual = ', 1, 'Predictioned = ', 3.643440440282467)
# ('Actual = ', 5, 'Predictioned = ', 4.914713473933619)
# ('Actual = ', 5, 'Predictioned = ', 3.972206537406783)
# ('Actual = ', 3, 'Predictioned = ', 5.007414369243045)
# ('Actual = ', 5, 'Predictioned = ', 4.75019413005785)
# ('Actual = ', 5, 'Predictioned = ', 4.674225427357915)
# ('Actual = ', 4, 'Predictioned = ', 2.6364896832474636)
# ('Actual = ', 5, 'Predictioned = ', 4.233396729527635)
# ('Actual = ', 3, 'Predictioned = ', 4.063772764258581)
# ('Actual = ', 1, 'Predictioned = ', 3.355968765029836)
# ('Actual = ', 3, 'Predictioned = ', 4.166814811356305)
# ('Actual = ', 4, 'Predictioned = ', 3.083077528390203)
# ('Actual = ', 5, 'Predictioned = ', 4.321187743269569)
# ('Actual = ', 5, 'Predictioned = ', 2.3461584816192467)
# ('Actual = ', 5, 'Predictioned = ', 5.129828446276672)
# ('Actual = ', 5, 'Predictioned = ', 4.778750458299111)
# ('Actual = ', 5, 'Predictioned = ', 3.029903295157699)
# ('Actual = ', 2, 'Predictioned = ', 4.341968731098476)
# ('Actual = ', 1, 'Predictioned = ', 3.4275086312599417)
# ('Actual = ', 2, 'Predictioned = ', 3.1816821669411737)
# ('Actual = ', 1, 'Predictioned = ', 2.62179084424955)
# ('Actual = ', 3, 'Predictioned = ', 3.633540832734951)
# ('Actual = ', 5, 'Predictioned = ', 3.7206492359699066)
# ('Actual = ', 4, 'Predictioned = ', 4.032276744853095)
# ('Actual = ', 4, 'Predictioned = ', 3.3841633043319304)
# ('Actual = ', 1, 'Predictioned = ', 4.586248823870214)
# ('Actual = ', 1, 'Predictioned = ', 2.41358796442331)
# ('Actual = ', 4, 'Predictioned = ', 3.4340942841132978)
# ('Actual = ', 5, 'Predictioned = ', 5.00956952722879)
# ('Actual = ', 3, 'Predictioned = ', 4.4998073351155)
# ('Actual = ', 3, 'Predictioned = ', 3.9054903274211394)
# ('Actual = ', 5, 'Predictioned = ', 5.010571187680386)
# ('Actual = ', 5, 'Predictioned = ', 4.400488966246099)
# ('Actual = ', 4, 'Predictioned = ', 4.380768304917158)
# ('Actual = ', 4, 'Predictioned = ', 3.974788373634033)
# ('Actual = ', 4, 'Predictioned = ', 4.81626491130621)
# ('Actual = ', 4, 'Predictioned = ', 3.6279544321468133)
# ('Actual = ', 5, 'Predictioned = ', 4.777155207785659)
# ('Actual = ', 2, 'Predictioned = ', 3.12837448159482)
# ('Actual = ', 5, 'Predictioned = ', 4.091473608148439)
# ('Actual = ', 5, 'Predictioned = ', 3.8239204640454814)
# ('Actual = ', 5, 'Predictioned = ', 4.434090183711579)
# ('Actual = ', 3, 'Predictioned = ', 4.833394723691063)
# ('Actual = ', 5, 'Predictioned = ', 3.9251690226075935)
# ('Actual = ', 5, 'Predictioned = ', 2.637606264303289)
# ('Actual = ', 5, 'Predictioned = ', 3.8306831211510004)
# ('Actual = ', 2, 'Predictioned = ', 4.6460349988616105)
# ('Actual = ', 5, 'Predictioned = ', 4.613425629416683)
# ('Actual = ', 3, 'Predictioned = ', 4.086846447212085)
# ('Actual = ', 5, 'Predictioned = ', 3.0051909800994725)
# ('Actual = ', 3, 'Predictioned = ', 3.803380360783285)
# ('Actual = ', 5, 'Predictioned = ', 3.66493241589904)
# ('Actual = ', 4, 'Predictioned = ', 3.725274989499432)
# ('Actual = ', 5, 'Predictioned = ', 4.114623607197388)
# ('Actual = ', 5, 'Predictioned = ', 3.7425335129065935)
# ('Actual = ', 4, 'Predictioned = ', 3.250079084848935)
# ('Actual = ', 1, 'Predictioned = ', 4.169056517988516)
# ('Actual = ', 5, 'Predictioned = ', 4.973585781859468)
# ('Actual = ', 5, 'Predictioned = ', 2.8184095779552414)
# ('Actual = ', 5, 'Predictioned = ', 4.729803490133327)
# ('Actual = ', 5, 'Predictioned = ', 5.027614179139541)
# ('Actual = ', 4, 'Predictioned = ', 4.616193558418711)
# ('Actual = ', 5, 'Predictioned = ', 4.507786223197065)
# ('Actual = ', 5, 'Predictioned = ', 4.316595775178339)
# ('Actual = ', 2, 'Predictioned = ', 3.1993973831051026)
# ('Actual = ', 3, 'Predictioned = ', 3.3407790928749854)
# ('Actual = ', 5, 'Predictioned = ', 5.196289523566689)
# ('Actual = ', 5, 'Predictioned = ', 4.262415807494445)
# ('Actual = ', 1, 'Predictioned = ', 4.447879113544436)
# ('Actual = ', 5, 'Predictioned = ', 3.392350748099799)
# ('Actual = ', 5, 'Predictioned = ', 4.380410732946157)
# ('Actual = ', 2, 'Predictioned = ', 5.198129843236549)
# ('Actual = ', 5, 'Predictioned = ', 4.600284409052364)
# ('Actual = ', 5, 'Predictioned = ', 5.0005447241452)
# ('Actual = ', 5, 'Predictioned = ', 4.0604924368210185)
# ('Actual = ', 3, 'Predictioned = ', 4.3130341801645)
# ('Actual = ', 5, 'Predictioned = ', 5.184988110198482)
# ('Actual = ', 5, 'Predictioned = ', 5.044833908283416)
# ('Actual = ', 4, 'Predictioned = ', 4.846419454394275)
# ('Actual = ', 4, 'Predictioned = ', 3.0540711316238167)
# ('Actual = ', 5, 'Predictioned = ', 4.752402312146905)
# ('Actual = ', 5, 'Predictioned = ', 3.0004142975335375)
# ('Actual = ', 4, 'Predictioned = ', 3.991891425686503)
# ('Actual = ', 5, 'Predictioned = ', 4.981133903132377)
# ('Actual = ', 1, 'Predictioned = ', 3.2501707577864725)
# ('Actual = ', 5, 'Predictioned = ', 4.000331164366092)
# ('Actual = ', 3, 'Predictioned = ', 4.23697970147467)
# ('Actual = ', 5, 'Predictioned = ', 4.477782114348872)
# ('Actual = ', 5, 'Predictioned = ', 3.7359438484819276)
# ('Actual = ', 5, 'Predictioned = ', 3.3325497526372843)
# ('Actual = ', 5, 'Predictioned = ', 3.99995071771806)
# ('Actual = ', 5, 'Predictioned = ', 4.473965299832947)
# ('Actual = ', 5, 'Predictioned = ', 3.0210959001456064)
# ('Actual = ', 5, 'Predictioned = ', 4.268450750392439)
# ('Actual = ', 3, 'Predictioned = ', 5.065088298371062)
# ('Actual = ', 5, 'Predictioned = ', 4.204038319383696)
# ('Actual = ', 5, 'Predictioned = ', 4.270800127070283)
# ('Actual = ', 4, 'Predictioned = ', 4.878937758754803)
# ('Actual = ', 5, 'Predictioned = ', 3.835490947988837)
# ('Actual = ', 5, 'Predictioned = ', 4.936787789717524)
# ('Actual = ', 5, 'Predictioned = ', 5.173055228114265)
# ('Actual = ', 5, 'Predictioned = ', 2.7357232719715943)
# ('Actual = ', 4, 'Predictioned = ', 4.328206046080627)
# ('Actual = ', 5, 'Predictioned = ', 5.038109219824552)
# ('Actual = ', 5, 'Predictioned = ', 4.75672608698635)
# ('Actual = ', 5, 'Predictioned = ', 5.188936992225356)
# ('Actual = ', 5, 'Predictioned = ', 4.458451185743531)
# ('Actual = ', 5, 'Predictioned = ', 4.91793710169787)
# ('Actual = ', 1, 'Predictioned = ', 1.0560450969015207)
# ('Actual = ', 5, 'Predictioned = ', 6.7215525045687885)
# ('Actual = ', 5, 'Predictioned = ', 3.5542136094022507)
# ('Actual = ', 5, 'Predictioned = ', 4.533343714818588)
# ('Actual = ', 5, 'Predictioned = ', 1.967261969868357)
# ('Actual = ', 5, 'Predictioned = ', 4.481691845215318)
# ('Actual = ', 5, 'Predictioned = ', 4.302203181297063)
# ('Actual = ', 4, 'Predictioned = ', 3.759130027475317)
# ('Actual = ', 3, 'Predictioned = ', 4.000244649502853)
# ('Actual = ', 5, 'Predictioned = ', 4.772048928655539)
# ('Actual = ', 2, 'Predictioned = ', 2.60044688014722)
# ('Actual = ', 5, 'Predictioned = ', 2.6268173837845303)
# ('Actual = ', 3, 'Predictioned = ', 4.360907911535661)
# ('Actual = ', 5, 'Predictioned = ', 4.098784537207565)
# ('Actual = ', 5, 'Predictioned = ', 4.6596501504133006)
# ('Actual = ', 5, 'Predictioned = ', 3.8899342763327027)
# ('Actual = ', 5, 'Predictioned = ', 4.859807104826084)
# ('Actual = ', 5, 'Predictioned = ', 5.006490257215074)
# ('Actual = ', 5, 'Predictioned = ', 5.285751037325175)
# ('Actual = ', 5, 'Predictioned = ', 4.6634438946663135)
# ('Actual = ', 4, 'Predictioned = ', 4.017314852208578)
# ('Actual = ', 5, 'Predictioned = ', 5.079303758232974)
# ('Actual = ', 5, 'Predictioned = ', 7.72415846570155)
# ('Actual = ', 4, 'Predictioned = ', 5.209131492646335)
# ('Actual = ', 5, 'Predictioned = ', 4.4594314234020285)
# ('Actual = ', 5, 'Predictioned = ', 3.7392597073370637)
# ('Actual = ', 1, 'Predictioned = ', 2.698521988877859)
# ('Actual = ', 1, 'Predictioned = ', 3.891248193716194)
# ('Actual = ', 1, 'Predictioned = ', 4.089813340121124)
# ('Actual = ', 4, 'Predictioned = ', 4.645027695604241)
# ('Actual = ', 2, 'Predictioned = ', 4.2380579400061995)
# ('Actual = ', 5, 'Predictioned = ', 4.39345348459142)
# ('Actual = ', 5, 'Predictioned = ', 4.845653748109617)
# ('Actual = ', 3, 'Predictioned = ', 3.173331779443787)
# ('Actual = ', 5, 'Predictioned = ', 3.750026408517034)
# ('Actual = ', 4, 'Predictioned = ', 4.787754316261339)
# ('Actual = ', 5, 'Predictioned = ', 4.307419557237788)
# ('Actual = ', 4, 'Predictioned = ', 4.293906009411455)
# ('Actual = ', 1, 'Predictioned = ', 4.258729321156277)
# ('Actual = ', 1, 'Predictioned = ', 4.064464611688437)
# ('Actual = ', 4, 'Predictioned = ', 4.081158820923071)
# ('Actual = ', 4, 'Predictioned = ', 5.001395631957468)
# ('Actual = ', 3, 'Predictioned = ', 3.504188609077266)
# ('Actual = ', 2, 'Predictioned = ', 2.750414929487715)
# ('Actual = ', 1, 'Predictioned = ', 3.7713814880111722)
# ('Actual = ', 5, 'Predictioned = ', 4.583616398257061)
# ('Actual = ', 5, 'Predictioned = ', 4.6635100929301245)
# ('Actual = ', 5, 'Predictioned = ', 3.8752539242055395)
# ('Actual = ', 5, 'Predictioned = ', 4.834057447310228)
# ('Actual = ', 5, 'Predictioned = ', 5.758050033417655)
# ('Actual = ', 5, 'Predictioned = ', 3.703973054213499)
# ('Actual = ', 5, 'Predictioned = ', 3.3163291890517543)
# ('Actual = ', 4, 'Predictioned = ', 5.1093139173098)
# ('Actual = ', 5, 'Predictioned = ', 3.429423809672867)
# ('Actual = ', 5, 'Predictioned = ', 4.636667106043895)
# ('Actual = ', 3, 'Predictioned = ', 2.4609646043409232)
# ('Actual = ', 5, 'Predictioned = ', 4.456451017469789)
# ('Actual = ', 1, 'Predictioned = ', 1.3991465752151566)
# ('Actual = ', 2, 'Predictioned = ', 3.691749627417875)
# ('Actual = ', 2, 'Predictioned = ', 2.7482552549377206)
# ('Actual = ', 5, 'Predictioned = ', 4.773256346522674)
# ('Actual = ', 4, 'Predictioned = ', 3.3203825959177773)
# ('Actual = ', 5, 'Predictioned = ', 4.573315200018827)
# ('Actual = ', 5, 'Predictioned = ', 2.445457361520071)
# ('Actual = ', 3, 'Predictioned = ', 3.5764750057738266)
# ('Actual = ', 5, 'Predictioned = ', 5.078091231783015)
# ('Actual = ', 5, 'Predictioned = ', 4.937458957476636)
# ('Actual = ', 1, 'Predictioned = ', 4.6668579396234255)
# ('Actual = ', 5, 'Predictioned = ', 3.6007941506018786)
# ('Actual = ', 5, 'Predictioned = ', 4.233783230206025)
# ('Actual = ', 5, 'Predictioned = ', 4.35602558424896)
# ('Actual = ', 3, 'Predictioned = ', 3.671876564513564)
# ('Actual = ', 2, 'Predictioned = ', 4.222448337524516)
# ('Actual = ', 5, 'Predictioned = ', 3.9937226332319926)
# ('Actual = ', 5, 'Predictioned = ', 1.8447360562977904)
# ('Actual = ', 2, 'Predictioned = ', 2.7516356810728557)
# ('Actual = ', 5, 'Predictioned = ', 3.833000053041833)
# ('Actual = ', 5, 'Predictioned = ', 3.693376086301858)
# ('Actual = ', 1, 'Predictioned = ', 4.480258416627045)
# ('Actual = ', 4, 'Predictioned = ', 4.017733640520279)
# ('Actual = ', 5, 'Predictioned = ', 4.4990513864795085)
# ('Actual = ', 4, 'Predictioned = ', 5.111854124739871)
# ('Actual = ', 4, 'Predictioned = ', 4.643871054950201)
# ('Actual = ', 5, 'Predictioned = ', 3.19122941160739)
# ('Actual = ', 5, 'Predictioned = ', 3.703925903536051)
# ('Actual = ', 4, 'Predictioned = ', 3.0132073551194765)
# ('Actual = ', 5, 'Predictioned = ', 5.302750824491859)
# ('Actual = ', 3, 'Predictioned = ', 4.524185545566548)
# ('Actual = ', 3, 'Predictioned = ', 3.2504264336930326)
# ('Actual = ', 3, 'Predictioned = ', 4.043288821721329)
# ('Actual = ', 5, 'Predictioned = ', 3.558358906709405)
# ('Actual = ', 5, 'Predictioned = ', 5.9356461926554225)
# ('Actual = ', 4, 'Predictioned = ', 4.518122327214336)
# ('Actual = ', 5, 'Predictioned = ', 4.254985529837968)
# ('Actual = ', 3, 'Predictioned = ', 4.785401525073167)
# ('Actual = ', 4, 'Predictioned = ', 4.240027069826588)
# ('Actual = ', 5, 'Predictioned = ', 4.968252236565239)
# ('Actual = ', 4, 'Predictioned = ', 4.24601449059057)
# ('Actual = ', 1, 'Predictioned = ', 3.2417184504072267)
# ('Actual = ', 3, 'Predictioned = ', 3.2084136206302736)
# ('Actual = ', 3, 'Predictioned = ', 3.6157387836585273)
# ('Actual = ', 5, 'Predictioned = ', 4.364888603115279)
# ('Actual = ', 1, 'Predictioned = ', 3.747271795823047)
# ('Actual = ', 5, 'Predictioned = ', 4.624929818471932)
# ('Actual = ', 3, 'Predictioned = ', 4.218857652167795)
# ('Actual = ', 5, 'Predictioned = ', 6.125652510242269)
# ('Actual = ', 5, 'Predictioned = ', 4.766979804287591)
# ('Actual = ', 5, 'Predictioned = ', 1.7794555633307025)
# ('Actual = ', 5, 'Predictioned = ', 8.515195535634755)
# ('Actual = ', 4, 'Predictioned = ', 3.9771353456121346)
# ('Actual = ', 5, 'Predictioned = ', 4.546524021601154)
# ('Actual = ', 4, 'Predictioned = ', 4.756740250378139)
# ('Actual = ', 4, 'Predictioned = ', 3.5751477077290015)
# ('Actual = ', 5, 'Predictioned = ', 4.761359688081564)
# ('Actual = ', 4, 'Predictioned = ', 4.229645144776592)
# ('Actual = ', 5, 'Predictioned = ', 5.000345825204604)
# ('Actual = ', 5, 'Predictioned = ', 4.583615315321246)
# ('Actual = ', 4, 'Predictioned = ', 3.203414738168479)
# ('Actual = ', 5, 'Predictioned = ', 4.372410653056201)
# ('Actual = ', 5, 'Predictioned = ', 4.726253165099242)
# ('Actual = ', 5, 'Predictioned = ', 4.000039513658168)
# ('Actual = ', 4, 'Predictioned = ', 3.6636847663403476)
# ('Actual = ', 4, 'Predictioned = ', 3.133107582907805)
# ('Actual = ', 5, 'Predictioned = ', 3.950707626168241)
# ('Actual = ', 5, 'Predictioned = ', 4.305299373152275)
# ('Actual = ', 5, 'Predictioned = ', 3.50843499428511)
# ('Actual = ', 5, 'Predictioned = ', 3.9516870878336285)
# ('Actual = ', 5, 'Predictioned = ', 4.655969221440395)
# ('Actual = ', 5, 'Predictioned = ', 4.2033177064358265)
# ('Actual = ', 4, 'Predictioned = ', 3.7834888386884145)
# ('Actual = ', 5, 'Predictioned = ', 5.561418899769237)
# ('Actual = ', 5, 'Predictioned = ', 5.305854721227418)
# ('Actual = ', 5, 'Predictioned = ', 3.255713907817195)
# ('Actual = ', 5, 'Predictioned = ', 4.05423083491503)
# ('Actual = ', 3, 'Predictioned = ', 4.2517795089422625)
# ('Actual = ', 4, 'Predictioned = ', 3.004533979844901)
# ('Actual = ', 5, 'Predictioned = ', 4.016720621845001)
# ('Actual = ', 4, 'Predictioned = ', 4.163219467361062)
# ('Actual = ', 1, 'Predictioned = ', 4.902535012833363)
# ('Actual = ', 5, 'Predictioned = ', 5.005822823522986)
# ('Actual = ', 3, 'Predictioned = ', 4.073800973832424)
# ('Actual = ', 4, 'Predictioned = ', 4.235277794828273)
# ('Actual = ', 5, 'Predictioned = ', 7.338853585698275)
# ('Actual = ', 5, 'Predictioned = ', 5.298742558345786)
# ('Actual = ', 5, 'Predictioned = ', 3.907344588819937)
# ('Actual = ', 5, 'Predictioned = ', 5.030076988641795)
# ('Actual = ', 5, 'Predictioned = ', 4.772618190677072)
# ('Actual = ', 5, 'Predictioned = ', 4.966002396442951)
# ('Actual = ', 5, 'Predictioned = ', 3.043178453821886)
# ('Actual = ', 4, 'Predictioned = ', 3.2102587487355017)
# ('Actual = ', 1, 'Predictioned = ', 4.263393413769542)
# ('Actual = ', 4, 'Predictioned = ', 4.32006294741721)
# ('Actual = ', 5, 'Predictioned = ', 3.997631327449513)
# ('Actual = ', 4, 'Predictioned = ', 4.187150390903658)
# ('Actual = ', 5, 'Predictioned = ', 4.528360173893421)
# ('Actual = ', 4, 'Predictioned = ', 6.056709833446705)
# ('Actual = ', 5, 'Predictioned = ', 5.035839919016443)
# ('Actual = ', 5, 'Predictioned = ', 4.539803752307899)
# ('Actual = ', 4, 'Predictioned = ', 2.612503750721528)
# ('Actual = ', 3, 'Predictioned = ', 4.224888824281246)
# ('Actual = ', 5, 'Predictioned = ', 3.6830949149466505)
# ('Actual = ', 5, 'Predictioned = ', 4.116741636371142)
# ('Actual = ', 4, 'Predictioned = ', 3.4992466335523806)
# ('Actual = ', 5, 'Predictioned = ', 7.545280372001173)
# ('Actual = ', 5, 'Predictioned = ', 5.648420953833192)
# ('Actual = ', 5, 'Predictioned = ', 3.002392729399213)
# ('Actual = ', 5, 'Predictioned = ', 4.44779734538588)
# ('Actual = ', 5, 'Predictioned = ', 4.015525411541132)
# ('Actual = ', 1, 'Predictioned = ', 3.7961081042150355)
# ('Actual = ', 4, 'Predictioned = ', 3.280951239115884)
# ('Actual = ', 4, 'Predictioned = ', 4.54340586666185)
# ('Actual = ', 5, 'Predictioned = ', 4.5797122599803375)
# ('Actual = ', 1, 'Predictioned = ', 3.428499841964228)
# ('Actual = ', 5, 'Predictioned = ', 4.330138348342981)
# ('Actual = ', 5, 'Predictioned = ', 4.147587267935431)
# ('Actual = ', 2, 'Predictioned = ', 4.522133087526365)
# ('Actual = ', 5, 'Predictioned = ', 6.171227710109672)
# ('Actual = ', 5, 'Predictioned = ', 3.5747347534918914)
# ('Actual = ', 5, 'Predictioned = ', 4.946264722347891)
# ('Actual = ', 5, 'Predictioned = ', 4.869548105897877)
# ('Actual = ', 5, 'Predictioned = ', 5.710374138424462)
# ('Actual = ', 1, 'Predictioned = ', 4.192695744148089)
# ('Actual = ', 1, 'Predictioned = ', 2.1002876859627313)
# ('Actual = ', 4, 'Predictioned = ', 6.331508535025083)
# ('Actual = ', 4, 'Predictioned = ', 4.139191936977027)
# ('Actual = ', 5, 'Predictioned = ', 4.572246938236705)
# ('Actual = ', 5, 'Predictioned = ', 5.029008862726668)
# ('Actual = ', 1, 'Predictioned = ', 4.264034412404452)
# ('Actual = ', 4, 'Predictioned = ', 3.6215742828836532)
# ('Actual = ', 5, 'Predictioned = ', 4.879028474759119)
# ('Actual = ', 5, 'Predictioned = ', 5.064751559989363)
# ('Actual = ', 5, 'Predictioned = ', 4.704230406686655)
# ('Actual = ', 5, 'Predictioned = ', 5.476814560093662)
# ('Actual = ', 4, 'Predictioned = ', 3.2537922569105646)
# ('Actual = ', 4, 'Predictioned = ', 4.465202571452915)
# ('Actual = ', 5, 'Predictioned = ', 4.354523149577309)
# ('Actual = ', 4, 'Predictioned = ', 4.483797041977438)
# ('Actual = ', 2, 'Predictioned = ', 4.264426050034758)
# ('Actual = ', 5, 'Predictioned = ', 3.4557879866513503)
# ('Actual = ', 5, 'Predictioned = ', 5.530521987262766)
# ('Actual = ', 5, 'Predictioned = ', 3.009604943540756)
# ('Actual = ', 5, 'Predictioned = ', 5.673675752126051)
# ('Actual = ', 1, 'Predictioned = ', 2.680263958767289)
# ('Actual = ', 5, 'Predictioned = ', 3.6396501988803984)
# ('Actual = ', 5, 'Predictioned = ', 3.8682332458216555)
# ('Actual = ', 5, 'Predictioned = ', 4.330296285949297)
# ('Actual = ', 5, 'Predictioned = ', 4.273453863570562)
# ('Actual = ', 5, 'Predictioned = ', 3.2130368844508452)
# ('Actual = ', 4, 'Predictioned = ', 5.269949487055514)
# ('Actual = ', 5, 'Predictioned = ', 5.1587420162028605)
# ('Actual = ', 4, 'Predictioned = ', 4.347764029651915)
# ('Actual = ', 5, 'Predictioned = ', 3.202777399752811)
# ('Actual = ', 5, 'Predictioned = ', 5.003215395658922)
# ('Actual = ', 3, 'Predictioned = ', 3.0110401367357422)
# ('Actual = ', 4, 'Predictioned = ', 4.15578601490929)
# ('Actual = ', 3, 'Predictioned = ', 3.3328421408521165)
# ('Actual = ', 5, 'Predictioned = ', 3.2825906141881167)
# ('Actual = ', 4, 'Predictioned = ', 4.711699674840224)
# ('Actual = ', 3, 'Predictioned = ', 3.4788291254673243)
# ('Actual = ', 5, 'Predictioned = ', 4.214144225170589)
# ('Actual = ', 5, 'Predictioned = ', 5.02358364511284)
# ('Actual = ', 5, 'Predictioned = ', 4.438203728267962)
# ('Actual = ', 5, 'Predictioned = ', 4.640145846827584)
# ('Actual = ', 5, 'Predictioned = ', 4.596462606286952)
# ('Actual = ', 1, 'Predictioned = ', 3.8612257140083557)
# ('Actual = ', 4, 'Predictioned = ', 4.78983248373457)
# ('Actual = ', 5, 'Predictioned = ', 5.220287669008843)
# ('Actual = ', 5, 'Predictioned = ', 3.571474948230409)
# ('Actual = ', 1, 'Predictioned = ', 3.773291560137338)
# ('Actual = ', 5, 'Predictioned = ', 4.995837240290758)
# ('Actual = ', 4, 'Predictioned = ', 3.7147847903192295)
# ('Actual = ', 1, 'Predictioned = ', 1.3442545618960462)
# ('Actual = ', 5, 'Predictioned = ', 4.577417226394699)
# ('Actual = ', 1, 'Predictioned = ', 2.6079581299839254)
# ('Actual = ', 5, 'Predictioned = ', 4.999558375698507)
# ('Actual = ', 5, 'Predictioned = ', 6.049879167249773)
# ('Actual = ', 5, 'Predictioned = ', 3.768417686368945)
# ('Actual = ', 4, 'Predictioned = ', 3.6031873729252673)
# ('Actual = ', 5, 'Predictioned = ', 3.736795238986293)
# ('Actual = ', 4, 'Predictioned = ', 4.041286190388603)
# ('Actual = ', 5, 'Predictioned = ', 5.068002125904381)
# ('Actual = ', 5, 'Predictioned = ', 4.548268703293919)
# ('Actual = ', 5, 'Predictioned = ', 3.441698484071967)
# ('Actual = ', 5, 'Predictioned = ', 5.037785515046886)
# ('Actual = ', 2, 'Predictioned = ', 3.667755099269375)
# ('Actual = ', 5, 'Predictioned = ', 4.421683608812267)
# ('Actual = ', 5, 'Predictioned = ', 4.548297071467435)
# ('Actual = ', 4, 'Predictioned = ', 3.693313816287124)
# ('Actual = ', 5, 'Predictioned = ', 3.741576708416625)
# ('Actual = ', 5, 'Predictioned = ', 4.640885468925918)
# ('Actual = ', 1, 'Predictioned = ', 3.3881681186400034)
# ('Actual = ', 4, 'Predictioned = ', 4.024916897675329)
# ('Actual = ', 3, 'Predictioned = ', 3.3656885312564233)
# ('Actual = ', 3, 'Predictioned = ', 3.0000804814475606)
# ('Actual = ', 5, 'Predictioned = ', 3.254115334544056)
# ('Actual = ', 1, 'Predictioned = ', 2.9460720851459175)
# ('Actual = ', 4, 'Predictioned = ', 3.0086616729915794)
# ('Actual = ', 5, 'Predictioned = ', 4.822520445698073)
# ('Actual = ', 4, 'Predictioned = ', 4.48755473600882)
# ('Actual = ', 1, 'Predictioned = ', 1.9128789667125867)
# ('Actual = ', 5, 'Predictioned = ', 2.7999562466222874)
# ('Actual = ', 5, 'Predictioned = ', 4.189317930623885)
# ('Actual = ', 5, 'Predictioned = ', 3.2558292051660196)
# ('Actual = ', 4, 'Predictioned = ', 3.8261147625973337)
# ('Actual = ', 3, 'Predictioned = ', 3.7481845006619245)
# ('Actual = ', 4, 'Predictioned = ', 2.3902119089986087)
# ('Actual = ', 4, 'Predictioned = ', 4.426793058768899)
# ('Actual = ', 5, 'Predictioned = ', 4.608589665644413)
# ('Actual = ', 5, 'Predictioned = ', 6.139435876308111)
# ('Actual = ', 5, 'Predictioned = ', 4.528557473131753)
# ('Actual = ', 5, 'Predictioned = ', 1.7249754532518835)
# ('Actual = ', 1, 'Predictioned = ', 3.3423301689492577)
# ('Actual = ', 5, 'Predictioned = ', 3.3371364548540536)
# ('Actual = ', 2, 'Predictioned = ', 3.814144291408557)
# ('Actual = ', 4, 'Predictioned = ', 3.4492950620062786)
# ('Actual = ', 1, 'Predictioned = ', 3.5001923661263015)
# ('Actual = ', 5, 'Predictioned = ', 3.9738756282311436)
# ('Actual = ', 5, 'Predictioned = ', 3.076543063046021)
# ('Actual = ', 4, 'Predictioned = ', 4.167477478443234)
# ('Actual = ', 5, 'Predictioned = ', 4.841466066624258)
# ('Actual = ', 5, 'Predictioned = ', 3.6140547125494953)
# ('Actual = ', 5, 'Predictioned = ', 3.8270917724468596)
# ('Actual = ', 5, 'Predictioned = ', 3.359472879147856)
# ('Actual = ', 5, 'Predictioned = ', 4.951591084214867)
# ('Actual = ', 3, 'Predictioned = ', 3.249867827181475)
# ('Actual = ', 5, 'Predictioned = ', 4.709902538104883)
# ('Actual = ', 5, 'Predictioned = ', 5.142440276450764)
# ('Actual = ', 3, 'Predictioned = ', 4.497242392071358)
# ('Actual = ', 3, 'Predictioned = ', 3.9485862685476194)
# ('Actual = ', 5, 'Predictioned = ', 3.3894635111394793)
# ('Actual = ', 5, 'Predictioned = ', 4.526878903252559)
# ('Actual = ', 5, 'Predictioned = ', 3.958865318299284)
# ('Actual = ', 5, 'Predictioned = ', 5.011969062327923)
# ('Actual = ', 2, 'Predictioned = ', 2.9715173384491003)
# ('Actual = ', 1, 'Predictioned = ', 3.2004999770350153)
# ('Actual = ', 1, 'Predictioned = ', 2.6233229275724352)
# ('Actual = ', 5, 'Predictioned = ', 5.017932989974431)
# ('Actual = ', 3, 'Predictioned = ', 3.840479825262636)
# ('Actual = ', 4, 'Predictioned = ', 3.56880424212587)
# ('Actual = ', 5, 'Predictioned = ', 4.79791144195182)
# ('Actual = ', 5, 'Predictioned = ', 5.744643366134785)
# ('Actual = ', 5, 'Predictioned = ', 4.505231691567643)
# ('Actual = ', 1, 'Predictioned = ', 4.349807259907463)
# ('Actual = ', 4, 'Predictioned = ', 4.228327980978989)
# ('Actual = ', 4, 'Predictioned = ', 4.530713189210876)
# ('Actual = ', 5, 'Predictioned = ', 4.3559735729015205)
# ('Actual = ', 3, 'Predictioned = ', 3.9623926728564953)
# ('Actual = ', 5, 'Predictioned = ', 4.240807313191441)
# ('Actual = ', 5, 'Predictioned = ', 4.430046223788111)
# ('Actual = ', 3, 'Predictioned = ', 4.621087700535508)
# ('Actual = ', 1, 'Predictioned = ', 2.1467810709774637)
# ('Actual = ', 5, 'Predictioned = ', 4.262313466566806)
# ('Actual = ', 5, 'Predictioned = ', 4.987717623517629)
# ('Actual = ', 4, 'Predictioned = ', 4.7450228320826975)
# ('Actual = ', 5, 'Predictioned = ', 4.363314598674337)
# ('Actual = ', 4, 'Predictioned = ', 4.132399345810532)
# ('Actual = ', 1, 'Predictioned = ', 3.9680726943453792)
# ('Actual = ', 1, 'Predictioned = ', 4.693631087272766)
# ('Actual = ', 5, 'Predictioned = ', 4.793399648292735)
# ('Actual = ', 4, 'Predictioned = ', 3.425696474138412)
# ('Actual = ', 5, 'Predictioned = ', 3.0087914739132424)
# ('Actual = ', 5, 'Predictioned = ', 3.8017321543965257)
# ('Actual = ', 4, 'Predictioned = ', 5.157253759874128)
# ('Actual = ', 3, 'Predictioned = ', 3.2371314573077212)
# ('Actual = ', 5, 'Predictioned = ', 3.931857826342966)
# ('Actual = ', 4, 'Predictioned = ', 3.2148417070730897)
# ('Actual = ', 5, 'Predictioned = ', 4.455266742863776)
# ('Actual = ', 5, 'Predictioned = ', 5.002673287939445)
# ('Actual = ', 5, 'Predictioned = ', 4.1723441820833305)
# ('Actual = ', 5, 'Predictioned = ', 5.452635880748016)
# ('Actual = ', 5, 'Predictioned = ', 2.7128351303211162)
# ('Actual = ', 5, 'Predictioned = ', 5.065192015146609)
# ('Actual = ', 5, 'Predictioned = ', 5.249377473017572)
# ('Actual = ', 3, 'Predictioned = ', 3.7743359014371687)
# ('Actual = ', 4, 'Predictioned = ', 3.3409007512981344)
# ('Actual = ', 5, 'Predictioned = ', 4.672105362431273)
# ('Actual = ', 5, 'Predictioned = ', 4.036306333096808)
# ('Actual = ', 4, 'Predictioned = ', 5.000139506893055)
# ('Actual = ', 4, 'Predictioned = ', 5.033973678815619)
# ('Actual = ', 5, 'Predictioned = ', 6.0632209336966225)
# ('Actual = ', 3, 'Predictioned = ', 3.465422448054973)
# ('Actual = ', 4, 'Predictioned = ', 3.6345762538781634)
# ('Actual = ', 5, 'Predictioned = ', 4.010816062670485)
# ('Actual = ', 3, 'Predictioned = ', 4.744247837882812)
# ('Actual = ', 1, 'Predictioned = ', 5.18185468604058)
# ('Actual = ', 4, 'Predictioned = ', 4.131440507839702)
# ('Actual = ', 5, 'Predictioned = ', 5.599693239173346)
# ('Actual = ', 4, 'Predictioned = ', 4.264662138267203)
# ('Actual = ', 5, 'Predictioned = ', 2.5346342502200354)
# ('Actual = ', 1, 'Predictioned = ', 2.3244605161285947)
# ('Actual = ', 5, 'Predictioned = ', 4.633924972426654)
# ('Actual = ', 4, 'Predictioned = ', 3.3904690651079052)
# ('Actual = ', 5, 'Predictioned = ', 5.1504511718984745)
# ('Actual = ', 5, 'Predictioned = ', 3.5039074199813336)
# ('Actual = ', 5, 'Predictioned = ', 4.722001719603746)
# ('Actual = ', 5, 'Predictioned = ', 6.85526211760622)
# ('Actual = ', 1, 'Predictioned = ', 4.32950150697193)
# ('Actual = ', 4, 'Predictioned = ', 3.1748903390115584)
# ('Actual = ', 1, 'Predictioned = ', 2.9195037515558773)
# ('Actual = ', 5, 'Predictioned = ', 3.027851987760109)
# ('Actual = ', 1, 'Predictioned = ', 4.8267094038292475)
# ('Actual = ', 1, 'Predictioned = ', 4.251392488442511)
# ('Actual = ', 4, 'Predictioned = ', 4.051374402883458)
# ('Actual = ', 3, 'Predictioned = ', 4.286646662200577)
# ('Actual = ', 4, 'Predictioned = ', 4.254822774321574)
# ('Actual = ', 4, 'Predictioned = ', 4.665695162148129)
# ('Actual = ', 5, 'Predictioned = ', 5.695227095645587)
# ('Actual = ', 5, 'Predictioned = ', 3.7989370181332625)
# ('Actual = ', 5, 'Predictioned = ', 6.014169702430004)
# ('Actual = ', 1, 'Predictioned = ', 3.2187166907143956)
# ('Actual = ', 5, 'Predictioned = ', 4.439900716388803)
# ('Actual = ', 4, 'Predictioned = ', 4.224328257653472)

# %%
MAE

# %%
RMSE
