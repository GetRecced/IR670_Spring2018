# %%
# Imports 
import pandas as pd
import numpy as np
import time
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.neighbors import NearestNeighbors
from scipy.sparse import csr_matrix
import operator

# %%
# load the data, keep only selected columns
# Read the file using super fast Pandas.read_csv
def load_required_data(path, required_columns):
    dataframe = pd.read_json(path, lines=True)
    dataframe = dataframe[required_columns]
    return dataframe, dataframe.values

# %%
dataframe, values = load_required_data('train_15000.json', ["asin", "reviewerID", "overall"])

# %%
dataframe[:10]
# Out:
#          asin             reviewerID  overall
# 0  B00ANT8OF6  A00100742Q4O8VH0YMUBZ        4
# 1  B00AMR1HZ8  A00100742Q4O8VH0YMUBZ        4
# 2  B004WGGQPQ  A00100742Q4O8VH0YMUBZ        5
# 3  B006C1ZSO4  A00100742Q4O8VH0YMUBZ        5
# 4  B008LY1B32  A00100742Q4O8VH0YMUBZ        4
# 5  B007KPT2N4  A00100742Q4O8VH0YMUBZ        1
# 6  B0080JJLBW  A00100742Q4O8VH0YMUBZ        5
# 7  B009P8EMCK  A00100742Q4O8VH0YMUBZ        5
# 8  B00I8Q77Y0  A001619027H9L9EG4UVRB        5
# 9  B00H0BGCJK  A001619027H9L9EG4UVRB        5

# %%
dataframe.shape
# Out:
# (15000, 3)

# %%
# Create user-item matrix given a matrix and mapping from original matrix columns to new matrix rows/columns
def create_user_item_matrix(data, rowMapping, columnMapping):
    # Create table of users to items by taking row and column pivots
    # Rows of user-item table are users
    rows, row_pos = np.unique(data[:, rowMapping], return_inverse=True)
    # Columns of user-item table are movies
    cols, col_pos = np.unique(data[:, columnMapping], return_inverse=True)

    pivot_table = np.zeros((len(rows), len(cols)), dtype=data.dtype)
    pivot_table[row_pos, col_pos] = data[:, 2]
    return pivot_table, rows, cols

# %%
ratings_matrix, rows, cols = create_user_item_matrix(values, rowMapping=1, columnMapping=0)
print (ratings_matrix.shape)
# Out:
# (3139, 1842)

# %%
pd.DataFrame(ratings_matrix[:10], index = rows[:10], columns= cols)
# Out:
#                       B004ALVL6W B004ANMWPY B004DLNC4I B004DLPXAO B004DM1OAQ  \
# A00100742Q4O8VH0YMUBZ          0          0          0          0          0
# A001619027H9L9EG4UVRB          0          0          0          0          0
# A002359833QJM7OQHCXWY          0          0          0          0          0
# A0037670NPLI11RBWYFA           0          0          0          0          0
# A003841815JTX0JFLR8B1          0          0          0          0          0
# A0038872349TB5N0JHQQW          0          0          0          0          0
# A00455683H6M1GQZMPQPV          0          0          0          0          0
# A0047670XAAJD587LXS7           0          0          0          0          0
# A00501041JRAPWYLPQ4TE          0          0          0          0          0
# A00507662MEMHI1YMGQ15          0          0          0          0          0
#
#                       B004DM1ZQY B004DPBGCO B004DPC5Y2 B004DPCSKI B004DPIEF6  \
# A00100742Q4O8VH0YMUBZ          0          0          0          0          0
# A001619027H9L9EG4UVRB          0          0          0          0          0
# A002359833QJM7OQHCXWY          0          0          0          0          0
# A0037670NPLI11RBWYFA           0          0          0          0          0
# A003841815JTX0JFLR8B1          0          0          0          0          0
# A0038872349TB5N0JHQQW          0          0          0          0          0
# A00455683H6M1GQZMPQPV          0          0          0          0          0
# A0047670XAAJD587LXS7           0          0          0          0          0
# A00501041JRAPWYLPQ4TE          0          0          0          0          0
# A00507662MEMHI1YMGQ15          0          0          0          0          0
#
#                          ...     B00K7WGUKA B00KFNXUY0 B00KGCNRAM B00KI5Q8X0  \
# A00100742Q4O8VH0YMUBZ    ...              0          0          0          0
# A001619027H9L9EG4UVRB    ...              0          0          0          0
# A002359833QJM7OQHCXWY    ...              0          0          0          0
# A0037670NPLI11RBWYFA     ...              0          0          0          0
# A003841815JTX0JFLR8B1    ...              0          0          0          0
# A0038872349TB5N0JHQQW    ...              0          0          0          0
# A00455683H6M1GQZMPQPV    ...              0          0          0          0
# A0047670XAAJD587LXS7     ...              0          0          0          0
# A00501041JRAPWYLPQ4TE    ...              0          0          0          0
# A00507662MEMHI1YMGQ15    ...              0          0          0          0
#
#                       B00KMX5V8G B00KOEHQCW B00KQHVWWC B00KSOQ66K B00KWVZ750  \
# A00100742Q4O8VH0YMUBZ          0          0          0          0          0
# A001619027H9L9EG4UVRB          0          0          0          0          0
# A002359833QJM7OQHCXWY          0          0          0          0          0
# A0037670NPLI11RBWYFA           0          0          0          0          0
# A003841815JTX0JFLR8B1          0          0          0          0          0
# A0038872349TB5N0JHQQW          0          0          0          0          0
# A00455683H6M1GQZMPQPV          0          0          0          0          5
# A0047670XAAJD587LXS7           0          0          0          0          0
# A00501041JRAPWYLPQ4TE          0          0          0          0          0
# A00507662MEMHI1YMGQ15          0          0          0          0          0
#
#                       B00L3MNCNQ
# A00100742Q4O8VH0YMUBZ          0
# A001619027H9L9EG4UVRB          0
# A002359833QJM7OQHCXWY          0
# A0037670NPLI11RBWYFA           0
# A003841815JTX0JFLR8B1          0
# A0038872349TB5N0JHQQW          0
# A00455683H6M1GQZMPQPV          0
# A0047670XAAJD587LXS7           0
# A00501041JRAPWYLPQ4TE          0
# A00507662MEMHI1YMGQ15          0
#
# [10 rows x 1842 columns]

# %%
def get_index_map(arr):
    index_map = {}
    for el in arr:
        index_map[el] = len(index_map)
    return index_map

# %%
# Get unique movies and users
unique_items = np.unique(values[:,0])
unique_users = np.unique(values[:,1])

# %%
unique_items.shape
# Out:
# (1842,)

# %%
unique_users.shape
# Out:
# (3139,)

# %%
# Create mapping from unique list to 
item_idx_map = get_index_map(unique_items)
user_idx_map = get_index_map(unique_users)

# %%
mean_users = np.true_divide(ratings_matrix.sum(1), (ratings_matrix!=0).sum(1))
mean_items = np.true_divide(ratings_matrix.sum(0),(ratings_matrix!=0).sum(0))
mean_overall = np.true_divide(ratings_matrix.sum(),(ratings_matrix!=0).sum())

# %%
def get_users_who_rated_item(item_id):
    return np.where(ratings_matrix[:,item_idx_map[item_id]] > 0)[0]

def get_users_who_rated_item_by_index(item_idx):
    return np.where(ratings_matrix[:,item_idx] > 0)

def predict(user_id, item_id):
    item_idx = item_idx_map[item_id]
    user_idx = user_idx_map[user_id]
    bias_user = mean_overall - mean_users[user_idx]
    bias_item = mean_overall - mean_items[item_idx]
    return mean + bias_user + bias_item

# %%
test_dataframe, test_values = load_required_data('test_5000.json', ["asin", "reviewerID", "overall"])

# %%
test_dataframe['reviewerID'].unique().shape
# Out:
# (2507,)

# %%
# Returns DF containing predictions, MAE, RMSE
def get_predictions(dataframe):
    df = dataframe.copy()
    print ("Predicting ratings..")
    start_time = time.time()
    df['Prediction'] = df.apply(lambda row: predict_row(row) , axis=1)
    MAE = round(mean_absolute_error(df['overall'], df['Prediction']), 2)
    RMSE = round(np.sqrt(mean_squared_error(df['overall'], df['Prediction'])), 2)
    print "Done Predicting in",  round((time.time() - start_time), 2), "seconds"
    return df, MAE, RMSE

i = 0
def predict_row(row):
    global i
    i+= 1
    prediction = predict(row['reviewerID'], row['asin'])
    print ("#", i, "Actual = ", row['overall'], "Predictioned = ", prediction)
    return prediction

# %%
df, MAE, RMSE = get_predictions(test_dataframe)
# Out:
# Predicting ratings..
# ('#', 1, 'Actual = ', 5, 'Predictioned = ', 2.9101535501242664)
# ('#', 2, 'Actual = ', 2, 'Predictioned = ', 4.687931327902044)
# ('#', 3, 'Actual = ', 5, 'Predictioned = ', 3.701820216790933)
# ('#', 4, 'Actual = ', 5, 'Predictioned = ', 2.2573757723464887)
# ('#', 5, 'Actual = ', 5, 'Predictioned = ', 3.385153550124266)
# ('#', 6, 'Actual = ', 3, 'Predictioned = ', 3.0792711971830897)
# ('#', 7, 'Actual = ', 5, 'Predictioned = ', 4.035153550124266)
# ('#', 8, 'Actual = ', 4, 'Predictioned = ', 4.903574602755845)
# ('#', 9, 'Actual = ', 5, 'Predictioned = ', 2.463724978695695)
# ('#', 10, 'Actual = ', 5, 'Predictioned = ', 2.3719956553874244)
# ('#', 11, 'Actual = ', 1, 'Predictioned = ', 5.335153550124266)
# ('#', 12, 'Actual = ', 4, 'Predictioned = ', 3.701820216790933)
# ('#', 13, 'Actual = ', 5, 'Predictioned = ', 3.0684868834575996)
# ('#', 14, 'Actual = ', 5, 'Predictioned = ', 3.1351535501242664)
# ('#', 15, 'Actual = ', 4, 'Predictioned = ', 3.664783179753896)
# ('#', 16, 'Actual = ', 1, 'Predictioned = ', 3.820867835838552)
# ('#', 17, 'Actual = ', 5, 'Predictioned = ', 7.785153550124266)
# ('#', 18, 'Actual = ', 4, 'Predictioned = ', 7.164185808188782)
# ('#', 19, 'Actual = ', 3, 'Predictioned = ', 5.0351535501242655)
# ('#', 20, 'Actual = ', 4, 'Predictioned = ', 4.178010692981409)
# ('#', 21, 'Actual = ', 5, 'Predictioned = ', 3.0351535501242664)
# ('#', 22, 'Actual = ', 5, 'Predictioned = ', 2.8043843193550355)
# ('#', 23, 'Actual = ', 4, 'Predictioned = ', 3.0351535501242664)
# ('#', 24, 'Actual = ', 4, 'Predictioned = ', 3.7715876586513986)
# ('#', 25, 'Actual = ', 5, 'Predictioned = ', 4.008837760650582)
# ('#', 26, 'Actual = ', 5, 'Predictioned = ', 4.201820216790933)
# ('#', 27, 'Actual = ', 5, 'Predictioned = ', 2.3684868834575994)
# ('#', 28, 'Actual = ', 4, 'Predictioned = ', 3.404201169171885)
# ('#', 29, 'Actual = ', 5, 'Predictioned = ', 4.285153550124266)
# ('#', 30, 'Actual = ', 4, 'Predictioned = ', 3.2018202167909333)
# ('#', 31, 'Actual = ', 1, 'Predictioned = ', 6.035153550124266)
# ('#', 32, 'Actual = ', 1, 'Predictioned = ', 6.160153550124266)
# ('#', 33, 'Actual = ', 5, 'Predictioned = ', 3.5351535501242664)
# ('#', 34, 'Actual = ', 5, 'Predictioned = ', 3.0351535501242664)
# ('#', 35, 'Actual = ', 4, 'Predictioned = ', 3.701820216790933)
# ('#', 36, 'Actual = ', 5, 'Predictioned = ', 3.102721117691834)
# ('#', 37, 'Actual = ', 5, 'Predictioned = ', 2.0351535501242664)
# ('#', 38, 'Actual = ', 5, 'Predictioned = ', 3.701820216790933)
# ('#', 39, 'Actual = ', 4, 'Predictioned = ', 2.646264661235377)
# ('#', 40, 'Actual = ', 5, 'Predictioned = ', 3.2932180662532984)
# ('#', 41, 'Actual = ', 5, 'Predictioned = ', 4.082772597743315)
# ('#', 42, 'Actual = ', 5, 'Predictioned = ', 3.149439264409981)
# ('#', 43, 'Actual = ', 5, 'Predictioned = ', 4.035153550124266)
# ('#', 44, 'Actual = ', 5, 'Predictioned = ', 3.835153550124266)
# ('#', 45, 'Actual = ', 1, 'Predictioned = ', 2.0351535501242664)
# ('#', 46, 'Actual = ', 1, 'Predictioned = ', 5.368486883457599)
# ('#', 47, 'Actual = ', 4, 'Predictioned = ', 4.785153550124266)
# ('#', 48, 'Actual = ', 5, 'Predictioned = ', 4.785153550124266)
# ('#', 49, 'Actual = ', 5, 'Predictioned = ', 3.5351535501242664)
# ('#', 50, 'Actual = ', 5, 'Predictioned = ', 2.0351535501242664)
# ('#', 51, 'Actual = ', 3, 'Predictioned = ', 4.035153550124266)
# ('#', 52, 'Actual = ', 4, 'Predictioned = ', 3.5351535501242664)
# ('#', 53, 'Actual = ', 5, 'Predictioned = ', 2.7018202167909333)
# ('#', 54, 'Actual = ', 5, 'Predictioned = ', 2.9018202167909335)
# ('#', 55, 'Actual = ', 3, 'Predictioned = ', 3.0351535501242664)
# ('#', 56, 'Actual = ', 2, 'Predictioned = ', 3.350943023808477)
# ('#', 57, 'Actual = ', 1, 'Predictioned = ', 2.7684868834575997)
# ('#', 58, 'Actual = ', 3, 'Predictioned = ', 4.194573839979339)
# ('#', 59, 'Actual = ', 5, 'Predictioned = ', 2.7329447147829002)
# ('#', 60, 'Actual = ', 4, 'Predictioned = ', 2.6184868834575994)
# ('#', 61, 'Actual = ', 3, 'Predictioned = ', 3.9518202167909333)
# ('#', 62, 'Actual = ', 5, 'Predictioned = ', 3.1018202167909337)
# ('#', 63, 'Actual = ', 5, 'Predictioned = ', 2.5494392644099806)
# ('#', 64, 'Actual = ', 3, 'Predictioned = ', 3.3684868834576)
# ('#', 65, 'Actual = ', 5, 'Predictioned = ', 4.410153550124266)
# ('#', 66, 'Actual = ', 5, 'Predictioned = ', 7.035153550124266)
# ('#', 67, 'Actual = ', 5, 'Predictioned = ', 3.2851535501242664)
# ('#', 68, 'Actual = ', 5, 'Predictioned = ', 2.146264661235377)
# ('#', 69, 'Actual = ', 1, 'Predictioned = ', 2.7018202167909333)
# ('#', 70, 'Actual = ', 1, 'Predictioned = ', 3.2851535501242664)
# ('#', 71, 'Actual = ', 5, 'Predictioned = ', 4.679597994568711)
# ('#', 72, 'Actual = ', 5, 'Predictioned = ', 4.368486883457599)
# ('#', 73, 'Actual = ', 3, 'Predictioned = ', 4.3043843193550355)
# ('#', 74, 'Actual = ', 4, 'Predictioned = ', 4.868486883457599)
# ('#', 75, 'Actual = ', 5, 'Predictioned = ', 5.549439264409981)
# ('#', 76, 'Actual = ', 4, 'Predictioned = ', 7.035153550124266)
# ('#', 77, 'Actual = ', 3, 'Predictioned = ', 4.285153550124266)
# ('#', 78, 'Actual = ', 4, 'Predictioned = ', 3.7351535501242665)
# ('#', 79, 'Actual = ', 4, 'Predictioned = ', 5.439915454886172)
# ('#', 80, 'Actual = ', 4, 'Predictioned = ', 4.311109834277272)
# ('#', 81, 'Actual = ', 5, 'Predictioned = ', 3.648486883457599)
# ('#', 82, 'Actual = ', 3, 'Predictioned = ', 3.3684868834575994)
# ('#', 83, 'Actual = ', 1, 'Predictioned = ', 4.635153550124266)
# ('#', 84, 'Actual = ', 1, 'Predictioned = ', 4.635153550124266)
# ('#', 85, 'Actual = ', 4, 'Predictioned = ', 4.220867835838552)
# ('#', 86, 'Actual = ', 5, 'Predictioned = ', 3.9875345025052185)
# ('#', 87, 'Actual = ', 5, 'Predictioned = ', 3.6851535501242663)
# ('#', 88, 'Actual = ', 5, 'Predictioned = ', 4.035153550124266)
# ('#', 89, 'Actual = ', 5, 'Predictioned = ', 4.035153550124266)
# ('#', 90, 'Actual = ', 3, 'Predictioned = ', 4.310153550124266)
# ('#', 91, 'Actual = ', 2, 'Predictioned = ', 3.6157987114145893)
# ('#', 92, 'Actual = ', 5, 'Predictioned = ', 4.410153550124266)
# ('#', 93, 'Actual = ', 5, 'Predictioned = ', 2.2851535501242664)
# ('#', 94, 'Actual = ', 5, 'Predictioned = ', 2.635153550124266)
# ('#', 95, 'Actual = ', 2, 'Predictioned = ', 6.335153550124266)
# ('#', 96, 'Actual = ', 3, 'Predictioned = ', 6.410153550124266)
# ('#', 97, 'Actual = ', 5, 'Predictioned = ', 5.961079476050192)
# ('#', 98, 'Actual = ', 1, 'Predictioned = ', 5.805645353402955)
# ('#', 99, 'Actual = ', 5, 'Predictioned = ', 4.435153550124266)
# ('#', 100, 'Actual = ', 2, 'Predictioned = ', 3.6184868834575994)
# ('#', 101, 'Actual = ', 1, 'Predictioned = ', 3.9961925111632275)
# ('#', 102, 'Actual = ', 5, 'Predictioned = ', 4.853335368306085)
# ('#', 103, 'Actual = ', 3, 'Predictioned = ', 3.7018202167909333)
# ('#', 104, 'Actual = ', 5, 'Predictioned = ', 3.135153550124266)
# ('#', 105, 'Actual = ', 2, 'Predictioned = ', 4.090709105679822)
# ('#', 106, 'Actual = ', 3, 'Predictioned = ', 4.035153550124266)
# ('#', 107, 'Actual = ', 5, 'Predictioned = ', 3.3251535501242664)
# ('#', 108, 'Actual = ', 4, 'Predictioned = ', 4.285153550124266)
# ('#', 109, 'Actual = ', 4, 'Predictioned = ', 3.7851535501242664)
# ('#', 110, 'Actual = ', 2, 'Predictioned = ', 4.285153550124266)
# ('#', 111, 'Actual = ', 5, 'Predictioned = ', 4.035153550124266)
# ('#', 112, 'Actual = ', 5, 'Predictioned = ', 3.5351535501242664)
# ('#', 113, 'Actual = ', 5, 'Predictioned = ', 3.2851535501242664)
# ('#', 114, 'Actual = ', 5, 'Predictioned = ', 4.201820216790933)
# ('#', 115, 'Actual = ', 3, 'Predictioned = ', 3.8256297406004567)
# ('#', 116, 'Actual = ', 4, 'Predictioned = ', 3.692296407267123)
# ('#', 117, 'Actual = ', 5, 'Predictioned = ', 3.2137249786956947)
# ('#', 118, 'Actual = ', 5, 'Predictioned = ', 3.9351535501242663)
# ('#', 119, 'Actual = ', 5, 'Predictioned = ', 3.496692011662728)
# ('#', 120, 'Actual = ', 5, 'Predictioned = ', 3.635153550124266)
# ('#', 121, 'Actual = ', 4, 'Predictioned = ', 3.7065821215528376)
# ('#', 122, 'Actual = ', 4, 'Predictioned = ', 3.6065821215528375)
# ('#', 123, 'Actual = ', 4, 'Predictioned = ', 3.713724978695695)
# ('#', 124, 'Actual = ', 5, 'Predictioned = ', 3.885153550124266)
# ('#', 125, 'Actual = ', 4, 'Predictioned = ', 2.949439264409981)
# ('#', 126, 'Actual = ', 5, 'Predictioned = ', 3.149439264409981)
# ('#', 127, 'Actual = ', 4, 'Predictioned = ', 3.933704274761948)
# ('#', 128, 'Actual = ', 4, 'Predictioned = ', 3.6184868834576003)
# ('#', 129, 'Actual = ', 5, 'Predictioned = ', 2.555153550124267)
# ('#', 130, 'Actual = ', 4, 'Predictioned = ', 3.085153550124266)
# ('#', 131, 'Actual = ', 4, 'Predictioned = ', 5.035153550124266)
# ('#', 132, 'Actual = ', 5, 'Predictioned = ', 4.8395013762112224)
# ('#', 133, 'Actual = ', 4, 'Predictioned = ', 4.906948421919139)
# ('#', 134, 'Actual = ', 4, 'Predictioned = ', 4.3684868834576)
# ('#', 135, 'Actual = ', 5, 'Predictioned = ', 3.1973157122864286)
# ('#', 136, 'Actual = ', 5, 'Predictioned = ', 2.741035903065443)
# ('#', 137, 'Actual = ', 5, 'Predictioned = ', 3.1601535501242664)
# ('#', 138, 'Actual = ', 3, 'Predictioned = ', 2.9101535501242664)
# ('#', 139, 'Actual = ', 4, 'Predictioned = ', 3.4518202167909324)
# ('#', 140, 'Actual = ', 4, 'Predictioned = ', 3.961079476050192)
# ('#', 141, 'Actual = ', 5, 'Predictioned = ', 4.7434868834576)
# ('#', 142, 'Actual = ', 1, 'Predictioned = ', 5.968486883457601)
# ('#', 143, 'Actual = ', 5, 'Predictioned = ', 3.7793395966358942)
# ('#', 144, 'Actual = ', 4, 'Predictioned = ', 3.0806080955788118)
# ('#', 145, 'Actual = ', 5, 'Predictioned = ', 3.3684868834575994)
# ('#', 146, 'Actual = ', 4, 'Predictioned = ', 3.3684868834575994)
# ('#', 147, 'Actual = ', 5, 'Predictioned = ', 3.5232487882195045)
# ('#', 148, 'Actual = ', 5, 'Predictioned = ', 3.4065821215528374)
# ('#', 149, 'Actual = ', 5, 'Predictioned = ', 3.5351535501242664)
# ('#', 150, 'Actual = ', 5, 'Predictioned = ', 4.435153550124266)
# ('#', 151, 'Actual = ', 2, 'Predictioned = ', 4.599859432477207)
# ('#', 152, 'Actual = ', 1, 'Predictioned = ', 5.085153550124266)
# ('#', 153, 'Actual = ', 5, 'Predictioned = ', 4.435153550124266)
# ('#', 154, 'Actual = ', 5, 'Predictioned = ', 3.605645353402955)
# ('#', 155, 'Actual = ', 5, 'Predictioned = ', 3.3556663706370866)
# ('#', 156, 'Actual = ', 4, 'Predictioned = ', 3.5351535501242655)
# ('#', 157, 'Actual = ', 5, 'Predictioned = ', 3.849107038496359)
# ('#', 158, 'Actual = ', 1, 'Predictioned = ', 4.535153550124266)
# ('#', 159, 'Actual = ', 1, 'Predictioned = ', 4.493486883457599)
# ('#', 160, 'Actual = ', 5, 'Predictioned = ', 3.475943023808477)
# ('#', 161, 'Actual = ', 5, 'Predictioned = ', 4.346264661235377)
# ('#', 162, 'Actual = ', 3, 'Predictioned = ', 4.304920991984732)
# ('#', 163, 'Actual = ', 5, 'Predictioned = ', 2.835153550124266)
# ('#', 164, 'Actual = ', 5, 'Predictioned = ', 2.649611381449567)
# ('#', 165, 'Actual = ', 1, 'Predictioned = ', 4.535153550124266)
# ('#', 166, 'Actual = ', 1, 'Predictioned = ', 3.5351535501242664)
# ('#', 167, 'Actual = ', 5, 'Predictioned = ', 2.7053289887207574)
# ('#', 168, 'Actual = ', 5, 'Predictioned = ', 2.3684868834575994)
# ('#', 169, 'Actual = ', 5, 'Predictioned = ', 3.701820216790933)
# ('#', 170, 'Actual = ', 5, 'Predictioned = ', 2.8684868834575994)
# ('#', 171, 'Actual = ', 4, 'Predictioned = ', 3.316278048116234)
# ('#', 172, 'Actual = ', 4, 'Predictioned = ', 3.635153550124267)
# ('#', 173, 'Actual = ', 5, 'Predictioned = ', 3.635153550124266)
# ('#', 174, 'Actual = ', 5, 'Predictioned = ', 3.885153550124266)
# ('#', 175, 'Actual = ', 5, 'Predictioned = ', 3.7351535501242665)
# ('#', 176, 'Actual = ', 5, 'Predictioned = ', 3.710829225799942)
# ('#', 177, 'Actual = ', 5, 'Predictioned = ', 4.194467275614461)
# ('#', 178, 'Actual = ', 4, 'Predictioned = ', 5.076820216790932)
# ('#', 179, 'Actual = ', 5, 'Predictioned = ', 2.5351535501242664)
# ('#', 180, 'Actual = ', 5, 'Predictioned = ', 2.5351535501242664)
# ('#', 181, 'Actual = ', 1, 'Predictioned = ', 4.201820216790933)
# ('#', 182, 'Actual = ', 5, 'Predictioned = ', 3.6351535501242664)
# ('#', 183, 'Actual = ', 5, 'Predictioned = ', 3.5976535501242664)
# ('#', 184, 'Actual = ', 4, 'Predictioned = ', 4.035153550124266)
# ('#', 185, 'Actual = ', 4, 'Predictioned = ', 3.525349628555639)
# ('#', 186, 'Actual = ', 1, 'Predictioned = ', 3.80708337468567)
# ('#', 187, 'Actual = ', 5, 'Predictioned = ', 2.835153550124266)
# ('#', 188, 'Actual = ', 5, 'Predictioned = ', 3.3684868834576)
# ('#', 189, 'Actual = ', 5, 'Predictioned = ', 3.1184868834575994)
# ('#', 190, 'Actual = ', 5, 'Predictioned = ', 5.285153550124266)
# ('#', 191, 'Actual = ', 5, 'Predictioned = ', 2.3719956553874244)
# ('#', 192, 'Actual = ', 5, 'Predictioned = ', 2.835153550124266)
# ('#', 193, 'Actual = ', 5, 'Predictioned = ', 2.301820216790933)
# ('#', 194, 'Actual = ', 5, 'Predictioned = ', 2.2851535501242664)
# ('#', 195, 'Actual = ', 5, 'Predictioned = ', 4.0895013762112224)
# ('#', 196, 'Actual = ', 5, 'Predictioned = ', 4.285153550124266)
# ('#', 197, 'Actual = ', 4, 'Predictioned = ', 4.106582121552838)
# ('#', 198, 'Actual = ', 3, 'Predictioned = ', 4.368486883457599)
# ('#', 199, 'Actual = ', 5, 'Predictioned = ', 3.1184868834575994)
# ('#', 200, 'Actual = ', 5, 'Predictioned = ', 3.3684868834575994)
# ('#', 201, 'Actual = ', 5, 'Predictioned = ', 2.6780106929814096)
# ('#', 202, 'Actual = ', 5, 'Predictioned = ', 3.335153550124266)
# ('#', 203, 'Actual = ', 4, 'Predictioned = ', 3.0113440263147426)
# ('#', 204, 'Actual = ', 4, 'Predictioned = ', 3.320867835838552)
# ('#', 205, 'Actual = ', 5, 'Predictioned = ', 4.762426277396994)
# ('#', 206, 'Actual = ', 4, 'Predictioned = ', 4.835153550124266)
# ('#', 207, 'Actual = ', 5, 'Predictioned = ', 2.892296407267123)
# ('#', 208, 'Actual = ', 4, 'Predictioned = ', 3.5351535501242664)
# ('#', 209, 'Actual = ', 1, 'Predictioned = ', 6.535153550124266)
# ('#', 210, 'Actual = ', 5, 'Predictioned = ', 5.285153550124266)
# ('#', 211, 'Actual = ', 4, 'Predictioned = ', 3.7018202167909333)
# ('#', 212, 'Actual = ', 5, 'Predictioned = ', 4.551820216790933)
# ('#', 213, 'Actual = ', 5, 'Predictioned = ', 2.3719956553874244)
# ('#', 214, 'Actual = ', 5, 'Predictioned = ', 2.892296407267123)
# ('#', 215, 'Actual = ', 2, 'Predictioned = ', 2.5494392644099806)
# ('#', 216, 'Actual = ', 1, 'Predictioned = ', 3.39878991376063)
# ('#', 217, 'Actual = ', 4, 'Predictioned = ', 4.035153550124266)
# ('#', 218, 'Actual = ', 4, 'Predictioned = ', 4.285153550124266)
# ('#', 219, 'Actual = ', 5, 'Predictioned = ', 2.135153550124266)
# ('#', 220, 'Actual = ', 1, 'Predictioned = ', 2.7018202167909333)
# ('#', 221, 'Actual = ', 5, 'Predictioned = ', 5.085153550124266)
# ('#', 222, 'Actual = ', 5, 'Predictioned = ', 5.150943023808477)
# ('#', 223, 'Actual = ', 5, 'Predictioned = ', 3.250538165508881)
# ('#', 224, 'Actual = ', 5, 'Predictioned = ', 2.8380381655088813)
# ('#', 225, 'Actual = ', 5, 'Predictioned = ', 5.315153550124267)
# ('#', 226, 'Actual = ', 5, 'Predictioned = ', 5.479597994568711)
# ('#', 227, 'Actual = ', 4, 'Predictioned = ', 4.035153550124266)
# ('#', 228, 'Actual = ', 5, 'Predictioned = ', 3.5351535501242664)
# ('#', 229, 'Actual = ', 5, 'Predictioned = ', 2.6157987114145893)
# ('#', 230, 'Actual = ', 3, 'Predictioned = ', 2.5190245178662014)
# ('#', 231, 'Actual = ', 4, 'Predictioned = ', 3.4063656713363875)
# ('#', 232, 'Actual = ', 5, 'Predictioned = ', 3.4518202167909333)
# ('#', 233, 'Actual = ', 5, 'Predictioned = ', 3.835153550124266)
# ('#', 234, 'Actual = ', 5, 'Predictioned = ', 3.0351535501242664)
# ('#', 235, 'Actual = ', 4, 'Predictioned = ', 2.9018202167909335)
# ('#', 236, 'Actual = ', 5, 'Predictioned = ', 2.2351535501242665)
# ('#', 237, 'Actual = ', 4, 'Predictioned = ', 3.4351535501242667)
# ('#', 238, 'Actual = ', 5, 'Predictioned = ', 3.3719956553874244)
# ('#', 239, 'Actual = ', 5, 'Predictioned = ', 4.535153550124267)
# ('#', 240, 'Actual = ', 5, 'Predictioned = ', 3.4518202167909333)
# ('#', 241, 'Actual = ', 5, 'Predictioned = ', 3.0351535501242664)
# ('#', 242, 'Actual = ', 5, 'Predictioned = ', 2.0351535501242664)
# ('#', 243, 'Actual = ', 5, 'Predictioned = ', 3.3684868834576)
# ('#', 244, 'Actual = ', 1, 'Predictioned = ', 3.7851535501242664)
# ('#', 245, 'Actual = ', 4, 'Predictioned = ', 4.392296407267123)
# ('#', 246, 'Actual = ', 5, 'Predictioned = ', 3.5684868834575996)
# ('#', 247, 'Actual = ', 5, 'Predictioned = ', 3.2609600017371694)
# ('#', 248, 'Actual = ', 5, 'Predictioned = ', 2.216971731942448)
# ('#', 249, 'Actual = ', 5, 'Predictioned = ', 3.2851535501242664)
# ('#', 250, 'Actual = ', 5, 'Predictioned = ', 3.0351535501242664)
# ('#', 251, 'Actual = ', 5, 'Predictioned = ', 2.7494392644099808)
# ('#', 252, 'Actual = ', 5, 'Predictioned = ', 2.3719956553874244)
# ('#', 253, 'Actual = ', 4, 'Predictioned = ', 3.7351535501242665)
# ('#', 254, 'Actual = ', 5, 'Predictioned = ', 3.0351535501242664)
# ('#', 255, 'Actual = ', 5, 'Predictioned = ', 3.085153550124266)
# ('#', 256, 'Actual = ', 5, 'Predictioned = ', 3.2851535501242664)
# ('#', 257, 'Actual = ', 1, 'Predictioned = ', 6.679597994568711)
# ('#', 258, 'Actual = ', 1, 'Predictioned = ', 6.881307396278112)
# ('#', 259, 'Actual = ', 5, 'Predictioned = ', 2.97959799456871)
# ('#', 260, 'Actual = ', 5, 'Predictioned = ', 3.1728347095445555)
# ('#', 261, 'Actual = ', 5, 'Predictioned = ', 4.368486883457599)
# ('#', 262, 'Actual = ', 5, 'Predictioned = ', 4.701820216790933)
# ('#', 263, 'Actual = ', 5, 'Predictioned = ', 4.727461242431959)
# ('#', 264, 'Actual = ', 5, 'Predictioned = ', 4.035153550124266)
# ('#', 265, 'Actual = ', 1, 'Predictioned = ', 6.435153550124267)
# ('#', 266, 'Actual = ', 1, 'Predictioned = ', 4.939699004669721)
# ('#', 267, 'Actual = ', 5, 'Predictioned = ', 3.7049209919847312)
# ('#', 268, 'Actual = ', 4, 'Predictioned = ', 3.215798711414589)
# ('#', 269, 'Actual = ', 4, 'Predictioned = ', 3.244303876921652)
# ('#', 270, 'Actual = ', 4, 'Predictioned = ', 5.368486883457599)
# ('#', 271, 'Actual = ', 3, 'Predictioned = ', 3.4442444592151755)
# ('#', 272, 'Actual = ', 5, 'Predictioned = ', 2.8684868834575994)
# ('#', 273, 'Actual = ', 5, 'Predictioned = ', 3.225629740600456)
# ('#', 274, 'Actual = ', 1, 'Predictioned = ', 3.7351535501242665)
# ('#', 275, 'Actual = ', 1, 'Predictioned = ', 3.7998594324772075)
# ('#', 276, 'Actual = ', 3, 'Predictioned = ', 3.892296407267123)
# ('#', 277, 'Actual = ', 5, 'Predictioned = ', 3.0351535501242664)
# ('#', 278, 'Actual = ', 5, 'Predictioned = ', 2.9442444592151755)
# ('#', 279, 'Actual = ', 4, 'Predictioned = ', 4.435153550124266)
# ('#', 280, 'Actual = ', 1, 'Predictioned = ', 2.649611381449567)
# ('#', 281, 'Actual = ', 5, 'Predictioned = ', 2.392296407267123)
# ('#', 282, 'Actual = ', 4, 'Predictioned = ', 3.3684868834576003)
# ('#', 283, 'Actual = ', 4, 'Predictioned = ', 5.3684868834576)
# ('#', 284, 'Actual = ', 4, 'Predictioned = ', 2.9442444592151755)
# ('#', 285, 'Actual = ', 5, 'Predictioned = ', 3.4351535501242663)
# ('#', 286, 'Actual = ', 5, 'Predictioned = ', 2.7494392644099808)
# ('#', 287, 'Actual = ', 5, 'Predictioned = ', 2.635153550124266)
# ('#', 288, 'Actual = ', 5, 'Predictioned = ', 2.2851535501242664)
# ('#', 289, 'Actual = ', 5, 'Predictioned = ', 2.762426277396994)
# ('#', 290, 'Actual = ', 5, 'Predictioned = ', 4.130391645362362)
# ('#', 291, 'Actual = ', 5, 'Predictioned = ', 3.463724978695695)
# ('#', 292, 'Actual = ', 5, 'Predictioned = ', 3.8684868834575994)
# ('#', 293, 'Actual = ', 5, 'Predictioned = ', 3.903574602755845)
# ('#', 294, 'Actual = ', 5, 'Predictioned = ', 2.903574602755845)
# ('#', 295, 'Actual = ', 5, 'Predictioned = ', 2.0351535501242664)
# ('#', 296, 'Actual = ', 4, 'Predictioned = ', 2.8934868834575997)
# ('#', 297, 'Actual = ', 4, 'Predictioned = ', 3.0072928536068533)
# ('#', 298, 'Actual = ', 4, 'Predictioned = ', 3.5866687016394176)
# ('#', 299, 'Actual = ', 4, 'Predictioned = ', 3.182440371829692)
# ('#', 300, 'Actual = ', 5, 'Predictioned = ', 3.263724978695695)
# ('#', 301, 'Actual = ', 5, 'Predictioned = ', 4.835153550124266)
# ('#', 302, 'Actual = ', 5, 'Predictioned = ', 3.3684868834575994)
# ('#', 303, 'Actual = ', 1, 'Predictioned = ', 5.535153550124266)
# ('#', 304, 'Actual = ', 1, 'Predictioned = ', 6.535153550124266)
# ('#', 305, 'Actual = ', 5, 'Predictioned = ', 5.701820216790933)
# ('#', 306, 'Actual = ', 4, 'Predictioned = ', 3.0559868834575994)
# ('#', 307, 'Actual = ', 4, 'Predictioned = ', 3.889320216790933)
# ('#', 308, 'Actual = ', 5, 'Predictioned = ', 3.3322964072671235)
# ('#', 309, 'Actual = ', 5, 'Predictioned = ', 3.4396648283197546)
# ('#', 310, 'Actual = ', 4, 'Predictioned = ', 3.5907091056798217)
# ('#', 311, 'Actual = ', 5, 'Predictioned = ', 3.5806080955788118)
# ('#', 312, 'Actual = ', 4, 'Predictioned = ', 4.392296407267123)
# ('#', 313, 'Actual = ', 5, 'Predictioned = ', 3.7851535501242664)
# ('#', 314, 'Actual = ', 5, 'Predictioned = ', 6.035153550124266)
# ('#', 315, 'Actual = ', 5, 'Predictioned = ', 6.035153550124266)
# ('#', 316, 'Actual = ', 5, 'Predictioned = ', 3.0351535501242664)
# ('#', 317, 'Actual = ', 5, 'Predictioned = ', 5.035153550124266)
# ('#', 318, 'Actual = ', 3, 'Predictioned = ', 4.035153550124266)
# ('#', 319, 'Actual = ', 3, 'Predictioned = ', 4.924042439013156)
# ('#', 320, 'Actual = ', 5, 'Predictioned = ', 3.060577278937826)
# ('#', 321, 'Actual = ', 5, 'Predictioned = ', 3.179597994568711)
# ('#', 322, 'Actual = ', 2, 'Predictioned = ', 2.3446773596480766)
# ('#', 323, 'Actual = ', 3, 'Predictioned = ', 3.6224551374258542)
# ('#', 324, 'Actual = ', 4, 'Predictioned = ', 4.247778134841874)
# ('#', 325, 'Actual = ', 4, 'Predictioned = ', 4.428010692981409)
# ('#', 326, 'Actual = ', 1, 'Predictioned = ', 4.174042439013156)
# ('#', 327, 'Actual = ', 5, 'Predictioned = ', 4.586668701639418)
# ('#', 328, 'Actual = ', 5, 'Predictioned = ', 5.701820216790933)
# ('#', 329, 'Actual = ', 1, 'Predictioned = ', 4.47807592455349)
# ('#', 330, 'Actual = ', 5, 'Predictioned = ', 2.5351535501242664)
# ('#', 331, 'Actual = ', 5, 'Predictioned = ', 3.5351535501242664)
# ('#', 332, 'Actual = ', 4, 'Predictioned = ', 4.9851535501242665)
# ('#', 333, 'Actual = ', 3, 'Predictioned = ', 4.710829225799942)
# ('#', 334, 'Actual = ', 2, 'Predictioned = ', 6.035153550124266)
# ('#', 335, 'Actual = ', 3, 'Predictioned = ', 4.606582121552838)
# ('#', 336, 'Actual = ', 4, 'Predictioned = ', 4.32927119718309)
# ('#', 337, 'Actual = ', 3, 'Predictioned = ', 4.479597994568711)
# ('#', 338, 'Actual = ', 5, 'Predictioned = ', 2.8684868834575994)
# ('#', 339, 'Actual = ', 4, 'Predictioned = ', 3.0351535501242664)
# ('#', 340, 'Actual = ', 5, 'Predictioned = ', 2.5351535501242664)
# ('#', 341, 'Actual = ', 3, 'Predictioned = ', 2.0351535501242664)
# ('#', 342, 'Actual = ', 2, 'Predictioned = ', 3.1018202167909337)
# ('#', 343, 'Actual = ', 3, 'Predictioned = ', 3.4351535501242667)
# ('#', 344, 'Actual = ', 5, 'Predictioned = ', 2.0351535501242664)
# ('#', 345, 'Actual = ', 5, 'Predictioned = ', 2.101820216790933)
# ('#', 346, 'Actual = ', 5, 'Predictioned = ', 2.649611381449567)
# ('#', 347, 'Actual = ', 5, 'Predictioned = ', 2.849107038496359)
# ('#', 348, 'Actual = ', 5, 'Predictioned = ', 4.278743293714009)
# ('#', 349, 'Actual = ', 4, 'Predictioned = ', 5.2732487882195045)
# ('#', 350, 'Actual = ', 2, 'Predictioned = ', 3.0351535501242664)
# ('#', 351, 'Actual = ', 1, 'Predictioned = ', 2.0351535501242664)
# ('#', 352, 'Actual = ', 5, 'Predictioned = ', 2.4934868834575994)
# ('#', 353, 'Actual = ', 5, 'Predictioned = ', 2.707521971176898)
# ('#', 354, 'Actual = ', 2, 'Predictioned = ', 5.035153550124266)
# ('#', 355, 'Actual = ', 3, 'Predictioned = ', 4.035153550124266)
# ('#', 356, 'Actual = ', 5, 'Predictioned = ', 2.3684868834575994)
# ('#', 357, 'Actual = ', 4, 'Predictioned = ', 3.0351535501242664)
# ('#', 358, 'Actual = ', 4, 'Predictioned = ', 4.035153550124266)
# ('#', 359, 'Actual = ', 1, 'Predictioned = ', 4.035153550124266)
# ('#', 360, 'Actual = ', 3, 'Predictioned = ', 3.701820216790933)
# ('#', 361, 'Actual = ', 5, 'Predictioned = ', 2.2351535501242665)
# ('#', 362, 'Actual = ', 1, 'Predictioned = ', 7.701820216790933)
# ('#', 363, 'Actual = ', 1, 'Predictioned = ', 6.635153550124266)
# ('#', 364, 'Actual = ', 4, 'Predictioned = ', 4.003407518378234)
# ('#', 365, 'Actual = ', 5, 'Predictioned = ', 3.8462646612353772)
# ('#', 366, 'Actual = ', 2, 'Predictioned = ', 5.785153550124266)
# ('#', 367, 'Actual = ', 2, 'Predictioned = ', 5.863724978695695)
# ('#', 368, 'Actual = ', 5, 'Predictioned = ', 3.3684868834576)
# ('#', 369, 'Actual = ', 4, 'Predictioned = ', 5.17801069298141)
# ('#', 370, 'Actual = ', 4, 'Predictioned = ', 6.451820216790932)
# ('#', 371, 'Actual = ', 5, 'Predictioned = ', 6.951820216790932)
# ('#', 372, 'Actual = ', 5, 'Predictioned = ', 4.535153550124266)
# ('#', 373, 'Actual = ', 5, 'Predictioned = ', 4.535153550124266)
# ('#', 374, 'Actual = ', 1, 'Predictioned = ', 6.906582121552837)
# ('#', 375, 'Actual = ', 5, 'Predictioned = ', 6.27395952027352)
# ('#', 376, 'Actual = ', 4, 'Predictioned = ', 4.876423391394107)
# ('#', 377, 'Actual = ', 3, 'Predictioned = ', 4.304994819965536)
# ('#', 378, 'Actual = ', 5, 'Predictioned = ', 2.7018202167909333)
# ('#', 379, 'Actual = ', 5, 'Predictioned = ', 2.3684868834575994)
# ('#', 380, 'Actual = ', 5, 'Predictioned = ', 6.035153550124266)
# ('#', 381, 'Actual = ', 5, 'Predictioned = ', 2.7018202167909333)
# ('#', 382, 'Actual = ', 4, 'Predictioned = ', 4.5351535501242655)
# ('#', 383, 'Actual = ', 5, 'Predictioned = ', 3.9018202167909326)
# ('#', 384, 'Actual = ', 4, 'Predictioned = ', 4.835153550124266)
# ('#', 385, 'Actual = ', 5, 'Predictioned = ', 5.417506491300737)
# ('#', 386, 'Actual = ', 3, 'Predictioned = ', 3.5986456136163296)
# ('#', 387, 'Actual = ', 4, 'Predictioned = ', 3.457375772346489)
# ('#', 388, 'Actual = ', 5, 'Predictioned = ', 3.190293737040154)
# ('#', 389, 'Actual = ', 4, 'Predictioned = ', 3.5396990046697203)
# ('#', 390, 'Actual = ', 4, 'Predictioned = ', 3.595759610730327)
# ('#', 391, 'Actual = ', 1, 'Predictioned = ', 2.8684868834575994)
# ('#', 392, 'Actual = ', 1, 'Predictioned = ', 2.2018202167909333)
# ('#', 393, 'Actual = ', 5, 'Predictioned = ', 2.635153550124266)
# ('#', 394, 'Actual = ', 5, 'Predictioned = ', 2.998116513087229)
# ('#', 395, 'Actual = ', 1, 'Predictioned = ', 2.4101535501242664)
# ('#', 396, 'Actual = ', 2, 'Predictioned = ', 4.835153550124266)
# ('#', 397, 'Actual = ', 2, 'Predictioned = ', 4.835153550124266)
# ('#', 398, 'Actual = ', 3, 'Predictioned = ', 3.725629740600456)
# ('#', 399, 'Actual = ', 3, 'Predictioned = ', 3.4922964072671228)
# ('#', 400, 'Actual = ', 5, 'Predictioned = ', 3.4351535501242663)
# ('#', 401, 'Actual = ', 1, 'Predictioned = ', 4.2351535501242665)
# ('#', 402, 'Actual = ', 5, 'Predictioned = ', 4.285153550124266)
# ('#', 403, 'Actual = ', 5, 'Predictioned = ', 5.135153550124267)
# ('#', 404, 'Actual = ', 4, 'Predictioned = ', 4.035153550124266)
# ('#', 405, 'Actual = ', 4, 'Predictioned = ', 3.4351535501242667)
# ('#', 406, 'Actual = ', 5, 'Predictioned = ', 2.820867835838552)
# ('#', 407, 'Actual = ', 5, 'Predictioned = ', 4.535153550124266)
# ('#', 408, 'Actual = ', 5, 'Predictioned = ', 3.0864356014063183)
# ('#', 409, 'Actual = ', 4, 'Predictioned = ', 3.316278048116234)
# ('#', 410, 'Actual = ', 4, 'Predictioned = ', 4.685153550124266)
# ('#', 411, 'Actual = ', 4, 'Predictioned = ', 4.256307396278112)
# ('#', 412, 'Actual = ', 3, 'Predictioned = ', 3.9976535501242667)
# ('#', 413, 'Actual = ', 2, 'Predictioned = ', 7.597653550124266)
# ('#', 414, 'Actual = ', 4, 'Predictioned = ', 4.320867835838552)
# ('#', 415, 'Actual = ', 3, 'Predictioned = ', 4.209756724727441)
# ('#', 416, 'Actual = ', 1, 'Predictioned = ', 4.301820216790932)
# ('#', 417, 'Actual = ', 5, 'Predictioned = ', 5.240281755252471)
# ('#', 418, 'Actual = ', 5, 'Predictioned = ', 3.2851535501242664)
# ('#', 419, 'Actual = ', 5, 'Predictioned = ', 2.0351535501242664)
# ('#', 420, 'Actual = ', 5, 'Predictioned = ', 5.035153550124266)
# ('#', 421, 'Actual = ', 4, 'Predictioned = ', 5.035153550124266)
# ('#', 422, 'Actual = ', 5, 'Predictioned = ', 4.035153550124266)
# ('#', 423, 'Actual = ', 2, 'Predictioned = ', 4.710829225799942)
# ('#', 424, 'Actual = ', 4, 'Predictioned = ', 4.035153550124266)
# ('#', 425, 'Actual = ', 3, 'Predictioned = ', 4.414463894951853)
# ('#', 426, 'Actual = ', 5, 'Predictioned = ', 2.794412809383526)
# ('#', 427, 'Actual = ', 5, 'Predictioned = ', 3.2573757723464887)
# ('#', 428, 'Actual = ', 5, 'Predictioned = ', 3.2018202167909333)
# ('#', 429, 'Actual = ', 4, 'Predictioned = ', 5.285153550124266)
# ('#', 430, 'Actual = ', 5, 'Predictioned = ', 5.701820216790933)
# ('#', 431, 'Actual = ', 3, 'Predictioned = ', 4.182440371829693)
# ('#', 432, 'Actual = ', 5, 'Predictioned = ', 6.035153550124266)
# ('#', 433, 'Actual = ', 4, 'Predictioned = ', 3.679597994568711)
# ('#', 434, 'Actual = ', 5, 'Predictioned = ', 2.7851535501242664)
# ('#', 435, 'Actual = ', 4, 'Predictioned = ', 4.035153550124266)
# ('#', 436, 'Actual = ', 4, 'Predictioned = ', 4.035153550124266)
# ('#', 437, 'Actual = ', 3, 'Predictioned = ', 3.335153550124266)
# ('#', 438, 'Actual = ', 1, 'Predictioned = ', 5.535153550124266)
# ('#', 439, 'Actual = ', 5, 'Predictioned = ', 4.785153550124266)
# ('#', 440, 'Actual = ', 3, 'Predictioned = ', 6.035153550124266)
# ('#', 441, 'Actual = ', 4, 'Predictioned = ', 5.556892680559049)
# ('#', 442, 'Actual = ', 3, 'Predictioned = ', 4.785153550124266)
# ('#', 443, 'Actual = ', 4, 'Predictioned = ', 3.6942444592151755)
# ('#', 444, 'Actual = ', 5, 'Predictioned = ', 2.8268202167909333)
# ('#', 445, 'Actual = ', 1, 'Predictioned = ', 4.2351535501242665)
# ('#', 446, 'Actual = ', 5, 'Predictioned = ', 2.987534502505219)
# ('#', 447, 'Actual = ', 1, 'Predictioned = ', 4.9018202167909335)
# ('#', 448, 'Actual = ', 5, 'Predictioned = ', 3.9190821215528375)
# ('#', 449, 'Actual = ', 4, 'Predictioned = ', 4.939915454886171)
# ('#', 450, 'Actual = ', 5, 'Predictioned = ', 3.835153550124266)
# ('#', 451, 'Actual = ', 5, 'Predictioned = ', 3.0351535501242664)
# ('#', 452, 'Actual = ', 5, 'Predictioned = ', 2.590293737040154)
# ('#', 453, 'Actual = ', 4, 'Predictioned = ', 3.1981165130872293)
# ('#', 454, 'Actual = ', 5, 'Predictioned = ', 2.8682362568911834)
# ('#', 455, 'Actual = ', 5, 'Predictioned = ', 2.9208678358385516)
# ('#', 456, 'Actual = ', 3, 'Predictioned = ', 2.7851535501242664)
# ('#', 457, 'Actual = ', 5, 'Predictioned = ', 4.535153550124266)
# ('#', 458, 'Actual = ', 4, 'Predictioned = ', 3.2851535501242664)
# ('#', 459, 'Actual = ', 5, 'Predictioned = ', 3.1601535501242664)
# ('#', 460, 'Actual = ', 5, 'Predictioned = ', 4.785153550124266)
# ('#', 461, 'Actual = ', 4, 'Predictioned = ', 3.2851535501242664)
# ('#', 462, 'Actual = ', 5, 'Predictioned = ', 3.0647831797538965)
# ('#', 463, 'Actual = ', 4, 'Predictioned = ', 2.911344026314743)
# ('#', 464, 'Actual = ', 4, 'Predictioned = ', 2.4101535501242664)
# ('#', 465, 'Actual = ', 5, 'Predictioned = ', 2.0351535501242664)
# ('#', 466, 'Actual = ', 4, 'Predictioned = ', 3.998116513087229)
# ('#', 467, 'Actual = ', 3, 'Predictioned = ', 5.368486883457599)
# ('#', 468, 'Actual = ', 5, 'Predictioned = ', 2.351820216790933)
# ('#', 469, 'Actual = ', 5, 'Predictioned = ', 2.885153550124266)
# ('#', 470, 'Actual = ', 4, 'Predictioned = ', 2.5351535501242664)
# ('#', 471, 'Actual = ', 5, 'Predictioned = ', 3.4518202167909333)
# ('#', 472, 'Actual = ', 5, 'Predictioned = ', 2.2851535501242664)
# ('#', 473, 'Actual = ', 5, 'Predictioned = ', 2.5351535501242664)
# ('#', 474, 'Actual = ', 4, 'Predictioned = ', 2.335153550124266)
# ('#', 475, 'Actual = ', 4, 'Predictioned = ', 2.335153550124266)
# ('#', 476, 'Actual = ', 5, 'Predictioned = ', 3.7018202167909333)
# ('#', 477, 'Actual = ', 3, 'Predictioned = ', 5.035153550124267)
# ('#', 478, 'Actual = ', 5, 'Predictioned = ', 3.684276357141811)
# ('#', 479, 'Actual = ', 5, 'Predictioned = ', 3.7053289887207583)
# ('#', 480, 'Actual = ', 5, 'Predictioned = ', 3.106582121552838)
# ('#', 481, 'Actual = ', 4, 'Predictioned = ', 2.6065821215528375)
# ('#', 482, 'Actual = ', 5, 'Predictioned = ', 2.903574602755845)
# ('#', 483, 'Actual = ', 4, 'Predictioned = ', 3.8684868834576)
# ('#', 484, 'Actual = ', 5, 'Predictioned = ', 5.316278048116233)
# ('#', 485, 'Actual = ', 5, 'Predictioned = ', 5.401820216790933)
# ('#', 486, 'Actual = ', 5, 'Predictioned = ', 3.7018202167909333)
# ('#', 487, 'Actual = ', 4, 'Predictioned = ', 3.0351535501242664)
# ('#', 488, 'Actual = ', 5, 'Predictioned = ', 5.535153550124266)
# ('#', 489, 'Actual = ', 5, 'Predictioned = ', 5.035153550124266)
# ('#', 490, 'Actual = ', 5, 'Predictioned = ', 3.8351535501242666)
# ('#', 491, 'Actual = ', 3, 'Predictioned = ', 5.435153550124267)
# ('#', 492, 'Actual = ', 1, 'Predictioned = ', 4.241035903065443)
# ('#', 493, 'Actual = ', 5, 'Predictioned = ', 3.979597994568711)
# ('#', 494, 'Actual = ', 4, 'Predictioned = ', 2.640293737040154)
# ('#', 495, 'Actual = ', 5, 'Predictioned = ', 3.085153550124266)
# ('#', 496, 'Actual = ', 2, 'Predictioned = ', 3.3922964072671236)
# ('#', 497, 'Actual = ', 5, 'Predictioned = ', 2.0351535501242664)
# ('#', 498, 'Actual = ', 4, 'Predictioned = ', 4.432589447560164)
# ('#', 499, 'Actual = ', 4, 'Predictioned = ', 5.535153550124266)
# ('#', 500, 'Actual = ', 5, 'Predictioned = ', 2.3684868834575994)
# ('#', 501, 'Actual = ', 5, 'Predictioned = ', 3.0806080955788118)
# ('#', 502, 'Actual = ', 5, 'Predictioned = ', 3.0190245178662014)
# ('#', 503, 'Actual = ', 5, 'Predictioned = ', 2.798311444861109)
# ('#', 504, 'Actual = ', 2, 'Predictioned = ', 5.701820216790933)
# ('#', 505, 'Actual = ', 5, 'Predictioned = ', 4.137717652688369)
# ('#', 506, 'Actual = ', 4, 'Predictioned = ', 4.035153550124266)
# ('#', 507, 'Actual = ', 5, 'Predictioned = ', 3.3684868834576)
# ('#', 508, 'Actual = ', 5, 'Predictioned = ', 3.3951535501242667)
# ('#', 509, 'Actual = ', 3, 'Predictioned = ', 3.835153550124266)
# ('#', 510, 'Actual = ', 3, 'Predictioned = ', 4.130391645362361)
# ('#', 511, 'Actual = ', 3, 'Predictioned = ', 3.7018202167909324)
# ('#', 512, 'Actual = ', 5, 'Predictioned = ', 3.9101535501242664)
# ('#', 513, 'Actual = ', 1, 'Predictioned = ', 3.392296407267123)
# ('#', 514, 'Actual = ', 4, 'Predictioned = ', 2.7018202167909333)
# ('#', 515, 'Actual = ', 5, 'Predictioned = ', 2.7018202167909333)
# ('#', 516, 'Actual = ', 5, 'Predictioned = ', 2.649611381449567)
# ('#', 517, 'Actual = ', 1, 'Predictioned = ', 2.7851535501242664)
# ('#', 518, 'Actual = ', 5, 'Predictioned = ', 4.035153550124266)
# ('#', 519, 'Actual = ', 5, 'Predictioned = ', 3.0351535501242664)
# ('#', 520, 'Actual = ', 3, 'Predictioned = ', 3.7851535501242664)
# ('#', 521, 'Actual = ', 2, 'Predictioned = ', 3.651315166285883)
# ('#', 522, 'Actual = ', 2, 'Predictioned = ', 3.2351535501242665)
# ('#', 523, 'Actual = ', 4, 'Predictioned = ', 2.5351535501242664)
# ('#', 524, 'Actual = ', 5, 'Predictioned = ', 4.368486883457599)
# ('#', 525, 'Actual = ', 5, 'Predictioned = ', 2.8342403081151337)
# ('#', 526, 'Actual = ', 4, 'Predictioned = ', 2.8043843193550355)
# ('#', 527, 'Actual = ', 5, 'Predictioned = ', 2.820867835838552)
# ('#', 528, 'Actual = ', 2, 'Predictioned = ', 3.4184868834575997)
# ('#', 529, 'Actual = ', 5, 'Predictioned = ', 3.0351535501242664)
# ('#', 530, 'Actual = ', 5, 'Predictioned = ', 3.5351535501242664)
# ('#', 531, 'Actual = ', 5, 'Predictioned = ', 3.0976535501242664)
# ('#', 532, 'Actual = ', 5, 'Predictioned = ', 2.3684868834575994)
# ('#', 533, 'Actual = ', 5, 'Predictioned = ', 2.3684868834575994)
# ('#', 534, 'Actual = ', 5, 'Predictioned = ', 2.649611381449567)
# ('#', 535, 'Actual = ', 5, 'Predictioned = ', 3.0351535501242664)
# ('#', 536, 'Actual = ', 5, 'Predictioned = ', 4.035153550124266)
# ('#', 537, 'Actual = ', 5, 'Predictioned = ', 4.580608095578812)
# ('#', 538, 'Actual = ', 3, 'Predictioned = ', 4.44411713555844)
# ('#', 539, 'Actual = ', 3, 'Predictioned = ', 5.011344026314743)
# ('#', 540, 'Actual = ', 1, 'Predictioned = ', 3.1462646612353775)
# ('#', 541, 'Actual = ', 4, 'Predictioned = ', 3.2351535501242665)
# ('#', 542, 'Actual = ', 4, 'Predictioned = ', 3.487534502505219)
# ('#', 543, 'Actual = ', 4, 'Predictioned = ', 2.987534502505219)
# ('#', 544, 'Actual = ', 4, 'Predictioned = ', 4.4382543253180655)
# ('#', 545, 'Actual = ', 5, 'Predictioned = ', 4.082772597743315)
# ('#', 546, 'Actual = ', 5, 'Predictioned = ', 3.939915454886171)
# ('#', 547, 'Actual = ', 3, 'Predictioned = ', 3.539915454886171)
# ('#', 548, 'Actual = ', 5, 'Predictioned = ', 4.106582121552838)
# ('#', 549, 'Actual = ', 4, 'Predictioned = ', 4.535153550124266)
# ('#', 550, 'Actual = ', 4, 'Predictioned = ', 3.399611381449567)
# ('#', 551, 'Actual = ', 4, 'Predictioned = ', 3.9851535501242665)
# ('#', 552, 'Actual = ', 5, 'Predictioned = ', 6.035153550124266)
# ('#', 553, 'Actual = ', 1, 'Predictioned = ', 4.035153550124266)
# ('#', 554, 'Actual = ', 4, 'Predictioned = ', 2.9442444592151755)
# ('#', 555, 'Actual = ', 4, 'Predictioned = ', 2.7018202167909333)
# ('#', 556, 'Actual = ', 2, 'Predictioned = ', 3.3684868834575994)
# ('#', 557, 'Actual = ', 2, 'Predictioned = ', 3.0351535501242664)
# ('#', 558, 'Actual = ', 4, 'Predictioned = ', 3.7018202167909333)
# ('#', 559, 'Actual = ', 4, 'Predictioned = ', 3.5351535501242664)
# ('#', 560, 'Actual = ', 4, 'Predictioned = ', 3.7494392644099808)
# ('#', 561, 'Actual = ', 5, 'Predictioned = ', 3.5351535501242664)
# ('#', 562, 'Actual = ', 5, 'Predictioned = ', 3.7472747622454787)
# ('#', 563, 'Actual = ', 5, 'Predictioned = ', 3.2161059310766476)
# ('#', 564, 'Actual = ', 4, 'Predictioned = ', 5.25737577234649)
# ('#', 565, 'Actual = ', 4, 'Predictioned = ', 5.8684868834576)
# ('#', 566, 'Actual = ', 4, 'Predictioned = ', 4.727461242431959)
# ('#', 567, 'Actual = ', 5, 'Predictioned = ', 3.390293737040154)
# ('#', 568, 'Actual = ', 5, 'Predictioned = ', 3.0494392644099806)
# ('#', 569, 'Actual = ', 5, 'Predictioned = ', 3.4101535501242664)
# ('#', 570, 'Actual = ', 4, 'Predictioned = ', 4.701820216790933)
# ('#', 571, 'Actual = ', 5, 'Predictioned = ', 8.035153550124267)
# ('#', 572, 'Actual = ', 4, 'Predictioned = ', 2.0351535501242664)
# ('#', 573, 'Actual = ', 4, 'Predictioned = ', 3.0351535501242664)
# ('#', 574, 'Actual = ', 4, 'Predictioned = ', 3.4065821215528374)
# ('#', 575, 'Actual = ', 5, 'Predictioned = ', 3.210829225799942)
# ('#', 576, 'Actual = ', 3, 'Predictioned = ', 5.812931327902044)
# ('#', 577, 'Actual = ', 5, 'Predictioned = ', 4.451820216790933)
# ('#', 578, 'Actual = ', 4, 'Predictioned = ', 5.201820216790933)
# ('#', 579, 'Actual = ', 4, 'Predictioned = ', 3.835153550124266)
# ('#', 580, 'Actual = ', 5, 'Predictioned = ', 3.0351535501242664)
# ('#', 581, 'Actual = ', 4, 'Predictioned = ', 3.126062641033357)
# ('#', 582, 'Actual = ', 5, 'Predictioned = ', 2.8684868834575994)
# ('#', 583, 'Actual = ', 3, 'Predictioned = ', 3.301820216790933)
# ('#', 584, 'Actual = ', 4, 'Predictioned = ', 3.6065821215528375)
# ('#', 585, 'Actual = ', 3, 'Predictioned = ', 3.3565821215528375)
# ('#', 586, 'Actual = ', 5, 'Predictioned = ', 3.89391061227116)
# ('#', 587, 'Actual = ', 5, 'Predictioned = ', 4.035153550124267)
# ('#', 588, 'Actual = ', 5, 'Predictioned = ', 3.5351535501242664)
# ('#', 589, 'Actual = ', 5, 'Predictioned = ', 4.466971731942448)
# ('#', 590, 'Actual = ', 5, 'Predictioned = ', 3.701820216790933)
# ('#', 591, 'Actual = ', 5, 'Predictioned = ', 2.835153550124266)
# ('#', 592, 'Actual = ', 5, 'Predictioned = ', 3.5351535501242664)
# ('#', 593, 'Actual = ', 3, 'Predictioned = ', 5.285153550124266)
# ('#', 594, 'Actual = ', 4, 'Predictioned = ', 4.099597994568711)
# ('#', 595, 'Actual = ', 4, 'Predictioned = ', 3.7427558893055535)
# ('#', 596, 'Actual = ', 4, 'Predictioned = ', 3.2351535501242665)
# ('#', 597, 'Actual = ', 4, 'Predictioned = ', 2.4851535501242665)
# ('#', 598, 'Actual = ', 5, 'Predictioned = ', 2.5351535501242664)
# ('#', 599, 'Actual = ', 5, 'Predictioned = ', 2.6184868834575994)
# ('#', 600, 'Actual = ', 5, 'Predictioned = ', 5.406582121552837)
# ('#', 601, 'Actual = ', 3, 'Predictioned = ', 4.701820216790933)
# ('#', 602, 'Actual = ', 1, 'Predictioned = ', 5.906948421919138)
# ('#', 603, 'Actual = ', 1, 'Predictioned = ', 6.135153550124267)
# ('#', 604, 'Actual = ', 3, 'Predictioned = ', 4.62774614271686)
# ('#', 605, 'Actual = ', 3, 'Predictioned = ', 4.424042439013156)
# ('#', 606, 'Actual = ', 5, 'Predictioned = ', 2.9101535501242664)
# ('#', 607, 'Actual = ', 1, 'Predictioned = ', 3.6973157122864286)
# ('#', 608, 'Actual = ', 4, 'Predictioned = ', 2.4101535501242664)
# ('#', 609, 'Actual = ', 5, 'Predictioned = ', 4.951820216790933)
# ('#', 610, 'Actual = ', 5, 'Predictioned = ', 2.2851535501242664)
# ('#', 611, 'Actual = ', 5, 'Predictioned = ', 2.5351535501242664)
# ('#', 612, 'Actual = ', 5, 'Predictioned = ', 6.910153550124266)
# ('#', 613, 'Actual = ', 4, 'Predictioned = ', 6.201820216790933)
# ('#', 614, 'Actual = ', 5, 'Predictioned = ', 2.7018202167909333)
# ('#', 615, 'Actual = ', 4, 'Predictioned = ', 3.316278048116234)
# ('#', 616, 'Actual = ', 5, 'Predictioned = ', 2.6065821215528375)
# ('#', 617, 'Actual = ', 5, 'Predictioned = ', 2.2018202167909333)
# ('#', 618, 'Actual = ', 5, 'Predictioned = ', 3.0498594324772075)
# ('#', 619, 'Actual = ', 4, 'Predictioned = ', 4.451820216790933)
# ('#', 620, 'Actual = ', 5, 'Predictioned = ', 2.602721117691834)
# ('#', 621, 'Actual = ', 5, 'Predictioned = ', 2.8395013762112224)
# ('#', 622, 'Actual = ', 5, 'Predictioned = ', 3.012931327902044)
# ('#', 623, 'Actual = ', 5, 'Predictioned = ', 3.4382543253180646)
# ('#', 624, 'Actual = ', 5, 'Predictioned = ', 3.585153550124266)
# ('#', 625, 'Actual = ', 4, 'Predictioned = ', 2.7851535501242664)
# ('#', 626, 'Actual = ', 5, 'Predictioned = ', 3.320867835838552)
# ('#', 627, 'Actual = ', 5, 'Predictioned = ', 3.5026860176567336)
# ('#', 628, 'Actual = ', 5, 'Predictioned = ', 2.7351535501242665)
# ('#', 629, 'Actual = ', 5, 'Predictioned = ', 2.9101535501242664)
# ('#', 630, 'Actual = ', 4, 'Predictioned = ', 3.820867835838552)
# ('#', 631, 'Actual = ', 5, 'Predictioned = ', 3.320867835838552)
# ('#', 632, 'Actual = ', 4, 'Predictioned = ', 3.6065821215528375)
# ('#', 633, 'Actual = ', 4, 'Predictioned = ', 4.6065821215528375)
# ('#', 634, 'Actual = ', 5, 'Predictioned = ', 2.560577278937826)
# ('#', 635, 'Actual = ', 5, 'Predictioned = ', 2.7851535501242664)
# ('#', 636, 'Actual = ', 3, 'Predictioned = ', 4.035153550124266)
# ('#', 637, 'Actual = ', 4, 'Predictioned = ', 4.679597994568711)
# ('#', 638, 'Actual = ', 5, 'Predictioned = ', 2.5009069747818007)
# ('#', 639, 'Actual = ', 5, 'Predictioned = ', 3.3684868834576)
# ('#', 640, 'Actual = ', 4, 'Predictioned = ', 6.27395952027352)
# ('#', 641, 'Actual = ', 5, 'Predictioned = ', 6.849107038496359)
# ('#', 642, 'Actual = ', 4, 'Predictioned = ', 2.968486883457599)
# ('#', 643, 'Actual = ', 4, 'Predictioned = ', 2.6184868834575994)
# ('#', 644, 'Actual = ', 5, 'Predictioned = ', 3.0618202167909336)
# ('#', 645, 'Actual = ', 4, 'Predictioned = ', 3.7018202167909333)
# ('#', 646, 'Actual = ', 4, 'Predictioned = ', 3.3684868834575994)
# ('#', 647, 'Actual = ', 4, 'Predictioned = ', 2.8446773596480757)
# ('#', 648, 'Actual = ', 5, 'Predictioned = ', 2.3551535501242666)
# ('#', 649, 'Actual = ', 1, 'Predictioned = ', 2.710829225799942)
# ('#', 650, 'Actual = ', 2, 'Predictioned = ', 5.176179191149907)
# ('#', 651, 'Actual = ', 5, 'Predictioned = ', 3.676179191149907)
# ('#', 652, 'Actual = ', 5, 'Predictioned = ', 2.612076627047343)
# ('#', 653, 'Actual = ', 4, 'Predictioned = ', 2.1528006089477953)
# ('#', 654, 'Actual = ', 5, 'Predictioned = ', 3.0351535501242664)
# ('#', 655, 'Actual = ', 5, 'Predictioned = ', 2.639804712914964)
# ('#', 656, 'Actual = ', 5, 'Predictioned = ', 2.763490786658224)
# ('#', 657, 'Actual = ', 4, 'Predictioned = ', 2.8446773596480757)
# ('#', 658, 'Actual = ', 5, 'Predictioned = ', 2.4896990046697205)
# ('#', 659, 'Actual = ', 5, 'Predictioned = ', 4.035153550124266)
# ('#', 660, 'Actual = ', 1, 'Predictioned = ', 5.035153550124266)
# ('#', 661, 'Actual = ', 3, 'Predictioned = ', 4.785153550124266)
# ('#', 662, 'Actual = ', 5, 'Predictioned = ', 3.635153550124266)
# ('#', 663, 'Actual = ', 5, 'Predictioned = ', 4.035153550124266)
# ('#', 664, 'Actual = ', 5, 'Predictioned = ', 4.347653550124266)
# ('#', 665, 'Actual = ', 5, 'Predictioned = ', 3.4726535501242664)
# ('#', 666, 'Actual = ', 4, 'Predictioned = ', 4.146264661235377)
# ('#', 667, 'Actual = ', 2, 'Predictioned = ', 4.884359899330615)
# ('#', 668, 'Actual = ', 5, 'Predictioned = ', 2.2018202167909333)
# ('#', 669, 'Actual = ', 4, 'Predictioned = ', 2.3476535501242664)
# ('#', 670, 'Actual = ', 4, 'Predictioned = ', 5.97959799456871)
# ('#', 671, 'Actual = ', 5, 'Predictioned = ', 4.801820216790932)
# ('#', 672, 'Actual = ', 4, 'Predictioned = ', 3.3268202167909333)
# ('#', 673, 'Actual = ', 4, 'Predictioned = ', 3.701820216790933)
# ('#', 674, 'Actual = ', 5, 'Predictioned = ', 2.7494392644099808)
# ('#', 675, 'Actual = ', 5, 'Predictioned = ', 2.390293737040154)
# ('#', 676, 'Actual = ', 5, 'Predictioned = ', 2.3684868834575994)
# ('#', 677, 'Actual = ', 5, 'Predictioned = ', 2.0351535501242664)
# ('#', 678, 'Actual = ', 4, 'Predictioned = ', 2.8533353683060847)
# ('#', 679, 'Actual = ', 4, 'Predictioned = ', 2.635153550124266)
# ('#', 680, 'Actual = ', 5, 'Predictioned = ', 3.567621082591799)
# ('#', 681, 'Actual = ', 5, 'Predictioned = ', 3.043556911468804)
# ('#', 682, 'Actual = ', 1, 'Predictioned = ', 4.249439264409981)
# ('#', 683, 'Actual = ', 5, 'Predictioned = ', 3.9369392644099808)
# ('#', 684, 'Actual = ', 5, 'Predictioned = ', 3.6462646612353775)
# ('#', 685, 'Actual = ', 4, 'Predictioned = ', 3.3011109969327768)
# ('#', 686, 'Actual = ', 5, 'Predictioned = ', 4.335153550124266)
# ('#', 687, 'Actual = ', 5, 'Predictioned = ', 3.5396990046697203)
# ('#', 688, 'Actual = ', 1, 'Predictioned = ', 3.5494392644099806)
# ('#', 689, 'Actual = ', 5, 'Predictioned = ', 4.175153550124266)
# ('#', 690, 'Actual = ', 5, 'Predictioned = ', 4.6684868834576)
# ('#', 691, 'Actual = ', 4, 'Predictioned = ', 3.952800608947795)
# ('#', 692, 'Actual = ', 5, 'Predictioned = ', 2.390293737040154)
# ('#', 693, 'Actual = ', 5, 'Predictioned = ', 2.544587512388417)
# ('#', 694, 'Actual = ', 1, 'Predictioned = ', 6.054201169171885)
# ('#', 695, 'Actual = ', 5, 'Predictioned = ', 4.9684868834576)
# ('#', 696, 'Actual = ', 5, 'Predictioned = ', 3.168486883457599)
# ('#', 697, 'Actual = ', 4, 'Predictioned = ', 3.168486883457599)
# ('#', 698, 'Actual = ', 5, 'Predictioned = ', 6.849107038496359)
# ('#', 699, 'Actual = ', 1, 'Predictioned = ', 7.035153550124266)
# ('#', 700, 'Actual = ', 5, 'Predictioned = ', 2.390293737040154)
# ('#', 701, 'Actual = ', 5, 'Predictioned = ', 2.635153550124266)
# ('#', 702, 'Actual = ', 5, 'Predictioned = ', 2.646264661235377)
# ('#', 703, 'Actual = ', 5, 'Predictioned = ', 2.8395013762112224)
# ('#', 704, 'Actual = ', 4, 'Predictioned = ', 4.6184868834576)
# ('#', 705, 'Actual = ', 5, 'Predictioned = ', 4.3684868834576)
# ('#', 706, 'Actual = ', 4, 'Predictioned = ', 5.1822123736536785)
# ('#', 707, 'Actual = ', 4, 'Predictioned = ', 6.535153550124266)
# ('#', 708, 'Actual = ', 3, 'Predictioned = ', 3.5922964072671233)
# ('#', 709, 'Actual = ', 4, 'Predictioned = ', 3.8398047129149644)
# ('#', 710, 'Actual = ', 2, 'Predictioned = ', 4.112672929969227)
# ('#', 711, 'Actual = ', 5, 'Predictioned = ', 3.2775777925485086)
# ('#', 712, 'Actual = ', 5, 'Predictioned = ', 3.1751535501242665)
# ('#', 713, 'Actual = ', 5, 'Predictioned = ', 2.5494392644099806)
# ('#', 714, 'Actual = ', 3, 'Predictioned = ', 2.9442444592151755)
# ('#', 715, 'Actual = ', 5, 'Predictioned = ', 3.4101535501242664)
# ('#', 716, 'Actual = ', 5, 'Predictioned = ', 2.812931327902044)
# ('#', 717, 'Actual = ', 5, 'Predictioned = ', 4.146264661235378)
# ('#', 718, 'Actual = ', 5, 'Predictioned = ', 2.7851535501242664)
# ('#', 719, 'Actual = ', 5, 'Predictioned = ', 2.3551535501242666)
# ('#', 720, 'Actual = ', 4, 'Predictioned = ', 3.805645353402955)
# ('#', 721, 'Actual = ', 3, 'Predictioned = ', 3.885153550124266)
# ('#', 722, 'Actual = ', 5, 'Predictioned = ', 4.3684868834576)
# ('#', 723, 'Actual = ', 5, 'Predictioned = ', 3.982944714782901)
# ('#', 724, 'Actual = ', 3, 'Predictioned = ', 2.3684868834575994)
# ('#', 725, 'Actual = ', 5, 'Predictioned = ', 2.0351535501242664)
# ('#', 726, 'Actual = ', 4, 'Predictioned = ', 4.7684868834576)
# ('#', 727, 'Actual = ', 3, 'Predictioned = ', 4.435153550124267)
# ('#', 728, 'Actual = ', 2, 'Predictioned = ', 3.2851535501242664)
# ('#', 729, 'Actual = ', 5, 'Predictioned = ', 4.285153550124266)
# ('#', 730, 'Actual = ', 5, 'Predictioned = ', 2.5351535501242664)
# ('#', 731, 'Actual = ', 5, 'Predictioned = ', 2.7053289887207574)
# ('#', 732, 'Actual = ', 3, 'Predictioned = ', 4.885153550124266)
# ('#', 733, 'Actual = ', 5, 'Predictioned = ', 4.635153550124266)
# ('#', 734, 'Actual = ', 4, 'Predictioned = ', 4.035153550124266)
# ('#', 735, 'Actual = ', 5, 'Predictioned = ', 4.285153550124266)
# ...
# ('#', 4761, 'Actual = ', 5, 'Predictioned = ', 2.8268202167909333)
# ('#', 4762, 'Actual = ', 5, 'Predictioned = ', 4.701820216790933)
# ('#', 4763, 'Actual = ', 5, 'Predictioned = ', 4.368486883457599)
# ('#', 4764, 'Actual = ', 5, 'Predictioned = ', 3.015922780893497)
# ('#', 4765, 'Actual = ', 5, 'Predictioned = ', 3.515922780893497)
# ('#', 4766, 'Actual = ', 3, 'Predictioned = ', 4.910153550124266)
# ('#', 4767, 'Actual = ', 4, 'Predictioned = ', 4.535153550124266)
# ('#', 4768, 'Actual = ', 4, 'Predictioned = ', 6.368486883457599)
# ('#', 4769, 'Actual = ', 4, 'Predictioned = ', 6.394127909098625)
# ('#', 4770, 'Actual = ', 3, 'Predictioned = ', 5.479597994568711)
# ('#', 4771, 'Actual = ', 5, 'Predictioned = ', 4.035153550124266)
# ('#', 4772, 'Actual = ', 4, 'Predictioned = ', 3.2351535501242665)
# ('#', 4773, 'Actual = ', 5, 'Predictioned = ', 2.961079476050192)
# ('#', 4774, 'Actual = ', 5, 'Predictioned = ', 3.303652493041813)
# ('#', 4775, 'Actual = ', 5, 'Predictioned = ', 3.1615740046697205)
# ('#', 4776, 'Actual = ', 5, 'Predictioned = ', 5.8043843193550355)
# ('#', 4777, 'Actual = ', 1, 'Predictioned = ', 5.701820216790933)
# ('#', 4778, 'Actual = ', 5, 'Predictioned = ', 3.763786028756745)
# ('#', 4779, 'Actual = ', 5, 'Predictioned = ', 3.8153733303440465)
# ('#', 4780, 'Actual = ', 5, 'Predictioned = ', 3.0806080955788118)
# ('#', 4781, 'Actual = ', 5, 'Predictioned = ', 2.5351535501242664)
# ('#', 4782, 'Actual = ', 3, 'Predictioned = ', 4.635153550124267)
# ('#', 4783, 'Actual = ', 5, 'Predictioned = ', 4.101820216790934)
# ('#', 4784, 'Actual = ', 5, 'Predictioned = ', 3.3050564627456254)
# ('#', 4785, 'Actual = ', 5, 'Predictioned = ', 3.335153550124266)
# ('#', 4786, 'Actual = ', 5, 'Predictioned = ', 2.646264661235377)
# ('#', 4787, 'Actual = ', 4, 'Predictioned = ', 2.3684868834575994)
# ('#', 4788, 'Actual = ', 5, 'Predictioned = ', 3.2851535501242664)
# ('#', 4789, 'Actual = ', 5, 'Predictioned = ', 3.4851535501242665)
# ('#', 4790, 'Actual = ', 5, 'Predictioned = ', 2.7684868834575997)
# ('#', 4791, 'Actual = ', 5, 'Predictioned = ', 2.6213604466759906)
# ('#', 4792, 'Actual = ', 4, 'Predictioned = ', 3.0351535501242664)
# ('#', 4793, 'Actual = ', 5, 'Predictioned = ', 2.3684868834575994)
# ('#', 4794, 'Actual = ', 3, 'Predictioned = ', 4.951820216790933)
# ('#', 4795, 'Actual = ', 4, 'Predictioned = ', 3.5907091056798226)
# ('#', 4796, 'Actual = ', 5, 'Predictioned = ', 3.820867835838552)
# ('#', 4797, 'Actual = ', 4, 'Predictioned = ', 3.7018202167909333)
# ('#', 4798, 'Actual = ', 3, 'Predictioned = ', 5.910153550124266)
# ('#', 4799, 'Actual = ', 4, 'Predictioned = ', 7.035153550124266)
# ('#', 4800, 'Actual = ', 4, 'Predictioned = ', 6.035153550124266)
# ('#', 4801, 'Actual = ', 4, 'Predictioned = ', 4.7396990046697205)
# ('#', 4802, 'Actual = ', 4, 'Predictioned = ', 4.007375772346489)
# ('#', 4803, 'Actual = ', 4, 'Predictioned = ', 3.4518202167909333)
# ('#', 4804, 'Actual = ', 4, 'Predictioned = ', 4.6184868834576)
# ('#', 4805, 'Actual = ', 5, 'Predictioned = ', 5.189915454886172)
# ('#', 4806, 'Actual = ', 1, 'Predictioned = ', 4.368486883457599)
# ('#', 4807, 'Actual = ', 5, 'Predictioned = ', 3.3719956553874244)
# ('#', 4808, 'Actual = ', 5, 'Predictioned = ', 3.5351535501242664)
# ('#', 4809, 'Actual = ', 3, 'Predictioned = ', 3.892296407267123)
# ('#', 4810, 'Actual = ', 5, 'Predictioned = ', 3.4144638949518527)
# ('#', 4811, 'Actual = ', 5, 'Predictioned = ', 2.998116513087229)
# ('#', 4812, 'Actual = ', 5, 'Predictioned = ', 3.320867835838552)
# ('#', 4813, 'Actual = ', 5, 'Predictioned = ', 2.8684868834575994)
# ('#', 4814, 'Actual = ', 4, 'Predictioned = ', 6.287599734077299)
# ('#', 4815, 'Actual = ', 3, 'Predictioned = ', 5.798010692981409)
# ('#', 4816, 'Actual = ', 5, 'Predictioned = ', 2.5009069747818007)
# ('#', 4817, 'Actual = ', 3, 'Predictioned = ', 4.535153550124266)
# ('#', 4818, 'Actual = ', 2, 'Predictioned = ', 5.035153550124266)
# ('#', 4819, 'Actual = ', 1, 'Predictioned = ', 3.2851535501242664)
# ('#', 4820, 'Actual = ', 3, 'Predictioned = ', 3.8407091056798217)
# ('#', 4821, 'Actual = ', 5, 'Predictioned = ', 3.4751535501242667)
# ('#', 4822, 'Actual = ', 5, 'Predictioned = ', 3.0351535501242664)
# ('#', 4823, 'Actual = ', 5, 'Predictioned = ', 3.2351535501242665)
# ('#', 4824, 'Actual = ', 4, 'Predictioned = ', 5.535153550124266)
# ('#', 4825, 'Actual = ', 5, 'Predictioned = ', 3.2851535501242664)
# ('#', 4826, 'Actual = ', 4, 'Predictioned = ', 3.8601535501242665)
# ('#', 4827, 'Actual = ', 4, 'Predictioned = ', 5.993486883457599)
# ('#', 4828, 'Actual = ', 5, 'Predictioned = ', 3.0351535501242664)
# ('#', 4829, 'Actual = ', 5, 'Predictioned = ', 2.5351535501242664)
# ('#', 4830, 'Actual = ', 4, 'Predictioned = ', 5.28005150930794)
# ('#', 4831, 'Actual = ', 1, 'Predictioned = ', 6.035153550124266)
# ('#', 4832, 'Actual = ', 5, 'Predictioned = ', 2.8684868834575994)
# ('#', 4833, 'Actual = ', 5, 'Predictioned = ', 3.5866687016394176)
# ('#', 4834, 'Actual = ', 3, 'Predictioned = ', 2.350943023808477)
# ('#', 4835, 'Actual = ', 5, 'Predictioned = ', 3.0351535501242664)
# ('#', 4836, 'Actual = ', 4, 'Predictioned = ', 2.933704274761947)
# ('#', 4837, 'Actual = ', 4, 'Predictioned = ', 2.989176538630013)
# ('#', 4838, 'Actual = ', 5, 'Predictioned = ', 3.2851535501242664)
# ('#', 4839, 'Actual = ', 5, 'Predictioned = ', 3.7509069747818007)
# ('#', 4840, 'Actual = ', 5, 'Predictioned = ', 3.3551535501242666)
# ('#', 4841, 'Actual = ', 5, 'Predictioned = ', 4.335153550124266)
# ('#', 4842, 'Actual = ', 5, 'Predictioned = ', 3.2851535501242664)
# ('#', 4843, 'Actual = ', 5, 'Predictioned = ', 3.7351535501242665)
# ('#', 4844, 'Actual = ', 5, 'Predictioned = ', 4.285153550124266)
# ('#', 4845, 'Actual = ', 5, 'Predictioned = ', 4.110829225799942)
# ('#', 4846, 'Actual = ', 5, 'Predictioned = ', 2.5009069747818007)
# ('#', 4847, 'Actual = ', 5, 'Predictioned = ', 2.6065821215528375)
# ('#', 4848, 'Actual = ', 3, 'Predictioned = ', 3.935153550124266)
# ('#', 4849, 'Actual = ', 5, 'Predictioned = ', 3.544244459215175)
# ('#', 4850, 'Actual = ', 5, 'Predictioned = ', 3.1973157122864286)
# ('#', 4851, 'Actual = ', 5, 'Predictioned = ', 2.7494392644099808)
# ('#', 4852, 'Actual = ', 5, 'Predictioned = ', 2.0351535501242664)
# ('#', 4853, 'Actual = ', 5, 'Predictioned = ', 2.2851535501242664)
# ('#', 4854, 'Actual = ', 4, 'Predictioned = ', 4.227243945604492)
# ('#', 4855, 'Actual = ', 4, 'Predictioned = ', 5.201820216790932)
# ('#', 4856, 'Actual = ', 1, 'Predictioned = ', 4.035153550124266)
# ('#', 4857, 'Actual = ', 5, 'Predictioned = ', 4.479597994568711)
# ('#', 4858, 'Actual = ', 4, 'Predictioned = ', 6.600370941428614)
# ('#', 4859, 'Actual = ', 2, 'Predictioned = ', 7.035153550124266)
# ('#', 4860, 'Actual = ', 5, 'Predictioned = ', 3.635153550124266)
# ('#', 4861, 'Actual = ', 4, 'Predictioned = ', 3.8395013762112224)
# ('#', 4862, 'Actual = ', 4, 'Predictioned = ', 5.416105931076647)
# ('#', 4863, 'Actual = ', 5, 'Predictioned = ', 4.515773705163025)
# ('#', 4864, 'Actual = ', 3, 'Predictioned = ', 3.746692011662728)
# ('#', 4865, 'Actual = ', 5, 'Predictioned = ', 3.996692011662728)
# ('#', 4866, 'Actual = ', 4, 'Predictioned = ', 2.2018202167909333)
# ('#', 4867, 'Actual = ', 5, 'Predictioned = ', 2.646264661235377)
# ('#', 4868, 'Actual = ', 5, 'Predictioned = ', 3.183505198475914)
# ('#', 4869, 'Actual = ', 4, 'Predictioned = ', 3.206582121552837)
# ('#', 4870, 'Actual = ', 5, 'Predictioned = ', 4.196264661235377)
# ('#', 4871, 'Actual = ', 4, 'Predictioned = ', 3.668486883457599)
# ('#', 4872, 'Actual = ', 1, 'Predictioned = ', 3.2351535501242665)
# ('#', 4873, 'Actual = ', 5, 'Predictioned = ', 3.4351535501242663)
# ('#', 4874, 'Actual = ', 5, 'Predictioned = ', 3.168486883457599)
# ('#', 4875, 'Actual = ', 5, 'Predictioned = ', 3.5684868834575996)
# ('#', 4876, 'Actual = ', 2, 'Predictioned = ', 2.6157987114145893)
# ('#', 4877, 'Actual = ', 5, 'Predictioned = ', 2.216971731942448)
# ('#', 4878, 'Actual = ', 1, 'Predictioned = ', 3.0351535501242664)
# ('#', 4879, 'Actual = ', 1, 'Predictioned = ', 3.0351535501242664)
# ('#', 4880, 'Actual = ', 5, 'Predictioned = ', 4.203574602755845)
# ('#', 4881, 'Actual = ', 2, 'Predictioned = ', 5.635153550124266)
# ('#', 4882, 'Actual = ', 1, 'Predictioned = ', 2.2351535501242665)
# ('#', 4883, 'Actual = ', 3, 'Predictioned = ', 3.9851535501242665)
# ('#', 4884, 'Actual = ', 5, 'Predictioned = ', 2.9777765009439383)
# ('#', 4885, 'Actual = ', 5, 'Predictioned = ', 3.5351535501242664)
# ('#', 4886, 'Actual = ', 5, 'Predictioned = ', 3.3684868834575994)
# ('#', 4887, 'Actual = ', 5, 'Predictioned = ', 3.8184868834575996)
# ('#', 4888, 'Actual = ', 5, 'Predictioned = ', 2.7018202167909333)
# ('#', 4889, 'Actual = ', 5, 'Predictioned = ', 2.7018202167909333)
# ('#', 4890, 'Actual = ', 5, 'Predictioned = ', 4.8395013762112224)
# ('#', 4891, 'Actual = ', 5, 'Predictioned = ', 5.785153550124266)
# ('#', 4892, 'Actual = ', 3, 'Predictioned = ', 8.257375772346489)
# ('#', 4893, 'Actual = ', 4, 'Predictioned = ', 6.368486883457599)
# ('#', 4894, 'Actual = ', 5, 'Predictioned = ', 3.0351535501242664)
# ('#', 4895, 'Actual = ', 5, 'Predictioned = ', 2.528574602755845)
# ('#', 4896, 'Actual = ', 5, 'Predictioned = ', 3.4442444592151755)
# ('#', 4897, 'Actual = ', 4, 'Predictioned = ', 3.635153550124266)
# ('#', 4898, 'Actual = ', 2, 'Predictioned = ', 6.035153550124266)
# ('#', 4899, 'Actual = ', 4, 'Predictioned = ', 3.247274762245479)
# ('#', 4900, 'Actual = ', 5, 'Predictioned = ', 2.940626186940187)
# ('#', 4901, 'Actual = ', 2, 'Predictioned = ', 3.635153550124266)
# ('#', 4902, 'Actual = ', 4, 'Predictioned = ', 4.135153550124266)
# ('#', 4903, 'Actual = ', 5, 'Predictioned = ', 6.713724978695695)
# ('#', 4904, 'Actual = ', 1, 'Predictioned = ', 5.797058312029028)
# ('#', 4905, 'Actual = ', 5, 'Predictioned = ', 5.368486883457599)
# ('#', 4906, 'Actual = ', 5, 'Predictioned = ', 3.201820216790933)
# ('#', 4907, 'Actual = ', 5, 'Predictioned = ', 3.0351535501242664)
# ('#', 4908, 'Actual = ', 5, 'Predictioned = ', 2.635153550124266)
# ('#', 4909, 'Actual = ', 5, 'Predictioned = ', 2.0351535501242664)
# ('#', 4910, 'Actual = ', 2, 'Predictioned = ', 4.535153550124266)
# ('#', 4911, 'Actual = ', 5, 'Predictioned = ', 3.7208678358385514)
# ('#', 4912, 'Actual = ', 5, 'Predictioned = ', 3.229138512530281)
# ('#', 4913, 'Actual = ', 5, 'Predictioned = ', 2.885153550124266)
# ('#', 4914, 'Actual = ', 5, 'Predictioned = ', 2.8043843193550355)
# ('#', 4915, 'Actual = ', 5, 'Predictioned = ', 3.135153550124266)
# ('#', 4916, 'Actual = ', 5, 'Predictioned = ', 2.809572154775429)
# ('#', 4917, 'Actual = ', 5, 'Predictioned = ', 4.227243945604492)
# ('#', 4918, 'Actual = ', 4, 'Predictioned = ', 4.830852474855448)
# ('#', 4919, 'Actual = ', 4, 'Predictioned = ', 5.201820216790933)
# ('#', 4920, 'Actual = ', 4, 'Predictioned = ', 3.7018202167909333)
# ('#', 4921, 'Actual = ', 1, 'Predictioned = ', 6.368486883457599)
# ('#', 4922, 'Actual = ', 1, 'Predictioned = ', 7.2351535501242665)
# ('#', 4923, 'Actual = ', 5, 'Predictioned = ', 3.940626186940186)
# ('#', 4924, 'Actual = ', 5, 'Predictioned = ', 4.701820216790932)
# ('#', 4925, 'Actual = ', 1, 'Predictioned = ', 4.701820216790933)
# ('#', 4926, 'Actual = ', 1, 'Predictioned = ', 5.035153550124267)
# ('#', 4927, 'Actual = ', 5, 'Predictioned = ', 3.5351535501242664)
# ('#', 4928, 'Actual = ', 5, 'Predictioned = ', 3.5351535501242664)
# ('#', 4929, 'Actual = ', 3, 'Predictioned = ', 5.164185808188782)
# ('#', 4930, 'Actual = ', 5, 'Predictioned = ', 4.560577278937826)
# ('#', 4931, 'Actual = ', 5, 'Predictioned = ', 2.635153550124266)
# ('#', 4932, 'Actual = ', 5, 'Predictioned = ', 2.7684868834575997)
# ('#', 4933, 'Actual = ', 5, 'Predictioned = ', 3.0351535501242664)
# ('#', 4934, 'Actual = ', 5, 'Predictioned = ', 3.5351535501242664)
# ('#', 4935, 'Actual = ', 5, 'Predictioned = ', 4.035153550124266)
# ('#', 4936, 'Actual = ', 5, 'Predictioned = ', 4.135153550124266)
# ('#', 4937, 'Actual = ', 5, 'Predictioned = ', 5.573248788219503)
# ('#', 4938, 'Actual = ', 5, 'Predictioned = ', 6.42909294406366)
# ('#', 4939, 'Actual = ', 5, 'Predictioned = ', 3.396264661235377)
# ('#', 4940, 'Actual = ', 5, 'Predictioned = ', 3.320867835838552)
# ('#', 4941, 'Actual = ', 5, 'Predictioned = ', 4.368486883457599)
# ('#', 4942, 'Actual = ', 5, 'Predictioned = ', 3.9518202167909333)
# ('#', 4943, 'Actual = ', 5, 'Predictioned = ', 3.306471379581631)
# ('#', 4944, 'Actual = ', 5, 'Predictioned = ', 3.9276266684038363)
# ('#', 4945, 'Actual = ', 5, 'Predictioned = ', 3.9351535501242663)
# ('#', 4946, 'Actual = ', 4, 'Predictioned = ', 3.5351535501242664)
# ('#', 4947, 'Actual = ', 5, 'Predictioned = ', 3.2851535501242664)
# ('#', 4948, 'Actual = ', 5, 'Predictioned = ', 2.2018202167909333)
# ('#', 4949, 'Actual = ', 3, 'Predictioned = ', 6.381307396278112)
# ('#', 4950, 'Actual = ', 4, 'Predictioned = ', 6.15584320529668)
# ('#', 4951, 'Actual = ', 1, 'Predictioned = ', 4.6684868834576)
# ('#', 4952, 'Actual = ', 2, 'Predictioned = ', 4.570867835838552)
# ('#', 4953, 'Actual = ', 5, 'Predictioned = ', 3.6210121359828524)
# ('#', 4954, 'Actual = ', 5, 'Predictioned = ', 3.3684868834576)
# ('#', 4955, 'Actual = ', 1, 'Predictioned = ', 3.0351535501242664)
# ('#', 4956, 'Actual = ', 2, 'Predictioned = ', 3.2800515093079397)
# ('#', 4957, 'Actual = ', 5, 'Predictioned = ', 2.582521971176898)
# ('#', 4958, 'Actual = ', 2, 'Predictioned = ', 3.1351535501242664)
# ('#', 4959, 'Actual = ', 5, 'Predictioned = ', 3.635153550124266)
# ('#', 4960, 'Actual = ', 5, 'Predictioned = ', 4.063724978695694)
# ('#', 4961, 'Actual = ', 4, 'Predictioned = ', 3.8684868834575994)
# ('#', 4962, 'Actual = ', 1, 'Predictioned = ', 3.7851535501242664)
# ('#', 4963, 'Actual = ', 5, 'Predictioned = ', 4.275413290384007)
# ('#', 4964, 'Actual = ', 3, 'Predictioned = ', 5.045254560225277)
# ('#', 4965, 'Actual = ', 3, 'Predictioned = ', 3.4475959464376302)
# ('#', 4966, 'Actual = ', 5, 'Predictioned = ', 3.6780106929814096)
# ('#', 4967, 'Actual = ', 4, 'Predictioned = ', 2.3601535501242665)
# ('#', 4968, 'Actual = ', 5, 'Predictioned = ', 2.7190245178662016)
# ('#', 4969, 'Actual = ', 5, 'Predictioned = ', 4.168486883457599)
# ('#', 4970, 'Actual = ', 5, 'Predictioned = ', 3.0383897960789588)
# ('#', 4971, 'Actual = ', 4, 'Predictioned = ', 4.126062641033357)
# ('#', 4972, 'Actual = ', 3, 'Predictioned = ', 4.080608095578812)
# ('#', 4973, 'Actual = ', 5, 'Predictioned = ', 4.785153550124266)
# ('#', 4974, 'Actual = ', 5, 'Predictioned = ', 3.6184868834575994)
# ('#', 4975, 'Actual = ', 5, 'Predictioned = ', 2.5113440263147426)
# ('#', 4976, 'Actual = ', 5, 'Predictioned = ', 2.762426277396994)
# ('#', 4977, 'Actual = ', 5, 'Predictioned = ', 3.082772597743314)
# ('#', 4978, 'Actual = ', 5, 'Predictioned = ', 2.2851535501242664)
# ('#', 4979, 'Actual = ', 4, 'Predictioned = ', 3.3684868834575994)
# ('#', 4980, 'Actual = ', 4, 'Predictioned = ', 3.7018202167909333)
# ('#', 4981, 'Actual = ', 5, 'Predictioned = ', 2.8043843193550355)
# ('#', 4982, 'Actual = ', 5, 'Predictioned = ', 2.544587512388417)
# ('#', 4983, 'Actual = ', 5, 'Predictioned = ', 2.580608095578812)
# ('#', 4984, 'Actual = ', 5, 'Predictioned = ', 2.9065821215528374)
# ('#', 4985, 'Actual = ', 5, 'Predictioned = ', 4.285153550124266)
# ('#', 4986, 'Actual = ', 5, 'Predictioned = ', 2.9351535501242667)
# ('#', 4987, 'Actual = ', 5, 'Predictioned = ', 2.560577278937826)
# ('#', 4988, 'Actual = ', 5, 'Predictioned = ', 2.55896307393379)
# ('#', 4989, 'Actual = ', 5, 'Predictioned = ', 2.5351535501242664)
# ('#', 4990, 'Actual = ', 5, 'Predictioned = ', 2.0351535501242664)
# ('#', 4991, 'Actual = ', 5, 'Predictioned = ', 2.6551535501242665)
# ('#', 4992, 'Actual = ', 5, 'Predictioned = ', 2.0351535501242664)
# ('#', 4993, 'Actual = ', 5, 'Predictioned = ', 3.146264661235377)
# ('#', 4994, 'Actual = ', 4, 'Predictioned = ', 2.654201169171885)
# ('#', 4995, 'Actual = ', 4, 'Predictioned = ', 3.3907091056798215)
# ('#', 4996, 'Actual = ', 5, 'Predictioned = ', 3.1719956553874242)
# ('#', 4997, 'Actual = ', 4, 'Predictioned = ', 6.701820216790933)
# ('#', 4998, 'Actual = ', 4, 'Predictioned = ', 4.582521971176898)
# ('#', 4999, 'Actual = ', 5, 'Predictioned = ', 3.335153550124266)
# ('#', 5000, 'Actual = ', 4, 'Predictioned = ', 2.7396990046697205)
# Done Predicting in 1.2 seconds

# %%
print "MAE=", MAE
print "RMSE=", RMSE
# Out:
# MAE= 1.62
# RMSE= 1.99

# %%
sparse_ratings = csr_matrix(ratings_matrix, dtype='float')

# %%
model_knn = NearestNeighbors(metric = 'cosine', n_neighbors = 6)
model_knn.fit(sparse_ratings)
# Out:
# NearestNeighbors(algorithm='auto', leaf_size=30, metric='cosine',
#          metric_params=None, n_jobs=1, n_neighbors=6, p=2, radius=1.0)

# %%
def get_recommendations(user_index, n_reccomendations=5, n_neighbors=10):
    distances,indices = model_knn.kneighbors(ratings_matrix[user_index].reshape(1, -1), n_neighbors=n_neighbors)
    probable_items = list()
    for user in indices[0]:
        if user == user_index:
            print "Recommendations for user ", unique_users[user_index]
            continue
        # all other users
        for items in np.nonzero(ratings_matrix[user]):
            for item in items:
                if ratings_matrix[user_index][item] == 0:
                    probable_items.append(unique_items[item])

    predictions = {}
    for item in probable_items:
        predictions[item] = predict(unique_users[0], item)
        sorted_predictions = sorted(predictions.items(), key=operator.itemgetter(1))
    return [i[0] for i in sorted_predictions[:n_reccomendations]]

# %%
def get_user_items_rated_df(user_id):
    df = pd.DataFrame()
    np.nonzero(ratings_matrix[user_id])
    for i in np.nonzero(ratings_matrix[user_id]):
        x = pd.DataFrame({"item":unique_items[i], "rating":ratings_matrix[user_id][i]})
        df = df.append(x)
        return df

def print_items_rated(user_id):
    np.nonzero(ratings_matrix[user_id])
    for i in unique_items[np.nonzero(ratings_matrix[user_id])]:
        print i

# %%
get_user_items_rated_df(0)
# Out:
#          item rating
# 0  B004WGGQPQ      5
# 1  B006C1ZSO4      5
# 2  B007KPT2N4      1
# 3  B0080JJLBW      5
# 4  B008LY1B32      4
# 5  B009P8EMCK      5
# 6  B00AMR1HZ8      4
# 7  B00ANT8OF6      4

# %%
for i in get_recommendations(user_index=1):
    print i
# Out:
# Recommendations for user  A001619027H9L9EG4UVRB
# ('Choosing 5 out of ', 23)
# B008V06NRU
# B009UX2YAC
# B00A6S051A
# B00HEJZ1KO
# B00ED4TX2A
