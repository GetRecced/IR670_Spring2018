# %%
# Imports 
import pandas as pd
import numpy as np
import time
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.neighbors import NearestNeighbors
from scipy.sparse import csr_matrix
import operator

# %%
# load the data, keep only selected columns
# Read the file using super fast Pandas.read_csv
def load_required_data(path, required_columns):
    dataframe = pd.read_json(path, lines=True)
    dataframe = dataframe[required_columns]
    return dataframe, dataframe.values

# %%
dataframe, values = load_required_data('train_15000.json', ["asin", "reviewerID", "overall"])

# %%
dataframe[:10]
# Out:
#          asin             reviewerID  overall
# 0  B00ANT8OF6  A00100742Q4O8VH0YMUBZ        4
# 1  B00AMR1HZ8  A00100742Q4O8VH0YMUBZ        4
# 2  B004WGGQPQ  A00100742Q4O8VH0YMUBZ        5
# 3  B006C1ZSO4  A00100742Q4O8VH0YMUBZ        5
# 4  B008LY1B32  A00100742Q4O8VH0YMUBZ        4
# 5  B007KPT2N4  A00100742Q4O8VH0YMUBZ        1
# 6  B0080JJLBW  A00100742Q4O8VH0YMUBZ        5
# 7  B009P8EMCK  A00100742Q4O8VH0YMUBZ        5
# 8  B00I8Q77Y0  A001619027H9L9EG4UVRB        5
# 9  B00H0BGCJK  A001619027H9L9EG4UVRB        5

# %%
dataframe.shape
# Out:
# (15000, 3)

# %%
# Create user-item matrix given a matrix and mapping from original matrix columns to new matrix rows/columns
def create_user_item_matrix(data, rowMapping, columnMapping):
    # Create table of users to items by taking row and column pivots
    # Rows of user-item table are users
    rows, row_pos = np.unique(data[:, rowMapping], return_inverse=True)
    # Columns of user-item table are movies
    cols, col_pos = np.unique(data[:, columnMapping], return_inverse=True)

    pivot_table = np.zeros((len(rows), len(cols)), dtype=data.dtype)
    pivot_table[row_pos, col_pos] = data[:, 2]
    return pivot_table, rows, cols

# %%
ratings_matrix, rows, cols = create_user_item_matrix(values, rowMapping=1, columnMapping=0)
print (ratings_matrix.shape)
# Out:
# (3139, 1842)

# %%
pd.DataFrame(ratings_matrix[:10], index = rows[:10], columns= cols)
# Out:
#                       B004ALVL6W B004ANMWPY B004DLNC4I B004DLPXAO B004DM1OAQ  \
# A00100742Q4O8VH0YMUBZ          0          0          0          0          0
# A001619027H9L9EG4UVRB          0          0          0          0          0
# A002359833QJM7OQHCXWY          0          0          0          0          0
# A0037670NPLI11RBWYFA           0          0          0          0          0
# A003841815JTX0JFLR8B1          0          0          0          0          0
# A0038872349TB5N0JHQQW          0          0          0          0          0
# A00455683H6M1GQZMPQPV          0          0          0          0          0
# A0047670XAAJD587LXS7           0          0          0          0          0
# A00501041JRAPWYLPQ4TE          0          0          0          0          0
# A00507662MEMHI1YMGQ15          0          0          0          0          0
#
#                       B004DM1ZQY B004DPBGCO B004DPC5Y2 B004DPCSKI B004DPIEF6  \
# A00100742Q4O8VH0YMUBZ          0          0          0          0          0
# A001619027H9L9EG4UVRB          0          0          0          0          0
# A002359833QJM7OQHCXWY          0          0          0          0          0
# A0037670NPLI11RBWYFA           0          0          0          0          0
# A003841815JTX0JFLR8B1          0          0          0          0          0
# A0038872349TB5N0JHQQW          0          0          0          0          0
# A00455683H6M1GQZMPQPV          0          0          0          0          0
# A0047670XAAJD587LXS7           0          0          0          0          0
# A00501041JRAPWYLPQ4TE          0          0          0          0          0
# A00507662MEMHI1YMGQ15          0          0          0          0          0
#
#                          ...     B00K7WGUKA B00KFNXUY0 B00KGCNRAM B00KI5Q8X0  \
# A00100742Q4O8VH0YMUBZ    ...              0          0          0          0
# A001619027H9L9EG4UVRB    ...              0          0          0          0
# A002359833QJM7OQHCXWY    ...              0          0          0          0
# A0037670NPLI11RBWYFA     ...              0          0          0          0
# A003841815JTX0JFLR8B1    ...              0          0          0          0
# A0038872349TB5N0JHQQW    ...              0          0          0          0
# A00455683H6M1GQZMPQPV    ...              0          0          0          0
# A0047670XAAJD587LXS7     ...              0          0          0          0
# A00501041JRAPWYLPQ4TE    ...              0          0          0          0
# A00507662MEMHI1YMGQ15    ...              0          0          0          0
#
#                       B00KMX5V8G B00KOEHQCW B00KQHVWWC B00KSOQ66K B00KWVZ750  \
# A00100742Q4O8VH0YMUBZ          0          0          0          0          0
# A001619027H9L9EG4UVRB          0          0          0          0          0
# A002359833QJM7OQHCXWY          0          0          0          0          0
# A0037670NPLI11RBWYFA           0          0          0          0          0
# A003841815JTX0JFLR8B1          0          0          0          0          0
# A0038872349TB5N0JHQQW          0          0          0          0          0
# A00455683H6M1GQZMPQPV          0          0          0          0          5
# A0047670XAAJD587LXS7           0          0          0          0          0
# A00501041JRAPWYLPQ4TE          0          0          0          0          0
# A00507662MEMHI1YMGQ15          0          0          0          0          0
#
#                       B00L3MNCNQ
# A00100742Q4O8VH0YMUBZ          0
# A001619027H9L9EG4UVRB          0
# A002359833QJM7OQHCXWY          0
# A0037670NPLI11RBWYFA           0
# A003841815JTX0JFLR8B1          0
# A0038872349TB5N0JHQQW          0
# A00455683H6M1GQZMPQPV          0
# A0047670XAAJD587LXS7           0
# A00501041JRAPWYLPQ4TE          0
# A00507662MEMHI1YMGQ15          0
#
# [10 rows x 1842 columns]

# %%
def get_index_map(arr):
    index_map = {}
    for el in arr:
        index_map[el] = len(index_map)
    return index_map

# %%
# Get unique movies and users
unique_items = np.unique(values[:,0])
unique_users = np.unique(values[:,1])

# %%
unique_items.shape
# Out:
# (1842,)

# %%
unique_users.shape
# Out:
# (3139,)

# %%
mean_overall = np.true_divide(ratings_matrix.sum(),(ratings_matrix!=0).sum())

# %%
def get_users_who_rated_item(item_id):
    return np.where(ratings_matrix[:,item_idx_map[item_id]] > 0)[0]

def get_users_who_rated_item_by_index(item_idx):
    return np.where(ratings_matrix[:,item_idx] > 0)

def predict(user_id, item_id):
    return mean_overall

# %%
test_dataframe, test_values = load_required_data('test_5000.json', ["asin", "reviewerID", "overall"])

# %%
test_dataframe['reviewerID'].unique().shape
# Out:
# (2507,)

# %%
# Returns DF containing predictions, MAE, RMSE
def get_predictions(dataframe):
    df = dataframe.copy()
    print ("Predicting ratings..")
    start_time = time.time()
    df['Prediction'] = df.apply(lambda row: predict_row(row) , axis=1)
    MAE = round(mean_absolute_error(df['overall'], df['Prediction']), 2)
    RMSE = round(np.sqrt(mean_squared_error(df['overall'], df['Prediction'])), 2)
    print "Done Predicting in",  round((time.time() - start_time), 2), "seconds"
    return df, MAE, RMSE

i = 0
def predict_row(row):
    global i
    i+= 1
    prediction = predict(row['reviewerID'], row['asin'])
    print ("#", i, "Actual = ", row['overall'], "Predictioned = ", prediction)
    return prediction

# %%
df, MAE, RMSE = get_predictions(test_dataframe)
# Out:
# Predicting ratings..
# ('#', 1, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 2, 'Actual = ', 2, 'Predictioned = ', 4.0581333333333331)
# ('#', 3, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 5, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 6, 'Actual = ', 3, 'Predictioned = ', 4.0581333333333331)
# ('#', 7, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 8, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 9, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 10, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 11, 'Actual = ', 1, 'Predictioned = ', 4.0581333333333331)
# ('#', 12, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 13, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 14, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 15, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 16, 'Actual = ', 1, 'Predictioned = ', 4.0581333333333331)
# ('#', 17, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 18, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 19, 'Actual = ', 3, 'Predictioned = ', 4.0581333333333331)
# ('#', 20, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 21, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 22, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 23, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 24, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 25, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 26, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 27, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 28, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 29, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 30, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 31, 'Actual = ', 1, 'Predictioned = ', 4.0581333333333331)
# ('#', 32, 'Actual = ', 1, 'Predictioned = ', 4.0581333333333331)
# ('#', 33, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 34, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 35, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 36, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 37, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 38, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 39, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 40, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 41, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 42, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 43, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 44, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 45, 'Actual = ', 1, 'Predictioned = ', 4.0581333333333331)
# ('#', 46, 'Actual = ', 1, 'Predictioned = ', 4.0581333333333331)
# ('#', 47, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 48, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 49, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 50, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 51, 'Actual = ', 3, 'Predictioned = ', 4.0581333333333331)
# ('#', 52, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 53, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 54, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 55, 'Actual = ', 3, 'Predictioned = ', 4.0581333333333331)
# ('#', 56, 'Actual = ', 2, 'Predictioned = ', 4.0581333333333331)
# ('#', 57, 'Actual = ', 1, 'Predictioned = ', 4.0581333333333331)
# ('#', 58, 'Actual = ', 3, 'Predictioned = ', 4.0581333333333331)
# ('#', 59, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 60, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 61, 'Actual = ', 3, 'Predictioned = ', 4.0581333333333331)
# ('#', 62, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 63, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 64, 'Actual = ', 3, 'Predictioned = ', 4.0581333333333331)
# ('#', 65, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 66, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 67, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 68, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 69, 'Actual = ', 1, 'Predictioned = ', 4.0581333333333331)
# ('#', 70, 'Actual = ', 1, 'Predictioned = ', 4.0581333333333331)
# ('#', 71, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 72, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 73, 'Actual = ', 3, 'Predictioned = ', 4.0581333333333331)
# ('#', 74, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 75, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 76, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 77, 'Actual = ', 3, 'Predictioned = ', 4.0581333333333331)
# ('#', 78, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 79, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 80, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 81, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 82, 'Actual = ', 3, 'Predictioned = ', 4.0581333333333331)
# ('#', 83, 'Actual = ', 1, 'Predictioned = ', 4.0581333333333331)
# ('#', 84, 'Actual = ', 1, 'Predictioned = ', 4.0581333333333331)
# ('#', 85, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 86, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 87, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 88, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 89, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 90, 'Actual = ', 3, 'Predictioned = ', 4.0581333333333331)
# ('#', 91, 'Actual = ', 2, 'Predictioned = ', 4.0581333333333331)
# ('#', 92, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 93, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 94, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 95, 'Actual = ', 2, 'Predictioned = ', 4.0581333333333331)
# ('#', 96, 'Actual = ', 3, 'Predictioned = ', 4.0581333333333331)
# ('#', 97, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 98, 'Actual = ', 1, 'Predictioned = ', 4.0581333333333331)
# ('#', 99, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 100, 'Actual = ', 2, 'Predictioned = ', 4.0581333333333331)
# ('#', 101, 'Actual = ', 1, 'Predictioned = ', 4.0581333333333331)
# ('#', 102, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 103, 'Actual = ', 3, 'Predictioned = ', 4.0581333333333331)
# ('#', 104, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 105, 'Actual = ', 2, 'Predictioned = ', 4.0581333333333331)
# ('#', 106, 'Actual = ', 3, 'Predictioned = ', 4.0581333333333331)
# ('#', 107, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 108, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 109, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 110, 'Actual = ', 2, 'Predictioned = ', 4.0581333333333331)
# ('#', 111, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 112, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 113, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 114, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 115, 'Actual = ', 3, 'Predictioned = ', 4.0581333333333331)
# ('#', 116, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 117, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 118, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 119, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 120, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 121, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 122, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 123, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 124, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 125, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 126, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 127, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 128, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 129, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 130, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 131, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 132, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 133, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 134, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 135, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 136, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 137, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 138, 'Actual = ', 3, 'Predictioned = ', 4.0581333333333331)
# ('#', 139, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 140, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 141, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 142, 'Actual = ', 1, 'Predictioned = ', 4.0581333333333331)
# ('#', 143, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 144, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#',
 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 4921, 'Actual = ', 1, 'Predictioned = ', 4.0581333333333331)
# ('#', 4922, 'Actual = ', 1, 'Predictioned = ', 4.0581333333333331)
# ('#', 4923, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4924, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4925, 'Actual = ', 1, 'Predictioned = ', 4.0581333333333331)
# ('#', 4926, 'Actual = ', 1, 'Predictioned = ', 4.0581333333333331)
# ('#', 4927, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4928, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4929, 'Actual = ', 3, 'Predictioned = ', 4.0581333333333331)
# ('#', 4930, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4931, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4932, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4933, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4934, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4935, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4936, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4937, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4938, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4939, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4940, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4941, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4942, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4943, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4944, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4945, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4946, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 4947, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4948, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4949, 'Actual = ', 3, 'Predictioned = ', 4.0581333333333331)
# ('#', 4950, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 4951, 'Actual = ', 1, 'Predictioned = ', 4.0581333333333331)
# ('#', 4952, 'Actual = ', 2, 'Predictioned = ', 4.0581333333333331)
# ('#', 4953, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4954, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4955, 'Actual = ', 1, 'Predictioned = ', 4.0581333333333331)
# ('#', 4956, 'Actual = ', 2, 'Predictioned = ', 4.0581333333333331)
# ('#', 4957, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4958, 'Actual = ', 2, 'Predictioned = ', 4.0581333333333331)
# ('#', 4959, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4960, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4961, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 4962, 'Actual = ', 1, 'Predictioned = ', 4.0581333333333331)
# ('#', 4963, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4964, 'Actual = ', 3, 'Predictioned = ', 4.0581333333333331)
# ('#', 4965, 'Actual = ', 3, 'Predictioned = ', 4.0581333333333331)
# ('#', 4966, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4967, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 4968, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4969, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4970, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4971, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 4972, 'Actual = ', 3, 'Predictioned = ', 4.0581333333333331)
# ('#', 4973, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4974, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4975, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4976, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4977, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4978, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4979, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 4980, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 4981, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4982, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4983, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4984, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4985, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4986, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4987, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4988, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4989, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4990, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4991, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4992, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4993, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4994, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 4995, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 4996, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 4997, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 4998, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# ('#', 4999, 'Actual = ', 5, 'Predictioned = ', 4.0581333333333331)
# ('#', 5000, 'Actual = ', 4, 'Predictioned = ', 4.0581333333333331)
# Done Predicting in 1.69 seconds

# %%
print "MAE=", MAE
print "RMSE=", RMSE
# Out:
# MAE= 0.98
# RMSE= 1.26

# %%
sparse_ratings = csr_matrix(ratings_matrix, dtype='float')

# %%
model_knn = NearestNeighbors(metric = 'cosine', n_neighbors = 6)
model_knn.fit(sparse_ratings)
# Out:
# NearestNeighbors(algorithm='auto', leaf_size=30, metric='cosine',
#          metric_params=None, n_jobs=1, n_neighbors=6, p=2, radius=1.0)

# %%
def get_recommendations(user_index, n_reccomendations=5, n_neighbors=10):
    distances,indices = model_knn.kneighbors(ratings_matrix[user_index].reshape(1, -1), n_neighbors=n_neighbors)
    probable_items = list()
    for user in indices[0]:
        if user == user_index:
            #print "Recommendations for user ", unique_users[user_index]
            continue
        # all other users
        for items in np.nonzero(ratings_matrix[user]):
            for item in items:
                if ratings_matrix[user_index][item] == 0:
                    probable_items.append(unique_items[item])

    predictions = {}
    for item in probable_items:
        predictions[item] = predict(unique_users[0], item)
        sorted_predictions = sorted(predictions.items(), key=operator.itemgetter(1))
    return [i[0] for i in sorted_predictions[:n_reccomendations]]

# %%
def get_user_items_rated_df(user_id):
    df = pd.DataFrame()
    np.nonzero(ratings_matrix[user_id])
    for i in np.nonzero(ratings_matrix[user_id]):
        x = pd.DataFrame({"item":unique_items[i], "rating":ratings_matrix[user_id][i]})
        df = df.append(x)
        return df

def print_items_rated(user_id):
    np.nonzero(ratings_matrix[user_id])
    for i in unique_items[np.nonzero(ratings_matrix[user_id])]:
        print i

# %%
get_user_items_rated_df(0)
# Out:
#          item rating
# 0  B004WGGQPQ      5
# 1  B006C1ZSO4      5
# 2  B007KPT2N4      1
# 3  B0080JJLBW      5
# 4  B008LY1B32      4
# 5  B009P8EMCK      5
# 6  B00AMR1HZ8      4
# 7  B00ANT8OF6      4

# %%
print get_recommendations(user_index=0)
import asin_to_rec
asin_to_rec.get_recommendation_items(get_recommendations(user_index=0)[:2])
# Out:
# [u'B0064TVQ5E', u'B00ARRDTX6', u'B00A13BI7U', u'B008Y7SMQU', u'B006D1ONE4']
