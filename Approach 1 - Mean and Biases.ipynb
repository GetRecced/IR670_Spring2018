# %%
# Imports 
import pandas as pd
import numpy as np
import time
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.neighbors import NearestNeighbors
from scipy.sparse import csr_matrix
import operator

# %%
# load the data, keep only selected columns
# Read the file using super fast Pandas.read_csv
def load_required_data(path, required_columns):
    dataframe = pd.read_json(path, lines=True)
    dataframe = dataframe[required_columns]
    return dataframe, dataframe.values

# %%
dataframe, values = load_required_data('train_15000.json', ["asin", "reviewerID", "overall"])

# %%
dataframe[:10]
# Out:
#          asin             reviewerID  overall
# 0  B00ANT8OF6  A00100742Q4O8VH0YMUBZ        4
# 1  B00AMR1HZ8  A00100742Q4O8VH0YMUBZ        4
# 2  B004WGGQPQ  A00100742Q4O8VH0YMUBZ        5
# 3  B006C1ZSO4  A00100742Q4O8VH0YMUBZ        5
# 4  B008LY1B32  A00100742Q4O8VH0YMUBZ        4
# 5  B007KPT2N4  A00100742Q4O8VH0YMUBZ        1
# 6  B0080JJLBW  A00100742Q4O8VH0YMUBZ        5
# 7  B009P8EMCK  A00100742Q4O8VH0YMUBZ        5
# 8  B00I8Q77Y0  A001619027H9L9EG4UVRB        5
# 9  B00H0BGCJK  A001619027H9L9EG4UVRB        5

# %%
dataframe.shape
# Out:
# (15000, 3)

# %%
# Create user-item matrix given a matrix and mapping from original matrix columns to new matrix rows/columns
def create_user_item_matrix(data, rowMapping, columnMapping):
    # Create table of users to items by taking row and column pivots
    # Rows of user-item table are users
    rows, row_pos = np.unique(data[:, rowMapping], return_inverse=True)
    # Columns of user-item table are movies
    cols, col_pos = np.unique(data[:, columnMapping], return_inverse=True)

    pivot_table = np.zeros((len(rows), len(cols)), dtype=data.dtype)
    pivot_table[row_pos, col_pos] = data[:, 2]
    return pivot_table, rows, cols

# %%
ratings_matrix, rows, cols = create_user_item_matrix(values, rowMapping=1, columnMapping=0)
print (ratings_matrix.shape)
# Out:
# (3139, 1842)

# %%
pd.DataFrame(ratings_matrix[:10], index = rows[:10], columns= cols)
# Out:
#                       B004ALVL6W B004ANMWPY B004DLNC4I B004DLPXAO B004DM1OAQ  \
# A00100742Q4O8VH0YMUBZ          0          0          0          0          0
# A001619027H9L9EG4UVRB          0          0          0          0          0
# A002359833QJM7OQHCXWY          0          0          0          0          0
# A0037670NPLI11RBWYFA           0          0          0          0          0
# A003841815JTX0JFLR8B1          0          0          0          0          0
# A0038872349TB5N0JHQQW          0          0          0          0          0
# A00455683H6M1GQZMPQPV          0          0          0          0          0
# A0047670XAAJD587LXS7           0          0          0          0          0
# A00501041JRAPWYLPQ4TE          0          0          0          0          0
# A00507662MEMHI1YMGQ15          0          0          0          0          0
#
#                       B004DM1ZQY B004DPBGCO B004DPC5Y2 B004DPCSKI B004DPIEF6  \
# A00100742Q4O8VH0YMUBZ          0          0          0          0          0
# A001619027H9L9EG4UVRB          0          0          0          0          0
# A002359833QJM7OQHCXWY          0          0          0          0          0
# A0037670NPLI11RBWYFA           0          0          0          0          0
# A003841815JTX0JFLR8B1          0          0          0          0          0
# A0038872349TB5N0JHQQW          0          0          0          0          0
# A00455683H6M1GQZMPQPV          0          0          0          0          0
# A0047670XAAJD587LXS7           0          0          0          0          0
# A00501041JRAPWYLPQ4TE          0          0          0          0          0
# A00507662MEMHI1YMGQ15          0          0          0          0          0
#
#                          ...     B00K7WGUKA B00KFNXUY0 B00KGCNRAM B00KI5Q8X0  \
# A00100742Q4O8VH0YMUBZ    ...              0          0          0          0
# A001619027H9L9EG4UVRB    ...              0          0          0          0
# A002359833QJM7OQHCXWY    ...              0          0          0          0
# A0037670NPLI11RBWYFA     ...              0          0          0          0
# A003841815JTX0JFLR8B1    ...              0          0          0          0
# A0038872349TB5N0JHQQW    ...              0          0          0          0
# A00455683H6M1GQZMPQPV    ...              0          0          0          0
# A0047670XAAJD587LXS7     ...              0          0          0          0
# A00501041JRAPWYLPQ4TE    ...              0          0          0          0
# A00507662MEMHI1YMGQ15    ...              0          0          0          0
#
#                       B00KMX5V8G B00KOEHQCW B00KQHVWWC B00KSOQ66K B00KWVZ750  \
# A00100742Q4O8VH0YMUBZ          0          0          0          0          0
# A001619027H9L9EG4UVRB          0          0          0          0          0
# A002359833QJM7OQHCXWY          0          0          0          0          0
# A0037670NPLI11RBWYFA           0          0          0          0          0
# A003841815JTX0JFLR8B1          0          0          0          0          0
# A0038872349TB5N0JHQQW          0          0          0          0          0
# A00455683H6M1GQZMPQPV          0          0          0          0          5
# A0047670XAAJD587LXS7           0          0          0          0          0
# A00501041JRAPWYLPQ4TE          0          0          0          0          0
# A00507662MEMHI1YMGQ15          0          0          0          0          0
#
#                       B00L3MNCNQ
# A00100742Q4O8VH0YMUBZ          0
# A001619027H9L9EG4UVRB          0
# A002359833QJM7OQHCXWY          0
# A0037670NPLI11RBWYFA           0
# A003841815JTX0JFLR8B1          0
# A0038872349TB5N0JHQQW          0
# A00455683H6M1GQZMPQPV          0
# A0047670XAAJD587LXS7           0
# A00501041JRAPWYLPQ4TE          0
# A00507662MEMHI1YMGQ15          0
#
# [10 rows x 1842 columns]

# %%
def get_index_map(arr):
    index_map = {}
    for el in arr:
        index_map[el] = len(index_map)
    return index_map

# %%
# Get unique movies and users
unique_items = np.unique(values[:,0])
unique_users = np.unique(values[:,1])

# %%
unique_items.shape
# Out:
# (1842,)

# %%
unique_users.shape
# Out:
# (3139,)

# %%
# Create mapping from unique list to 
item_idx_map = get_index_map(unique_items)
user_idx_map = get_index_map(unique_users)

# %%
mean_users = np.true_divide(ratings_matrix.sum(1), (ratings_matrix!=0).sum(1))
mean_items = np.true_divide(ratings_matrix.sum(0),(ratings_matrix!=0).sum(0))
mean_overall = np.true_divide(ratings_matrix.sum(),(ratings_matrix!=0).sum())

# %%
def get_users_who_rated_item(item_id):
    return np.where(ratings_matrix[:,item_idx_map[item_id]] > 0)[0]

def get_users_who_rated_item_by_index(item_idx):
    return np.where(ratings_matrix[:,item_idx] > 0)

def predict(user_id, item_id):
    item_idx = item_idx_map[item_id]
    user_idx = user_idx_map[user_id]
    bias_user = mean_users[user_idx] - mean_overall
    bias_item = mean_items[item_idx] - mean_overall
    return mean_overall + bias_user + bias_item

# %%
test_dataframe, test_values = load_required_data('test_5000.json', ["asin", "reviewerID", "overall"])

# %%
test_dataframe['reviewerID'].unique().shape
# Out:
# (2507,)

# %%
# Returns DF containing predictions, MAE, RMSE
def get_predictions(dataframe):
    df = dataframe.copy()
    print ("Predicting ratings..")
    start_time = time.time()
    df['Prediction'] = df.apply(lambda row: predict_row(row) , axis=1)
    MAE = round(mean_absolute_error(df['overall'], df['Prediction']), 2)
    RMSE = round(np.sqrt(mean_squared_error(df['overall'], df['Prediction'])), 2)
    print "Done Predicting in",  round((time.time() - start_time), 2), "seconds"
    return df, MAE, RMSE

i = 0
def predict_row(row):
    global i
    i+= 1
    prediction = predict(row['reviewerID'], row['asin'])
    print ("#", i, "Actual = ", row['overall'], "Predictioned = ", prediction)
    return prediction

# %%
df, MAE, RMSE = get_predictions(test_dataframe)
# Out:
# Predicting ratings..
# ('#', 1, 'Actual = ', 5, 'Predictioned = ', 5.066866666666667)
# ('#', 2, 'Actual = ', 2, 'Predictioned = ', 3.289088888888889)
# ('#', 3, 'Actual = ', 5, 'Predictioned = ', 4.2752)
# ('#', 4, 'Actual = ', 5, 'Predictioned = ', 5.7196444444444445)
# ('#', 5, 'Actual = ', 5, 'Predictioned = ', 4.591866666666667)
# ('#', 6, 'Actual = ', 3, 'Predictioned = ', 4.8977490196078435)
# ('#', 7, 'Actual = ', 5, 'Predictioned = ', 3.941866666666667)
# ('#', 8, 'Actual = ', 4, 'Predictioned = ', 3.073445614035088)
# ('#', 9, 'Actual = ', 5, 'Predictioned = ', 5.513295238095238)
# ('#', 10, 'Actual = ', 5, 'Predictioned = ', 5.605024561403509)
# ('#', 11, 'Actual = ', 1, 'Predictioned = ', 2.641866666666667)
# ('#', 12, 'Actual = ', 4, 'Predictioned = ', 4.2752)
# ('#', 13, 'Actual = ', 5, 'Predictioned = ', 4.908533333333334)
# ('#', 14, 'Actual = ', 5, 'Predictioned = ', 4.841866666666666)
# ('#', 15, 'Actual = ', 4, 'Predictioned = ', 4.312237037037037)
# ('#', 16, 'Actual = ', 1, 'Predictioned = ', 4.156152380952381)
# ('#', 17, 'Actual = ', 5, 'Predictioned = ', 0.19186666666666685)
# ('#', 18, 'Actual = ', 4, 'Predictioned = ', 0.8128344086021508)
# ('#', 19, 'Actual = ', 3, 'Predictioned = ', 2.941866666666667)
# ('#', 20, 'Actual = ', 4, 'Predictioned = ', 3.799009523809524)
# ('#', 21, 'Actual = ', 5, 'Predictioned = ', 4.941866666666667)
# ('#', 22, 'Actual = ', 5, 'Predictioned = ', 5.172635897435898)
# ('#', 23, 'Actual = ', 4, 'Predictioned = ', 4.941866666666667)
# ('#', 24, 'Actual = ', 4, 'Predictioned = ', 4.205432558139535)
# ('#', 25, 'Actual = ', 5, 'Predictioned = ', 3.968182456140351)
# ('#', 26, 'Actual = ', 5, 'Predictioned = ', 3.7752)
# ('#', 27, 'Actual = ', 5, 'Predictioned = ', 5.608533333333334)
# ('#', 28, 'Actual = ', 4, 'Predictioned = ', 4.572819047619048)
# ('#', 29, 'Actual = ', 5, 'Predictioned = ', 3.691866666666667)
# ('#', 30, 'Actual = ', 4, 'Predictioned = ', 4.7752)
# ('#', 31, 'Actual = ', 1, 'Predictioned = ', 1.9418666666666669)
# ('#', 32, 'Actual = ', 1, 'Predictioned = ', 1.8168666666666669)
# ('#', 33, 'Actual = ', 5, 'Predictioned = ', 4.441866666666667)
# ('#', 34, 'Actual = ', 5, 'Predictioned = ', 4.941866666666667)
# ('#', 35, 'Actual = ', 4, 'Predictioned = ', 4.2752)
# ('#', 36, 'Actual = ', 5, 'Predictioned = ', 4.874299099099099)
# ('#', 37, 'Actual = ', 5, 'Predictioned = ', 5.941866666666667)
# ('#', 38, 'Actual = ', 5, 'Predictioned = ', 4.2752)
# ('#', 39, 'Actual = ', 4, 'Predictioned = ', 5.330755555555556)
# ('#', 40, 'Actual = ', 5, 'Predictioned = ', 4.683802150537635)
# ('#', 41, 'Actual = ', 5, 'Predictioned = ', 3.894247619047619)
# ('#', 42, 'Actual = ', 5, 'Predictioned = ', 4.827580952380952)
# ('#', 43, 'Actual = ', 5, 'Predictioned = ', 3.941866666666667)
# ('#', 44, 'Actual = ', 5, 'Predictioned = ', 4.141866666666667)
# ('#', 45, 'Actual = ', 1, 'Predictioned = ', 5.941866666666667)
# ('#', 46, 'Actual = ', 1, 'Predictioned = ', 2.608533333333334)
# ('#', 47, 'Actual = ', 4, 'Predictioned = ', 3.191866666666667)
# ('#', 48, 'Actual = ', 5, 'Predictioned = ', 3.191866666666667)
# ('#', 49, 'Actual = ', 5, 'Predictioned = ', 4.441866666666667)
# ('#', 50, 'Actual = ', 5, 'Predictioned = ', 5.941866666666667)
# ('#', 51, 'Actual = ', 3, 'Predictioned = ', 3.941866666666667)
# ('#', 52, 'Actual = ', 4, 'Predictioned = ', 4.441866666666667)
# ('#', 53, 'Actual = ', 5, 'Predictioned = ', 5.2752)
# ('#', 54, 'Actual = ', 5, 'Predictioned = ', 5.0752)
# ('#', 55, 'Actual = ', 3, 'Predictioned = ', 4.941866666666667)
# ('#', 56, 'Actual = ', 2, 'Predictioned = ', 4.626077192982456)
# ('#', 57, 'Actual = ', 1, 'Predictioned = ', 5.2085333333333335)
# ('#', 58, 'Actual = ', 3, 'Predictioned = ', 3.7824463768115946)
# ('#', 59, 'Actual = ', 5, 'Predictioned = ', 5.244075502008033)
# ('#', 60, 'Actual = ', 4, 'Predictioned = ', 5.358533333333334)
# ('#', 61, 'Actual = ', 3, 'Predictioned = ', 4.0252)
# ('#', 62, 'Actual = ', 5, 'Predictioned = ', 4.8751999999999995)
# ('#', 63, 'Actual = ', 5, 'Predictioned = ', 5.427580952380953)
# ('#', 64, 'Actual = ', 3, 'Predictioned = ', 4.608533333333334)
# ('#', 65, 'Actual = ', 5, 'Predictioned = ', 3.566866666666667)
# ('#', 66, 'Actual = ', 5, 'Predictioned = ', 0.9418666666666669)
# ('#', 67, 'Actual = ', 5, 'Predictioned = ', 4.691866666666667)
# ('#', 68, 'Actual = ', 5, 'Predictioned = ', 5.830755555555556)
# ('#', 69, 'Actual = ', 1, 'Predictioned = ', 5.2752)
# ('#', 70, 'Actual = ', 1, 'Predictioned = ', 4.691866666666667)
# ('#', 71, 'Actual = ', 5, 'Predictioned = ', 3.297422222222222)
# ('#', 72, 'Actual = ', 5, 'Predictioned = ', 3.608533333333334)
# ('#', 73, 'Actual = ', 3, 'Predictioned = ', 3.6726358974358977)
# ('#', 74, 'Actual = ', 4, 'Predictioned = ', 3.1085333333333334)
# ('#', 75, 'Actual = ', 5, 'Predictioned = ', 2.4275809523809526)
# ('#', 76, 'Actual = ', 4, 'Predictioned = ', 0.9418666666666669)
# ('#', 77, 'Actual = ', 3, 'Predictioned = ', 3.691866666666667)
# ('#', 78, 'Actual = ', 4, 'Predictioned = ', 4.241866666666667)
# ('#', 79, 'Actual = ', 4, 'Predictioned = ', 2.5371047619047618)
# ('#', 80, 'Actual = ', 4, 'Predictioned = ', 3.6659103825136614)
# ('#', 81, 'Actual = ', 5, 'Predictioned = ', 4.3285333333333345)
# ('#', 82, 'Actual = ', 3, 'Predictioned = ', 4.608533333333334)
# ('#', 83, 'Actual = ', 1, 'Predictioned = ', 3.3418666666666668)
# ('#', 84, 'Actual = ', 1, 'Predictioned = ', 3.3418666666666668)
# ('#', 85, 'Actual = ', 4, 'Predictioned = ', 3.7561523809523814)
# ('#', 86, 'Actual = ', 5, 'Predictioned = ', 3.9894857142857147)
# ('#', 87, 'Actual = ', 5, 'Predictioned = ', 4.291866666666667)
# ('#', 88, 'Actual = ', 5, 'Predictioned = ', 3.941866666666667)
# ('#', 89, 'Actual = ', 5, 'Predictioned = ', 3.941866666666667)
# ('#', 90, 'Actual = ', 3, 'Predictioned = ', 3.666866666666667)
# ('#', 91, 'Actual = ', 2, 'Predictioned = ', 4.361221505376344)
# ('#', 92, 'Actual = ', 5, 'Predictioned = ', 3.566866666666667)
# ('#', 93, 'Actual = ', 5, 'Predictioned = ', 5.691866666666667)
# ('#', 94, 'Actual = ', 5, 'Predictioned = ', 5.341866666666667)
# ('#', 95, 'Actual = ', 2, 'Predictioned = ', 1.641866666666667)
# ('#', 96, 'Actual = ', 3, 'Predictioned = ', 1.5668666666666669)
# ('#', 97, 'Actual = ', 5, 'Predictioned = ', 2.0159407407407413)
# ('#', 98, 'Actual = ', 1, 'Predictioned = ', 2.171374863387978)
# ('#', 99, 'Actual = ', 5, 'Predictioned = ', 3.541866666666667)
# ('#', 100, 'Actual = ', 2, 'Predictioned = ', 4.358533333333334)
# ('#', 101, 'Actual = ', 1, 'Predictioned = ', 3.9808277056277057)
# ('#', 102, 'Actual = ', 5, 'Predictioned = ', 3.1236848484848485)
# ('#', 103, 'Actual = ', 3, 'Predictioned = ', 4.2752)
# ('#', 104, 'Actual = ', 5, 'Predictioned = ', 4.841866666666667)
# ('#', 105, 'Actual = ', 2, 'Predictioned = ', 3.8863111111111115)
# ('#', 106, 'Actual = ', 3, 'Predictioned = ', 3.941866666666667)
# ('#', 107, 'Actual = ', 5, 'Predictioned = ', 4.651866666666667)
# ('#', 108, 'Actual = ', 4, 'Predictioned = ', 3.691866666666667)
# ('#', 109, 'Actual = ', 4, 'Predictioned = ', 4.191866666666667)
# ('#', 110, 'Actual = ', 2, 'Predictioned = ', 3.691866666666667)
# ('#', 111, 'Actual = ', 5, 'Predictioned = ', 3.941866666666667)
# ('#', 112, 'Actual = ', 5, 'Predictioned = ', 4.441866666666667)
# ('#', 113, 'Actual = ', 5, 'Predictioned = ', 4.691866666666667)
# ('#', 114, 'Actual = ', 5, 'Predictioned = ', 3.7752000000000003)
# ('#', 115, 'Actual = ', 3, 'Predictioned = ', 4.1513904761904765)
# ('#', 116, 'Actual = ', 4, 'Predictioned = ', 4.28472380952381)
# ('#', 117, 'Actual = ', 5, 'Predictioned = ', 4.763295238095239)
# ('#', 118, 'Actual = ', 5, 'Predictioned = ', 4.041866666666667)
# ('#', 119, 'Actual = ', 5, 'Predictioned = ', 4.480328205128205)
# ('#', 120, 'Actual = ', 5, 'Predictioned = ', 4.341866666666667)
# ('#', 121, 'Actual = ', 4, 'Predictioned = ', 4.270438095238095)
# ('#', 122, 'Actual = ', 4, 'Predictioned = ', 4.370438095238096)
# ('#', 123, 'Actual = ', 4, 'Predictioned = ', 4.263295238095238)
# ('#', 124, 'Actual = ', 5, 'Predictioned = ', 4.091866666666667)
# ('#', 125, 'Actual = ', 4, 'Predictioned = ', 5.027580952380952)
# ('#', 126, 'Actual = ', 5, 'Predictioned = ', 4.827580952380952)
# ('#', 127, 'Actual = ', 4, 'Predictioned = ', 4.043315942028986)
# ('#', 128, 'Actual = ', 4, 'Predictioned = ', 4.358533333333334)
# ('#', 129, 'Actual = ', 5, 'Predictioned = ', 5.421866666666666)
# ('#', 130, 'Actual = ', 4, 'Predictioned = ', 4.891866666666667)
# ('#', 131, 'Actual = ', 4, 'Predictioned = ', 2.941866666666667)
# ('#', 132, 'Actual = ', 5, 'Predictioned = ', 3.1375188405797108)
# ('#', 133, 'Actual = ', 4, 'Predictioned = ', 3.070071794871795)
# ('#', 134, 'Actual = ', 4, 'Predictioned = ', 3.6085333333333334)
# ('#', 135, 'Actual = ', 5, 'Predictioned = ', 4.779704504504505)
# ('#', 136, 'Actual = ', 5, 'Predictioned = ', 5.23598431372549)
# ('#', 137, 'Actual = ', 5, 'Predictioned = ', 4.816866666666667)
# ('#', 138, 'Actual = ', 3, 'Predictioned = ', 5.066866666666667)
# ('#', 139, 'Actual = ', 4, 'Predictioned = ', 4.5252)
# ('#', 140, 'Actual = ', 4, 'Predictioned = ', 4.01594074074074)
# ('#', 141, 'Actual = ', 5, 'Predictioned = ', 3.2335333333333334)
# ('#', 142, 'Actual = ', 1, 'Predictioned = ', 2.0085333333333333)
# ('#', 143, 'Actual = ', 5, 'Predictioned = ', 4.1976806201550385)
# ('#', 144, 'Actual = ', 4, 'Predictioned = ', 4.896412121212121)
# ('#', 145, 'Actual = ', 5, 'Predictioned = ', 4.608533333333334)
# ('#', 146, 'Actual = ', 4, 'Predictioned = ', 4.608533333333334)
# ('#', 147, 'Actual = ', 5, 'Predictioned = ', 4.453771428571429)
# ('#', 148, 'Actual = ', 5, 'Predictioned = ', 4.570438095238096)
# ('#', 149, 'Actual = ', 5, 'Predictioned = ', 4.441866666666667)
# ('#', 150, 'Actual = ', 5, 'Predictioned = ', 3.541866666666667)
# ('#', 151, 'Actual = ', 2, 'Predictioned = ', 3.377160784313726)
# ('#', 152, 'Actual = ', 1, 'Predictioned = ', 2.891866666666667)
# ('#', 153, 'Actual = ', 5, 'Predictioned = ', 3.541866666666667)
# ('#', 154, 'Actual = ', 5, 'Predictioned = ', 4.371374863387978)
# ('#', 155, 'Actual = ', 5, 'Predictioned = ', 4.621353846153847)
# ('#', 156, 'Actual = ', 4, 'Predictioned = ', 4.441866666666668)
# ('#', 157, 'Actual = ', 5, 'Predictioned = ', 4.127913178294574)
# ('#', 158, 'Actual = ', 1, 'Predictioned = ', 3.441866666666667)
# ('#', 159, 'Actual = ', 1, 'Predictioned = ', 3.4835333333333334)
# ('#', 160, 'Actual = ', 5, 'Predictioned = ', 4.501077192982456)
# ('#', 161, 'Actual = ', 5, 'Predictioned = ', 3.6307555555555555)
# ('#', 162, 'Actual = ', 3, 'Predictioned = ', 3.6720992248062014)
# ('#', 163, 'Actual = ', 5, 'Predictioned = ', 5.141866666666667)
# ('#', 164, 'Actual = ', 5, 'Predictioned = ', 5.327408835341366)
# ('#', 165, 'Actual = ', 1, 'Predictioned = ', 3.441866666666667)
# ('#', 166, 'Actual = ', 1, 'Predictioned = ', 4.441866666666667)
# ('#', 167, 'Actual = ', 5, 'Predictioned = ', 5.271691228070176)
# ('#', 168, 'Actual = ', 5, 'Predictioned = ', 5.608533333333334)
# ('#', 169, 'Actual = ', 5, 'Predictioned = ', 4.2752)
# ('#', 170, 'Actual = ', 5, 'Predictioned = ', 5.108533333333334)
# ('#', 171, 'Actual = ', 4, 'Predictioned = ', 4.660742168674699)
# ('#', 172, 'Actual = ', 4, 'Predictioned = ', 4.341866666666666)
# ('#', 173, 'Actual = ', 5, 'Predictioned = ', 4.341866666666667)
# ('#', 174, 'Actual = ', 5, 'Predictioned = ', 4.091866666666667)
# ('#', 175, 'Actual = ', 5, 'Predictioned = ', 4.241866666666667)
# ('#', 176, 'Actual = ', 5, 'Predictioned = ', 4.266190990990991)
# ('#', 177, 'Actual = ', 5, 'Predictioned = ', 3.7825529411764713)
# ('#', 178, 'Actual = ', 4, 'Predictioned = ', 2.9002000000000003)
# ('#', 179, 'Actual = ', 5, 'Predictioned = ', 5.441866666666667)
# ('#', 180, 'Actual = ', 5, 'Predictioned = ', 5.441866666666667)
# ('#', 181, 'Actual = ', 1, 'Predictioned = ', 3.7752000000000003)
# ('#', 182, 'Actual = ', 5, 'Predictioned = ', 4.341866666666666)
# ('#', 183, 'Actual = ', 5, 'Predictioned = ', 4.379366666666667)
# ('#', 184, 'Actual = ', 4, 'Predictioned = ', 3.941866666666667)
# ('#', 185, 'Actual = ', 4, 'Predictioned = ', 4.451670588235294)
# ('#', 186, 'Actual = ', 1, 'Predictioned = ', 4.169936842105264)
# ('#', 187, 'Actual = ', 5, 'Predictioned = ', 5.141866666666667)
# ('#', 188, 'Actual = ', 5, 'Predictioned = ', 4.608533333333334)
# ('#', 189, 'Actual = ', 5, 'Predictioned = ', 4.858533333333334)
# ('#', 190, 'Actual = ', 5, 'Predictioned = ', 2.691866666666667)
# ('#', 191, 'Actual = ', 5, 'Predictioned = ', 5.605024561403509)
# ('#', 192, 'Actual = ', 5, 'Predictioned = ', 5.141866666666667)
# ('#', 193, 'Actual = ', 5, 'Predictioned = ', 5.6752)
# ('#', 194, 'Actual = ', 5, 'Predictioned = ', 5.691866666666667)
# ('#', 195, 'Actual = ', 5, 'Predictioned = ', 3.8875188405797108)
# ('#', 196, 'Actual = ', 5, 'Predictioned = ', 3.691866666666667)
# ('#', 197, 'Actual = ', 4, 'Predictioned = ', 3.8704380952380952)
# ('#', 198, 'Actual = ', 3, 'Predictioned = ', 3.6085333333333334)
# ('#', 199, 'Actual = ', 5, 'Predictioned = ', 4.858533333333334)
# ('#', 200, 'Actual = ', 5, 'Predictioned = ', 4.608533333333334)
# ('#', 201, 'Actual = ', 5, 'Predictioned = ', 5.299009523809524)
# ('#', 202, 'Actual = ', 5, 'Predictioned = ', 4.641866666666667)
# ('#', 203, 'Actual = ', 4, 'Predictioned = ', 4.965676190476191)
# ('#', 204, 'Actual = ', 4, 'Predictioned = ', 4.656152380952381)
# ('#', 205, 'Actual = ', 5, 'Predictioned = ', 3.2145939393939393)
# ('#', 206, 'Actual = ', 4, 'Predictioned = ', 3.141866666666667)
# ('#', 207, 'Actual = ', 5, 'Predictioned = ', 5.08472380952381)
# ('#', 208, 'Actual = ', 4, 'Predictioned = ', 4.441866666666667)
# ('#', 209, 'Actual = ', 1, 'Predictioned = ', 1.4418666666666669)
# ('#', 210, 'Actual = ', 5, 'Predictioned = ', 2.691866666666667)
# ('#', 211, 'Actual = ', 4, 'Predictioned = ', 4.2752)
# ('#', 212, 'Actual = ', 5, 'Predictioned = ', 3.4252)
# ('#', 213, 'Actual = ', 5, 'Predictioned = ', 5.605024561403509)
# ('#', 214, 'Actual = ', 5, 'Predictioned = ', 5.08472380952381)
# ('#', 215, 'Actual = ', 2, 'Predictioned = ', 5.427580952380953)
# ('#', 216, 'Actual = ', 1, 'Predictioned = ', 4.578230303030303)
# ('#', 217, 'Actual = ', 4, 'Predictioned = ', 3.941866666666667)
# ('#', 218, 'Actual = ', 4, 'Predictioned = ', 3.691866666666667)
# ('#', 219, 'Actual = ', 5, 'Predictioned = ', 5.841866666666667)
# ('#', 220, 'Actual = ', 1, 'Predictioned = ', 5.2752)
# ('#', 221, 'Actual = ', 5, 'Predictioned = ', 2.891866666666667)
# ('#', 222, 'Actual = ', 5, 'Predictioned = ', 2.8260771929824564)
# ('#', 223, 'Actual = ', 5, 'Predictioned = ', 4.726482051282052)
# ('#', 224, 'Actual = ', 5, 'Predictioned = ', 5.138982051282052)
# ('#', 225, 'Actual = ', 5, 'Predictioned = ', 2.661866666666667)
# ('#', 226, 'Actual = ', 5, 'Predictioned = ', 2.497422222222222)
# ('#', 227, 'Actual = ', 4, 'Predictioned = ', 3.941866666666667)
# ('#', 228, 'Actual = ', 5, 'Predictioned = ', 4.441866666666667)
# ('#', 229, 'Actual = ', 5, 'Predictioned = ', 5.361221505376344)
# ('#', 230, 'Actual = ', 3, 'Predictioned = ', 5.457995698924732)
# ('#', 231, 'Actual = ', 4, 'Predictioned = ', 4.570654545454546)
# ('#', 232, 'Actual = ', 5, 'Predictioned = ', 4.5252)
# ('#', 233, 'Actual = ', 5, 'Predictioned = ', 4.141866666666667)
# ('#', 234, 'Actual = ', 5, 'Predictioned = ', 4.941866666666667)
# ('#', 235, 'Actual = ', 4, 'Predictioned = ', 5.0752)
# ('#', 236, 'Actual = ', 5, 'Predictioned = ', 5.741866666666667)
# ('#', 237, 'Actual = ', 4, 'Predictioned = ', 4.5418666666666665)
# ('#', 238, 'Actual = ', 5, 'Predictioned = ', 4.605024561403509)
# ('#', 239, 'Actual = ', 5, 'Predictioned = ', 3.4418666666666664)
# ('#', 240, 'Actual = ', 5, 'Predictioned = ', 4.5252)
# ('#', 241, 'Actual = ', 5, 'Predictioned = ', 4.941866666666667)
# ('#', 242, 'Actual = ', 5, 'Predictioned = ', 5.941866666666667)
# ('#', 243, 'Actual = ', 5, 'Predictioned = ', 4.608533333333334)
# ('#', 244, 'Actual = ', 1, 'Predictioned = ', 4.191866666666667)
# ('#', 245, 'Actual = ', 4, 'Predictioned = ', 3.5847238095238096)
# ('#', 246, 'Actual = ', 5, 'Predictioned = ', 4.408533333333334)
# ('#', 247, 'Actual = ', 5, 'Predictioned = ', 4.716060215053764)
# ('#', 248, 'Actual = ', 5, 'Predictioned = ', 5.760048484848485)
# ('#', 249, 'Actual = ', 5, 'Predictioned = ', 4.691866666666667)
# ('#', 250, 'Actual = ', 5, 'Predictioned = ', 4.941866666666667)
# ('#', 251, 'Actual = ', 5, 'Predictioned = ', 5.227580952380952)
# ('#', 252, 'Actual = ', 5, 'Predictioned = ', 5.605024561403509)
# ('#', 253, 'Actual = ', 4, 'Predictioned = ', 4.241866666666667)
# ('#', 254, 'Actual = ', 5, 'Predictioned = ', 4.941866666666667)
# ('#', 255, 'Actual = ', 5, 'Predictioned = ', 4.891866666666667)
# ('#', 256, 'Actual = ', 5, 'Predictioned = ', 4.691866666666667)
# ('#', 257, 'Actual = ', 1, 'Predictioned = ', 1.297422222222222)
# ('#', 258, 'Actual = ', 1, 'Predictioned = ', 1.095712820512821)
# ('#', 259, 'Actual = ', 5, 'Predictioned = ', 4.997422222222223)
# ('#', 260, 'Actual = ', 5, 'Predictioned = ', 4.804185507246378)
# ('#', 261, 'Actual = ', 5, 'Predictioned = ', 3.608533333333334)
# ('#', 262, 'Actual = ', 5, 'Predictioned = ', 3.2752)
# ('#', 263, 'Actual = ', 5, 'Predictioned = ', 3.2495589743589743)
# ('#', 264, 'Actual = ', 5, 'Predictioned = ', 3.941866666666667)
# ('#', 265, 'Actual = ', 1, 'Predictioned = ', 1.5418666666666665)
# ('#', 266, 'Actual = ', 1, 'Predictioned = ', 3.0373212121212125)
# ('#', 267, 'Actual = ', 5, 'Predictioned = ', 4.272099224806202)
# ('#', 268, 'Actual = ', 4, 'Predictioned = ', 4.761221505376344)
# ('#', 269, 'Actual = ', 4, 'Predictioned = ', 4.732716339869281)
# ('#', 270, 'Actual = ', 4, 'Predictioned = ', 2.6085333333333334)
# ('#', 271, 'Actual = ', 3, 'Predictioned = ', 4.532775757575758)
# ('#', 272, 'Actual = ', 5, 'Predictioned = ', 5.108533333333334)
# ('#', 273, 'Actual = ', 5, 'Predictioned = ', 4.751390476190477)
# ('#', 274, 'Actual = ', 1, 'Predictioned = ', 4.241866666666667)
# ('#', 275, 'Actual = ', 1, 'Predictioned = ', 4.177160784313726)
# ('#', 276, 'Actual = ', 3, 'Predictioned = ', 4.08472380952381)
# ('#', 277, 'Actual = ', 5, 'Predictioned = ', 4.941866666666667)
# ('#', 278, 'Actual = ', 5, 'Predictioned = ', 5.032775757575758)
# ('#', 279, 'Actual = ', 4, 'Predictioned = ', 3.541866666666667)
# ('#', 280, 'Actual = ', 1, 'Predictioned = ', 5.327408835341366)
# ('#', 281, 'Actual = ', 5, 'Predictioned = ', 5.58472380952381)
# ('#', 282, 'Actual = ', 4, 'Predictioned = ', 4.608533333333334)
# ('#', 283, 'Actual = ', 4, 'Predictioned = ', 2.6085333333333334)
# ('#', 284, 'Actual = ', 4, 'Predictioned = ', 5.032775757575758)
# ('#', 285, 'Actual = ', 5, 'Predictioned = ', 4.541866666666667)
# ('#', 286, 'Actual = ', 5, 'Predictioned = ', 5.227580952380952)
# ('#', 287, 'Actual = ', 5, 'Predictioned = ', 5.341866666666667)
# ('#', 288, 'Actual = ', 5, 'Predictioned = ', 5.691866666666667)
# ('#', 289, 'Actual = ', 5, 'Predictioned = ', 5.214593939393939)
# ('#', 290, 'Actual = ', 5, 'Predictioned = ', 3.8466285714285715)
# ('#', 291, 'Actual = ', 5, 'Predictioned = ', 4.513295238095238)
# ('#', 292, 'Actual = ', 5, 'Predictioned = ', 4.108533333333334)
# ('#', 293, 'Actual = ', 5, 'Predictioned = ', 4.073445614035088)
# ('#', 294, 'Actual = ', 5, 'Predictioned = ', 5.073445614035088)
# ('#', 295, 'Actual = ', 5, 'Predictioned = ', 5.941866666666667)
# ('#', 296, 'Actual = ', 4, 'Predictioned = ', 5.0835333333333335)
# ('#', 297, 'Actual = ', 4, 'Predictioned = ', 4.96972736318408)
# ('#', 298, 'Actual = ', 4, 'Predictioned = ', 4.390351515151515)
# ('#', 299, 'Actual = ', 4, 'Predictioned = ', 4.794579844961241)
# ('#', 300, 'Actual = ', 5, 'Predictioned = ', 4.713295238095238)
# ('#', 301, 'Actual = ', 5, 'Predictioned = ', 3.141866666666667)
# ('#', 302, 'Actual = ', 5, 'Predictioned = ', 4.608533333333334)
# ('#', 303, 'Actual = ', 1, 'Predictioned = ', 2.441866666666667)
# ('#', 304, 'Actual = ', 1, 'Predictioned = ', 1.4418666666666669)
# ('#', 305, 'Actual = ', 5, 'Predictioned = ', 2.2752)
# ('#', 306, 'Actual = ', 4, 'Predictioned = ', 4.921033333333334)
# ('#', 307, 'Actual = ', 4, 'Predictioned = ', 4.0877)
# ('#', 308, 'Actual = ', 5, 'Predictioned = ', 4.64472380952381)
# ('#', 309, 'Actual = ', 5, 'Predictioned = ', 4.537355388471179)
# ('#', 310, 'Actual = ', 4, 'Predictioned = ', 4.3863111111111115)
# ('#', 311, 'Actual = ', 5, 'Predictioned = ', 4.396412121212121)
# ('#', 312, 'Actual = ', 4, 'Predictioned = ', 3.58472380952381)
# ('#', 313, 'Actual = ', 5, 'Predictioned = ', 4.191866666666667)
# ('#', 314, 'Actual = ', 5, 'Predictioned = ', 1.9418666666666669)
# ('#', 315, 'Actual = ', 5, 'Predictioned = ', 1.9418666666666669)
# ('#', 316, 'Actual = ', 5, 'Predictioned = ', 4.941866666666667)
# ('#', 317, 'Actual = ', 5, 'Predictioned = ', 2.941866666666667)
# ('#', 318, 'Actual = ', 3, 'Predictioned = ', 3.941866666666667)
# ('#', 319, 'Actual = ', 3, 'Predictioned = ', 3.0529777777777776)
# ('#', 320, 'Actual = ', 5, 'Predictioned = ', 4.916442937853107)
# ('#', 321, 'Actual = ', 5, 'Predictioned = ', 4.797422222222222)
# ('#', 322, 'Actual = ', 2, 'Predictioned = ', 5.632342857142857)
# ('#', 323, 'Actual = ', 3, 'Predictioned = ', 4.354565079365079)
# ('#', 324, 'Actual = ', 4, 'Predictioned = ', 3.729242081949059)
# ('#', 325, 'Actual = ', 4, 'Predictioned = ', 3.549009523809524)
# ('#', 326, 'Actual = ', 1, 'Predictioned = ', 3.802977777777778)
# ('#', 327, 'Actual = ', 5, 'Predictioned = ', 3.390351515151515)
# ('#', 328, 'Actual = ', 5, 'Predictioned = ', 2.2752)
# ('#', 329, 'Actual = ', 1, 'Predictioned = ', 3.498944292237443)
# ('#', 330, 'Actual = ', 5, 'Predictioned = ', 5.441866666666667)
# ('#', 331, 'Actual = ', 5, 'Predictioned = ', 4.441866666666667)
# ('#', 332, 'Actual = ', 4, 'Predictioned = ', 2.9918666666666667)
# ('#', 333, 'Actual = ', 3, 'Predictioned = ', 3.2661909909909914)
# ('#', 334, 'Actual = ', 2, 'Predictioned = ', 1.9418666666666669)
# ('#', 335, 'Actual = ', 3, 'Predictioned = ', 3.3704380952380952)
# ('#', 336, 'Actual = ', 4, 'Predictioned = ', 3.6477490196078435)
# ('#', 337, 'Actual = ', 3, 'Predictioned = ', 3.497422222222222)
# ('#', 338, 'Actual = ', 5, 'Predictioned = ', 5.108533333333334)
# ('#', 339, 'Actual = ', 4, 'Predictioned = ', 4.941866666666667)
# ('#', 340, 'Actual = ', 5, 'Predictioned = ', 5.441866666666667)
# ('#', 341, 'Actual = ', 3, 'Predictioned = ', 5.941866666666667)
# ('#', 342, 'Actual = ', 2, 'Predictioned = ', 4.8751999999999995)
# ('#', 343, 'Actual = ', 3, 'Predictioned = ', 4.5418666666666665)
# ('#', 344, 'Actual = ', 5, 'Predictioned = ', 5.941866666666667)
# ('#', 345, 'Actual = ', 5, 'Predictioned = ', 5.8752)
# ('#', 346, 'Actual = ', 5, 'Predictioned = ', 5.327408835341366)
# ('#', 347, 'Actual = ', 5, 'Predictioned = ', 5.127913178294574)
# ('#', 348, 'Actual = ', 5, 'Predictioned = ', 3.6982769230769237)
# ('#', 349, 'Actual = ', 4, 'Predictioned = ', 2.7037714285714287)
# ('#', 350, 'Actual = ', 2, 'Predictioned = ', 4.941866666666667)
# ('#', 351, 'Actual = ', 1, 'Predictioned = ', 5.941866666666667)
# ('#', 352, 'Actual = ', 5, 'Predictioned = ', 5.483533333333334)
# ('#', 353, 'Actual = ', 5, 'Predictioned = ', 5.269498245614035)
# ('#', 354, 'Actual = ', 2, 'Predictioned = ', 2.941866666666667)
# ('#', 355, 'Actual = ', 3, 'Predictioned = ', 3.941866666666667)
# ('#', 356, 'Actual = ', 5, 'Predictioned = ', 5.608533333333334)
# ('#', 357, 'Actual = ', 4, 'Predictioned = ', 4.941866666666667)
# ('#', 358, 'Actual = ', 4, 'Predictioned = ', 3.941866666666667)
# ('#', 359, 'Actual = ', 1, 'Predictioned = ', 3.941866666666667)
# ('#', 360, 'Actual = ', 3, 'Predictioned = ', 4.2752)
# ('#', 361, 'Actual = ', 5, 'Predictioned = ', 5.741866666666667)
# ('#', 362, 'Actual = ', 1, 'Predictioned = ', 0.27520000000000033)
# ('#', 363, 'Actual = ', 1, 'Predictioned = ', 1.3418666666666672)
# ('#', 364, 'Actual = ', 4, 'Predictioned = ', 3.973612698412699)
# ('#', 365, 'Actual = ', 5, 'Predictioned = ', 4.130755555555556)
# ('#', 366, 'Actual = ', 2, 'Predictioned = ', 2.191866666666667)
# ('#', 367, 'Actual = ', 2, 'Predictioned = ', 2.1132952380952386)
# ('#', 368, 'Actual = ', 5, 'Predictioned = ', 4.608533333333334)
# ('#', 369, 'Actual = ', 4, 'Predictioned = ', 2.799009523809524)
# ('#', 370, 'Actual = ', 4, 'Predictioned = ', 1.5252000000000003)
# ('#', 371, 'Actual = ', 5, 'Predictioned = ', 1.0252000000000003)
# ('#', 372, 'Actual = ', 5, 'Predictioned = ', 3.441866666666667)
# ('#', 373, 'Actual = ', 5, 'Predictioned = ', 3.441866666666667)
# ('#', 374, 'Actual = ', 1, 'Predictioned = ', 1.0704380952380959)
# ('#', 375, 'Actual = ', 5, 'Predictioned = ', 1.7030606965174133)
# ('#', 376, 'Actual = ', 4, 'Predictioned = ', 3.100596825396826)
# ('#', 377, 'Actual = ', 3, 'Predictioned = ', 3.672025396825397)
# ('#', 378, 'Actual = ', 5, 'Predictioned = ', 5.2752)
# ('#', 379, 'Actual = ', 5, 'Predictioned = ', 5.608533333333334)
# ('#', 380, 'Actual = ', 5, 'Predictioned = ', 1.9418666666666669)
# ('#', 381, 'Actual = ', 5, 'Predictioned = ', 5.2752)
# ('#', 382, 'Actual = ', 4, 'Predictioned = ', 3.4418666666666673)
# ('#', 383, 'Actual = ', 5, 'Predictioned = ', 4.075200000000001)
# ('#', 384, 'Actual = ', 4, 'Predictioned = ', 3.141866666666667)
# ('#', 385, 'Actual = ', 5, 'Predictioned = ', 2.559513725490196)
# ('#', 386, 'Actual = ', 3, 'Predictioned = ', 4.378374603174604)
# ('#', 387, 'Actual = ', 4, 'Predictioned = ', 4.519644444444444)
# ('#', 388, 'Actual = ', 5, 'Predictioned = ', 4.786726479750779)
# ('#', 389, 'Actual = ', 4, 'Predictioned = ', 4.437321212121213)
# ('#', 390, 'Actual = ', 4, 'Predictioned = ', 4.381260606060606)
# ('#', 391, 'Actual = ', 1, 'Predictioned = ', 5.108533333333334)
# ('#', 392, 'Actual = ', 1, 'Predictioned = ', 5.7752)
# ('#', 393, 'Actual = ', 5, 'Predictioned = ', 5.341866666666667)
# ('#', 394, 'Actual = ', 5, 'Predictioned = ', 4.978903703703704)
# ('#', 395, 'Actual = ', 1, 'Predictioned = ', 5.566866666666667)
# ('#', 396, 'Actual = ', 2, 'Predictioned = ', 3.141866666666667)
# ('#', 397, 'Actual = ', 2, 'Predictioned = ', 3.141866666666667)
# ('#', 398, 'Actual = ', 3, 'Predictioned = ', 4.251390476190477)
# ('#', 399, 'Actual = ', 3, 'Predictioned = ', 4.4847238095238104)
# ('#', 400, 'Actual = ', 5, 'Predictioned = ', 4.541866666666667)
# ('#', 401, 'Actual = ', 1, 'Predictioned = ', 3.7418666666666667)
# ('#', 402, 'Actual = ', 5, 'Predictioned = ', 3.691866666666667)
# ('#', 403, 'Actual = ', 5, 'Predictioned = ', 2.8418666666666668)
# ('#', 404, 'Actual = ', 4, 'Predictioned = ', 3.941866666666667)
# ('#', 405, 'Actual = ', 4, 'Predictioned = ', 4.5418666666666665)
# ('#', 406, 'Actual = ', 5, 'Predictioned = ', 5.156152380952381)
# ('#', 407, 'Actual = ', 5, 'Predictioned = ', 3.441866666666667)
# ('#', 408, 'Actual = ', 5, 'Predictioned = ', 4.890584615384615)
# ('#', 409, 'Actual = ', 4, 'Predictioned = ', 4.660742168674699)
# ('#', 410, 'Actual = ', 4, 'Predictioned = ', 3.291866666666667)
# ('#', 411, 'Actual = ', 4, 'Predictioned = ', 3.720712820512821)
# ('#', 412, 'Actual = ', 3, 'Predictioned = ', 3.9793666666666665)
# ('#', 413, 'Actual = ', 2, 'Predictioned = ', 0.37936666666666685)
# ('#', 414, 'Actual = ', 4, 'Predictioned = ', 3.6561523809523813)
# ('#', 415, 'Actual = ', 3, 'Predictioned = ', 3.767263492063492)
# ('#', 416, 'Actual = ', 1, 'Predictioned = ', 3.6752000000000007)
# ('#', 417, 'Actual = ', 5, 'Predictioned = ', 2.736738461538462)
# ('#', 418, 'Actual = ', 5, 'Predictioned = ', 4.691866666666667)
# ('#', 419, 'Actual = ', 5, 'Predictioned = ', 5.941866666666667)
# ('#', 420, 'Actual = ', 5, 'Predictioned = ', 2.941866666666667)
# ('#', 421, 'Actual = ', 4, 'Predictioned = ', 2.941866666666667)
# ('#', 422, 'Actual = ', 5, 'Predictioned = ', 3.941866666666667)
# ('#', 423, 'Actual = ', 2, 'Predictioned = ', 3.2661909909909914)
# ('#', 424, 'Actual = ', 4, 'Predictioned = ', 3.941866666666667)
# ('#', 425, 'Actual = ', 3, 'Predictioned = ', 3.5625563218390806)
# ('#', 426, 'Actual = ', 5, 'Predictioned = ', 5.182607407407407)
# ('#', 427, 'Actual = ', 5, 'Predictioned = ', 4.7196444444444445)
# ('#', 428, 'Actual = ', 5, 'Predictioned = ', 4.7752)
# ('#', 429, 'Actual = ', 4, 'Predictioned = ', 2.691866666666667)
# ('#', 430, 'Actual = ', 5, 'Predictioned = ', 2.2752)
# ('#', 431, 'Actual = ', 3, 'Predictioned = ', 3.7945798449612407)
# ('#', 432, 'Actual = ', 5, 'Predictioned = ', 1.9418666666666669)
# ('#', 433, 'Actual = ', 4, 'Predictioned = ', 4.297422222222222)
# ('#', 434, 'Actual = ', 5, 'Predictioned = ', 5.191866666666667)
# ('#', 435, 'Actual = ', 4, 'Predictioned = ', 3.941866666666667)
# ('#', 436, 'Actual = ', 4, 'Predictioned = ', 3.941866666666667)
# ('#', 437, 'Actual = ', 3, 'Predictioned = ', 4.641866666666667)
# ('#', 438, 'Actual = ', 1, 'Predictioned = ', 2.441866666666667)
# ('#', 439, 'Actual = ', 5, 'Predictioned = ', 3.191866666666667)
# ('#', 440, 'Actual = ', 3, 'Predictioned = ', 1.9418666666666669)
# ('#', 441, 'Actual = ', 4, 'Predictioned = ', 2.420127536231884)
# ('#', 442, 'Actual = ', 3, 'Predictioned = ', 3.191866666666667)
# ('#', 443, 'Actual = ', 4, 'Predictioned = ', 4.282775757575758)
# ('#', 444, 'Actual = ', 5, 'Predictioned = ', 5.1502)
# ('#', 445, 'Actual = ', 1, 'Predictioned = ', 3.7418666666666667)
# ('#', 446, 'Actual = ', 5, 'Predictioned = ', 4.989485714285714)
# ('#', 447, 'Actual = ', 1, 'Predictioned = ', 3.0751999999999997)
# ('#', 448, 'Actual = ', 5, 'Predictioned = ', 4.057938095238095)
# ('#', 449, 'Actual = ', 4, 'Predictioned = ', 3.0371047619047618)
# ('#', 450, 'Actual = ', 5, 'Predictioned = ', 4.141866666666667)
# ('#', 451, 'Actual = ', 5, 'Predictioned = ', 4.941866666666667)
# ('#', 452, 'Actual = ', 5, 'Predictioned = ', 5.386726479750779)
# ('#', 453, 'Actual = ', 4, 'Predictioned = ', 4.778903703703704)
# ('#', 454, 'Actual = ', 5, 'Predictioned = ', 5.10878395989975)
# ('#', 455, 'Actual = ', 5, 'Predictioned = ', 5.056152380952382)
# ('#', 456, 'Actual = ', 3, 'Predictioned = ', 5.191866666666667)
# ('#', 457, 'Actual = ', 5, 'Predictioned = ', 3.441866666666667)
# ('#', 458, 'Actual = ', 4, 'Predictioned = ', 4.691866666666667)
# ('#', 459, 'Actual = ', 5, 'Predictioned = ', 4.816866666666667)
# ('#', 460, 'Actual = ', 5, 'Predictioned = ', 3.191866666666667)
# ('#', 461, 'Actual = ', 4, 'Predictioned = ', 4.691866666666667)
# ('#', 462, 'Actual = ', 5, 'Predictioned = ', 4.912237037037037)
# ('#', 463, 'Actual = ', 4, 'Predictioned = ', 5.06567619047619)
# ('#', 464, 'Actual = ', 4, 'Predictioned = ', 5.566866666666667)
# ('#', 465, 'Actual = ', 5, 'Predictioned = ', 5.941866666666667)
# ('#', 466, 'Actual = ', 4, 'Predictioned = ', 3.978903703703704)
# ('#', 467, 'Actual = ', 3, 'Predictioned = ', 2.6085333333333334)
# ('#', 468, 'Actual = ', 5, 'Predictioned = ', 5.6252)
# ('#', 469, 'Actual = ', 5, 'Predictioned = ', 5.091866666666667)
# ('#', 470, 'Actual = ', 4, 'Predictioned = ', 5.441866666666667)
# ('#', 471, 'Actual = ', 5, 'Predictioned = ', 4.5252)
# ('#', 472, 'Actual = ', 5, 'Predictioned = ', 5.691866666666667)
# ('#', 473, 'Actual = ', 5, 'Predictioned = ', 5.441866666666667)
# ('#', 474, 'Actual = ', 4, 'Predictioned = ', 5.641866666666667)
# ('#', 475, 'Actual = ', 4, 'Predictioned = ', 5.641866666666667)
# ('#', 476, 'Actual = ', 5, 'Predictioned = ', 4.2752)
# ('#', 477, 'Actual = ', 3, 'Predictioned = ', 2.9418666666666664)
# ('#', 478, 'Actual = ', 5, 'Predictioned = ', 4.292743859649123)
# ('#', 479, 'Actual = ', 5, 'Predictioned = ', 4.271691228070175)
# ('#', 480, 'Actual = ', 5, 'Predictioned = ', 4.870438095238095)
# ('#', 481, 'Actual = ', 4, 'Predictioned = ', 5.370438095238096)
# ('#', 482, 'Actual = ', 5, 'Predictioned = ', 5.073445614035088)
# ('#', 483, 'Actual = ', 4, 'Predictioned = ', 4.108533333333334)
# ('#', 484, 'Actual = ', 5, 'Predictioned = ', 2.6607421686746995)
# ('#', 485, 'Actual = ', 5, 'Predictioned = ', 2.5752)
# ('#', 486, 'Actual = ', 5, 'Predictioned = ', 4.2752)
# ('#', 487, 'Actual = ', 4, 'Predictioned = ', 4.941866666666667)
# ('#', 488, 'Actual = ', 5, 'Predictioned = ', 2.441866666666667)
# ('#', 489, 'Actual = ', 5, 'Predictioned = ', 2.941866666666667)
# ('#', 490, 'Actual = ', 5, 'Predictioned = ', 4.141866666666667)
# ('#', 491, 'Actual = ', 3, 'Predictioned = ', 2.5418666666666665)
# ('#', 492, 'Actual = ', 1, 'Predictioned = ', 3.7359843137254902)
# ('#', 493, 'Actual = ', 5, 'Predictioned = ', 3.997422222222222)
# ('#', 494, 'Actual = ', 4, 'Predictioned = ', 5.336726479750779)
# ('#', 495, 'Actual = ', 5, 'Predictioned = ', 4.891866666666667)
# ('#', 496, 'Actual = ', 2, 'Predictioned = ', 4.58472380952381)
# ('#', 497, 'Actual = ', 5, 'Predictioned = ', 5.941866666666667)
# ('#', 498, 'Actual = ', 4, 'Predictioned = ', 3.544430769230769)
# ('#', 499, 'Actual = ', 4, 'Predictioned = ', 2.441866666666667)
# ('#', 500, 'Actual = ', 5, 'Predictioned = ', 5.608533333333334)
# ('#', 501, 'Actual = ', 5, 'Predictioned = ', 4.896412121212121)
# ('#', 502, 'Actual = ', 5, 'Predictioned = ', 4.957995698924732)
# ('#', 503, 'Actual = ', 5, 'Predictioned = ', 5.178708771929824)
# ('#', 504, 'Actual = ', 2, 'Predictioned = ', 2.2752)
# ('#', 505, 'Actual = ', 5, 'Predictioned = ', 3.839302564102564)
# ('#', 506, 'Actual = ', 4, 'Predictioned = ', 3.941866666666667)
# ('#', 507, 'Actual = ', 5, 'Predictioned = ', 4.608533333333334)
# ('#', 508, 'Actual = ', 5, 'Predictioned = ', 4.5818666666666665)
# ('#', 509, 'Actual = ', 3, 'Predictioned = ', 4.141866666666667)
# ('#', 510, 'Actual = ', 3, 'Predictioned = ', 3.8466285714285715)
# ('#', 511, 'Actual = ', 3, 'Predictioned = ', 4.2752)
# ('#', 512, 'Actual = ', 5, 'Predictioned = ', 4.066866666666667)
# ('#', 513, 'Actual = ', 1, 'Predictioned = ', 4.58472380952381)
# ('#', 514, 'Actual = ', 4, 'Predictioned = ', 5.2752)
# ('#', 515, 'Actual = ', 5, 'Predictioned = ', 5.2752)
# ('#', 516, 'Actual = ', 5, 'Predictioned = ', 5.327408835341366)
# ('#', 517, 'Actual = ', 1, 'Predictioned = ', 5.191866666666667)
# ('#', 518, 'Actual = ', 5, 'Predictioned = ', 3.941866666666667)
# ('#', 519, 'Actual = ', 5, 'Predictioned = ', 4.941866666666667)
# ('#', 520, 'Actual = ', 3, 'Predictioned = ', 4.191866666666667)
# ('#', 521, 'Actual = ', 2, 'Predictioned = ', 4.32570505050505)
# ('#', 522, 'Actual = ', 2, 'Predictioned = ', 4.741866666666667)
# ('#', 523, 'Actual = ', 4, 'Predictioned = ', 5.441866666666667)
# ('#', 524, 'Actual = ', 5, 'Predictioned = ', 3.608533333333334)
# ('#', 525, 'Actual = ', 5, 'Predictioned = ', 5.1427799086757995)
# ('#', 526, 'Actual = ', 4, 'Predictioned = ', 5.172635897435898)
# ('#', 527, 'Actual = ', 5, 'Predictioned = ', 5.156152380952381)
# ('#', 528, 'Actual = ', 2, 'Predictioned = ', 4.558533333333333)
# ('#', 529, 'Actual = ', 5, 'Predictioned = ', 4.941866666666667)
# ('#', 530, 'Actual = ', 5, 'Predictioned = ', 4.441866666666667)
# ('#', 531, 'Actual = ', 5, 'Predictioned = ', 4.879366666666667)
# ('#', 532, 'Actual = ', 5, 'Predictioned = ', 5.608533333333334)
# ('#', 533, 'Actual = ', 5, 'Predictioned = ', 5.608533333333334)
# ('#', 534, 'Actual = ', 5, 'Predictioned = ', 5.327408835341366)
# ('#', 535, 'Actual = ', 5, 'Predictioned = ', 4.941866666666667)
# ('#', 536, 'Actual = ', 5, 'Predictioned = ', 3.941866666666667)
# ('#', 537, 'Actual = ', 5, 'Predictioned = ', 3.396412121212121)
# ('#', 538, 'Actual = ', 3, 'Predictioned = ', 3.532903081232493)
# ('#', 539, 'Actual = ', 3, 'Predictioned = ', 2.9656761904761906)
# ('#', 540, 'Actual = ', 1, 'Predictioned = ', 4.830755555555555)
# ('#', 541, 'Actual = ', 4, 'Predictioned = ', 4.741866666666667)
# ('#', 542, 'Actual = ', 4, 'Predictioned = ', 4.489485714285714)
# ('#', 543, 'Actual = ', 4, 'Predictioned = ', 4.989485714285714)
# ('#', 544, 'Actual = ', 4, 'Predictioned = ', 3.538765891472868)
# ('#', 545, 'Actual = ', 5, 'Predictioned = ', 3.894247619047619)
# ('#', 546, 'Actual = ', 5, 'Predictioned = ', 4.037104761904763)
# ('#', 547, 'Actual = ', 3, 'Predictioned = ', 4.437104761904762)
# ('#', 548, 'Actual = ', 5, 'Predictioned = ', 3.8704380952380952)
# ('#', 549, 'Actual = ', 4, 'Predictioned = ', 3.441866666666667)
# ('#', 550, 'Actual = ', 4, 'Predictioned = ', 4.577408835341366)
# ('#', 551, 'Actual = ', 4, 'Predictioned = ', 3.9918666666666667)
# ('#', 552, 'Actual = ', 5, 'Predictioned = ', 1.9418666666666669)
# ('#', 553, 'Actual = ', 1, 'Predictioned = ', 3.941866666666667)
# ('#', 554, 'Actual = ', 4, 'Predictioned = ', 5.032775757575758)
# ('#', 555, 'Actual = ', 4, 'Predictioned = ', 5.2752)
# ('#', 556, 'Actual = ', 2, 'Predictioned = ', 4.608533333333334)
# ('#', 557, 'Actual = ', 2, 'Predictioned = ', 4.941866666666667)
# ('#', 558, 'Actual = ', 4, 'Predictioned = ', 4.2752)
# ('#', 559, 'Actual = ', 4, 'Predictioned = ', 4.441866666666667)
# ('#', 560, 'Actual = ', 4, 'Predictioned = ', 4.227580952380952)
# ('#', 561, 'Actual = ', 5, 'Predictioned = ', 4.441866666666667)
# ('#', 562, 'Actual = ', 5, 'Predictioned = ', 4.229745454545455)
# ('#', 563, 'Actual = ', 5, 'Predictioned = ', 4.760914285714286)
# ('#', 564, 'Actual = ', 4, 'Predictioned = ', 2.719644444444444)
# ('#', 565, 'Actual = ', 4, 'Predictioned = ', 2.1085333333333334)
# ('#', 566, 'Actual = ', 4, 'Predictioned = ', 3.2495589743589743)
# ('#', 567, 'Actual = ', 5, 'Predictioned = ', 4.586726479750779)
# ('#', 568, 'Actual = ', 5, 'Predictioned = ', 4.927580952380953)
# ('#', 569, 'Actual = ', 5, 'Predictioned = ', 4.566866666666667)
# ('#', 570, 'Actual = ', 4, 'Predictioned = ', 3.2752)
# ('#', 571, 'Actual = ', 5, 'Predictioned = ', -0.05813333333333315)
# ('#', 572, 'Actual = ', 4, 'Predictioned = ', 5.941866666666667)
# ('#', 573, 'Actual = ', 4, 'Predictioned = ', 4.941866666666667)
# ('#', 574, 'Actual = ', 4, 'Predictioned = ', 4.570438095238096)
# ('#', 575, 'Actual = ', 5, 'Predictioned = ', 4.766190990990991)
# ('#', 576, 'Actual = ', 3, 'Predictioned = ', 2.164088888888889)
# ('#', 577, 'Actual = ', 5, 'Predictioned = ', 3.5252)
# ('#', 578, 'Actual = ', 4, 'Predictioned = ', 2.7752000000000003)
# ('#', 579, 'Actual = ', 4, 'Predictioned = ', 4.141866666666667)
# ('#', 580, 'Actual = ', 5, 'Predictioned = ', 4.941866666666667)
# ('#', 581, 'Actual = ', 4, 'Predictioned = ', 4.850957575757576)
# ('#', 582, 'Actual = ', 5, 'Predictioned = ', 5.108533333333334)
# ('#', 583, 'Actual = ', 3, 'Predictioned = ', 4.6752)
# ('#', 584, 'Actual = ', 4, 'Predictioned = ', 4.370438095238096)
# ('#', 585, 'Actual = ', 3, 'Predictioned = ', 4.620438095238096)
# ('#', 586, 'Actual = ', 5, 'Predictioned = ', 4.083109604519773)
# ('#', 587, 'Actual = ', 5, 'Predictioned = ', 3.9418666666666664)
# ('#', 588, 'Actual = ', 5, 'Predictioned = ', 4.441866666666667)
# ('#', 589, 'Actual = ', 5, 'Predictioned = ', 3.510048484848485)
# ('#', 590, 'Actual = ', 5, 'Predictioned = ', 4.2752)
# ('#', 591, 'Actual = ', 5, 'Predictioned = ', 5.141866666666667)
# ('#', 592, 'Actual = ', 5, 'Predictioned = ', 4.441866666666667)
# ('#', 593, 'Actual = ', 3, 'Predictioned = ', 2.691866666666667)
# ('#', 594, 'Actual = ', 4, 'Predictioned = ', 3.877422222222222)
# ('#', 595, 'Actual = ', 4, 'Predictioned = ', 4.23426432748538)
# ('#', 596, 'Actual = ', 4, 'Predictioned = ', 4.741866666666667)
# ('#', 597, 'Actual = ', 4, 'Predictioned = ', 5.491866666666667)
# ('#', 598, 'Actual = ', 5, 'Predictioned = ', 5.441866666666667)
# ('#', 599, 'Actual = ', 5, 'Predictioned = ', 5.358533333333334)
# ('#', 600, 'Actual = ', 5, 'Predictioned = ', 2.570438095238096)
# ('#', 601, 'Actual = ', 3, 'Predictioned = ', 3.2752)
# ('#', 602, 'Actual = ', 1, 'Predictioned = ', 2.0700717948717955)
# ('#', 603, 'Actual = ', 1, 'Predictioned = ', 1.8418666666666668)
# ('#', 604, 'Actual = ', 3, 'Predictioned = ', 3.349274074074074)
# ('#', 605, 'Actual = ', 3, 'Predictioned = ', 3.552977777777778)
# ('#', 606, 'Actual = ', 5, 'Predictioned = ', 5.066866666666667)
# ('#', 607, 'Actual = ', 1, 'Predictioned = ', 4.279704504504505)
# ('#', 608, 'Actual = ', 4, 'Predictioned = ', 5.566866666666667)
# ('#', 609, 'Actual = ', 5, 'Predictioned = ', 3.0252000000000003)
# ('#', 610, 'Actual = ', 5, 'Predictioned = ', 5.691866666666667)
# ('#', 611, 'Actual = ', 5, 'Predictioned = ', 5.441866666666667)
# ('#', 612, 'Actual = ', 5, 'Predictioned = ', 1.0668666666666669)
# ('#', 613, 'Actual = ', 4, 'Predictioned = ', 1.7752)
# ('#', 614, 'Actual = ', 5, 'Predictioned = ', 5.2752)
# ('#', 615, 'Actual = ', 4, 'Predictioned = ', 4.660742168674699)
# ('#', 616, 'Actual = ', 5, 'Predictioned = ', 5.370438095238096)
# ('#', 617, 'Actual = ', 5, 'Predictioned = ', 5.7752)
# ('#', 618, 'Actual = ', 5, 'Predictioned = ', 4.927160784313726)
# ('#', 619, 'Actual = ', 4, 'Predictioned = ', 3.5252000000000003)
# ('#', 620, 'Actual = ', 5, 'Predictioned = ', 5.374299099099099)
# ('#', 621, 'Actual = ', 5, 'Predictioned = ', 5.137518840579711)
# ('#', 622, 'Actual = ', 5, 'Predictioned = ', 4.964088888888889)
# ('#', 623, 'Actual = ', 5, 'Predictioned = ', 4.538765891472869)
# ('#', 624, 'Actual = ', 5, 'Predictioned = ', 4.391866666666667)
# ('#', 625, 'Actual = ', 4, 'Predictioned = ', 5.191866666666667)
# ('#', 626, 'Actual = ', 5, 'Predictioned = ', 4.656152380952381)
# ('#', 627, 'Actual = ', 5, 'Predictioned = ', 4.4743341991342)
# ('#', 628, 'Actual = ', 5, 'Predictioned = ', 5.241866666666667)
# ('#', 629, 'Actual = ', 5, 'Predictioned = ', 5.066866666666667)
# ('#', 630, 'Actual = ', 4, 'Predictioned = ', 4.156152380952381)
# ('#', 631, 'Actual = ', 5, 'Predictioned = ', 4.656152380952381)
# ('#', 632, 'Actual = ', 4, 'Predictioned = ', 4.370438095238095)
# ('#', 633, 'Actual = ', 4, 'Predictioned = ', 3.3704380952380952)
# ('#', 634, 'Actual = ', 5, 'Predictioned = ', 5.416442937853107)
# ('#', 635, 'Actual = ', 5, 'Predictioned = ', 5.191866666666667)
# ('#', 636, 'Actual = ', 3, 'Predictioned = ', 3.941866666666667)
# ('#', 637, 'Actual = ', 4, 'Predictioned = ', 3.297422222222222)
# ('#', 638, 'Actual = ', 5, 'Predictioned = ', 5.4761132420091325)
# ('#', 639, 'Actual = ', 5, 'Predictioned = ', 4.608533333333334)
# ('#', 640, 'Actual = ', 4, 'Predictioned = ', 1.7030606965174133)
# ('#', 641, 'Actual = ', 5, 'Predictioned = ', 1.1279131782945742)
# ('#', 642, 'Actual = ', 4, 'Predictioned = ', 5.008533333333334)
# ('#', 643, 'Actual = ', 4, 'Predictioned = ', 5.358533333333334)
# ('#', 644, 'Actual = ', 5, 'Predictioned = ', 4.9152)
# ('#', 645, 'Actual = ', 4, 'Predictioned = ', 4.2752)
# ('#', 646, 'Actual = ', 4, 'Predictioned = ', 4.608533333333334)
# ('#', 647, 'Actual = ', 4, 'Predictioned = ', 5.1323428571428575)
# ('#', 648, 'Actual = ', 5, 'Predictioned = ', 5.621866666666667)
# ('#', 649, 'Actual = ', 1, 'Predictioned = ', 5.266190990990991)
# ('#', 650, 'Actual = ', 2, 'Predictioned = ', 2.800841025641026)
# ('#', 651, 'Actual = ', 5, 'Predictioned = ', 4.300841025641025)
# ('#', 652, 'Actual = ', 5, 'Predictioned = ', 5.36494358974359)
# ('#', 653, 'Actual = ', 4, 'Predictioned = ', 5.824219607843138)
# ('#', 654, 'Actual = ', 5, 'Predictioned = ', 4.941866666666667)
# ('#', 655, 'Actual = ', 5, 'Predictioned = ', 5.337215503875969)
# ('#', 656, 'Actual = ', 5, 'Predictioned = ', 5.213529430132709)
# ('#', 657, 'Actual = ', 4, 'Predictioned = ', 5.1323428571428575)
# ('#', 658, 'Actual = ', 5, 'Predictioned = ', 5.487321212121213)
# ('#', 659, 'Actual = ', 5, 'Predictioned = ', 3.941866666666667)
# ('#', 660, 'Actual = ', 1, 'Predictioned = ', 2.941866666666667)
# ('#', 661, 'Actual = ', 3, 'Predictioned = ', 3.191866666666667)
# ('#', 662, 'Actual = ', 5, 'Predictioned = ', 4.341866666666667)
# ('#', 663, 'Actual = ', 5, 'Predictioned = ', 3.941866666666667)
# ('#', 664, 'Actual = ', 5, 'Predictioned = ', 3.629366666666667)
# ('#', 665, 'Actual = ', 5, 'Predictioned = ', 4.504366666666667)
# ('#', 666, 'Actual = ', 4, 'Predictioned = ', 3.830755555555556)
# ('#', 667, 'Actual = ', 2, 'Predictioned = ', 3.0926603174603176)
# ('#', 668, 'Actual = ', 5, 'Predictioned = ', 5.7752)
# ('#', 669, 'Actual = ', 4, 'Predictioned = ', 5.629366666666667)
# ('#', 670, 'Actual = ', 4, 'Predictioned = ', 1.9974222222222227)
# ('#', 671, 'Actual = ', 5, 'Predictioned = ', 3.1752000000000007)
# ('#', 672, 'Actual = ', 4, 'Predictioned = ', 4.6502)
# ('#', 673, 'Actual = ', 4, 'Predictioned = ', 4.2752)
# ('#', 674, 'Actual = ', 5, 'Predictioned = ', 5.227580952380952)
# ('#', 675, 'Actual = ', 5, 'Predictioned = ', 5.586726479750779)
# ('#', 676, 'Actual = ', 5, 'Predictioned = ', 5.608533333333334)
# ('#', 677, 'Actual = ', 5, 'Predictioned = ', 5.941866666666667)
# ('#', 678, 'Actual = ', 4, 'Predictioned = ', 5.1236848484848485)
# ('#', 679, 'Actual = ', 4, 'Predictioned = ', 5.341866666666667)
# ('#', 680, 'Actual = ', 5, 'Predictioned = ', 4.409399134199134)
# ('#', 681, 'Actual = ', 5, 'Predictioned = ', 4.933463305322129)
# ('#', 682, 'Actual = ', 1, 'Predictioned = ', 3.7275809523809524)
# ('#', 683, 'Actual = ', 5, 'Predictioned = ', 4.040080952380952)
# ('#', 684, 'Actual = ', 5, 'Predictioned = ', 4.330755555555555)
# ('#', 685, 'Actual = ', 4, 'Predictioned = ', 4.675909219858156)
# ('#', 686, 'Actual = ', 5, 'Predictioned = ', 3.641866666666667)
# ('#', 687, 'Actual = ', 5, 'Predictioned = ', 4.437321212121213)
# ('#', 688, 'Actual = ', 1, 'Predictioned = ', 4.427580952380953)
# ('#', 689, 'Actual = ', 5, 'Predictioned = ', 3.8018666666666667)
# ('#', 690, 'Actual = ', 5, 'Predictioned = ', 3.3085333333333335)
# ('#', 691, 'Actual = ', 4, 'Predictioned = ', 4.024219607843138)
# ('#', 692, 'Actual = ', 5, 'Predictioned = ', 5.586726479750779)
# ('#', 693, 'Actual = ', 5, 'Predictioned = ', 5.432432704402516)
# ('#', 694, 'Actual = ', 1, 'Predictioned = ', 1.9228190476190479)
# ('#', 695, 'Actual = ', 5, 'Predictioned = ', 3.0085333333333333)
# ('#', 696, 'Actual = ', 5, 'Predictioned = ', 4.808533333333334)
# ('#', 697, 'Actual = ', 4, 'Predictioned = ', 4.808533333333334)
# ('#', 698, 'Actual = ', 5, 'Predictioned = ', 1.1279131782945742)
# ('#', 699, 'Actual = ', 1, 'Predictioned = ', 0.9418666666666669)
# ('#', 700, 'Actual = ', 5, 'Predictioned = ', 5.586726479750779)
# ('#', 701, 'Actual = ', 5, 'Predictioned = ', 5.341866666666667)
# ('#', 702, 'Actual = ', 5, 'Predictioned = ', 5.330755555555556)
# ('#', 703, 'Actual = ', 5, 'Predictioned = ', 5.137518840579711)
# ('#', 704, 'Actual = ', 4, 'Predictioned = ', 3.3585333333333334)
# ('#', 705, 'Actual = ', 5, 'Predictioned = ', 3.6085333333333334)
# ('#', 706, 'Actual = ', 4, 'Predictioned = ', 2.7948078431372547)
# ('#', 707, 'Actual = ', 4, 'Predictioned = ', 1.4418666666666669)
# ('#', 708, 'Actual = ', 3, 'Predictioned = ', 4.38472380952381)
# ('#', 709, 'Actual = ', 4, 'Predictioned = ', 4.137215503875969)
# ('#', 710, 'Actual = ', 2, 'Predictioned = ', 3.864347286821706)
# ('#', 711, 'Actual = ', 5, 'Predictioned = ', 4.699442424242425)
# ('#', 712, 'Actual = ', 5, 'Predictioned = ', 4.801866666666667)
# ('#', 713, 'Actual = ', 5, 'Predictioned = ', 5.427580952380953)
# ('#', 714, 'Actual = ', 3, 'Predictioned = ', 5.032775757575758)
# ('#', 715, 'Actual = ', 5, 'Predictioned = ', 4.566866666666667)
# ('#', 716, 'Actual = ', 5, 'Predictioned = ', 5.164088888888889)
# ('#', 717, 'Actual = ', 5, 'Predictioned = ', 3.8307555555555557)
# ('#', 718, 'Actual = ', 5, 'Predictioned = ', 5.191866666666667)
# ('#', 719, 'Actual = ', 5, 'Predictioned = ', 5.621866666666667)
# ('#', 720, 'Actual = ', 4, 'Predictioned = ', 4.171374863387978)
# ('#', 721, 'Actual = ', 3, 'Predictioned = ', 4.091866666666667)
# ('#', 722, 'Actual = ', 5, 'Predictioned = ', 3.6085333333333334)
# ('#', 723, 'Actual = ', 5, 'Predictioned = ', 3.9940755020080325)
# ('#', 724, 'Actual = ', 3, 'Predictioned = ', 5.608533333333334)
# ('#', 725, 'Actual = ', 5, 'Predictioned = ', 5.941866666666667)
# ('#', 726, 'Actual = ', 4, 'Predictioned = ', 3.2085333333333335)
# ('#', 727, 'Actual = ', 3, 'Predictioned = ', 3.541866666666667)
# ('#', 728, 'Actual = ', 2, 'Predictioned = ', 4.691866666666667)
# ('#', 729, 'Actual = ', 5, 'Predictioned = ', 3.691866666666667)
# ('#', 730, 'Actual = ', 5, 'Predictioned = ', 5.441866666666667)
# ('#', 731, 'Actual = ', 5, 'Predictioned = ', 5.271691228070176)
# ('#', 732, 'Actual = ', 3, 'Predictioned = ', 3.0918666666666668)
# ('#', 733, 'Actual = ', 5, 'Predictioned = ', 3.3418666666666668)
# ('#', 734, 'Actual = ', 4, 'Predictioned = ', 3.941866666666667)
# ('#', 735, 'Actual = ', 5, 'Predictioned = ', 3.691866666666667)
# ('#', 736, 'Actual = ', 3, 'Predictioned = ', 3.8942476190476194)
# ('#', 737, 'Actual = ', 5, 'Predictioned = ', 3.7493200828157347)
# ('#', 738, 'Actual = ', 3, 'Predictioned = ', 2.095712820512821)
# ('#', 739, 'Actual = ', 5, 'Predictioned = ', 2.941866666666667)
# ('#', 740, 'Actual = ', 4, 'Predictioned = ', 4.457995698924732)
# ('#', 741, 'Actual = ', 1, 'Predictioned = ', 3.812834408602151)
# ('#', 742, 'Actual = ', 5, 'Predictioned = ', 2.391866666666667)
# ('#', 743, 'Actual = ', 5, 'Predictioned = ', 1.5863111111111117)
# ('#', 744, 'Actual = ', 5, 'Predictioned = ', 4.408533333333334)
# ('#', 745, 'Actual = ', 3, 'Predictioned = ', 4.441866666666667)
# ('#', 746, 'Actual = ', 3, 'Predictioned = ', 1.7085333333333335)
# ('#', 747, 'Actual = ', 3, 'Predictioned = ', 2.2752)
# ...
# ('#', 4758, 'Actual = ', 4, 'Predictioned = ', 4.737104761904763)
# ('#', 4759, 'Actual = ', 5, 'Predictioned = ', 5.513295238095239)
# ('#', 4760, 'Actual = ', 5, 'Predictioned = ', 5.441866666666667)
# ('#', 4761, 'Actual = ', 5, 'Predictioned = ', 5.1502)
# ('#', 4762, 'Actual = ', 5, 'Predictioned = ', 3.2752)
# ('#', 4763, 'Actual = ', 5, 'Predictioned = ', 3.6085333333333334)
# ('#', 4764, 'Actual = ', 5, 'Predictioned = ', 4.961097435897436)
# ('#', 4765, 'Actual = ', 5, 'Predictioned = ', 4.461097435897436)
# ('#', 4766, 'Actual = ', 3, 'Predictioned = ', 3.066866666666667)
# ('#', 4767, 'Actual = ', 4, 'Predictioned = ', 3.441866666666667)
# ('#', 4768, 'Actual = ', 4, 'Predictioned = ', 1.6085333333333338)
# ('#', 4769, 'Actual = ', 4, 'Predictioned = ', 1.5828923076923078)
# ('#', 4770, 'Actual = ', 3, 'Predictioned = ', 2.497422222222222)
# ('#', 4771, 'Actual = ', 5, 'Predictioned = ', 3.941866666666667)
# ('#', 4772, 'Actual = ', 4, 'Predictioned = ', 4.741866666666667)
# ('#', 4773, 'Actual = ', 5, 'Predictioned = ', 5.015940740740741)
# ('#', 4774, 'Actual = ', 5, 'Predictioned = ', 4.67336772374912)
# ('#', 4775, 'Actual = ', 5, 'Predictioned = ', 4.815446212121213)
# ('#', 4776, 'Actual = ', 5, 'Predictioned = ', 2.1726358974358977)
# ('#', 4777, 'Actual = ', 1, 'Predictioned = ', 2.2752)
# ('#', 4778, 'Actual = ', 5, 'Predictioned = ', 4.213234188034188)
# ('#', 4779, 'Actual = ', 5, 'Predictioned = ', 4.161646886446887)
# ('#', 4780, 'Actual = ', 5, 'Predictioned = ', 4.896412121212121)
# ('#', 4781, 'Actual = ', 5, 'Predictioned = ', 5.441866666666667)
# ('#', 4782, 'Actual = ', 3, 'Predictioned = ', 3.3418666666666668)
# ('#', 4783, 'Actual = ', 5, 'Predictioned = ', 3.8752)
# ('#', 4784, 'Actual = ', 5, 'Predictioned = ', 4.671963754045308)
# ('#', 4785, 'Actual = ', 5, 'Predictioned = ', 4.641866666666667)
# ('#', 4786, 'Actual = ', 5, 'Predictioned = ', 5.330755555555556)
# ('#', 4787, 'Actual = ', 4, 'Predictioned = ', 5.608533333333334)
# ('#', 4788, 'Actual = ', 5, 'Predictioned = ', 4.691866666666667)
# ('#', 4789, 'Actual = ', 5, 'Predictioned = ', 4.491866666666667)
# ('#', 4790, 'Actual = ', 5, 'Predictioned = ', 5.2085333333333335)
# ('#', 4791, 'Actual = ', 5, 'Predictioned = ', 5.355659770114943)
# ('#', 4792, 'Actual = ', 4, 'Predictioned = ', 4.941866666666667)
# ('#', 4793, 'Actual = ', 5, 'Predictioned = ', 5.608533333333334)
# ('#', 4794, 'Actual = ', 3, 'Predictioned = ', 3.0252)
# ('#', 4795, 'Actual = ', 4, 'Predictioned = ', 4.386311111111111)
# ('#', 4796, 'Actual = ', 5, 'Predictioned = ', 4.156152380952381)
# ('#', 4797, 'Actual = ', 4, 'Predictioned = ', 4.2752)
# ('#', 4798, 'Actual = ', 3, 'Predictioned = ', 2.066866666666667)
# ('#', 4799, 'Actual = ', 4, 'Predictioned = ', 0.9418666666666669)
# ('#', 4800, 'Actual = ', 4, 'Predictioned = ', 1.9418666666666669)
# ('#', 4801, 'Actual = ', 4, 'Predictioned = ', 3.2373212121212127)
# ('#', 4802, 'Actual = ', 4, 'Predictioned = ', 3.9696444444444445)
# ('#', 4803, 'Actual = ', 4, 'Predictioned = ', 4.5252)
# ('#', 4804, 'Actual = ', 4, 'Predictioned = ', 3.3585333333333334)
# ('#', 4805, 'Actual = ', 5, 'Predictioned = ', 2.7871047619047618)
# ('#', 4806, 'Actual = ', 1, 'Predictioned = ', 3.6085333333333334)
# ('#', 4807, 'Actual = ', 5, 'Predictioned = ', 4.605024561403509)
# ('#', 4808, 'Actual = ', 5, 'Predictioned = ', 4.441866666666667)
# ('#', 4809, 'Actual = ', 3, 'Predictioned = ', 4.08472380952381)
# ('#', 4810, 'Actual = ', 5, 'Predictioned = ', 4.5625563218390806)
# ('#', 4811, 'Actual = ', 5, 'Predictioned = ', 4.978903703703704)
# ('#', 4812, 'Actual = ', 5, 'Predictioned = ', 4.656152380952381)
# ('#', 4813, 'Actual = ', 5, 'Predictioned = ', 5.108533333333334)
# ('#', 4814, 'Actual = ', 4, 'Predictioned = ', 1.6894204827136337)
# ('#', 4815, 'Actual = ', 3, 'Predictioned = ', 2.179009523809524)
# ('#', 4816, 'Actual = ', 5, 'Predictioned = ', 5.4761132420091325)
# ('#', 4817, 'Actual = ', 3, 'Predictioned = ', 3.441866666666667)
# ('#', 4818, 'Actual = ', 2, 'Predictioned = ', 2.941866666666667)
# ('#', 4819, 'Actual = ', 1, 'Predictioned = ', 4.691866666666667)
# ('#', 4820, 'Actual = ', 3, 'Predictioned = ', 4.1363111111111115)
# ('#', 4821, 'Actual = ', 5, 'Predictioned = ', 4.5018666666666665)
# ('#', 4822, 'Actual = ', 5, 'Predictioned = ', 4.941866666666667)
# ('#', 4823, 'Actual = ', 5, 'Predictioned = ', 4.741866666666667)
# ('#', 4824, 'Actual = ', 4, 'Predictioned = ', 2.441866666666667)
# ('#', 4825, 'Actual = ', 5, 'Predictioned = ', 4.691866666666667)
# ('#', 4826, 'Actual = ', 4, 'Predictioned = ', 4.116866666666667)
# ('#', 4827, 'Actual = ', 4, 'Predictioned = ', 1.9835333333333334)
# ('#', 4828, 'Actual = ', 5, 'Predictioned = ', 4.941866666666667)
# ('#', 4829, 'Actual = ', 5, 'Predictioned = ', 5.441866666666667)
# ('#', 4830, 'Actual = ', 4, 'Predictioned = ', 2.6969687074829936)
# ('#', 4831, 'Actual = ', 1, 'Predictioned = ', 1.9418666666666669)
# ('#', 4832, 'Actual = ', 5, 'Predictioned = ', 5.108533333333334)
# ('#', 4833, 'Actual = ', 5, 'Predictioned = ', 4.390351515151515)
# ('#', 4834, 'Actual = ', 3, 'Predictioned = ', 5.626077192982456)
# ('#', 4835, 'Actual = ', 5, 'Predictioned = ', 4.941866666666667)
# ('#', 4836, 'Actual = ', 4, 'Predictioned = ', 5.043315942028986)
# ('#', 4837, 'Actual = ', 4, 'Predictioned = ', 4.98784367816092)
# ('#', 4838, 'Actual = ', 5, 'Predictioned = ', 4.691866666666667)
# ('#', 4839, 'Actual = ', 5, 'Predictioned = ', 4.2261132420091325)
# ('#', 4840, 'Actual = ', 5, 'Predictioned = ', 4.621866666666667)
# ('#', 4841, 'Actual = ', 5, 'Predictioned = ', 3.641866666666667)
# ('#', 4842, 'Actual = ', 5, 'Predictioned = ', 4.691866666666667)
# ('#', 4843, 'Actual = ', 5, 'Predictioned = ', 4.241866666666667)
# ('#', 4844, 'Actual = ', 5, 'Predictioned = ', 3.6918666666666673)
# ('#', 4845, 'Actual = ', 5, 'Predictioned = ', 3.8661909909909915)
# ('#', 4846, 'Actual = ', 5, 'Predictioned = ', 5.4761132420091325)
# ('#', 4847, 'Actual = ', 5, 'Predictioned = ', 5.370438095238096)
# ('#', 4848, 'Actual = ', 3, 'Predictioned = ', 4.041866666666667)
# ('#', 4849, 'Actual = ', 5, 'Predictioned = ', 4.432775757575758)
# ('#', 4850, 'Actual = ', 5, 'Predictioned = ', 4.779704504504505)
# ('#', 4851, 'Actual = ', 5, 'Predictioned = ', 5.227580952380952)
# ('#', 4852, 'Actual = ', 5, 'Predictioned = ', 5.941866666666667)
# ('#', 4853, 'Actual = ', 5, 'Predictioned = ', 5.691866666666667)
# ('#', 4854, 'Actual = ', 4, 'Predictioned = ', 3.7497762711864406)
# ('#', 4855, 'Actual = ', 4, 'Predictioned = ', 2.7752000000000003)
# ('#', 4856, 'Actual = ', 1, 'Predictioned = ', 3.941866666666667)
# ('#', 4857, 'Actual = ', 5, 'Predictioned = ', 3.497422222222222)
# ('#', 4858, 'Actual = ', 4, 'Predictioned = ', 1.3766492753623192)
# ('#', 4859, 'Actual = ', 2, 'Predictioned = ', 0.9418666666666669)
# ('#', 4860, 'Actual = ', 5, 'Predictioned = ', 4.341866666666667)
# ('#', 4861, 'Actual = ', 4, 'Predictioned = ', 4.137518840579711)
# ('#', 4862, 'Actual = ', 4, 'Predictioned = ', 2.560914285714286)
# ('#', 4863, 'Actual = ', 5, 'Predictioned = ', 3.4612465116279076)
# ('#', 4864, 'Actual = ', 3, 'Predictioned = ', 4.230328205128205)
# ('#', 4865, 'Actual = ', 5, 'Predictioned = ', 3.980328205128205)
# ('#', 4866, 'Actual = ', 4, 'Predictioned = ', 5.7752)
# ('#', 4867, 'Actual = ', 5, 'Predictioned = ', 5.330755555555556)
# ('#', 4868, 'Actual = ', 5, 'Predictioned = ', 4.793515018315019)
# ('#', 4869, 'Actual = ', 4, 'Predictioned = ', 4.770438095238096)
# ('#', 4870, 'Actual = ', 5, 'Predictioned = ', 3.7807555555555563)
# ('#', 4871, 'Actual = ', 4, 'Predictioned = ', 4.308533333333334)
# ('#', 4872, 'Actual = ', 1, 'Predictioned = ', 4.741866666666667)
# ('#', 4873, 'Actual = ', 5, 'Predictioned = ', 4.541866666666667)
# ('#', 4874, 'Actual = ', 5, 'Predictioned = ', 4.808533333333334)
# ('#', 4875, 'Actual = ', 5, 'Predictioned = ', 4.408533333333334)
# ('#', 4876, 'Actual = ', 2, 'Predictioned = ', 5.361221505376344)
# ('#', 4877, 'Actual = ', 5, 'Predictioned = ', 5.760048484848485)
# ('#', 4878, 'Actual = ', 1, 'Predictioned = ', 4.941866666666667)
# ('#', 4879, 'Actual = ', 1, 'Predictioned = ', 4.941866666666667)
# ('#', 4880, 'Actual = ', 5, 'Predictioned = ', 3.7734456140350883)
# ('#', 4881, 'Actual = ', 2, 'Predictioned = ', 2.341866666666667)
# ('#', 4882, 'Actual = ', 1, 'Predictioned = ', 5.741866666666667)
# ('#', 4883, 'Actual = ', 3, 'Predictioned = ', 3.9918666666666667)
# ('#', 4884, 'Actual = ', 5, 'Predictioned = ', 4.999243715846995)
# ('#', 4885, 'Actual = ', 5, 'Predictioned = ', 4.441866666666667)
# ('#', 4886, 'Actual = ', 5, 'Predictioned = ', 4.608533333333334)
# ('#', 4887, 'Actual = ', 5, 'Predictioned = ', 4.158533333333334)
# ('#', 4888, 'Actual = ', 5, 'Predictioned = ', 5.2752)
# ('#', 4889, 'Actual = ', 5, 'Predictioned = ', 5.2752)
# ('#', 4890, 'Actual = ', 5, 'Predictioned = ', 3.1375188405797108)
# ('#', 4891, 'Actual = ', 5, 'Predictioned = ', 2.191866666666667)
# ('#', 4892, 'Actual = ', 3, 'Predictioned = ', -0.28035555555555547)
# ('#', 4893, 'Actual = ', 4, 'Predictioned = ', 1.6085333333333338)
# ('#', 4894, 'Actual = ', 5, 'Predictioned = ', 4.941866666666667)
# ('#', 4895, 'Actual = ', 5, 'Predictioned = ', 5.448445614035088)
# ('#', 4896, 'Actual = ', 5, 'Predictioned = ', 4.532775757575758)
# ('#', 4897, 'Actual = ', 4, 'Predictioned = ', 4.341866666666667)
# ('#', 4898, 'Actual = ', 2, 'Predictioned = ', 1.9418666666666669)
# ('#', 4899, 'Actual = ', 4, 'Predictioned = ', 4.729745454545454)
# ('#', 4900, 'Actual = ', 5, 'Predictioned = ', 5.036394029850746)
# ('#', 4901, 'Actual = ', 2, 'Predictioned = ', 4.341866666666667)
# ('#', 4902, 'Actual = ', 4, 'Predictioned = ', 3.841866666666667)
# ('#', 4903, 'Actual = ', 5, 'Predictioned = ', 1.2632952380952385)
# ('#', 4904, 'Actual = ', 1, 'Predictioned = ', 2.179961904761905)
# ('#', 4905, 'Actual = ', 5, 'Predictioned = ', 2.608533333333334)
# ('#', 4906, 'Actual = ', 5, 'Predictioned = ', 4.7752)
# ('#', 4907, 'Actual = ', 5, 'Predictioned = ', 4.941866666666667)
# ('#', 4908, 'Actual = ', 5, 'Predictioned = ', 5.341866666666667)
# ('#', 4909, 'Actual = ', 5, 'Predictioned = ', 5.941866666666667)
# ('#', 4910, 'Actual = ', 2, 'Predictioned = ', 3.441866666666667)
# ('#', 4911, 'Actual = ', 5, 'Predictioned = ', 4.256152380952382)
# ('#', 4912, 'Actual = ', 5, 'Predictioned = ', 4.747881704260652)
# ('#', 4913, 'Actual = ', 5, 'Predictioned = ', 5.091866666666667)
# ('#', 4914, 'Actual = ', 5, 'Predictioned = ', 5.172635897435898)
# ('#', 4915, 'Actual = ', 5, 'Predictioned = ', 4.841866666666667)
# ('#', 4916, 'Actual = ', 5, 'Predictioned = ', 5.167448062015504)
# ('#', 4917, 'Actual = ', 5, 'Predictioned = ', 3.7497762711864406)
# ('#', 4918, 'Actual = ', 4, 'Predictioned = ', 3.1461677419354843)
# ('#', 4919, 'Actual = ', 4, 'Predictioned = ', 2.7752000000000003)
# ('#', 4920, 'Actual = ', 4, 'Predictioned = ', 4.2752)
# ('#', 4921, 'Actual = ', 1, 'Predictioned = ', 1.6085333333333334)
# ('#', 4922, 'Actual = ', 1, 'Predictioned = ', 0.7418666666666667)
# ('#', 4923, 'Actual = ', 5, 'Predictioned = ', 4.036394029850747)
# ('#', 4924, 'Actual = ', 5, 'Predictioned = ', 3.2752000000000003)
# ('#', 4925, 'Actual = ', 1, 'Predictioned = ', 3.2752)
# ('#', 4926, 'Actual = ', 1, 'Predictioned = ', 2.9418666666666664)
# ('#', 4927, 'Actual = ', 5, 'Predictioned = ', 4.441866666666667)
# ('#', 4928, 'Actual = ', 5, 'Predictioned = ', 4.441866666666667)
# ('#', 4929, 'Actual = ', 3, 'Predictioned = ', 2.812834408602151)
# ('#', 4930, 'Actual = ', 5, 'Predictioned = ', 3.416442937853107)
# ('#', 4931, 'Actual = ', 5, 'Predictioned = ', 5.341866666666667)
# ('#', 4932, 'Actual = ', 5, 'Predictioned = ', 5.2085333333333335)
# ('#', 4933, 'Actual = ', 5, 'Predictioned = ', 4.941866666666667)
# ('#', 4934, 'Actual = ', 5, 'Predictioned = ', 4.441866666666667)
# ('#', 4935, 'Actual = ', 5, 'Predictioned = ', 3.941866666666667)
# ('#', 4936, 'Actual = ', 5, 'Predictioned = ', 3.841866666666667)
# ('#', 4937, 'Actual = ', 5, 'Predictioned = ', 2.4037714285714293)
# ('#', 4938, 'Actual = ', 5, 'Predictioned = ', 1.5479272727272733)
# ('#', 4939, 'Actual = ', 5, 'Predictioned = ', 4.580755555555556)
# ('#', 4940, 'Actual = ', 5, 'Predictioned = ', 4.656152380952381)
# ('#', 4941, 'Actual = ', 5, 'Predictioned = ', 3.608533333333334)
# ('#', 4942, 'Actual = ', 5, 'Predictioned = ', 4.0252)
# ('#', 4943, 'Actual = ', 5, 'Predictioned = ', 4.670548837209302)
# ('#', 4944, 'Actual = ', 5, 'Predictioned = ', 4.049393548387097)
# ('#', 4945, 'Actual = ', 5, 'Predictioned = ', 4.041866666666667)
# ('#', 4946, 'Actual = ', 4, 'Predictioned = ', 4.441866666666667)
# ('#', 4947, 'Actual = ', 5, 'Predictioned = ', 4.691866666666667)
# ('#', 4948, 'Actual = ', 5, 'Predictioned = ', 5.7752)
# ('#', 4949, 'Actual = ', 3, 'Predictioned = ', 1.595712820512821)
# ('#', 4950, 'Actual = ', 4, 'Predictioned = ', 1.8211770114942532)
# ('#', 4951, 'Actual = ', 1, 'Predictioned = ', 3.3085333333333335)
# ('#', 4952, 'Actual = ', 2, 'Predictioned = ', 3.4061523809523813)
# ('#', 4953, 'Actual = ', 5, 'Predictioned = ', 4.356008080808081)
# ('#', 4954, 'Actual = ', 5, 'Predictioned = ', 4.608533333333334)
# ('#', 4955, 'Actual = ', 1, 'Predictioned = ', 4.941866666666667)
# ('#', 4956, 'Actual = ', 2, 'Predictioned = ', 4.696968707482993)
# ('#', 4957, 'Actual = ', 5, 'Predictioned = ', 5.394498245614035)
# ('#', 4958, 'Actual = ', 2, 'Predictioned = ', 4.841866666666666)
# ('#', 4959, 'Actual = ', 5, 'Predictioned = ', 4.341866666666667)
# ('#', 4960, 'Actual = ', 5, 'Predictioned = ', 3.913295238095239)
# ('#', 4961, 'Actual = ', 4, 'Predictioned = ', 4.108533333333334)
# ('#', 4962, 'Actual = ', 1, 'Predictioned = ', 4.191866666666667)
# ('#', 4963, 'Actual = ', 5, 'Predictioned = ', 3.7016069264069267)
# ('#', 4964, 'Actual = ', 3, 'Predictioned = ', 2.931765656565657)
# ('#', 4965, 'Actual = ', 3, 'Predictioned = ', 4.529424270353303)
# ('#', 4966, 'Actual = ', 5, 'Predictioned = ', 4.299009523809524)
# ('#', 4967, 'Actual = ', 4, 'Predictioned = ', 5.616866666666667)
# ('#', 4968, 'Actual = ', 5, 'Predictioned = ', 5.257995698924732)
# ('#', 4969, 'Actual = ', 5, 'Predictioned = ', 3.808533333333334)
# ('#', 4970, 'Actual = ', 5, 'Predictioned = ', 4.9386304207119744)
# ('#', 4971, 'Actual = ', 4, 'Predictioned = ', 3.850957575757576)
# ('#', 4972, 'Actual = ', 3, 'Predictioned = ', 3.8964121212121214)
# ('#', 4973, 'Actual = ', 5, 'Predictioned = ', 3.191866666666667)
# ('#', 4974, 'Actual = ', 5, 'Predictioned = ', 4.358533333333334)
# ('#', 4975, 'Actual = ', 5, 'Predictioned = ', 5.465676190476191)
# ('#', 4976, 'Actual = ', 5, 'Predictioned = ', 5.214593939393939)
# ('#', 4977, 'Actual = ', 5, 'Predictioned = ', 4.894247619047619)
# ('#', 4978, 'Actual = ', 5, 'Predictioned = ', 5.691866666666667)
# ('#', 4979, 'Actual = ', 4, 'Predictioned = ', 4.608533333333334)
# ('#', 4980, 'Actual = ', 4, 'Predictioned = ', 4.2752)
# ('#', 4981, 'Actual = ', 5, 'Predictioned = ', 5.172635897435898)
# ('#', 4982, 'Actual = ', 5, 'Predictioned = ', 5.432432704402516)
# ('#', 4983, 'Actual = ', 5, 'Predictioned = ', 5.396412121212121)
# ('#', 4984, 'Actual = ', 5, 'Predictioned = ', 5.070438095238096)
# ('#', 4985, 'Actual = ', 5, 'Predictioned = ', 3.691866666666667)
# ('#', 4986, 'Actual = ', 5, 'Predictioned = ', 5.0418666666666665)
# ('#', 4987, 'Actual = ', 5, 'Predictioned = ', 5.416442937853107)
# ('#', 4988, 'Actual = ', 5, 'Predictioned = ', 5.418057142857143)
# ('#', 4989, 'Actual = ', 5, 'Predictioned = ', 5.441866666666667)
# ('#', 4990, 'Actual = ', 5, 'Predictioned = ', 5.941866666666667)
# ('#', 4991, 'Actual = ', 5, 'Predictioned = ', 5.321866666666667)
# ('#', 4992, 'Actual = ', 5, 'Predictioned = ', 5.941866666666667)
# ('#', 4993, 'Actual = ', 5, 'Predictioned = ', 4.830755555555556)
# ('#', 4994, 'Actual = ', 4, 'Predictioned = ', 5.322819047619048)
# ('#', 4995, 'Actual = ', 4, 'Predictioned = ', 4.586311111111112)
# ('#', 4996, 'Actual = ', 5, 'Predictioned = ', 4.805024561403509)
# ('#', 4997, 'Actual = ', 4, 'Predictioned = ', 1.2752000000000003)
# ('#', 4998, 'Actual = ', 4, 'Predictioned = ', 3.3944982456140353)
# ('#', 4999, 'Actual = ', 5, 'Predictioned = ', 4.641866666666667)
# ('#', 5000, 'Actual = ', 4, 'Predictioned = ', 5.237321212121213)
# Done Predicting in 1.24 seconds

# %%
print "MAE=", MAE
print "RMSE=", RMSE
# Out:
# MAE= 1.0
# RMSE= 1.37

# %%
sparse_ratings = csr_matrix(ratings_matrix, dtype='float')

# %%
model_knn = NearestNeighbors(metric = 'cosine', n_neighbors = 6)
model_knn.fit(sparse_ratings)
# Out:
# NearestNeighbors(algorithm='auto', leaf_size=30, metric='cosine',
#          metric_params=None, n_jobs=1, n_neighbors=6, p=2, radius=1.0)

# %%
def get_recommendations(user_index, n_reccomendations=5, n_neighbors=10):
    distances,indices = model_knn.kneighbors(ratings_matrix[user_index].reshape(1, -1), n_neighbors=n_neighbors)
    probable_items = list()
    for user in indices[0]:
        if user == user_index:
            print "Recommendations for user ", unique_users[user_index]
            continue
        # all other users
        for items in np.nonzero(ratings_matrix[user]):
            for item in items:
                if ratings_matrix[user_index][item] == 0:
                    probable_items.append(unique_items[item])

    predictions = {}
    for item in probable_items:
        predictions[item] = predict(unique_users[0], item)
        sorted_predictions = sorted(predictions.items(), key=operator.itemgetter(1))
    return [i[0] for i in sorted_predictions[:n_reccomendations]]

# %%
def get_user_items_rated_df(user_id):
    df = pd.DataFrame()
    np.nonzero(ratings_matrix[user_id])
    for i in np.nonzero(ratings_matrix[user_id]):
        x = pd.DataFrame({"item":unique_items[i], "rating":ratings_matrix[user_id][i]})
        df = df.append(x)
        return df

def print_items_rated(user_id):
    np.nonzero(ratings_matrix[user_id])
    for i in unique_items[np.nonzero(ratings_matrix[user_id])]:
        print i

# %%
get_user_items_rated_df(0)
# Out:
#          item rating
# 0  B004WGGQPQ      5
# 1  B006C1ZSO4      5
# 2  B007KPT2N4      1
# 3  B0080JJLBW      5
# 4  B008LY1B32      4
# 5  B009P8EMCK      5
# 6  B00AMR1HZ8      4
# 7  B00ANT8OF6      4

# %%
for i in get_recommendations(user_index=1):
    print i
# Out:
# Recommendations for user  A001619027H9L9EG4UVRB
# B00529IOXO
# B00G5LQ5MU
# B00CZDSK7K
# B008Y7SMQU
# B00992CF6W
