# %%
# Imports 
import pandas as pd
import numpy as np
import time
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.neighbors import NearestNeighbors
from scipy.sparse import csr_matrix
import operator

# %%
# load the data, keep only selected columns
# Read the file using super fast Pandas.read_csv
def load_required_data(path, required_columns):
    dataframe = pd.read_json(path, lines=True)
    dataframe = dataframe[required_columns]
    return dataframe, dataframe.values

# %%
dataframe, values = load_required_data('train_15000.json', ["asin", "reviewerID", "overall"])

# %%
dataframe[:10]
# Out:
#          asin             reviewerID  overall
# 0  B00ANT8OF6  A00100742Q4O8VH0YMUBZ        4
# 1  B00AMR1HZ8  A00100742Q4O8VH0YMUBZ        4
# 2  B004WGGQPQ  A00100742Q4O8VH0YMUBZ        5
# 3  B006C1ZSO4  A00100742Q4O8VH0YMUBZ        5
# 4  B008LY1B32  A00100742Q4O8VH0YMUBZ        4
# 5  B007KPT2N4  A00100742Q4O8VH0YMUBZ        1
# 6  B0080JJLBW  A00100742Q4O8VH0YMUBZ        5
# 7  B009P8EMCK  A00100742Q4O8VH0YMUBZ        5
# 8  B00I8Q77Y0  A001619027H9L9EG4UVRB        5
# 9  B00H0BGCJK  A001619027H9L9EG4UVRB        5

# %%
dataframe.shape
# Out:
# (15000, 3)

# %%
# Create user-item matrix given a matrix and mapping from original matrix columns to new matrix rows/columns
def create_user_item_matrix(data, rowMapping, columnMapping):
    # Create table of users to items by taking row and column pivots
    # Rows of user-item table are users
    rows, row_pos = np.unique(data[:, rowMapping], return_inverse=True)
    # Columns of user-item table are movies
    cols, col_pos = np.unique(data[:, columnMapping], return_inverse=True)

    pivot_table = np.zeros((len(rows), len(cols)), dtype=data.dtype)
    pivot_table[row_pos, col_pos] = data[:, 2]
    return pivot_table, rows, cols

# %%
ratings_matrix, rows, cols = create_user_item_matrix(values, rowMapping=1, columnMapping=0)
print (ratings_matrix.shape)
# Out:
# (3139, 1842)

# %%
pd.DataFrame(ratings_matrix[:10], index = rows[:10], columns= cols)
# Out:
#                       B004ALVL6W B004ANMWPY B004DLNC4I B004DLPXAO B004DM1OAQ  \
# A00100742Q4O8VH0YMUBZ          0          0          0          0          0
# A001619027H9L9EG4UVRB          0          0          0          0          0
# A002359833QJM7OQHCXWY          0          0          0          0          0
# A0037670NPLI11RBWYFA           0          0          0          0          0
# A003841815JTX0JFLR8B1          0          0          0          0          0
# A0038872349TB5N0JHQQW          0          0          0          0          0
# A00455683H6M1GQZMPQPV          0          0          0          0          0
# A0047670XAAJD587LXS7           0          0          0          0          0
# A00501041JRAPWYLPQ4TE          0          0          0          0          0
# A00507662MEMHI1YMGQ15          0          0          0          0          0
#
#                       B004DM1ZQY B004DPBGCO B004DPC5Y2 B004DPCSKI B004DPIEF6  \
# A00100742Q4O8VH0YMUBZ          0          0          0          0          0
# A001619027H9L9EG4UVRB          0          0          0          0          0
# A002359833QJM7OQHCXWY          0          0          0          0          0
# A0037670NPLI11RBWYFA           0          0          0          0          0
# A003841815JTX0JFLR8B1          0          0          0          0          0
# A0038872349TB5N0JHQQW          0          0          0          0          0
# A00455683H6M1GQZMPQPV          0          0          0          0          0
# A0047670XAAJD587LXS7           0          0          0          0          0
# A00501041JRAPWYLPQ4TE          0          0          0          0          0
# A00507662MEMHI1YMGQ15          0          0          0          0          0
#
#                          ...     B00K7WGUKA B00KFNXUY0 B00KGCNRAM B00KI5Q8X0  \
# A00100742Q4O8VH0YMUBZ    ...              0          0          0          0
# A001619027H9L9EG4UVRB    ...              0          0          0          0
# A002359833QJM7OQHCXWY    ...              0          0          0          0
# A0037670NPLI11RBWYFA     ...              0          0          0          0
# A003841815JTX0JFLR8B1    ...              0          0          0          0
# A0038872349TB5N0JHQQW    ...              0          0          0          0
# A00455683H6M1GQZMPQPV    ...              0          0          0          0
# A0047670XAAJD587LXS7     ...              0          0          0          0
# A00501041JRAPWYLPQ4TE    ...              0          0          0          0
# A00507662MEMHI1YMGQ15    ...              0          0          0          0
#
#                       B00KMX5V8G B00KOEHQCW B00KQHVWWC B00KSOQ66K B00KWVZ750  \
# A00100742Q4O8VH0YMUBZ          0          0          0          0          0
# A001619027H9L9EG4UVRB          0          0          0          0          0
# A002359833QJM7OQHCXWY          0          0          0          0          0
# A0037670NPLI11RBWYFA           0          0          0          0          0
# A003841815JTX0JFLR8B1          0          0          0          0          0
# A0038872349TB5N0JHQQW          0          0          0          0          0
# A00455683H6M1GQZMPQPV          0          0          0          0          5
# A0047670XAAJD587LXS7           0          0          0          0          0
# A00501041JRAPWYLPQ4TE          0          0          0          0          0
# A00507662MEMHI1YMGQ15          0          0          0          0          0
#
#                       B00L3MNCNQ
# A00100742Q4O8VH0YMUBZ          0
# A001619027H9L9EG4UVRB          0
# A002359833QJM7OQHCXWY          0
# A0037670NPLI11RBWYFA           0
# A003841815JTX0JFLR8B1          0
# A0038872349TB5N0JHQQW          0
# A00455683H6M1GQZMPQPV          0
# A0047670XAAJD587LXS7           0
# A00501041JRAPWYLPQ4TE          0
# A00507662MEMHI1YMGQ15          0
#
# [10 rows x 1842 columns]

# %%
def get_index_map(arr):
    index_map = {}
    for el in arr:
        index_map[el] = len(index_map)
    return index_map

# %%
# Get unique movies and users
unique_items = np.unique(values[:,0])
unique_users = np.unique(values[:,1])

# %%
unique_items.shape
# Out:
# (1842,)

# %%
unique_users.shape
# Out:
# (3139,)

# %%
# Create mapping from unique list to 
item_idx_map = get_index_map(unique_items)
user_idx_map = get_index_map(unique_users)

# %%
mean_users = np.true_divide(ratings_matrix.sum(1), (ratings_matrix!=0).sum(1))
mean_items = np.true_divide(ratings_matrix.sum(0),(ratings_matrix!=0).sum(0))
mean_overall = np.true_divide(ratings_matrix.sum(),(ratings_matrix!=0).sum())

# %%
def get_users_who_rated_item(item_id):
    return np.where(ratings_matrix[:,item_idx_map[item_id]] > 0)[0]

def get_users_who_rated_item_by_index(item_idx):
    return np.where(ratings_matrix[:,item_idx] > 0)

def predict(user_id, item_id):
    item_idx = item_idx_map[item_id]
    user_idx = user_idx_map[user_id]
    bias_user = - mean_overall + mean_users[user_idx]
    bias_item = - mean_overall + mean_items[item_idx]
    return mean_overall + bias_user + bias_item

# %%
test_dataframe, test_values = load_required_data('test_5000.json', ["asin", "reviewerID", "overall"])

# %%
test_dataframe['reviewerID'].unique().shape
# Out:
# (2507,)

# %%
# Returns DF containing predictions, MAE, RMSE
def get_predictions(dataframe):
    df = dataframe.copy()
    print ("Predicting ratings..")
    start_time = time.time()
    df['Prediction'] = df.apply(lambda row: predict_row(row) , axis=1)
    MAE = round(mean_absolute_error(df['overall'], df['Prediction']), 2)
    RMSE = round(np.sqrt(mean_squared_error(df['overall'], df['Prediction'])), 2)
    print "Done Predicting in",  round((time.time() - start_time), 2), "seconds"
    return df, MAE, RMSE

i = 0
def predict_row(row):
    global i
    i+= 1
    prediction = predict(row['reviewerID'], row['asin'])
    print ("#", i, "Actual = ", row['overall'], "Predictioned = ", prediction)
    return prediction

# %%
df, MAE, RMSE = get_predictions(test_dataframe)
# Out:
# Predicting ratings..
# ('#', 1, 'Actual = ', 5, 'Predictioned = ', 5.0668666666666669)
# ('#', 2, 'Actual = ', 2, 'Predictioned = ', 3.2890888888888892)
# ('#', 3, 'Actual = ', 5, 'Predictioned = ', 4.2751999999999999)
# ('#', 4, 'Actual = ', 5, 'Predictioned = ', 5.7196444444444445)
# ('#', 5, 'Actual = ', 5, 'Predictioned = ', 4.5918666666666672)
# ('#', 6, 'Actual = ', 3, 'Predictioned = ', 4.8977490196078435)
# ('#', 7, 'Actual = ', 5, 'Predictioned = ', 3.9418666666666669)
# ('#', 8, 'Actual = ', 4, 'Predictioned = ', 3.0734456140350881)
# ('#', 9, 'Actual = ', 5, 'Predictioned = ', 5.513295238095238)
# ('#', 10, 'Actual = ', 5, 'Predictioned = ', 5.6050245614035088)
# ('#', 11, 'Actual = ', 1, 'Predictioned = ', 2.641866666666667)
# ('#', 12, 'Actual = ', 4, 'Predictioned = ', 4.2751999999999999)
# ('#', 13, 'Actual = ', 5, 'Predictioned = ', 4.9085333333333336)
# ('#', 14, 'Actual = ', 5, 'Predictioned = ', 4.8418666666666663)
# ('#', 15, 'Actual = ', 4, 'Predictioned = ', 4.3122370370370371)
# ('#', 16, 'Actual = ', 1, 'Predictioned = ', 4.1561523809523813)
# ('#', 17, 'Actual = ', 5, 'Predictioned = ', 0.19186666666666685)
# ('#', 18, 'Actual = ', 4, 'Predictioned = ', 0.81283440860215084)
# ('#', 19, 'Actual = ', 3, 'Predictioned = ', 2.9418666666666669)
# ('#', 20, 'Actual = ', 4, 'Predictioned = ', 3.7990095238095241)
# ('#', 21, 'Actual = ', 5, 'Predictioned = ', 4.9418666666666669)
# ('#', 22, 'Actual = ', 5, 'Predictioned = ', 5.1726358974358977)
# ('#', 23, 'Actual = ', 4, 'Predictioned = ', 4.9418666666666669)
# ('#', 24, 'Actual = ', 4, 'Predictioned = ', 4.2054325581395346)
# ('#', 25, 'Actual = ', 5, 'Predictioned = ', 3.9681824561403509)
# ('#', 26, 'Actual = ', 5, 'Predictioned = ', 3.7751999999999999)
# ('#', 27, 'Actual = ', 5, 'Predictioned = ', 5.6085333333333338)
# ('#', 28, 'Actual = ', 4, 'Predictioned = ', 4.5728190476190482)
# ('#', 29, 'Actual = ', 5, 'Predictioned = ', 3.6918666666666669)
# ('#', 30, 'Actual = ', 4, 'Predictioned = ', 4.7751999999999999)
# ('#', 31, 'Actual = ', 1, 'Predictioned = ', 1.9418666666666669)
# ('#', 32, 'Actual = ', 1, 'Predictioned = ', 1.8168666666666669)
# ('#', 33, 'Actual = ', 5, 'Predictioned = ', 4.4418666666666669)
# ('#', 34, 'Actual = ', 5, 'Predictioned = ', 4.9418666666666669)
# ('#', 35, 'Actual = ', 4, 'Predictioned = ', 4.2751999999999999)
# ('#', 36, 'Actual = ', 5, 'Predictioned = ', 4.8742990990990993)
# ('#', 37, 'Actual = ', 5, 'Predictioned = ', 5.9418666666666669)
# ('#', 38, 'Actual = ', 5, 'Predictioned = ', 4.2751999999999999)
# ('#', 39, 'Actual = ', 4, 'Predictioned = ', 5.3307555555555561)
# ('#', 40, 'Actual = ', 5, 'Predictioned = ', 4.6838021505376348)
# ('#', 41, 'Actual = ', 5, 'Predictioned = ', 3.894247619047619)
# ('#', 42, 'Actual = ', 5, 'Predictioned = ', 4.8275809523809521)
# ('#', 43, 'Actual = ', 5, 'Predictioned = ', 3.9418666666666669)
# ('#', 44, 'Actual = ', 5, 'Predictioned = ', 4.141866666666667)
# ('#', 45, 'Actual = ', 1, 'Predictioned = ', 5.9418666666666669)
# ('#', 46, 'Actual = ', 1, 'Predictioned = ', 2.6085333333333338)
# ('#', 47, 'Actual = ', 4, 'Predictioned = ', 3.1918666666666669)
# ('#', 48, 'Actual = ', 5, 'Predictioned = ', 3.1918666666666669)
# ('#', 49, 'Actual = ', 5, 'Predictioned = ', 4.4418666666666669)
# ('#', 50, 'Actual = ', 5, 'Predictioned = ', 5.9418666666666669)
# ('#', 51, 'Actual = ', 3, 'Predictioned = ', 3.9418666666666669)
# ('#', 52, 'Actual = ', 4, 'Predictioned = ', 4.4418666666666669)
# ('#', 53, 'Actual = ', 5, 'Predictioned = ', 5.2751999999999999)
# ('#', 54, 'Actual = ', 5, 'Predictioned = ', 5.0751999999999997)
# ('#', 55, 'Actual = ', 3, 'Predictioned = ', 4.9418666666666669)
# ('#', 56, 'Actual = ', 2, 'Predictioned = ', 4.6260771929824562)
# ('#', 57, 'Actual = ', 1, 'Predictioned = ', 5.2085333333333335)
# ('#', 58, 'Actual = ', 3, 'Predictioned = ', 3.7824463768115946)
# ('#', 59, 'Actual = ', 5, 'Predictioned = ', 5.244075502008033)
# ('#', 60, 'Actual = ', 4, 'Predictioned = ', 5.3585333333333338)
# ('#', 61, 'Actual = ', 3, 'Predictioned = ', 4.0251999999999999)
# ('#', 62, 'Actual = ', 5, 'Predictioned = ', 4.8751999999999995)
# ('#', 63, 'Actual = ', 5, 'Predictioned = ', 5.4275809523809526)
# ('#', 64, 'Actual = ', 3, 'Predictioned = ', 4.6085333333333338)
# ('#', 65, 'Actual = ', 5, 'Predictioned = ', 3.5668666666666669)
# ('#', 66, 'Actual = ', 5, 'Predictioned = ', 0.94186666666666685)
# ('#', 67, 'Actual = ', 5, 'Predictioned = ', 4.6918666666666669)
# ('#', 68, 'Actual = ', 5, 'Predictioned = ', 5.8307555555555561)
# ('#', 69, 'Actual = ', 1, 'Predictioned = ', 5.2751999999999999)
# ('#', 70, 'Actual = ', 1, 'Predictioned = ', 4.6918666666666669)
# ('#', 71, 'Actual = ', 5, 'Predictioned = ', 3.297422222222222)
# ('#', 72, 'Actual = ', 5, 'Predictioned = ', 3.6085333333333338)
# ('#', 73, 'Actual = ', 3, 'Predictioned = ', 3.6726358974358977)
# ('#', 74, 'Actual = ', 4, 'Predictioned = ', 3.1085333333333334)
# ('#', 75, 'Actual = ', 5, 'Predictioned = ', 2.4275809523809526)
# ('#', 76, 'Actual = ', 4, 'Predictioned = ', 0.94186666666666685)
# ('#', 77, 'Actual = ', 3, 'Predictioned = ', 3.6918666666666669)
# ('#', 78, 'Actual = ', 4, 'Predictioned = ', 4.2418666666666667)
# ('#', 79, 'Actual = ', 4, 'Predictioned = ', 2.5371047619047618)
# ('#', 80, 'Actual = ', 4, 'Predictioned = ', 3.6659103825136614)
# ('#', 81, 'Actual = ', 5, 'Predictioned = ', 4.3285333333333345)
# ('#', 82, 'Actual = ', 3, 'Predictioned = ', 4.6085333333333338)
# ('#', 83, 'Actual = ', 1, 'Predictioned = ', 3.3418666666666668)
# ('#', 84, 'Actual = ', 1, 'Predictioned = ', 3.3418666666666668)
# ('#', 85, 'Actual = ', 4, 'Predictioned = ', 3.7561523809523814)
# ('#', 86, 'Actual = ', 5, 'Predictioned = ', 3.9894857142857147)
# ('#', 87, 'Actual = ', 5, 'Predictioned = ', 4.2918666666666674)
# ('#', 88, 'Actual = ', 5, 'Predictioned = ', 3.9418666666666669)
# ('#', 89, 'Actual = ', 5, 'Predictioned = ', 3.9418666666666669)
# ('#', 90, 'Actual = ', 3, 'Predictioned = ', 3.6668666666666669)
# ('#', 91, 'Actual = ', 2, 'Predictioned = ', 4.3612215053763439)
# ('#', 92, 'Actual = ', 5, 'Predictioned = ', 3.5668666666666669)
# ('#', 93, 'Actual = ', 5, 'Predictioned = ', 5.6918666666666669)
# ('#', 94, 'Actual = ', 5, 'Predictioned = ', 5.3418666666666672)
# ('#', 95, 'Actual = ', 2, 'Predictioned = ', 1.641866666666667)
# ('#', 96, 'Actual = ', 3, 'Predictioned = ', 1.5668666666666669)
# ('#', 97, 'Actual = ', 5, 'Predictioned = ', 2.0159407407407413)
# ('#', 98, 'Actual = ', 1, 'Predictioned = ', 2.1713748633879781)
# ('#', 99, 'Actual = ', 5, 'Predictioned = ', 3.5418666666666669)
# ('#', 100, 'Actual = ', 2, 'Predictioned = ', 4.3585333333333338)
# ('#', 101, 'Actual = ', 1, 'Predictioned = ', 3.9808277056277057)
# ('#', 102, 'Actual = ', 5, 'Predictioned = ', 3.1236848484848485)
# ('#', 103, 'Actual = ', 3, 'Predictioned = ', 4.2751999999999999)
# ('#', 104, 'Actual = ', 5, 'Predictioned = ', 4.8418666666666672)
# ('#', 105, 'Actual = ', 2, 'Predictioned = ', 3.8863111111111115)
# ('#', 106, 'Actual = ', 3, 'Predictioned = ', 3.9418666666666669)
# ('#', 107, 'Actual = ', 5, 'Predictioned = ', 4.6518666666666668)
# ('#', 108, 'Actual = ', 4, 'Predictioned = ', 3.6918666666666669)
# ('#', 109, 'Actual = ', 4, 'Predictioned = ', 4.1918666666666669)
# ('#', 110, 'Actual = ', 2, 'Predictioned = ', 3.6918666666666669)
# ('#', 111, 'Actual = ', 5, 'Predictioned = ', 3.9418666666666669)
# ('#', 112, 'Actual = ', 5, 'Predictioned = ', 4.4418666666666669)
# ('#', 113, 'Actual = ', 5, 'Predictioned = ', 4.6918666666666669)
# ('#', 114, 'Actual = ', 5, 'Predictioned = ', 3.7752000000000003)
# ('#', 115, 'Actual = ', 3, 'Predictioned = ', 4.1513904761904765)
# ('#', 116, 'Actual = ', 4, 'Predictioned = ', 4.2847238095238103)
# ('#', 117, 'Actual = ', 5, 'Predictioned = ', 4.7632952380952389)
# ('#', 118, 'Actual = ', 5, 'Predictioned = ', 4.0418666666666674)
# ('#', 119, 'Actual = ', 5, 'Predictioned = ', 4.4803282051282052)
# ('#', 120, 'Actual = ', 5, 'Predictioned = ', 4.3418666666666672)
# ('#', 121, 'Actual = ', 4, 'Predictioned = ', 4.2704380952380951)
# ('#', 122, 'Actual = ', 4, 'Predictioned = ', 4.3704380952380957)
# ('#', 123, 'Actual = ', 4, 'Predictioned = ', 4.263295238095238)
# ('#', 124, 'Actual = ', 5, 'Predictioned = ', 4.0918666666666672)
# ('#', 125, 'Actual = ', 4, 'Predictioned = ', 5.0275809523809523)
# ('#', 126, 'Actual = ', 5, 'Predictioned = ', 4.8275809523809521)
# ('#', 127, 'Actual = ', 4, 'Predictioned = ', 4.0433159420289861)
# ('#', 128, 'Actual = ', 4, 'Predictioned = ', 4.3585333333333338)
# ('#', 129, 'Actual = ', 5, 'Predictioned = ', 5.4218666666666664)
# ('#', 130, 'Actual = ', 4, 'Predictioned = ', 4.891866666666667)
# ('#', 131, 'Actual = ', 4, 'Predictioned = ', 2.9418666666666669)
# ('#', 132, 'Actual = ', 5, 'Predictioned = ', 3.1375188405797108)
# ('#', 133, 'Actual = ', 4, 'Predictioned = ', 3.070071794871795)
# ('#', 134, 'Actual = ', 4, 'Predictioned = ', 3.6085333333333334)
# ('#', 135, 'Actual = ', 5, 'Predictioned = ', 4.7797045045045046)
# ('#', 136, 'Actual = ', 5, 'Predictioned = ', 5.2359843137254902)
# ('#', 137, 'Actual = ', 5, 'Predictioned = ', 4.8168666666666669)
# ('#', 138, 'Actual = ', 3, 'Predictioned = ', 5.0668666666666669)
# ('#', 139, 'Actual = ', 4, 'Predictioned = ', 4.5251999999999999)
# ('#', 140, 'Actual = ', 4, 'Predictioned = ', 4.0159407407407404)
# ('#', 141, 'Actual = ', 5, 'Predictioned = ', 3.2335333333333334)
# ('#', 142, 'Actual = ', 1, 'Predictioned = ', 2.0085333333333333)
# ('#', 143, 'Actual = ', 5, 'Predictioned = ', 4.1976806201550385)
# ('#', 144, 'Actual = ', 4, 'Predictioned = ', 4.896412121212121)
# ('#', 145, 'Actual = ', 5, 'Predictioned = ', 4.6085333333333338)
# ('#', 146, 'Actual = ', 4, 'Predictioned = ', 4.6085333333333338)
# ('#', 147, 'Actual = ', 5, 'Predictioned = ', 4.4537714285714287)
# ('#', 148, 'Actual = ', 5, 'Predictioned = ', 4.5704380952380959)
# ('#', 149, 'Actual = ', 5, 'Predictioned = ', 4.4418666666666669)
# ('#', 150, 'Actual = ', 5, 'Predictioned = ', 3.5418666666666669)
# ('#', 151, 'Actual = ', 2, 'Predictioned = ', 3.3771607843137259)
# ('#', 152, 'Actual = ', 1, 'Predictioned = ', 2.891866666666667)
# ('#', 153, 'Actual = ', 5, 'Predictioned = ', 3.5418666666666669)
# ('#', 154, 'Actual = ', 5, 'Predictioned = ', 4.3713748633879783)
# ('#', 155, 'Actual = ', 5, 'Predictioned = ', 4.6213538461538466)
# ('#', 156, 'Actual = ', 4, 'Predictioned = ', 4.4418666666666677)
# ('#', 157, 'Actual = ', 5, 'Predictioned = ', 4.1279131782945742)
# ('#', 158, 'Actual = ', 1, 'Predictioned = ', 3.4418666666666669)
# ('#', 159, 'Actual = ', 1, 'Predictioned = ', 3.4835333333333334)
# ('#', 160, 'Actual = ', 5, 'Predictioned = ', 4.5010771929824562)
# ('#', 161, 'Actual = ', 5, 'Predictioned = ', 3.6307555555555555)
# ('#', 162, 'Actual = ', 3, 'Predictioned = ', 3.6720992248062014)
# ('#', 163, 'Actual = ', 5, 'Predictioned = ', 5.141866666666667)
# ('#', 164, 'Actual = ', 5, 'Predictioned = ', 5.327408835341366)
# ('#', 165, 'Actual = ', 1, 'Predictioned = ', 3.4418666666666669)
# ('#', 166, 'Actual = ', 1, 'Predictioned = ', 4.4418666666666669)
# ('#', 167, 'Actual = ', 5, 'Predictioned = ', 5.2716912280701758)
# ('#', 168, 'Actual = ', 5, 'Predictioned = ', 5.6085333333333338)
# ('#', 169, 'Actual = ', 5, 'Predictioned = ', 4.2751999999999999)
# ('#', 170, 'Actual = ', 5, 'Predictioned = ', 5.1085333333333338)
# ('#', 171, 'Actual = ', 4, 'Predictioned = ', 4.660742168674699)
# ('#', 172, 'Actual = ', 4, 'Predictioned = ', 4.3418666666666663)
# ('#', 173, 'Actual = ', 5, 'Predictioned = ', 4.3418666666666672)
# ('#', 174, 'Actual = ', 5, 'Predictioned = ', 4.0918666666666672)
# ('#', 175, 'Actual = ', 5, 'Predictioned = ', 4.2418666666666667)
# ('#', 176, 'Actual = ', 5, 'Predictioned = ', 4.2661909909909914)
# ('#', 177, 'Actual = ', 5, 'Predictioned = ', 3.7825529411764713)
# ('#', 178, 'Actual = ', 4, 'Predictioned = ', 2.9002000000000003)
# ('#', 179, 'Actual = ', 5, 'Predictioned = ', 5.4418666666666669)
# ('#', 180, 'Actual = ', 5, 'Predictioned = ', 5.4418666666666669)
# ('#', 181, 'Actual = ', 1, 'Predictioned = ', 3.7752000000000003)
# ('#', 182, 'Actual = ', 5, 'Predictioned = ', 4.3418666666666663)
# ('#', 183, 'Actual = ', 5, 'Predictioned = ', 4.3793666666666669)
# ('#', 184, 'Actual = ', 4, 'Predictioned = ', 3.9418666666666669)
# ('#', 185, 'Actual = ', 4, 'Predictioned = ', 4.4516705882352943)
# ('#', 186, 'Actual = ', 1, 'Predictioned = ', 4.1699368421052636)
# ('#', 187, 'Actual = ', 5, 'Predictioned = ', 5.141866666666667)
# ('#', 188, 'Actual = ', 5, 'Predictioned = ', 4.6085333333333338)
# ('#', 189, 'Actual = ', 5, 'Predictioned = ', 4.8585333333333338)
# ('#', 190, 'Actual = ', 5, 'Predictioned = ', 2.6918666666666669)
# ('#', 191, 'Actual = ', 5, 'Predictioned = ', 5.6050245614035088)
# ('#', 192, 'Actual = ', 5, 'Predictioned = ', 5.141866666666667)
# ('#', 193, 'Actual = ', 5, 'Predictioned = ', 5.6752000000000002)
# ('#', 194, 'Actual = ', 5, 'Predictioned = ', 5.6918666666666669)
# ('#', 195, 'Actual = ', 5, 'Predictioned = ', 3.8875188405797108)
# ('#', 196, 'Actual = ', 5, 'Predictioned = ', 3.6918666666666669)
# ('#', 197, 'Actual = ', 4, 'Predictioned = ', 3.8704380952380952)
# ('#', 198, 'Actual = ', 3, 'Predictioned = ', 3.6085333333333334)
# ('#', 199, 'Actual = ', 5, 'Predictioned = ', 4.8585333333333338)
# ('#', 200, 'Actual = ', 5, 'Predictioned = ', 4.6085333333333338)
# ('#', 201, 'Actual = ', 5, 'Predictioned = ', 5.2990095238095236)
# ('#', 202, 'Actual = ', 5, 'Predictioned = ', 4.641866666666667)
# ('#', 203, 'Actual = ', 4, 'Predictioned = ', 4.9656761904761906)
# ('#', 204, 'Actual = ', 4, 'Predictioned = ', 4.6561523809523813)
# ('#', 205, 'Actual = ', 5, 'Predictioned = ', 3.2145939393939393)
# ('#', 206, 'Actual = ', 4, 'Predictioned = ', 3.141866666666667)
# ('#', 207, 'Actual = ', 5, 'Predictioned = ', 5.0847238095238101)
# ('#', 208, 'Actual = ', 4, 'Predictioned = ', 4.4418666666666669)
# ('#', 209, 'Actual = ', 1, 'Predictioned = ', 1.4418666666666669)
# ('#', 210, 'Actual = ', 5, 'Predictioned = ', 2.6918666666666669)
# ('#', 211, 'Actual = ', 4, 'Predictioned = ', 4.2751999999999999)
# ('#', 212, 'Actual = ', 5, 'Predictioned = ', 3.4251999999999998)
# ('#', 213, 'Actual = ', 5, 'Predictioned = ', 5.6050245614035088)
# ('#', 214, 'Actual = ', 5, 'Predictioned = ', 5.0847238095238101)
# ('#', 215, 'Actual = ', 2, 'Predictioned = ', 5.4275809523809526)
# ('#', 216, 'Actual = ', 1, 'Predictioned = ', 4.5782303030303027)
# ('#', 217, 'Actual = ', 4, 'Predictioned = ', 3.9418666666666669)
# ('#', 218, 'Actual = ', 4, 'Predictioned = ', 3.6918666666666669)
# ('#', 219, 'Actual = ', 5, 'Predictioned = ', 5.8418666666666672)
# ('#', 220, 'Actual = ', 1, 'Predictioned = ', 5.2751999999999999)
# ('#', 221, 'Actual = ', 5, 'Predictioned = ', 2.891866666666667)
# ('#', 222, 'Actual = ', 5, 'Predictioned = ', 2.8260771929824564)
# ('#', 223, 'Actual = ', 5, 'Predictioned = ', 4.7264820512820522)
# ('#', 224, 'Actual = ', 5, 'Predictioned = ', 5.1389820512820519)
# ('#', 225, 'Actual = ', 5, 'Predictioned = ', 2.661866666666667)
# ('#', 226, 'Actual = ', 5, 'Predictioned = ', 2.4974222222222222)
# ('#', 227, 'Actual = ', 4, 'Predictioned = ', 3.9418666666666669)
# ('#', 228, 'Actual = ', 5, 'Predictioned = ', 4.4418666666666669)
# ('#', 229, 'Actual = ', 5, 'Predictioned = ', 5.3612215053763439)
# ('#', 230, 'Actual = ', 3, 'Predictioned = ', 5.4579956989247318)
# ('#', 231, 'Actual = ', 4, 'Predictioned = ', 4.5706545454545457)
# ('#', 232, 'Actual = ', 5, 'Predictioned = ', 4.5251999999999999)
# ('#', 233, 'Actual = ', 5, 'Predictioned = ', 4.141866666666667)
# ('#', 234, 'Actual = ', 5, 'Predictioned = ', 4.9418666666666669)
# ('#', 235, 'Actual = ', 4, 'Predictioned = ', 5.0751999999999997)
# ('#', 236, 'Actual = ', 5, 'Predictioned = ', 5.7418666666666667)
# ('#', 237, 'Actual = ', 4, 'Predictioned = ', 4.5418666666666665)
# ('#', 238, 'Actual = ', 5, 'Predictioned = ', 4.6050245614035088)
# ('#', 239, 'Actual = ', 5, 'Predictioned = ', 3.4418666666666664)
# ('#', 240, 'Actual = ', 5, 'Predictioned = ', 4.5251999999999999)
# ('#', 241, 'Actual = ', 5, 'Predictioned = ', 4.9418666666666669)
# ('#', 242, 'Actual = ', 5, 'Predictioned = ', 5.9418666666666669)
# ('#', 243, 'Actual = ', 5, 'Predictioned = ', 4.6085333333333338)
# ('#', 244, 'Actual = ', 1, 'Predictioned = ', 4.1918666666666669)
# ('#', 245, 'Actual = ', 4, 'Predictioned = ', 3.5847238095238096)
# ('#', 246, 'Actual = ', 5, 'Predictioned = ', 4.4085333333333336)
# ('#', 247, 'Actual = ', 5, 'Predictioned = ', 4.7160602150537638)
# ('#', 248, 'Actual = ', 5, 'Predictioned = ', 5.7600484848484852)
# ('#', 249, 'Actual = ', 5, 'Predictioned = ', 4.6918666666666669)
# ('#', 250, 'Actual = ', 5, 'Predictioned = ', 4.9418666666666669)
# ('#', 251, 'Actual = ', 5, 'Predictioned = ', 5.2275809523809524)
# ('#', 252, 'Actual = ', 5, 'Predictioned = ', 5.6050245614035088)
# ('#', 253, 'Actual = ', 4, 'Predictioned = ', 4.2418666666666667)
# ('#', 254, 'Actual = ', 5, 'Predictioned = ', 4.9418666666666669)
# ('#', 255, 'Actual = ', 5, 'Predictioned = ', 4.891866666666667)
# ('#', 256, 'Actual = ', 5, 'Predictioned = ', 4.6918666666666669)
# ('#', 257, 'Actual = ', 1, 'Predictioned = ', 1.297422222222222)
# ('#', 258, 'Actual = ', 1, 'Predictioned = ', 1.095712820512821)
# ('#', 259, 'Actual = ', 5, 'Predictioned = ', 4.9974222222222231)
# ('#', 260, 'Actual = ', 5, 'Predictioned = ', 4.8041855072463777)
# ('#', 261, 'Actual = ', 5, 'Predictioned = ', 3.6085333333333338)
# ('#', 262, 'Actual = ', 5, 'Predictioned = ', 3.2751999999999999)
# ('#', 263, 'Actual = ', 5, 'Predictioned = ', 3.2495589743589743)
# ('#', 264, 'Actual = ', 5, 'Predictioned = ', 3.9418666666666669)
# ('#', 265, 'Actual = ', 1, 'Predictioned = ', 1.5418666666666665)
# ('#', 266, 'Actual = ', 1, 'Predictioned = ', 3.0373212121212125)
# ('#', 267, 'Actual = ', 5, 'Predictioned = ', 4.272099224806202)
# ('#', 268, 'Actual = ', 4, 'Predictioned = ', 4.7612215053763443)
# ('#', 269, 'Actual = ', 4, 'Predictioned = ', 4.7327163398692811)
# ('#', 270, 'Actual = ', 4, 'Predictioned = ', 2.6085333333333334)
# ('#', 271, 'Actual = ', 3, 'Predictioned = ', 4.5327757575757577)
# ('#', 272, 'Actual = ', 5, 'Predictioned = ', 5.1085333333333338)
# ('#', 273, 'Actual = ', 5, 'Predictioned = ', 4.7513904761904771)
# ('#', 274, 'Actual = ', 1, 'Predictioned = ', 4.2418666666666667)
# ('#', 275, 'Actual = ', 1, 'Predictioned = ', 4.1771607843137257)
# ('#', 276, 'Actual = ', 3, 'Predictioned = ', 4.0847238095238101)
# ('#', 277, 'Actual = ', 5, 'Predictioned = ', 4.9418666666666669)
# ('#', 278, 'Actual = ', 5, 'Predictioned = ', 5.0327757575757577)
# ('#', 279, 'Actual = ', 4, 'Predictioned = ', 3.5418666666666669)
# ('#', 280, 'Actual = ', 1, 'Predictioned = ', 5.327408835341366)
# ('#', 281, 'Actual = ', 5, 'Predictioned = ', 5.5847238095238101)
# ('#', 282, 'Actual = ', 4, 'Predictioned = ', 4.6085333333333338)
# ('#', 283, 'Actual = ', 4, 'Predictioned = ', 2.6085333333333334)
# ('#', 284, 'Actual = ', 4, 'Predictioned = ', 5.0327757575757577)
# ('#', 285, 'Actual = ', 5, 'Predictioned = ', 4.5418666666666674)
# ('#', 286, 'Actual = ', 5, 'Predictioned = ', 5.2275809523809524)
# ('#', 287, 'Actual = ', 5, 'Predictioned = ', 5.3418666666666672)
# ('#', 288, 'Actual = ', 5, 'Predictioned = ', 5.6918666666666669)
# ('#', 289, 'Actual = ', 5, 'Predictioned = ', 5.2145939393939393)
# ('#', 290, 'Actual = ', 5, 'Predictioned = ', 3.8466285714285715)
# ('#', 291, 'Actual = ', 5, 'Predictioned = ', 4.513295238095238)
# ('#', 292, 'Actual = ', 5, 'Predictioned = ', 4.1085333333333338)
# ('#', 293, 'Actual = ', 5, 'Predictioned = ', 4.0734456140350881)
# ('#', 294, 'Actual = ', 5, 'Predictioned = ', 5.0734456140350881)
# ('#', 295, 'Actual = ', 5, 'Predictioned = ', 5.9418666666666669)
# ('#', 296, 'Actual = ', 4, 'Predictioned = ', 5.0835333333333335)
# ('#', 297, 'Actual = ', 4, 'Predictioned = ', 4.9697273631840799)
# ('#', 298, 'Actual = ', 4, 'Predictioned = ', 4.3903515151515151)
# ('#', 299, 'Actual = ', 4, 'Predictioned = ', 4.7945798449612411)
# ('#', 300, 'Actual = ', 5, 'Predictioned = ', 4.7132952380952382)
# ('#', 301, 'Actual = ', 5, 'Predictioned = ', 3.141866666666667)
# ('#', 302, 'Actual = ', 5, 'Predictioned = ', 4.6085333333333338)
# ('#', 303, 'Actual = ', 1, 'Predictioned = ', 2.4418666666666669)
# ('#', 304, 'Actual = ', 1, 'Predictioned = ', 1.4418666666666669)
# ('#', 305, 'Actual = ', 5, 'Predictioned = ', 2.2751999999999999)
# ('#', 306, 'Actual = ', 4, 'Predictioned = ', 4.9210333333333338)
# ('#', 307, 'Actual = ', 4, 'Predictioned = ', 4.0876999999999999)
# ('#', 308, 'Actual = ', 5, 'Predictioned = ', 4.6447238095238097)
# ('#', 309, 'Actual = ', 5, 'Predictioned = ', 4.5373553884711786)
# ('#', 310, 'Actual = ', 4, 'Predictioned = ', 4.3863111111111115)
# ('#', 311, 'Actual = ', 5, 'Predictioned = ', 4.396412121212121)
# ('#', 312, 'Actual = ', 4, 'Predictioned = ', 3.5847238095238101)
# ('#', 313, 'Actual = ', 5, 'Predictioned = ', 4.1918666666666669)
# ('#', 314, 'Actual = ', 5, 'Predictioned = ', 1.9418666666666669)
# ('#', 315, 'Actual = ', 5, 'Predictioned = ', 1.9418666666666669)
# ('#', 316, 'Actual = ', 5, 'Predictioned = ', 4.9418666666666669)
# ('#', 317, 'Actual = ', 5, 'Predictioned = ', 2.9418666666666669)
# ('#', 318, 'Actual = ', 3, 'Predictioned = ', 3.9418666666666669)
# ('#', 319, 'Actual = ', 3, 'Predictioned = ', 3.0529777777777776)
# ('#', 320, 'Actual = ', 5, 'Predictioned = ', 4.9164429378531072)
# ('#', 321, 'Actual = ', 5, 'Predictioned = ', 4.797422222222222)
# ('#', 322, 'Actual = ', 2, 'Predictioned = ', 5.6323428571428567)
# ('#', 323, 'Actual = ', 3, 'Predictioned = ', 4.354565079365079)
# ('#', 324, 'Actual = ', 4, 'Predictioned = ', 3.7292420819490588)
# ('#', 325, 'Actual = ', 4, 'Predictioned = ', 3.5490095238095241)
# ('#', 326, 'Actual = ', 1, 'Predictioned = ', 3.802977777777778)
# ('#', 327, 'Actual = ', 5, 'Predictioned = ', 3.3903515151515151)
# ('#', 328, 'Actual = ', 5, 'Predictioned = ', 2.2751999999999999)
# ('#', 329, 'Actual = ', 1, 'Predictioned = ', 3.498944292237443)
# ('#', 330, 'Actual = ', 5, 'Predictioned = ', 5.4418666666666669)
# ('#', 331, 'Actual = ', 5, 'Predictioned = ', 4.4418666666666669)
# ('#', 332, 'Actual = ', 4, 'Predictioned = ', 2.9918666666666667)
# ('#', 333, 'Actual = ', 3, 'Predictioned = ', 3.2661909909909914)
# ('#', 334, 'Actual = ', 2, 'Predictioned = ', 1.9418666666666669)
# ('#', 335, 'Actual = ', 3, 'Predictioned = ', 3.3704380952380952)
# ('#', 336, 'Actual = ', 4, 'Predictioned = ', 3.6477490196078435)
# ('#', 337, 'Actual = ', 3, 'Predictioned = ', 3.4974222222222222)
# ('#', 338, 'Actual = ', 5, 'Predictioned = ', 5.1085333333333338)
# ('#', 339, 'Actual = ', 4, 'Predictioned = ', 4.9418666666666669)
# ('#', 340, 'Actual = ', 5, 'Predictioned = ', 5.4418666666666669)
# ('#', 341, 'Actual = ', 3, 'Predictioned = ', 5.9418666666666669)
# ('#', 342, 'Actual = ', 2, 'Predictioned = ', 4.8751999999999995)
# ('#', 343, 'Actual = ', 3, 'Predictioned = ', 4.5418666666666665)
# ('#', 344, 'Actual = ', 5, 'Predictioned = ', 5.9418666666666669)
# ('#', 345, 'Actual = ', 5, 'Predictioned = ', 5.8752000000000004)
# ('#', 346, 'Actual = ', 5, 'Predictioned = ', 5.327408835341366)
# ('#', 347, 'Actual = ', 5, 'Predictioned = ', 5.1279131782945742)
# ('#', 348, 'Actual = ', 5, 'Predictioned = ', 3.6982769230769237)
# ('#', 349, 'Actual = ', 4, 'Predictioned = ', 2.7037714285714287)
# ('#', 350, 'Actual = ', 2, 'Predictioned = ', 4.9418666666666669)
# ('#', 351, 'Actual = ', 1, 'Predictioned = ', 5.9418666666666669)
# ('#', 352, 'Actual = ', 5, 'Predictioned = ', 5.4835333333333338)
# ('#', 353, 'Actual = ', 5, 'Predictioned = ', 5.2694982456140353)
# ('#', 354, 'Actual = ', 2, 'Predictioned = ', 2.9418666666666669)
# ('#', 355, 'Actual = ', 3, 'Predictioned = ', 3.9418666666666669)
# ('#', 356, 'Actual = ', 5, 'Predictioned = ', 5.6085333333333338)
# ('#', 357, 'Actual = ', 4, 'Predictioned = ', 4.9418666666666669)
# ('#', 358, 'Actual = ', 4, 'Predictioned = ', 3.9418666666666669)
# ('#', 359, 'Actual = ', 1, 'Predictioned = ', 3.9418666666666669)
# ('#', 360, 'Actual = ', 3, 'Predictioned = ', 4.2751999999999999)
# ('#', 361, 'Actual = ', 5, 'Predictioned = ', 5.7418666666666667)
# ('#', 362, 'Actual = ', 1, 'Predictioned = ', 0.27520000000000033)
# ('#', 363, 'Actual = ', 1, 'Predictioned = ', 1.3418666666666672)
# ('#', 364, 'Actual = ', 4, 'Predictioned = ', 3.9736126984126989)
# ('#', 365, 'Actual = ', 5, 'Predictioned = ', 4.130755555555556)
# ('#', 366, 'Actual = ', 2, 'Predictioned = ', 2.1918666666666669)
# ('#', 367, 'Actual = ', 2, 'Predictioned = ', 2.1132952380952386)
# ('#', 368, 'Actual = ', 5, 'Predictioned = ', 4.6085333333333338)
# ('#', 369, 'Actual = ', 4, 'Predictioned = ', 2.7990095238095241)
# ('#', 370, 'Actual = ', 4, 'Predictioned = ', 1.5252000000000003)
# ('#', 371, 'Actual = ', 5, 'Predictioned = ', 1.0252000000000003)
# ('#', 372, 'Actual = ', 5, 'Predictioned = ', 3.4418666666666669)
# ('#', 373, 'Actual = ', 5, 'Predictioned = ', 3.4418666666666669)
# ('#', 374, 'Actual = ', 1, 'Predictioned = ', 1.0704380952380959)
# ('#', 375, 'Actual = ', 5, 'Predictioned = ', 1.7030606965174133)
# ('#', 376, 'Actual = ', 4, 'Predictioned = ', 3.1005968253968259)
# ('#', 377, 'Actual = ', 3, 'Predictioned = ', 3.6720253968253971)
# ('#', 378, 'Actual = ', 5, 'Predictioned = ', 5.2751999999999999)
# ('#', 379, 'Actual = ', 5, 'Predictioned = ', 5.6085333333333338)
# ('#', 380, 'Actual = ', 5, 'Predictioned = ', 1.9418666666666669)
# ('#', 381, 'Actual = ', 5, 'Predictioned = ', 5.2751999999999999)
# ('#', 382, 'Actual = ', 4, 'Predictioned = ', 3.4418666666666673)
# ('#', 383, 'Actual = ', 5, 'Predictioned = ', 4.0752000000000006)
# ('#', 384, 'Actual = ', 4, 'Predictioned = ', 3.141866666666667)
# ('#', 385, 'Actual = ', 5, 'Predictioned = ', 2.5595137254901958)
# ('#', 386, 'Actual = ', 3, 'Predictioned = ', 4.3783746031746036)
# ('#', 387, 'Actual = ', 4, 'Predictioned = ', 4.5196444444444444)
# ('#', 388, 'Actual = ', 5, 'Predictioned = ', 4.7867264797507794)
# ('#', 389, 'Actual = ', 4, 'Predictioned = ', 4.4373212121212129)
# ('#', 390, 'Actual = ', 4, 'Predictioned = ', 4.3812606060606063)
# ('#', 391, 'Actual = ', 1, 'Predictioned = ', 5.1085333333333338)
# ('#', 392, 'Actual = ', 1, 'Predictioned = ', 5.7751999999999999)
# ('#', 393, 'Actual = ', 5, 'Predictioned = ', 5.3418666666666672)
# ('#', 394, 'Actual = ', 5, 'Predictioned = ', 4.9789037037037041)
# ('#', 395, 'Actual = ', 1, 'Predictioned = ', 5.5668666666666669)
# ('#', 396, 'Actual = ', 2, 'Predictioned = ', 3.141866666666667)
# ('#', 397, 'Actual = ', 2, 'Predictioned = ', 3.141866666666667)
# ('#', 398, 'Actual = ', 3, 'Predictioned = ', 4.2513904761904771)
# ('#', 399, 'Actual = ', 3, 'Predictioned = ', 4.4847238095238104)
# ('#', 400, 'Actual = ', 5, 'Predictioned = ', 4.5418666666666674)
# ('#', 401, 'Actual = ', 1, 'Predictioned = ', 3.7418666666666667)
# ('#', 402, 'Actual = ', 5, 'Predictioned = ', 3.6918666666666669)
# ('#', 403, 'Actual = ', 5, 'Predictioned = ', 2.8418666666666668)
# ('#', 404, 'Actual = ', 4, 'Predictioned = ', 3.9418666666666669)
# ('#', 405, 'Actual = ', 4, 'Predictioned = ', 4.5418666666666665)
# ('#', 406, 'Actual = ', 5, 'Predictioned = ', 5.1561523809523813)
# ('#', 407, 'Actual = ', 5, 'Predictioned = ', 3.4418666666666669)
# ('#', 408, 'Actual = ', 5, 'Predictioned = ', 4.8905846153846149)
# ('#', 409, 'Actual = ', 4, 'Predictioned = ', 4.660742168674699)
# ('#', 410, 'Actual = ', 4, 'Predictioned = ', 3.2918666666666669)
# ('#', 411, 'Actual = ', 4, 'Predictioned = ', 3.720712820512821)
# ('#', 412, 'Actual = ', 3, 'Predictioned = ', 3.9793666666666665)
# ('#', 413, 'Actual = ', 2, 'Predictioned = ', 0.37936666666666685)
# ('#', 414, 'Actual = ', 4, 'Predictioned = ', 3.6561523809523813)
# ('#', 415, 'Actual = ', 3, 'Predictioned = ', 3.767263492063492)
# ('#', 416, 'Actual = ', 1, 'Predictioned = ', 3.6752000000000007)
# ('#', 417, 'Actual = ', 5, 'Predictioned = ', 2.736738461538462)
# ('#', 418, 'Actual = ', 5, 'Predictioned = ', 4.6918666666666669)
# ('#', 419, 'Actual = ', 5, 'Predictioned = ', 5.9418666666666669)
# ('#', 420, 'Actual = ', 5, 'Predictioned = ', 2.9418666666666669)
# ('#', 421, 'Actual = ', 4, 'Predictioned = ', 2.9418666666666669)
# ('#', 422, 'Actual = ', 5, 'Predictioned = ', 3.9418666666666669)
# ('#', 423, 'Actual = ', 2, 'Predictioned = ', 3.2661909909909914)
# ('#', 424, 'Actual = ', 4, 'Predictioned = ', 3.9418666666666669)
# ('#', 425, 'Actual = ', 3, 'Predictioned = ', 3.5625563218390806)
# ('#', 426, 'Actual = ', 5, 'Predictioned = ', 5.1826074074074073)
# ('#', 427, 'Actual = ', 5, 'Predictioned = ', 4.7196444444444445)
# ('#', 428, 'Actual = ', 5, 'Predictioned = ', 4.7751999999999999)
# ('#', 429, 'Actual = ', 4, 'Predictioned = ', 2.6918666666666669)
# ('#', 430, 'Actual = ', 5, 'Predictioned = ', 2.2751999999999999)
# ('#', 431, 'Actual = ', 3, 'Predictioned = ', 3.7945798449612407)
# ('#', 432, 'Actual = ', 5, 'Predictioned = ', 1.9418666666666669)
# ('#', 433, 'Actual = ', 4, 'Predictioned = ', 4.297422222222222)
# ('#', 434, 'Actual = ', 5, 'Predictioned = ', 5.1918666666666669)
# ('#', 435, 'Actual = ', 4, 'Predictioned = ', 3.9418666666666669)
# ('#', 436, 'Actual = ', 4, 'Predictioned = ', 3.9418666666666669)
# ('#', 437, 'Actual = ', 3, 'Predictioned = ', 4.641866666666667)
# ('#', 438, 'Actual = ', 1, 'Predictioned = ', 2.4418666666666669)
# ('#', 439, 'Actual = ', 5, 'Predictioned = ', 3.1918666666666669)
# ('#', 440, 'Actual = ', 3, 'Predictioned = ', 1.9418666666666669)
# ('#', 441, 'Actual = ', 4, 'Predictioned = ', 2.4201275362318841)
# ('#', 442, 'Actual = ', 3, 'Predictioned = ', 3.1918666666666669)
# ('#', 443, 'Actual = ', 4, 'Predictioned = ', 4.2827757575757577)
# ('#', 444, 'Actual = ', 5, 'Predictioned = ', 5.1501999999999999)
# ('#', 445, 'Actual = ', 1, 'Predictioned = ', 3.7418666666666667)
# ('#', 446, 'Actual = ', 5, 'Predictioned = ', 4.9894857142857143)
# ('#', 447, 'Actual = ', 1, 'Predictioned = ', 3.0751999999999997)
# ('#', 448, 'Actual = ', 5, 'Predictioned = ', 4.0579380952380948)
# ('#', 449, 'Actual = ', 4, 'Predictioned = ', 3.0371047619047618)
# ('#', 450, 'Actual = ', 5, 'Predictioned = ', 4.141866666666667)
# ('#', 451, 'Actual = ', 5, 'Predictioned = ', 4.9418666666666669)
# ('#', 452, 'Actual = ', 5, 'Predictioned = ', 5.386726479750779)
# ('#', 453, 'Actual = ', 4, 'Predictioned = ', 4.7789037037037039)
# ('#', 454, 'Actual = ', 5, 'Predictioned = ', 5.1087839598997498)
# ('#', 455, 'Actual = ', 5, 'Predictioned = ', 5.0561523809523816)
# ('#', 456, 'Actual = ', 3, 'Predictioned = ', 5.1918666666666669)
# ('#', 457, 'Actual = ', 5, 'Predictioned = ', 3.4418666666666669)
# ('#', 458, 'Actual = ', 4, 'Predictioned = ', 4.6918666666666669)
# ('#', 459, 'Actual = ', 5, 'Predictioned = ', 4.8168666666666669)
# ('#', 460, 'Actual = ', 5, 'Predictioned = ', 3.1918666666666669)
# ('#', 461, 'Actual = ', 4, 'Predictioned = ', 4.6918666666666669)
# ('#', 462, 'Actual = ', 5, 'Predictioned = ', 4.9122370370370367)
# ('#', 463, 'Actual = ', 4, 'Predictioned = ', 5.0656761904761902)
# ('#', 464, 'Actual = ', 4, 'Predictioned = ', 5.5668666666666669)
# ('#', 465, 'Actual = ', 5, 'Predictioned = ', 5.9418666666666669)
# ('#', 466, 'Actual = ', 4, 'Predictioned = ', 3.9789037037037041)
# ('#', 467, 'Actual = ', 3, 'Predictioned = ', 2.6085333333333334)
# ('#', 468, 'Actual = ', 5, 'Predictioned = ', 5.6252000000000004)
# ('#', 469, 'Actual = ', 5, 'Predictioned = ', 5.0918666666666672)
# ('#', 470, 'Actual = ', 4, 'Predictioned = ', 5.4418666666666669)
# ('#', 471, 'Actual = ', 5, 'Predictioned = ', 4.5251999999999999)
# ('#', 472, 'Actual = ', 5, 'Predictioned = ', 5.6918666666666669)
# ('#', 473, 'Actual = ', 5, 'Predictioned = ', 5.4418666666666669)
# ('#', 474, 'Actual = ', 4, 'Predictioned = ', 5.641866666666667)
# ('#', 475, 'Actual = ', 4, 'Predictioned = ', 5.641866666666667)
# ('#', 476, 'Actual = ', 5, 'Predictioned = ', 4.2751999999999999)
# ('#', 477, 'Actual = ', 3, 'Predictioned = ', 2.9418666666666664)
# ('#', 478, 'Actual = ', 5, 'Predictioned = ', 4.2927438596491232)
# ('#', 479, 'Actual = ', 5, 'Predictioned = ', 4.2716912280701749)
# ('#', 480, 'Actual = ', 5, 'Predictioned = ', 4.8704380952380948)
# ('#', 481, 'Actual = ', 4, 'Predictioned = ', 5.3704380952380957)
# ('#', 482, 'Actual = ', 5, 'Predictioned = ', 5.0734456140350881)
# ('#', 483, 'Actual = ', 4, 'Predictioned = ', 4.1085333333333338)
# ('#', 484, 'Actual = ', 5, 'Predictioned = ', 2.6607421686746995)
# ('#', 485, 'Actual = ', 5, 'Predictioned = ', 2.5752000000000002)
# ('#', 486, 'Actual = ', 5, 'Predictioned = ', 4.2751999999999999)
# ('#', 487, 'Actual = ', 4, 'Predictioned = ', 4.9418666666666669)
# ('#', 488, 'Actual = ', 5, 'Predictioned = ', 2.4418666666666669)
# ('#', 489, 'Actual = ', 5, 'Predictioned = ', 2.9418666666666669)
# ('#', 490, 'Actual = ', 5, 'Predictioned = ', 4.141866666666667)
# ('#', 491, 'Actual = ', 3, 'Predictioned = ', 2.5418666666666665)
# ('#', 492, 'Actual = ', 1, 'Predictioned = ', 3.7359843137254902)
# ('#', 493, 'Actual = ', 5, 'Predictioned = ', 3.9974222222222222)
# ('#', 494, 'Actual = ', 4, 'Predictioned = ', 5.3367264797507792)
# ('#', 495, 'Actual = ', 5, 'Predictioned = ', 4.891866666666667)
# ('#', 496, 'Actual = ', 2, 'Predictioned = ', 4.5847238095238101)
# ('#', 497, 'Actual = ', 5, 'Predictioned = ', 5.9418666666666669)
# ('#', 498, 'Actual = ', 4, 'Predictioned = ', 3.5444307692307691)
# ('#', 499, 'Actual = ', 4, 'Predictioned = ', 2.4418666666666669)
# ('#', 500, 'Actual = ', 5, 'Predictioned = ', 5.6085333333333338)
# ('#', 501, 'Actual = ', 5, 'Predictioned = ', 4.896412121212121)
# ('#', 502, 'Actual = ', 5, 'Predictioned = ', 4.9579956989247318)
# ('#', 503, 'Actual = ', 5, 'Predictioned = ', 5.1787087719298244)
# ('#', 504, 'Actual = ', 2, 'Predictioned = ', 2.2751999999999999)
# ('#', 505, 'Actual = ', 5, 'Predictioned = ', 3.8393025641025642)
# ('#', 506, 'Actual = ', 4, 'Predictioned = ', 3.9418666666666669)
# ('#', 507, 'Actual = ', 5, 'Predictioned = ', 4.6085333333333338)
# ('#', 508, 'Actual = ', 5, 'Predictioned = ', 4.5818666666666665)
# ('#', 509, 'Actual = ', 3, 'Predictioned = ', 4.141866666666667)
# ('#', 510, 'Actual = ', 3, 'Predictioned = ', 3.8466285714285715)
# ('#', 511, 'Actual = ', 3, 'Predictioned = ', 4.2751999999999999)
# ('#', 512, 'Actual = ', 5, 'Predictioned = ', 4.0668666666666669)
# ('#', 513, 'Actual = ', 1, 'Predictioned = ', 4.5847238095238101)
# ('#', 514, 'Actual = ', 4, 'Predictioned = ', 5.2751999999999999)
# ('#', 515, 'Actual = ', 5, 'Predictioned = ', 5.2751999999999999)
# ('#', 516, 'Actual = ', 5, 'Predictioned = ', 5.327408835341366)
# ('#', 517, 'Actual = ', 1, 'Predictioned = ', 5.1918666666666669)
# ('#', 518, 'Actual = ', 5, 'Predictioned = ', 3.9418666666666669)
# ('#', 519, 'Actual = ', 5, 'Predictioned = ', 4.9418666666666669)
# ('#', 520, 'Actual = ', 3, 'Predictioned = ', 4.1918666666666669)
# ('#', 521, 'Actual = ', 2, 'Predictioned = ', 4.3257050505050501)
# ('#', 522, 'Actual = ', 2, 'Predictioned = ', 4.7418666666666667)
# ('#', 523, 'Actual = ', 4, 'Predictioned = ', 5.4418666666666669)
# ('#', 524, 'Actual = ', 5, 'Predictioned = ', 3.6085333333333338)
# ('#', 525, 'Actual = ', 5, 'Predictioned = ', 5.1427799086757995)
# ('#', 526, 'Actual = ', 4, 'Predictioned = ', 5.1726358974358977)
# ('#', 527, 'Actual = ', 5, 'Predictioned = ', 5.1561523809523813)
# ('#', 528, 'Actual = ', 2, 'Predictioned = ', 4.5585333333333331)
# ('#', 529, 'Actual = ', 5, 'Predictioned = ', 4.9418666666666669)
# ('#', 530, 'Actual = ', 5, 'Predictioned = ', 4.4418666666666669)
# ('#', 531, 'Actual = ', 5, 'Predictioned = ', 4.8793666666666669)
# ('#', 532, 'Actual = ', 5, 'Predictioned = ', 5.6085333333333338)
# ('#', 533, 'Actual = ', 5, 'Predictioned = ', 5.6085333333333338)
# ('#', 534, 'Actual = ', 5, 'Predictioned = ', 5.327408835341366)
# ('#', 535, 'Actual = ', 5, 'Predictioned = ', 4.9418666666666669)
# ('#', 536, 'Actual = ', 5, 'Predictioned = ', 3.9418666666666669)
# ('#', 537, 'Actual = ', 5, 'Predictioned = ', 3.396412121212121)
# ('#', 538, 'Actual = ', 3, 'Predictioned = ', 3.5329030812324929)
# ('#', 539, 'Actual = ', 3, 'Predictioned = ', 2.9656761904761906)
# ('#', 540, 'Actual = ', 1, 'Predictioned = ', 4.8307555555555552)
# ('#', 541, 'Actual = ', 4, 'Predictioned = ', 4.7418666666666667)
# ('#', 542, 'Actual = ', 4, 'Predictioned = ', 4.4894857142857143)
# ('#', 543, 'Actual = ', 4, 'Predictioned = ', 4.9894857142857143)
# ('#', 544, 'Actual = ', 4, 'Predictioned = ', 3.5387658914728681)
# ('#', 545, 'Actual = ', 5, 'Predictioned = ', 3.894247619047619)
# ('#', 546, 'Actual = ', 5, 'Predictioned = ', 4.0371047619047626)
# ('#', 547, 'Actual = ', 3, 'Predictioned = ', 4.4371047619047621)
# ('#', 548, 'Actual = ', 5, 'Predictioned = ', 3.8704380952380952)
# ('#', 549, 'Actual = ', 4, 'Predictioned = ', 3.4418666666666669)
# ('#', 550, 'Actual = ', 4, 'Predictioned = ', 4.577408835341366)
# ('#', 551, 'Actual = ', 4, 'Predictioned = ', 3.9918666666666667)
# ('#', 552, 'Actual = ', 5, 'Predictioned = ', 1.9418666666666669)
# ('#', 553, 'Actual = ', 1, 'Predictioned = ', 3.9418666666666669)
# ('#', 554, 'Actual = ', 4, 'Predictioned = ', 5.0327757575757577)
# ('#', 555, 'Actual = ', 4, 'Predictioned = ', 5.2751999999999999)
# ('#', 556, 'Actual = ', 2, 'Predictioned = ', 4.6085333333333338)
# ('#', 557, 'Actual = ', 2, 'Predictioned = ', 4.9418666666666669)
# ('#', 558, 'Actual = ', 4, 'Predictioned = ', 4.2751999999999999)
# ('#', 559, 'Actual = ', 4, 'Predictioned = ', 4.4418666666666669)
# ('#', 560, 'Actual = ', 4, 'Predictioned = ', 4.2275809523809524)
# ('#', 561, 'Actual = ', 5, 'Predictioned = ', 4.4418666666666669)
# ('#', 562, 'Actual = ', 5, 'Predictioned = ', 4.2297454545454549)
# ('#', 563, 'Actual = ', 5, 'Predictioned = ', 4.7609142857142857)
# ('#', 564, 'Actual = ', 4, 'Predictioned = ', 2.7196444444444441)
# ('#', 565, 'Actual = ', 4, 'Predictioned = ', 2.1085333333333334)
# ('#', 566, 'Actual = ', 4, 'Predictioned = ', 3.2495589743589743)
# ('#', 567, 'Actual = ', 5, 'Predictioned = ', 4.5867264797507792)
# ('#', 568, 'Actual = ', 5, 'Predictioned = ', 4.9275809523809526)
# ('#', 569, 'Actual = ', 5, 'Predictioned = ', 4.5668666666666669)
# ('#', 570, 'Actual = ', 4, 'Predictioned = ', 3.2751999999999999)
# ('#', 571, 'Actual = ', 5, 'Predictioned = ', -0.058133333333333148)
# ('#', 572, 'Actual = ', 4, 'Predictioned = ', 5.9418666666666669)
# ('#', 573, 'Actual = ', 4, 'Predictioned = ', 4.9418666666666669)
# ('#', 574, 'Actual = ', 4, 'Predictioned = ', 4.5704380952380959)
# ('#', 575, 'Actual = ', 5, 'Predictioned = ', 4.7661909909909914)
# ('#', 576, 'Actual = ', 3, 'Predictioned = ', 2.1640888888888892)
# ('#', 577, 'Actual = ', 5, 'Predictioned = ', 3.5251999999999999)
# ('#', 578, 'Actual = ', 4, 'Predictioned = ', 2.7752000000000003)
# ('#', 579, 'Actual = ', 4, 'Predictioned = ', 4.141866666666667)
# ('#', 580, 'Actual = ', 5, 'Predictioned = ', 4.9418666666666669)
# ('#', 581, 'Actual = ', 4, 'Predictioned = ', 4.850957575757576)
# ('#', 582, 'Actual = ', 5, 'Predictioned = ', 5.1085333333333338)
# ('#', 583, 'Actual = ', 3, 'Predictioned = ', 4.6752000000000002)
# ('#', 584, 'Actual = ', 4, 'Predictioned = ', 4.3704380952380957)
# ('#', 585, 'Actual = ', 3, 'Predictioned = ', 4.6204380952380957)
# ('#', 586, 'Actual = ', 5, 'Predictioned = ', 4.0831096045197732)
# ('#', 587, 'Actual = ', 5, 'Predictioned = ', 3.9418666666666664)
# ('#', 588, 'Actual = ', 5, 'Predictioned = ', 4.4418666666666669)
# ('#', 589, 'Actual = ', 5, 'Predictioned = ', 3.5100484848484852)
# ('#', 590, 'Actual = ', 5, 'Predictioned = ', 4.2751999999999999)
# ('#', 591, 'Actual = ', 5, 'Predictioned = ', 5.141866666666667)
# ('#', 592, 'Actual = ', 5, 'Predictioned = ', 4.4418666666666669)
# ('#', 593, 'Actual = ', 3, 'Predictioned = ', 2.6918666666666669)
# ('#', 594, 'Actual = ', 4, 'Predictioned = ', 3.8774222222222221)
# ('#', 595, 'Actual = ', 4, 'Predictioned = ', 4.2342643274853797)
# ('#', 596, 'Actual = ', 4, 'Predictioned = ', 4.7418666666666667)
# ('#', 597, 'Actual = ', 4, 'Predictioned = ', 5.4918666666666667)
# ('#', 598, 'Actual = ', 5, 'Predictioned = ', 5.4418666666666669)
# ('#', 599, 'Actual = ', 5, 'Predictioned = ', 5.3585333333333338)
# ('#', 600, 'Actual = ', 5, 'Predictioned = ', 2.5704380952380959)
# ('#', 601, 'Actual = ', 3, 'Predictioned = ', 3.2751999999999999)
# ('#', 602, 'Actual = ', 1, 'Predictioned = ', 2.0700717948717955)
# ('#', 603, 'Actual = ', 1, 'Predictioned = ', 1.8418666666666668)
# ('#', 604, 'Actual = ', 3, 'Predictioned = ', 3.3492740740740738)
# ('#', 605, 'Actual = ', 3, 'Predictioned = ', 3.552977777777778)
# ('#', 606, 'Actual = ', 5, 'Predictioned = ', 5.0668666666666669)
# ('#', 607, 'Actual = ', 1, 'Predictioned = ', 4.2797045045045046)
# ('#', 608, 'Actual = ', 4, 'Predictioned = ', 5.5668666666666669)
# ('#', 609, 'Actual = ', 5, 'Predictioned = ', 3.0252000000000003)
# ('#', 610, 'Actual = ', 5, 'Predictioned = ', 5.6918666666666669)
# ('#', 611, 'Actual = ', 5, 'Predictioned = ', 5.4418666666666669)
# ('#', 612, 'Actual = ', 5, 'Predictioned = ', 1.0668666666666669)
# ('#', 613, 'Actual = ', 4, 'Predictioned = ', 1.7751999999999999)
# ('#', 614, 'Actual = ', 5, 'Predictioned = ', 5.2751999999999999)
# ('#', 615, 'Actual = ', 4, 'Predictioned = ', 4.660742168674699)
# ('#', 616, 'Actual = ', 5, 'Predictioned = ', 5.3704380952380957)
# ('#', 617, 'Actual = ', 5, 'Predictioned = ', 5.7751999999999999)
# ('#', 618, 'Actual = ', 5, 'Predictioned = ', 4.9271607843137257)
# ('#', 619, 'Actual = ', 4, 'Predictioned = ', 3.5252000000000003)
# ('#', 620, 'Actual = ', 5, 'Predictioned = ', 5.3742990990990993)
# ('#', 621, 'Actual = ', 5, 'Predictioned = ', 5.1375188405797108)
# ('#', 622, 'Actual = ', 5, 'Predictioned = ', 4.964088888888889)
# ('#', 623, 'Actual = ', 5, 'Predictioned = ', 4.5387658914728686)
# ('#', 624, 'Actual = ', 5, 'Predictioned = ', 4.391866666666667)
# ('#', 625, 'Actual = ', 4, 'Predictioned = ', 5.1918666666666669)
# ('#', 626, 'Actual = ', 5, 'Predictioned = ', 4.6561523809523813)
# ('#', 627, 'Actual = ', 5, 'Predictioned = ', 4.4743341991341996)
# ('#', 628, 'Actual = ', 5, 'Predictioned = ', 5.2418666666666667)
# ('#', 629, 'Actual = ', 5, 'Predictioned = ', 5.0668666666666669)
# ('#', 630, 'Actual = ', 4, 'Predictioned = ', 4.1561523809523813)
# ('#', 631, 'Actual = ', 5, 'Predictioned = ', 4.6561523809523813)
# ('#', 632, 'Actual = ', 4, 'Predictioned = ', 4.3704380952380948)
# ('#', 633, 'Actual = ', 4, 'Predictioned = ', 3.3704380952380952)
# ('#', 634, 'Actual = ', 5, 'Predictioned = ', 5.4164429378531072)
# ('#', 635, 'Actual = ', 5, 'Predictioned = ', 5.1918666666666669)
# ('#', 636, 'Actual = ', 3, 'Predictioned = ', 3.9418666666666669)
# ('#', 637, 'Actual = ', 4, 'Predictioned = ', 3.297422222222222)
# ('#', 638, 'Actual = ', 5, 'Predictioned = ', 5.4761132420091325)
# ('#', 639, 'Actual = ', 5, 'Predictioned = ', 4.6085333333333338)
# ('#', 640, 'Actual = ', 4, 'Predictioned = ', 1.7030606965174133)
# ('#', 641, 'Actual = ', 5, 'Predictioned = ', 1.1279131782945742)
# ('#', 642, 'Actual = ', 4, 'Predictioned = ', 5.0085333333333342)
# ('#', 643, 'Actual = ', 4, 'Predictioned = ', 5.3585333333333338)
# ('#', 644, 'Actual = ', 5, 'Predictioned = ', 4.9151999999999996)
# ('#', 645, 'Actual = ', 4, 'Predictioned = ', 4.2751999999999999)
# ('#', 646, 'Actual = ', 4, 'Predictioned = ', 4.6085333333333338)
# ('#', 647, 'Actual = ', 4, 'Predictioned = ', 5.1323428571428575)
# ('#', 648, 'Actual = ', 5, 'Predictioned = ', 5.6218666666666666)
# ('#', 649, 'Actual = ', 1, 'Predictioned = ', 5.2661909909909914)
# ('#', 650, 'Actual = ', 2, 'Predictioned = ', 2.8008410256410259)
# ('#', 651, 'Actual = ', 5, 'Predictioned = ', 4.3008410256410254)
# ('#', 652, 'Actual = ', 5, 'Predictioned = ', 5.3649435897435902)
# ('#', 653, 'Actual = ', 4, 'Predictioned = ', 5.8242196078431379)
# ('#', 654, 'Actual = ', 5, 'Predictioned = ', 4.9418666666666669)
# ('#', 655, 'Actual = ', 5, 'Predictioned = ', 5.337215503875969)
# ('#', 656, 'Actual = ', 5, 'Predictioned = ', 5.2135294301327093)
# ('#', 657, 'Actual = ', 4, 'Predictioned = ', 5.1323428571428575)
# ('#', 658, 'Actual = ', 5, 'Predictioned = ', 5.4873212121212127)
# ('#', 659, 'Actual = ', 5, 'Predictioned = ', 3.9418666666666669)
# ('#', 660, 'Actual = ', 1, 'Predictioned = ', 2.9418666666666669)
# ('#', 661, 'Actual = ', 3, 'Predictioned = ', 3.1918666666666669)
# ('#', 662, 'Actual = ', 5, 'Predictioned = ', 4.3418666666666672)
# ('#', 663, 'Actual = ', 5, 'Predictioned = ', 3.9418666666666669)
# ('#', 664, 'Actual = ', 5, 'Predictioned = ', 3.6293666666666669)
# ('#', 665, 'Actual = ', 5, 'Predictioned = ', 4.5043666666666669)
# ('#', 666, 'Actual = ', 4, 'Predictioned = ', 3.8307555555555561)
# ('#', 667, 'Actual = ', 2, 'Predictioned = ', 3.0926603174603176)
# ('#', 668, 'Actual = ', 5, 'Predictioned = ', 5.7751999999999999)
# ('#', 669, 'Actual = ', 4, 'Predictioned = ', 5.6293666666666669)
# ('#', 670, 'Actual = ', 4, 'Predictioned = ', 1.9974222222222227)
# ('#', 671, 'Actual = ', 5, 'Predictioned = ', 3.1752000000000007)
# ('#', 672, 'Actual = ', 4, 'Predictioned = ', 4.6501999999999999)
# ('#', 673, 'Actual = ', 4, 'Predictioned = ', 4.2751999999999999)
# ('#', 674, 'Actual = ', 5, 'Predictioned = ', 5.2275809523809524)
# ('#', 675, 'Actual = ', 5, 'Predictioned = ', 5.5867264797507792)
# ('#', 676, 'Actual = ', 5, 'Predictioned = ', 5.6085333333333338)
# ('#', 677, 'Actual = ', 5, 'Predictioned = ', 5.9418666666666669)
# ('#', 678, 'Actual = ', 4, 'Predictioned = ', 5.1236848484848485)
# ('#', 679, 'Actual = ', 4, 'Predictioned = ', 5.3418666666666672)
# ('#', 680, 'Actual = ', 5, 'Predictioned = ', 4.4093991341991341)
# ('#', 681, 'Actual = ', 5, 'Predictioned = ', 4.9334633053221291)
# ('#', 682, 'Actual = ', 1, 'Predictioned = ', 3.7275809523809524)
# ('#', 683, 'Actual = ', 5, 'Predictioned = ', 4.0400809523809524)
# ('#', 684, 'Actual = ', 5, 'Predictioned = ', 4.3307555555555552)
# ('#', 685, 'Actual = ', 4, 'Predictioned = ', 4.6759092198581564)
# ('#', 686, 'Actual = ', 5, 'Predictioned = ', 3.641866666666667)
# ('#', 687, 'Actual = ', 5, 'Predictioned = ', 4.4373212121212129)
# ('#', 688, 'Actual = ', 1, 'Predictioned = ', 4.4275809523809526)
# ('#', 689, 'Actual = ', 5, 'Predictioned = ', 3.8018666666666667)
# ('#', 690, 'Actual = ', 5, 'Predictioned = ', 3.3085333333333335)
# ('#', 691, 'Actual = ', 4, 'Predictioned = ', 4.024219607843138)
# ('#', 692, 'Actual = ', 5, 'Predictioned = ', 5.5867264797507792)
# ('#', 693, 'Actual = ', 5, 'Predictioned = ', 5.4324327044025162)
# ('#', 694, 'Actual = ', 1, 'Predictioned = ', 1.9228190476190479)
# ('#', 695, 'Actual = ', 5, 'Predictioned = ', 3.0085333333333333)
# ('#', 696, 'Actual = ', 5, 'Predictioned = ', 4.808533333333334)
# ('#', 697, 'Actual = ', 4, 'Predictioned = ', 4.808533333333334)
# ('#', 698, 'Actual = ', 5, 'Predictioned = ', 1.1279131782945742)
# ('#', 699, 'Actual = ', 1, 'Predictioned = ', 0.94186666666666685)
# ('#', 700, 'Actual = ', 5, 'Predictioned = ', 5.5867264797507792)
# ('#', 701, 'Actual = ', 5, 'Predictioned = ', 5.3418666666666672)
# ('#', 702, 'Actual = ', 5, 'Predictioned = ', 5.3307555555555561)
# ('#', 703, 'Actual = ', 5, 'Predictioned = ', 5.1375188405797108)
# ('#', 704, 'Actual = ', 4, 'Predictioned = ', 3.3585333333333334)
# ('#', 705, 'Actual = ', 5, 'Predictioned = ', 3.6085333333333334)
# ('#', 706, 'Actual = ', 4, 'Predictioned = ', 2.7948078431372547)
# ('#', 707, 'Actual = ', 4, 'Predictioned = ', 1.4418666666666669)
# ('#', 708, 'Actual = ', 3, 'Predictioned = ', 4.3847238095238099)
# ('#', 709, 'Actual = ', 4, 'Predictioned = ', 4.1372155038759688)
# ('#', 710, 'Actual = ', 2, 'Predictioned = ', 3.8643472868217059)
# ('#', 711, 'Actual = ', 5, 'Predictioned = ', 4.6994424242424246)
# ('#', 712, 'Actual = ', 5, 'Predictioned = ', 4.8018666666666672)
# ('#', 713, 'Actual = ', 5, 'Predictioned = ', 5.4275809523809526)
# ('#', 714, 'Actual = ', 3, 'Predictioned = ', 5.0327757575757577)
# ('#', 715, 'Actual = ', 5, 'Predictioned = ', 4.5668666666666669)
# ('#', 716, 'Actual = ', 5, 'Predictioned = ', 5.1640888888888892)
# ('#', 717, 'Actual = ', 5, 'Predictioned = ', 3.8307555555555557)
# ('#', 718, 'Actual = ', 5, 'Predictioned = ', 5.1918666666666669)
# ('#', 719, 'Actual = ', 5, 'Predictioned = ', 5.6218666666666666)
# ('#', 720, 'Actual = ', 4, 'Predictioned = ', 4.1713748633879781)
# ('#', 721, 'Actual = ', 3, 'Predictioned = ', 4.0918666666666672)
# ('#', 722, 'Actual = ', 5, 'Predictioned = ', 3.6085333333333334)
# ('#', 723, 'Actual = ', 5, 'Predictioned = ', 3.9940755020080325)
# ('#', 724, 'Actual = ', 3, 'Predictioned = ', 5.6085333333333338)
# ('#', 725, 'Actual = ', 5, 'Predictioned = ', 5.9418666666666669)
# ('#', 726, 'Actual = ', 4, 'Predictioned = ', 3.2085333333333335)
# ('#', 727, 'Actual = ', 3, 'Predictioned = ', 3.5418666666666669)
# ('#', 728, 'Actual = ', 2, 'Predictioned = ', 4.6918666666666669)
# ('#', 729, 'Actual = ', 5, 'Predictioned = ', 3.6918666666666669)
# ...
# ('#', 4763, 'Actual = ', 5, 'Predictioned = ', 3.6085333333333334)
# ('#', 4764, 'Actual = ', 5, 'Predictioned = ', 4.961097435897436)
# ('#', 4765, 'Actual = ', 5, 'Predictioned = ', 4.461097435897436)
# ('#', 4766, 'Actual = ', 3, 'Predictioned = ', 3.0668666666666669)
# ('#', 4767, 'Actual = ', 4, 'Predictioned = ', 3.4418666666666669)
# ('#', 4768, 'Actual = ', 4, 'Predictioned = ', 1.6085333333333338)
# ('#', 4769, 'Actual = ', 4, 'Predictioned = ', 1.5828923076923078)
# ('#', 4770, 'Actual = ', 3, 'Predictioned = ', 2.4974222222222222)
# ('#', 4771, 'Actual = ', 5, 'Predictioned = ', 3.9418666666666669)
# ('#', 4772, 'Actual = ', 4, 'Predictioned = ', 4.7418666666666667)
# ('#', 4773, 'Actual = ', 5, 'Predictioned = ', 5.0159407407407413)
# ('#', 4774, 'Actual = ', 5, 'Predictioned = ', 4.67336772374912)
# ('#', 4775, 'Actual = ', 5, 'Predictioned = ', 4.8154462121212127)
# ('#', 4776, 'Actual = ', 5, 'Predictioned = ', 2.1726358974358977)
# ('#', 4777, 'Actual = ', 1, 'Predictioned = ', 2.2751999999999999)
# ('#', 4778, 'Actual = ', 5, 'Predictioned = ', 4.2132341880341881)
# ('#', 4779, 'Actual = ', 5, 'Predictioned = ', 4.1616468864468867)
# ('#', 4780, 'Actual = ', 5, 'Predictioned = ', 4.896412121212121)
# ('#', 4781, 'Actual = ', 5, 'Predictioned = ', 5.4418666666666669)
# ('#', 4782, 'Actual = ', 3, 'Predictioned = ', 3.3418666666666668)
# ('#', 4783, 'Actual = ', 5, 'Predictioned = ', 3.8752)
# ('#', 4784, 'Actual = ', 5, 'Predictioned = ', 4.6719637540453078)
# ('#', 4785, 'Actual = ', 5, 'Predictioned = ', 4.641866666666667)
# ('#', 4786, 'Actual = ', 5, 'Predictioned = ', 5.3307555555555561)
# ('#', 4787, 'Actual = ', 4, 'Predictioned = ', 5.6085333333333338)
# ('#', 4788, 'Actual = ', 5, 'Predictioned = ', 4.6918666666666669)
# ('#', 4789, 'Actual = ', 5, 'Predictioned = ', 4.4918666666666667)
# ('#', 4790, 'Actual = ', 5, 'Predictioned = ', 5.2085333333333335)
# ('#', 4791, 'Actual = ', 5, 'Predictioned = ', 5.3556597701149427)
# ('#', 4792, 'Actual = ', 4, 'Predictioned = ', 4.9418666666666669)
# ('#', 4793, 'Actual = ', 5, 'Predictioned = ', 5.6085333333333338)
# ('#', 4794, 'Actual = ', 3, 'Predictioned = ', 3.0251999999999999)
# ('#', 4795, 'Actual = ', 4, 'Predictioned = ', 4.3863111111111106)
# ('#', 4796, 'Actual = ', 5, 'Predictioned = ', 4.1561523809523813)
# ('#', 4797, 'Actual = ', 4, 'Predictioned = ', 4.2751999999999999)
# ('#', 4798, 'Actual = ', 3, 'Predictioned = ', 2.0668666666666669)
# ('#', 4799, 'Actual = ', 4, 'Predictioned = ', 0.94186666666666685)
# ('#', 4800, 'Actual = ', 4, 'Predictioned = ', 1.9418666666666669)
# ('#', 4801, 'Actual = ', 4, 'Predictioned = ', 3.2373212121212127)
# ('#', 4802, 'Actual = ', 4, 'Predictioned = ', 3.9696444444444445)
# ('#', 4803, 'Actual = ', 4, 'Predictioned = ', 4.5251999999999999)
# ('#', 4804, 'Actual = ', 4, 'Predictioned = ', 3.3585333333333334)
# ('#', 4805, 'Actual = ', 5, 'Predictioned = ', 2.7871047619047618)
# ('#', 4806, 'Actual = ', 1, 'Predictioned = ', 3.6085333333333334)
# ('#', 4807, 'Actual = ', 5, 'Predictioned = ', 4.6050245614035088)
# ('#', 4808, 'Actual = ', 5, 'Predictioned = ', 4.4418666666666669)
# ('#', 4809, 'Actual = ', 3, 'Predictioned = ', 4.0847238095238101)
# ('#', 4810, 'Actual = ', 5, 'Predictioned = ', 4.5625563218390806)
# ('#', 4811, 'Actual = ', 5, 'Predictioned = ', 4.9789037037037041)
# ('#', 4812, 'Actual = ', 5, 'Predictioned = ', 4.6561523809523813)
# ('#', 4813, 'Actual = ', 5, 'Predictioned = ', 5.1085333333333338)
# ('#', 4814, 'Actual = ', 4, 'Predictioned = ', 1.6894204827136337)
# ('#', 4815, 'Actual = ', 3, 'Predictioned = ', 2.179009523809524)
# ('#', 4816, 'Actual = ', 5, 'Predictioned = ', 5.4761132420091325)
# ('#', 4817, 'Actual = ', 3, 'Predictioned = ', 3.4418666666666669)
# ('#', 4818, 'Actual = ', 2, 'Predictioned = ', 2.9418666666666669)
# ('#', 4819, 'Actual = ', 1, 'Predictioned = ', 4.6918666666666669)
# ('#', 4820, 'Actual = ', 3, 'Predictioned = ', 4.1363111111111115)
# ('#', 4821, 'Actual = ', 5, 'Predictioned = ', 4.5018666666666665)
# ('#', 4822, 'Actual = ', 5, 'Predictioned = ', 4.9418666666666669)
# ('#', 4823, 'Actual = ', 5, 'Predictioned = ', 4.7418666666666667)
# ('#', 4824, 'Actual = ', 4, 'Predictioned = ', 2.4418666666666669)
# ('#', 4825, 'Actual = ', 5, 'Predictioned = ', 4.6918666666666669)
# ('#', 4826, 'Actual = ', 4, 'Predictioned = ', 4.1168666666666667)
# ('#', 4827, 'Actual = ', 4, 'Predictioned = ', 1.9835333333333334)
# ('#', 4828, 'Actual = ', 5, 'Predictioned = ', 4.9418666666666669)
# ('#', 4829, 'Actual = ', 5, 'Predictioned = ', 5.4418666666666669)
# ('#', 4830, 'Actual = ', 4, 'Predictioned = ', 2.6969687074829936)
# ('#', 4831, 'Actual = ', 1, 'Predictioned = ', 1.9418666666666669)
# ('#', 4832, 'Actual = ', 5, 'Predictioned = ', 5.1085333333333338)
# ('#', 4833, 'Actual = ', 5, 'Predictioned = ', 4.3903515151515151)
# ('#', 4834, 'Actual = ', 3, 'Predictioned = ', 5.6260771929824562)
# ('#', 4835, 'Actual = ', 5, 'Predictioned = ', 4.9418666666666669)
# ('#', 4836, 'Actual = ', 4, 'Predictioned = ', 5.0433159420289861)
# ('#', 4837, 'Actual = ', 4, 'Predictioned = ', 4.9878436781609201)
# ('#', 4838, 'Actual = ', 5, 'Predictioned = ', 4.6918666666666669)
# ('#', 4839, 'Actual = ', 5, 'Predictioned = ', 4.2261132420091325)
# ('#', 4840, 'Actual = ', 5, 'Predictioned = ', 4.6218666666666666)
# ('#', 4841, 'Actual = ', 5, 'Predictioned = ', 3.641866666666667)
# ('#', 4842, 'Actual = ', 5, 'Predictioned = ', 4.6918666666666669)
# ('#', 4843, 'Actual = ', 5, 'Predictioned = ', 4.2418666666666667)
# ('#', 4844, 'Actual = ', 5, 'Predictioned = ', 3.6918666666666673)
# ('#', 4845, 'Actual = ', 5, 'Predictioned = ', 3.8661909909909915)
# ('#', 4846, 'Actual = ', 5, 'Predictioned = ', 5.4761132420091325)
# ('#', 4847, 'Actual = ', 5, 'Predictioned = ', 5.3704380952380957)
# ('#', 4848, 'Actual = ', 3, 'Predictioned = ', 4.0418666666666674)
# ('#', 4849, 'Actual = ', 5, 'Predictioned = ', 4.432775757575758)
# ('#', 4850, 'Actual = ', 5, 'Predictioned = ', 4.7797045045045046)
# ('#', 4851, 'Actual = ', 5, 'Predictioned = ', 5.2275809523809524)
# ('#', 4852, 'Actual = ', 5, 'Predictioned = ', 5.9418666666666669)
# ('#', 4853, 'Actual = ', 5, 'Predictioned = ', 5.6918666666666669)
# ('#', 4854, 'Actual = ', 4, 'Predictioned = ', 3.7497762711864406)
# ('#', 4855, 'Actual = ', 4, 'Predictioned = ', 2.7752000000000003)
# ('#', 4856, 'Actual = ', 1, 'Predictioned = ', 3.9418666666666669)
# ('#', 4857, 'Actual = ', 5, 'Predictioned = ', 3.4974222222222222)
# ('#', 4858, 'Actual = ', 4, 'Predictioned = ', 1.3766492753623192)
# ('#', 4859, 'Actual = ', 2, 'Predictioned = ', 0.94186666666666685)
# ('#', 4860, 'Actual = ', 5, 'Predictioned = ', 4.3418666666666672)
# ('#', 4861, 'Actual = ', 4, 'Predictioned = ', 4.1375188405797108)
# ('#', 4862, 'Actual = ', 4, 'Predictioned = ', 2.5609142857142859)
# ('#', 4863, 'Actual = ', 5, 'Predictioned = ', 3.4612465116279076)
# ('#', 4864, 'Actual = ', 3, 'Predictioned = ', 4.2303282051282052)
# ('#', 4865, 'Actual = ', 5, 'Predictioned = ', 3.9803282051282052)
# ('#', 4866, 'Actual = ', 4, 'Predictioned = ', 5.7751999999999999)
# ('#', 4867, 'Actual = ', 5, 'Predictioned = ', 5.3307555555555561)
# ('#', 4868, 'Actual = ', 5, 'Predictioned = ', 4.793515018315019)
# ('#', 4869, 'Actual = ', 4, 'Predictioned = ', 4.770438095238096)
# ('#', 4870, 'Actual = ', 5, 'Predictioned = ', 3.7807555555555563)
# ('#', 4871, 'Actual = ', 4, 'Predictioned = ', 4.308533333333334)
# ('#', 4872, 'Actual = ', 1, 'Predictioned = ', 4.7418666666666667)
# ('#', 4873, 'Actual = ', 5, 'Predictioned = ', 4.5418666666666674)
# ('#', 4874, 'Actual = ', 5, 'Predictioned = ', 4.808533333333334)
# ('#', 4875, 'Actual = ', 5, 'Predictioned = ', 4.4085333333333336)
# ('#', 4876, 'Actual = ', 2, 'Predictioned = ', 5.3612215053763439)
# ('#', 4877, 'Actual = ', 5, 'Predictioned = ', 5.7600484848484852)
# ('#', 4878, 'Actual = ', 1, 'Predictioned = ', 4.9418666666666669)
# ('#', 4879, 'Actual = ', 1, 'Predictioned = ', 4.9418666666666669)
# ('#', 4880, 'Actual = ', 5, 'Predictioned = ', 3.7734456140350883)
# ('#', 4881, 'Actual = ', 2, 'Predictioned = ', 2.3418666666666672)
# ('#', 4882, 'Actual = ', 1, 'Predictioned = ', 5.7418666666666667)
# ('#', 4883, 'Actual = ', 3, 'Predictioned = ', 3.9918666666666667)
# ('#', 4884, 'Actual = ', 5, 'Predictioned = ', 4.9992437158469949)
# ('#', 4885, 'Actual = ', 5, 'Predictioned = ', 4.4418666666666669)
# ('#', 4886, 'Actual = ', 5, 'Predictioned = ', 4.6085333333333338)
# ('#', 4887, 'Actual = ', 5, 'Predictioned = ', 4.1585333333333336)
# ('#', 4888, 'Actual = ', 5, 'Predictioned = ', 5.2751999999999999)
# ('#', 4889, 'Actual = ', 5, 'Predictioned = ', 5.2751999999999999)
# ('#', 4890, 'Actual = ', 5, 'Predictioned = ', 3.1375188405797108)
# ('#', 4891, 'Actual = ', 5, 'Predictioned = ', 2.1918666666666669)
# ('#', 4892, 'Actual = ', 3, 'Predictioned = ', -0.28035555555555547)
# ('#', 4893, 'Actual = ', 4, 'Predictioned = ', 1.6085333333333338)
# ('#', 4894, 'Actual = ', 5, 'Predictioned = ', 4.9418666666666669)
# ('#', 4895, 'Actual = ', 5, 'Predictioned = ', 5.4484456140350881)
# ('#', 4896, 'Actual = ', 5, 'Predictioned = ', 4.5327757575757577)
# ('#', 4897, 'Actual = ', 4, 'Predictioned = ', 4.3418666666666672)
# ('#', 4898, 'Actual = ', 2, 'Predictioned = ', 1.9418666666666669)
# ('#', 4899, 'Actual = ', 4, 'Predictioned = ', 4.729745454545454)
# ('#', 4900, 'Actual = ', 5, 'Predictioned = ', 5.0363940298507464)
# ('#', 4901, 'Actual = ', 2, 'Predictioned = ', 4.3418666666666672)
# ('#', 4902, 'Actual = ', 4, 'Predictioned = ', 3.8418666666666672)
# ('#', 4903, 'Actual = ', 5, 'Predictioned = ', 1.2632952380952385)
# ('#', 4904, 'Actual = ', 1, 'Predictioned = ', 2.179961904761905)
# ('#', 4905, 'Actual = ', 5, 'Predictioned = ', 2.6085333333333338)
# ('#', 4906, 'Actual = ', 5, 'Predictioned = ', 4.7751999999999999)
# ('#', 4907, 'Actual = ', 5, 'Predictioned = ', 4.9418666666666669)
# ('#', 4908, 'Actual = ', 5, 'Predictioned = ', 5.3418666666666672)
# ('#', 4909, 'Actual = ', 5, 'Predictioned = ', 5.9418666666666669)
# ('#', 4910, 'Actual = ', 2, 'Predictioned = ', 3.4418666666666669)
# ('#', 4911, 'Actual = ', 5, 'Predictioned = ', 4.2561523809523818)
# ('#', 4912, 'Actual = ', 5, 'Predictioned = ', 4.747881704260652)
# ('#', 4913, 'Actual = ', 5, 'Predictioned = ', 5.0918666666666672)
# ('#', 4914, 'Actual = ', 5, 'Predictioned = ', 5.1726358974358977)
# ('#', 4915, 'Actual = ', 5, 'Predictioned = ', 4.8418666666666672)
# ('#', 4916, 'Actual = ', 5, 'Predictioned = ', 5.1674480620155041)
# ('#', 4917, 'Actual = ', 5, 'Predictioned = ', 3.7497762711864406)
# ('#', 4918, 'Actual = ', 4, 'Predictioned = ', 3.1461677419354843)
# ('#', 4919, 'Actual = ', 4, 'Predictioned = ', 2.7752000000000003)
# ('#', 4920, 'Actual = ', 4, 'Predictioned = ', 4.2751999999999999)
# ('#', 4921, 'Actual = ', 1, 'Predictioned = ', 1.6085333333333334)
# ('#', 4922, 'Actual = ', 1, 'Predictioned = ', 0.74186666666666667)
# ('#', 4923, 'Actual = ', 5, 'Predictioned = ', 4.0363940298507472)
# ('#', 4924, 'Actual = ', 5, 'Predictioned = ', 3.2752000000000003)
# ('#', 4925, 'Actual = ', 1, 'Predictioned = ', 3.2751999999999999)
# ('#', 4926, 'Actual = ', 1, 'Predictioned = ', 2.9418666666666664)
# ('#', 4927, 'Actual = ', 5, 'Predictioned = ', 4.4418666666666669)
# ('#', 4928, 'Actual = ', 5, 'Predictioned = ', 4.4418666666666669)
# ('#', 4929, 'Actual = ', 3, 'Predictioned = ', 2.8128344086021508)
# ('#', 4930, 'Actual = ', 5, 'Predictioned = ', 3.4164429378531072)
# ('#', 4931, 'Actual = ', 5, 'Predictioned = ', 5.3418666666666672)
# ('#', 4932, 'Actual = ', 5, 'Predictioned = ', 5.2085333333333335)
# ('#', 4933, 'Actual = ', 5, 'Predictioned = ', 4.9418666666666669)
# ('#', 4934, 'Actual = ', 5, 'Predictioned = ', 4.4418666666666669)
# ('#', 4935, 'Actual = ', 5, 'Predictioned = ', 3.9418666666666669)
# ('#', 4936, 'Actual = ', 5, 'Predictioned = ', 3.8418666666666672)
# ('#', 4937, 'Actual = ', 5, 'Predictioned = ', 2.4037714285714293)
# ('#', 4938, 'Actual = ', 5, 'Predictioned = ', 1.5479272727272733)
# ('#', 4939, 'Actual = ', 5, 'Predictioned = ', 4.5807555555555561)
# ('#', 4940, 'Actual = ', 5, 'Predictioned = ', 4.6561523809523813)
# ('#', 4941, 'Actual = ', 5, 'Predictioned = ', 3.6085333333333338)
# ('#', 4942, 'Actual = ', 5, 'Predictioned = ', 4.0251999999999999)
# ('#', 4943, 'Actual = ', 5, 'Predictioned = ', 4.670548837209302)
# ('#', 4944, 'Actual = ', 5, 'Predictioned = ', 4.0493935483870969)
# ('#', 4945, 'Actual = ', 5, 'Predictioned = ', 4.0418666666666674)
# ('#', 4946, 'Actual = ', 4, 'Predictioned = ', 4.4418666666666669)
# ('#', 4947, 'Actual = ', 5, 'Predictioned = ', 4.6918666666666669)
# ('#', 4948, 'Actual = ', 5, 'Predictioned = ', 5.7751999999999999)
# ('#', 4949, 'Actual = ', 3, 'Predictioned = ', 1.595712820512821)
# ('#', 4950, 'Actual = ', 4, 'Predictioned = ', 1.8211770114942532)
# ('#', 4951, 'Actual = ', 1, 'Predictioned = ', 3.3085333333333335)
# ('#', 4952, 'Actual = ', 2, 'Predictioned = ', 3.4061523809523813)
# ('#', 4953, 'Actual = ', 5, 'Predictioned = ', 4.3560080808080812)
# ('#', 4954, 'Actual = ', 5, 'Predictioned = ', 4.6085333333333338)
# ('#', 4955, 'Actual = ', 1, 'Predictioned = ', 4.9418666666666669)
# ('#', 4956, 'Actual = ', 2, 'Predictioned = ', 4.6969687074829931)
# ('#', 4957, 'Actual = ', 5, 'Predictioned = ', 5.3944982456140353)
# ('#', 4958, 'Actual = ', 2, 'Predictioned = ', 4.8418666666666663)
# ('#', 4959, 'Actual = ', 5, 'Predictioned = ', 4.3418666666666672)
# ('#', 4960, 'Actual = ', 5, 'Predictioned = ', 3.9132952380952388)
# ('#', 4961, 'Actual = ', 4, 'Predictioned = ', 4.1085333333333338)
# ('#', 4962, 'Actual = ', 1, 'Predictioned = ', 4.1918666666666669)
# ('#', 4963, 'Actual = ', 5, 'Predictioned = ', 3.7016069264069267)
# ('#', 4964, 'Actual = ', 3, 'Predictioned = ', 2.9317656565656569)
# ('#', 4965, 'Actual = ', 3, 'Predictioned = ', 4.529424270353303)
# ('#', 4966, 'Actual = ', 5, 'Predictioned = ', 4.2990095238095236)
# ('#', 4967, 'Actual = ', 4, 'Predictioned = ', 5.6168666666666667)
# ('#', 4968, 'Actual = ', 5, 'Predictioned = ', 5.2579956989247316)
# ('#', 4969, 'Actual = ', 5, 'Predictioned = ', 3.808533333333334)
# ('#', 4970, 'Actual = ', 5, 'Predictioned = ', 4.9386304207119744)
# ('#', 4971, 'Actual = ', 4, 'Predictioned = ', 3.850957575757576)
# ('#', 4972, 'Actual = ', 3, 'Predictioned = ', 3.8964121212121214)
# ('#', 4973, 'Actual = ', 5, 'Predictioned = ', 3.1918666666666669)
# ('#', 4974, 'Actual = ', 5, 'Predictioned = ', 4.3585333333333338)
# ('#', 4975, 'Actual = ', 5, 'Predictioned = ', 5.4656761904761906)
# ('#', 4976, 'Actual = ', 5, 'Predictioned = ', 5.2145939393939393)
# ('#', 4977, 'Actual = ', 5, 'Predictioned = ', 4.8942476190476194)
# ('#', 4978, 'Actual = ', 5, 'Predictioned = ', 5.6918666666666669)
# ('#', 4979, 'Actual = ', 4, 'Predictioned = ', 4.6085333333333338)
# ('#', 4980, 'Actual = ', 4, 'Predictioned = ', 4.2751999999999999)
# ('#', 4981, 'Actual = ', 5, 'Predictioned = ', 5.1726358974358977)
# ('#', 4982, 'Actual = ', 5, 'Predictioned = ', 5.4324327044025162)
# ('#', 4983, 'Actual = ', 5, 'Predictioned = ', 5.396412121212121)
# ('#', 4984, 'Actual = ', 5, 'Predictioned = ', 5.0704380952380959)
# ('#', 4985, 'Actual = ', 5, 'Predictioned = ', 3.6918666666666669)
# ('#', 4986, 'Actual = ', 5, 'Predictioned = ', 5.0418666666666665)
# ('#', 4987, 'Actual = ', 5, 'Predictioned = ', 5.4164429378531072)
# ('#', 4988, 'Actual = ', 5, 'Predictioned = ', 5.4180571428571431)
# ('#', 4989, 'Actual = ', 5, 'Predictioned = ', 5.4418666666666669)
# ('#', 4990, 'Actual = ', 5, 'Predictioned = ', 5.9418666666666669)
# ('#', 4991, 'Actual = ', 5, 'Predictioned = ', 5.3218666666666667)
# ('#', 4992, 'Actual = ', 5, 'Predictioned = ', 5.9418666666666669)
# ('#', 4993, 'Actual = ', 5, 'Predictioned = ', 4.8307555555555561)
# ('#', 4994, 'Actual = ', 4, 'Predictioned = ', 5.3228190476190482)
# ('#', 4995, 'Actual = ', 4, 'Predictioned = ', 4.5863111111111117)
# ('#', 4996, 'Actual = ', 5, 'Predictioned = ', 4.805024561403509)
# ('#', 4997, 'Actual = ', 4, 'Predictioned = ', 1.2752000000000003)
# ('#', 4998, 'Actual = ', 4, 'Predictioned = ', 3.3944982456140353)
# ('#', 4999, 'Actual = ', 5, 'Predictioned = ', 4.641866666666667)
# ('#', 5000, 'Actual = ', 4, 'Predictioned = ', 5.2373212121212127)
# Done Predicting in 1.59 seconds

# %%
print "MAE=", MAE
print "RMSE=", RMSE
# Out:
# MAE= 1.0
# RMSE= 1.37

# %%
sparse_ratings = csr_matrix(ratings_matrix, dtype='float')

# %%
model_knn = NearestNeighbors(metric = 'cosine', n_neighbors = 6)
model_knn.fit(sparse_ratings)
# Out:
# NearestNeighbors(algorithm='auto', leaf_size=30, metric='cosine',
#          metric_params=None, n_jobs=1, n_neighbors=6, p=2, radius=1.0)

# %%
def get_recommendations(user_index, n_reccomendations=5, n_neighbors=10):
    distances,indices = model_knn.kneighbors(ratings_matrix[user_index].reshape(1, -1), n_neighbors=n_neighbors)
    probable_items = list()
    for user in indices[0]:
        if user == user_index:
            #print "Recommendations for user ", unique_users[user_index]
            continue
        # all other users
        for items in np.nonzero(ratings_matrix[user]):
            for item in items:
                if ratings_matrix[user_index][item] == 0:
                    probable_items.append(unique_items[item])

    predictions = {}
    for item in probable_items:
        predictions[item] = predict(unique_users[0], item)
        sorted_predictions = sorted(predictions.items(), key=operator.itemgetter(1))
    return [i[0] for i in sorted_predictions[:n_reccomendations]]

# %%
def get_user_items_rated_df(user_id):
    df = pd.DataFrame()
    np.nonzero(ratings_matrix[user_id])
    for i in np.nonzero(ratings_matrix[user_id]):
        x = pd.DataFrame({"item":unique_items[i], "rating":ratings_matrix[user_id][i]})
        df = df.append(x)
        return df

def print_items_rated(user_id):
    np.nonzero(ratings_matrix[user_id])
    for i in unique_items[np.nonzero(ratings_matrix[user_id])]:
        print i

# %%
get_user_items_rated_df(0)
# Out:
#          item rating
# 0  B004WGGQPQ      5
# 1  B006C1ZSO4      5
# 2  B007KPT2N4      1
# 3  B0080JJLBW      5
# 4  B008LY1B32      4
# 5  B009P8EMCK      5
# 6  B00AMR1HZ8      4
# 7  B00ANT8OF6      4

# %%
print get_recommendations(user_index=0)
import asin_to_rec
asin_to_rec.get_recommendation_items(get_recommendations(user_index=0)[:2])
# Out:
# [u'B004Z2VHAQ', u'B00I6IKSZ0', u'B007BTE2F2', u'B00G4FAU14', u'B00A13BI7U']
