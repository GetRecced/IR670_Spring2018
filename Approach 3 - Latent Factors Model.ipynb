# %%
# Imports 
import pandas as pd
import numpy as np
import time
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.neighbors import NearestNeighbors
from scipy.sparse import csr_matrix
import operator
from collections import defaultdict

# %%
# load the data, keep only selected columns
# Read the file using super fast Pandas.read_csv
def load_required_data(path, required_columns):
    dataframe = pd.read_json(path, lines=True)
    dataframe = dataframe[required_columns]
    return dataframe, dataframe.values

# %%
dataframe, values = load_required_data('train_15000.json', ["asin", "reviewerID", "overall"])

# %%
dataframe[:10]
# Out:
#          asin             reviewerID  overall
# 0  B00ANT8OF6  A00100742Q4O8VH0YMUBZ        4
# 1  B00AMR1HZ8  A00100742Q4O8VH0YMUBZ        4
# 2  B004WGGQPQ  A00100742Q4O8VH0YMUBZ        5
# 3  B006C1ZSO4  A00100742Q4O8VH0YMUBZ        5
# 4  B008LY1B32  A00100742Q4O8VH0YMUBZ        4
# 5  B007KPT2N4  A00100742Q4O8VH0YMUBZ        1
# 6  B0080JJLBW  A00100742Q4O8VH0YMUBZ        5
# 7  B009P8EMCK  A00100742Q4O8VH0YMUBZ        5
# 8  B00I8Q77Y0  A001619027H9L9EG4UVRB        5
# 9  B00H0BGCJK  A001619027H9L9EG4UVRB        5

# %%
dataframe.shape
# Out:
# (15000, 3)

# %%
# Create user-item matrix given a matrix and mapping from original matrix columns to new matrix rows/columns
def create_user_item_matrix(data, rowMapping, columnMapping):
    # Create table of users to items by taking row and column pivots
    # Rows of user-item table are users
    rows, row_pos = np.unique(data[:, rowMapping], return_inverse=True)
    # Columns of user-item table are movies
    cols, col_pos = np.unique(data[:, columnMapping], return_inverse=True)

    pivot_table = np.zeros((len(rows), len(cols)), dtype=data.dtype)
    pivot_table[row_pos, col_pos] = data[:, 2]
    return pivot_table, rows, cols

# %%
ratings_matrix, rows, cols = create_user_item_matrix(values, rowMapping=1, columnMapping=0)
print (ratings_matrix.shape)
# Out:
# (3139, 1842)

# %%
pd.DataFrame(ratings_matrix[:10], index = rows[:10], columns= cols)
# Out:
#                       B004ALVL6W B004ANMWPY B004DLNC4I B004DLPXAO B004DM1OAQ  \
# A00100742Q4O8VH0YMUBZ          0          0          0          0          0
# A001619027H9L9EG4UVRB          0          0          0          0          0
# A002359833QJM7OQHCXWY          0          0          0          0          0
# A0037670NPLI11RBWYFA           0          0          0          0          0
# A003841815JTX0JFLR8B1          0          0          0          0          0
# A0038872349TB5N0JHQQW          0          0          0          0          0
# A00455683H6M1GQZMPQPV          0          0          0          0          0
# A0047670XAAJD587LXS7           0          0          0          0          0
# A00501041JRAPWYLPQ4TE          0          0          0          0          0
# A00507662MEMHI1YMGQ15          0          0          0          0          0
#
#                       B004DM1ZQY B004DPBGCO B004DPC5Y2 B004DPCSKI B004DPIEF6  \
# A00100742Q4O8VH0YMUBZ          0          0          0          0          0
# A001619027H9L9EG4UVRB          0          0          0          0          0
# A002359833QJM7OQHCXWY          0          0          0          0          0
# A0037670NPLI11RBWYFA           0          0          0          0          0
# A003841815JTX0JFLR8B1          0          0          0          0          0
# A0038872349TB5N0JHQQW          0          0          0          0          0
# A00455683H6M1GQZMPQPV          0          0          0          0          0
# A0047670XAAJD587LXS7           0          0          0          0          0
# A00501041JRAPWYLPQ4TE          0          0          0          0          0
# A00507662MEMHI1YMGQ15          0          0          0          0          0
#
#                          ...     B00K7WGUKA B00KFNXUY0 B00KGCNRAM B00KI5Q8X0  \
# A00100742Q4O8VH0YMUBZ    ...              0          0          0          0
# A001619027H9L9EG4UVRB    ...              0          0          0          0
# A002359833QJM7OQHCXWY    ...              0          0          0          0
# A0037670NPLI11RBWYFA     ...              0          0          0          0
# A003841815JTX0JFLR8B1    ...              0          0          0          0
# A0038872349TB5N0JHQQW    ...              0          0          0          0
# A00455683H6M1GQZMPQPV    ...              0          0          0          0
# A0047670XAAJD587LXS7     ...              0          0          0          0
# A00501041JRAPWYLPQ4TE    ...              0          0          0          0
# A00507662MEMHI1YMGQ15    ...              0          0          0          0
#
#                       B00KMX5V8G B00KOEHQCW B00KQHVWWC B00KSOQ66K B00KWVZ750  \
# A00100742Q4O8VH0YMUBZ          0          0          0          0          0
# A001619027H9L9EG4UVRB          0          0          0          0          0
# A002359833QJM7OQHCXWY          0          0          0          0          0
# A0037670NPLI11RBWYFA           0          0          0          0          0
# A003841815JTX0JFLR8B1          0          0          0          0          0
# A0038872349TB5N0JHQQW          0          0          0          0          0
# A00455683H6M1GQZMPQPV          0          0          0          0          5
# A0047670XAAJD587LXS7           0          0          0          0          0
# A00501041JRAPWYLPQ4TE          0          0          0          0          0
# A00507662MEMHI1YMGQ15          0          0          0          0          0
#
#                       B00L3MNCNQ
# A00100742Q4O8VH0YMUBZ          0
# A001619027H9L9EG4UVRB          0
# A002359833QJM7OQHCXWY          0
# A0037670NPLI11RBWYFA           0
# A003841815JTX0JFLR8B1          0
# A0038872349TB5N0JHQQW          0
# A00455683H6M1GQZMPQPV          0
# A0047670XAAJD587LXS7           0
# A00501041JRAPWYLPQ4TE          0
# A00507662MEMHI1YMGQ15          0
#
# [10 rows x 1842 columns]

# %%
def get_index_map(arr):
    index_map = {}
    for el in arr:
        index_map[el] = len(index_map)
    return index_map

# %%
# Get unique movies and users
unique_items = np.unique(values[:,0])
unique_users = np.unique(values[:,1])

# %%
# Create mapping from unique list to 
item_idx_map = get_index_map(unique_items)
user_idx_map = get_index_map(unique_users)

# %%
test_dataframe, test_values = load_required_data('test_5000.json', ["asin", "reviewerID", "overall"])

# %%
def get_user_items_rated_df(user_id):
    df = pd.DataFrame()
    np.nonzero(ratings_matrix[user_id])
    for i in np.nonzero(ratings_matrix[user_id]):
        x = pd.DataFrame({"item":unique_items[i], "rating":ratings_matrix[user_id][i]})
        df = df.append(x)
        return df

def print_items_rated(user_id):
    np.nonzero(ratings_matrix[user_id])
    for i in unique_items[np.nonzero(ratings_matrix[user_id])]:
        print i

# %%
from surprise import SVD
from surprise import accuracy
from surprise import Reader
from surprise import Dataset
from surprise.model_selection import train_test_split

reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(dataframe[['reviewerID', 'asin', 'overall']], reader)
data_train = data.build_full_trainset()

# %%
algo = SVD()
algo.fit(data_train)

# %%
data_test = Dataset.load_from_df(test_dataframe[['reviewerID', 'asin', 'overall']], reader)
testset = data_test.build_full_trainset().build_testset()

predictions = algo.test(testset)

# %%
accuracy.rmse(predictions)
accuracy.mae(predictions)
# Out:
# RMSE: 1.1818
# MAE:  0.9075
# 0.9074699375192018

# %%
def get_top_n(user, predictions, n=10):
    '''Return the top-N recommendation for each user from a set of predictions.

    Args:
        predictions(list of Prediction objects): The list of predictions, as
            returned by the test method of an algorithm.
        n(int): The number of recommendation to output for each user. Default
            is 10.

    Returns:
    A dict where keys are user (raw) ids and values are lists of tuples:
        [(raw item id, rating estimation), ...] of size n.
    '''

    # First map the predictions to each user.
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        if uid == user:
            top_n[uid].append((iid, est))

    # Then sort the predictions for each user and retrieve the k highest ones.
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]

    return top_n

# %%
get_top_n(u'A13Q9FMHS483MD, pred)
# Out:
# [Prediction(uid=u'A13Q9FMHS483MD', iid=u'B004MC8CA2', r_ui=5.0, est=4.669553694444572, details={u'was_impossible': False}),
#  Prediction(uid=u'A11NOHYMLI0Y1L', iid=u'B0093QQAEM', r_ui=5.0, est=4.55999053363123, details={u'was_impossible': False}),
#  Prediction(uid=u'A1316FBN61E6XS', iid=u'B009PCBEPE', r_ui=2.0, est=4.255684814787538, details={u'was_impossible': False}),
#  Prediction(uid=u'A107O88X9VTJXJ', iid=u'B00JVZ0DQG', r_ui=4.0, est=4.401010769235086, details={u'was_impossible': False}),
#  Prediction(uid=u'A12U6CX0KUGR8T', iid=u'B008L29K6E', r_ui=4.0, est=4.020879941260944, details={u'was_impossible': False}),
#  Prediction(uid=u'A10RH6B7URE1B', iid=u'B009UWL580', r_ui=4.0, est=4.2051289197499, details={u'was_impossible': False}),
#  Prediction(uid=u'A099280716ZEH5UPWAN4A', iid=u'B00HFTHXMC', r_ui=3.0, est=4.204530518653084, details={u'was_impossible': False}),
#  Prediction(uid=u'A02658263UUAM9CGW5U4S', iid=u'B00A9JG6RS', r_ui=3.0, est=3.8230195680081196, details={u'was_impossible': False}),
#  Prediction(uid=u'A122SYSEQO1Y9U', iid=u'B007Q3KX42', r_ui=3.0, est=3.2903739401011665, details={u'was_impossible': False}),
#  Prediction(uid=u'A13RNGFMP1ZK88', iid=u'B008841TP0', r_ui=3.0, est=3.8378765832982342, details={u'was_impossible': False}),
#  Prediction(uid=u'A10ZYL8EJ4PI9X', iid=u'B00DRHY8EW', r_ui=5.0, est=4.542848640167924, details={u'was_impossible': False}),
#  Prediction(uid=u'A12H68NUU2TB8I', iid=u'B0058VW36U', r_ui=5.0, est=4.137746672058653, details={u'was_impossible': False}),
#  Prediction(uid=u'A006458827ALF2J23JJTO', iid=u'B00IS87HYI', r_ui=5.0, est=4.295036304567067, details={u'was_impossible': False}),
#  Prediction(uid=u'A10XGVMHXKE74M', iid=u'B009UX2YAC', r_ui=5.0, est=4.843530179474637, details={u'was_impossible': False}),
#  Prediction(uid=u'A11O7CW8KQ1ED9', iid=u'B00AECGQF2', r_ui=5.0, est=4.400560768045748, details={u'was_impossible': False}),
#  Prediction(uid=u'A13OL3PG7T82PP', iid=u'B00DJFIMW6', r_ui=5.0, est=4.225275136701664, details={u'was_impossible': False}),
#  Prediction(uid=u'A10AMAR18JLUN7', iid=u'B00HPUGZI4', r_ui=5.0, est=3.91461332997644, details={u'was_impossible': False}),
#  Prediction(uid=u'A125RLBHHYTXC4', iid=u'B00632HWOG', r_ui=3.0, est=3.9488844704857216, details={u'was_impossible': False}),
#  Prediction(uid=u'A13419SLGGAS2I', iid=u'B00FYHXMQS', r_ui=4.0, est=4.279905142438266, details={u'was_impossible': False}),
#  Prediction(uid=u'A11COHG3O3GP40', iid=u'B00FAPF5U0', r_ui=4.0, est=4.3652411159323155, details={u'was_impossible': False}),
#  Prediction(uid=u'A10FSLJ39NOZKX', iid=u'B007PW1BZY', r_ui=4.0, est=4.225437782871026, details={u'was_impossible': False}),
#  Prediction(uid=u'A11DJSJRUVICKL', iid=u'B004TTY694', r_ui=3.0, est=3.8560136168772883, details={u'was_impossible': False}),
#  Prediction(uid=u'A12WCO9LEZPHY8', iid=u'B00HTKA4N2', r_ui=2.0, est=3.7740007506749733, details={u'was_impossible': False}),
#  Prediction(uid=u'A07305593IWIWUBQUZ288', iid=u'B004SIIBGU', r_ui=5.0, est=4.143701849507667, details={u'was_impossible': False}),
#  Prediction(uid=u'A132AHCK9U8HDS', iid=u'B0069G5Z9K', r_ui=5.0, est=4.701172479915736, details={u'was_impossible': False}),
#  Prediction(uid=u'A114D3RWPFJYMJ', iid=u'B0069G5Z9K', r_ui=5.0, est=4.562397640320311, details={u'was_impossible': False}),
#  Prediction(uid=u'A119NIBOR9KD0B', iid=u'B00E8KLWB4', r_ui=4.0, est=3.5474743714657317, details={u'was_impossible': False}),
#  Prediction(uid=u'A13UWVR2DT8RDJ', iid=u'B00GY0HJ4K', r_ui=5.0, est=4.55491331394786, details={u'was_impossible': False}),
#  Prediction(uid=u'A11TWPMDQUO6V2', iid=u'B007VT07QU', r_ui=4.0, est=3.788860970494649, details={u'was_impossible': False}),
#  Prediction(uid=u'A10Z5U9GROW4B8', iid=u'B00CAW96DI', r_ui=5.0, est=4.719146031291043, details={u'was_impossible': False}),
#  Prediction(uid=u'A10BW90I6MQW4N', iid=u'B005ZFOOE8', r_ui=5.0, est=4.881078494230468, details={u'was_impossible': False}),
#  Prediction(uid=u'A118WSI7TQJIA4', iid=u'B006VXRNYG', r_ui=5.0, est=4.643878567094678, details={u'was_impossible': False}),
#  Prediction(uid=u'A10GZKZ9022JSV', iid=u'B00992CF6W', r_ui=5.0, est=4.325087150146731, details={u'was_impossible': False}),
#  Prediction(uid=u'A11J3Q5DJG7Q1R', iid=u'B00GGOVTN6', r_ui=1.0, est=4.031313533285885, details={u'was_impossible': False}),
#  Prediction(uid=u'A132ZLX99BM5LB', iid=u'B006OOHVVC', r_ui=5.0, est=4.2478281589287015, details={u'was_impossible': False}),
#  Prediction(uid=u'A13EEI6YVFIUC5', iid=u'B00683JK9K', r_ui=4.0, est=3.4545389208511357, details={u'was_impossible': False}),
#  Prediction(uid=u'A12G5YEBGTJQPT', iid=u'B00B2W289G', r_ui=5.0, est=4.480738609086859, details={u'was_impossible': False}),
#  Prediction(uid=u'A1399H2GOYRYZA', iid=u'B00HCMG6LG', r_ui=5.0, est=4.679851589979537, details={u'was_impossible': False}),
#  Prediction(uid=u'A13US97ZVP6NQK', iid=u'B005LIYX5Y', r_ui=5.0, est=3.7126015702871045, details={u'was_impossible': False}),
#  Prediction(uid=u'A13F4W9JSPB7D', iid=u'B0050KDTSK', r_ui=5.0, est=3.564548026034247, details={u'was_impossible': False}),
#  Prediction(uid=u'A13GODQ53SMDCE', iid=u'B00BS3UFCQ', r_ui=4.0, est=4.630851444382055, details={u'was_impossible': False}),
#  Prediction(uid=u'A11RRV8HHLE2CA', iid=u'B00529IOXO', r_ui=4.0, est=3.4054790840732174, details={u'was_impossible': False}),
#  Prediction(uid=u'A10F3OX0ANZG2B', iid=u'B005KC664W', r_ui=5.0, est=4.108859654187091, details={u'was_impossible': False}),
#  Prediction(uid=u'A12LCVWV1SPSUV', iid=u'B00E5NH6YG', r_ui=5.0, est=3.954563019183893, details={u'was_impossible': False}),
#  Prediction(uid=u'A13DCD9PB6KAL4', iid=u'B00BMH4GQE', r_ui=4.0, est=4.121773707697119, details={u'was_impossible': False}),
#  Prediction(uid=u'A11SXWJ5NHPDT8', iid=u'B007P8BMTS', r_ui=5.0, est=3.407819375015526, details={u'was_impossible': False}),
#  Prediction(uid=u'A128YLFOZY23A0', iid=u'B0087SGWI6', r_ui=3.0, est=3.9551523277762204, details={u'was_impossible': False}),
#  Prediction(uid=u'A133Q8F14W1EP0', iid=u'B00846GKTW', r_ui=5.0, est=4.526847933153658, details={u'was_impossible': False}),
#  Prediction(uid=u'A10IOE89402WYK', iid=u'B007XJ3D82', r_ui=4.0, est=3.636514060514878, details={u'was_impossible': False}),
#  Prediction(uid=u'A10LBT4V6Z635U', iid=u'B00B4VI8MQ', r_ui=4.0, est=4.096079528047583, details={u'was_impossible': False}),
#  Prediction(uid=u'A115ERDOOK4J21', iid=u'B005CRCP36', r_ui=4.0, est=4.354221805539644, details={u'was_impossible': False}),
#  Prediction(uid=u'A121523X20MPDQ', iid=u'B009LFGG76', r_ui=4.0, est=4.044969978538614, details={u'was_impossible': False}),
#  Prediction(uid=u'A10FHEBZMXRT3R', iid=u'B004SBS8LA', r_ui=1.0, est=3.9812775565967824, details={u'was_impossible': False}),
#  Prediction(uid=u'A120HPZ0AW090S', iid=u'B0084DYNGC', r_ui=4.0, est=4.508150360913837, details={u'was_impossible': False}),
#  Prediction(uid=u'A134IQH0P819OA', iid=u'B009ZZDNT6', r_ui=5.0, est=4.264576910008702, details={u'was_impossible': False}),
#  Prediction(uid=u'A10M30ZEKY25VZ', iid=u'B004UBB1HQ', r_ui=5.0, est=4.455321954962223, details={u'was_impossible': False}),
#  Prediction(uid=u'A11J6YLV9ZLLZ5', iid=u'B005T87QCI', r_ui=5.0, est=4.144549545993911, details={u'was_impossible': False}),
#  Prediction(uid=u'A1076XRX563PLK', iid=u'B007KPOZK4', r_ui=5.0, est=4.379043605282189, details={u'was_impossible': False}),
#  Prediction(uid=u'A13UQNMCNE8LPG', iid=u'B004SJ3AXI', r_ui=3.0, est=4.570392722236614, details={u'was_impossible': False}),
#  Prediction(uid=u'A133FXP14UQSZW', iid=u'B00G4FAU14', r_ui=4.0, est=3.5578692061436366, details={u'was_impossible': False}),
#  Prediction(uid=u'A11NVWRXYJDEAO', iid=u'B00BG3ID0Y', r_ui=5.0, est=4.1386692522476025, details={u'was_impossible': False}),
#  Prediction(uid=u'A05314842GO6XH1MTNJDE', iid=u'B005HSL626', r_ui=4.0, est=4.018550199821229, details={u'was_impossible': False}),
#  Prediction(uid=u'A11A2ZK0UZ9YGQ', iid=u'B00AEJM6H2', r_ui=4.0, est=4.659486454565011, details={u'was_impossible': False}),
#  Prediction(uid=u'A13IIINDDABACO', iid=u'B00C7TAF3Y', r_ui=5.0, est=4.76625813528806, details={u'was_impossible': False}),
#  Prediction(uid=u'A10RN92S0XE4G5', iid=u'B004SJ3BCI', r_ui=5.0, est=4.476661882586232, details={u'was_impossible': False}),
#  Prediction(uid=u'A13QL2WC93Y4XW', iid=u'B0054JZC6E', r_ui=5.0, est=4.009907057218203, details={u'was_impossible': False}),
#  Prediction(uid=u'A12LP0CSD02SLM', iid=u'B004K4RY9M', r_ui=5.0, est=4.27622258958552, details={u'was_impossible': False}),
#  Prediction(uid=u'A12WTZIZ4EHCT1', iid=u'B0063GSL60', r_ui=5.0, est=4.325673617276528, details={u'was_impossible': False}),
#  Prediction(uid=u'A119D5ZWTNOVNJ', iid=u'B00GWJQVVA', r_ui=4.0, est=3.4848086294890956, details={u'was_impossible': False}),
#  Prediction(uid=u'A106VUWWBWE0WW', iid=u'B00C2YR3XE', r_ui=5.0, est=4.158196482653479, details={u'was_impossible': False}),
#  Prediction(uid=u'A13NUF7TMAZ1OH', iid=u'B0087HT36U', r_ui=3.0, est=3.709357243934822, details={u'was_impossible': False}),
#  Prediction(uid=u'A12HCPXHTX8QJ0', iid=u'B00BMR4RIG', r_ui=5.0, est=3.979137699855602, details={u'was_impossible': False}),
#  Prediction(uid=u'A112NDN7HZ46ON', iid=u'B00820STKI', r_ui=5.0, est=3.9186300679022583, details={u'was_impossible': False}),
#  Prediction(uid=u'A13KEEVJQ0GW0Z', iid=u'B00DZJ4O2S', r_ui=4.0, est=4.043958696721381, details={u'was_impossible': False}),
#  Prediction(uid=u'A11CF1V823RNGT', iid=u'B00DLJ31HQ', r_ui=5.0, est=4.453670495382737, details={u'was_impossible': False}),
#  Prediction(uid=u'A12EAUQGKGUMMO', iid=u'B004DPCSKI', r_ui=4.0, est=4.20265338619987, details={u'was_impossible': False}),
#  Prediction(uid=u'A122WLDCSMD757', iid=u'B0073U6WLG', r_ui=5.0, est=4.348914053428662, details={u'was_impossible': False}),
#  Prediction(uid=u'A1357F4E3JL6IR', iid=u'B00IKZX1ZI', r_ui=5.0, est=3.9983814711170176, details={u'was_impossible': False}),
#  Prediction(uid=u'A13FDSQXCRY4TD', iid=u'B007ZGO7EM', r_ui=4.0, est=4.5078135743415, details={u'was_impossible': False}),
#  Prediction(uid=u'A11XK7OX2IRSRL', iid=u'B00GWJQVVA', r_ui=5.0, est=4.184775434022524, details={u'was_impossible': False}),
#  Prediction(uid=u'A08880513V0KPDJZRHPVG', iid=u'B0066T0BTO', r_ui=5.0, est=4.3617138813520695, details={u'was_impossible': False}),
#  Prediction(uid=u'A1264AH5VE0ZGK', iid=u'B008OD6QYE', r_ui=5.0, est=4.469373062144526, details={u'was_impossible': False}),
#  Prediction(uid=u'A110346KD4UYN3', iid=u'B00529IOXO', r_ui=3.0, est=3.702120346947135, details={u'was_impossible': False}),
#  Prediction(uid=u'A12F1W1RC78NMN', iid=u'B00GY0HJ4K', r_ui=5.0, est=3.8893704975399013, details={u'was_impossible': False}),
#  Prediction(uid=u'A12EUQ6F7ZCJKH', iid=u'B004YWUV40', r_ui=4.0, est=4.203405755033953, details={u'was_impossible': False}),
#  Prediction(uid=u'A102KXC7ZQRJOO', iid=u'B009ZXT4BY', r_ui=3.0, est=3.7426878525269456, details={u'was_impossible': False}),
#  Prediction(uid=u'A1008B8GB8LA4L', iid=u'B00GP0G0IK', r_ui=5.0, est=4.076483157235162, details={u'was_impossible': False}),
#  Prediction(uid=u'A10VPXCQL92K1H', iid=u'B00HHBXYGM', r_ui=4.0, est=4.766847975997058, details={u'was_impossible': False}),
#  Prediction(uid=u'A10LUEAKM7F8W8', iid=u'B008DYK0I2', r_ui=1.0, est=3.970573776992304, details={u'was_impossible': False}),
#  Prediction(uid=u'A0855975204O8N178RKHV', iid=u'B0091SUMB4', r_ui=5.0, est=4.183166253907988, details={u'was_impossible': False}),
#  Prediction(uid=u'A13QT30V8PGKIY', iid=u'B00A8ECU24', r_ui=5.0, est=4.23430279682176, details={u'was_impossible': False}),
#  Prediction(uid=u'A12HHM3OU8TM6O', iid=u'B00E3CFTJS', r_ui=1.0, est=3.748517701553471, details={u'was_impossible': False}),
#  Prediction(uid=u'A05645781CK8V6Y1DOBE6', iid=u'B0098LBZPG', r_ui=5.0, est=3.8837130617204005, details={u'was_impossible': False}),
#  Prediction(uid=u'A1130CW6H5VK6W', iid=u'B00BM8UNUQ', r_ui=3.0, est=4.209503638302347, details={u'was_impossible': False}),
#  Prediction(uid=u'A1321DW782UQUZ', iid=u'B00AMRIZYY', r_ui=3.0, est=4.322566812972736, details={u'was_impossible': False}),
#  Prediction(uid=u'A12RYTFXE7BN1F', iid=u'B004S33RRI', r_ui=5.0, est=4.649730248935913, details={u'was_impossible': False}),
#  Prediction(uid=u'A129EF96JZGSL9', iid=u'B00D0VZLVE', r_ui=5.0, est=4.466891647888868, details={u'was_impossible': False}),
#  Prediction(uid=u'A127HMP5FOQYKC', iid=u'B00GSZEBE2', r_ui=4.0, est=3.634448043515511, details={u'was_impossible': False}),
#  Prediction(uid=u'A12H6LZYN1I2L3', iid=u'B0066T8M1I', r_ui=5.0, est=4.227997561236715, details={u'was_impossible': False}),
#  Prediction(uid=u'A10QQD7C9FMFZE', iid=u'B00E8KLWB4', r_ui=5.0, est=3.9942022531678676, details={u'was_impossible': False}),
#  Prediction(uid=u'A11SASQEC9O530', iid=u'B007CMROQW', r_ui=5.0, est=4.542913772952847, details={u'was_impossible': False}),
#  Prediction(uid=u'A11J6YLV9ZLLZ5', iid=u'B00A4KVFLY', r_ui=5.0, est=4.220011789588025, details={u'was_impossible': False}),
#  Prediction(uid=u'A0736509RC89JSLU0ST6', iid=u'B00D0VZLVE', r_ui=5.0, est=4.581818592527551, details={u'was_impossible': False}),
#  Prediction(uid=u'A10DZV0FS8ECPR', iid=u'B00BR5759Q', r_ui=5.0, est=4.1186138326852255, details={u'was_impossible': False}),
#  Prediction(uid=u'A10DOAZZKF2O5Q', iid=u'B00A1SL8SE', r_ui=5.0, est=4.078635226593923, details={u'was_impossible': False}),
#  Prediction(uid=u'A11KZ906QD08C5', iid=u'B0066W1AZK', r_ui=4.0, est=3.6157910572855463, details={u'was_impossible': False}),
#  Prediction(uid=u'A12B93UMS3UB7K', iid=u'B005UQ9FNC', r_ui=5.0, est=4.481584623098026, details={u'was_impossible': False}),
#  Prediction(uid=u'A115UTR7S7PN57', iid=u'B006R8GK2Q', r_ui=4.0, est=4.352222344620707, details={u'was_impossible': False}),
#  Prediction(uid=u'A13J3QZ4D3DSN1', iid=u'B00EBQRSTK', r_ui=4.0, est=4.308044311767311, details={u'was_impossible': False}),
#  Prediction(uid=u'A12A3LXUZKQO5F', iid=u'B0094J0J18', r_ui=4.0, est=4.4418959231901605, details={u'was_impossible': False}),
#  Prediction(uid=u'A12B7ZMXFI6IXY', iid=u'B0073LWEXK', r_ui=5.0, est=3.954310482412776, details={u'was_impossible': False}),
#  Prediction(uid=u'A10SFZKHMDN9SS', iid=u'B00A3NQNUU', r_ui=1.0, est=4.549049616234356, details={u'was_impossible': False}),
#  Prediction(uid=u'A104RLAA2X4C92', iid=u'B004H6WTJI', r_ui=4.0, est=4.23896924930148, details={u'was_impossible': False}),
#  Prediction(uid=u'A11CW1GHKVD425', iid=u'B008FRG6JO', r_ui=4.0, est=3.9966371831768064, details={u'was_impossible': False}),
#  Prediction(uid=u'A132SQUJZX4H17', iid=u'B004TBM4VY', r_ui=5.0, est=4.488568044311335, details={u'was_impossible': False}),
#  Prediction(uid=u'A11UTRXMAEUDE', iid=u'B0058VW36U', r_ui=5.0, est=4.4845903021686455, details={u'was_impossible': False}),
#  Prediction(uid=u'A128I65K3W9P4E', iid=u'B00ATDOVNK', r_ui=5.0, est=4.358798493361545, details={u'was_impossible': False}),
#  Prediction(uid=u'A11LJ8QVMZP3C6', iid=u'B0076POKVC', r_ui=5.0, est=4.031250518091576, details={u'was_impossible': False}),
#  Prediction(uid=u'A11LGCY3GBVFJ8', iid=u'B00824BM76', r_ui=1.0, est=3.264259440673438, details={u'was_impossible': False}),
#  Prediction(uid=u'A1053REE2BCFXA', iid=u'B008841TP0', r_ui=5.0, est=3.782691518176059, details={u'was_impossible': False}),
#  Prediction(uid=u'A1179Y4O5W62WS', iid=u'B006KX3GXO', r_ui=3.0, est=3.9144590583126098, details={u'was_impossible': False}),
#  Prediction(uid=u'A11KGDQSEHWF52', iid=u'B005UQ9FNC', r_ui=5.0, est=4.75982529588869, details={u'was_impossible': False}),
#  Prediction(uid=u'A12QOGEGR7HRXE', iid=u'B00DUVQIIY', r_ui=5.0, est=3.558988197148167, details={u'was_impossible': False}),
#  Prediction(uid=u'A11PR2XJYRSOTZ', iid=u'B00659XNK4', r_ui=4.0, est=4.095551900708943, details={u'was_impossible': False}),
#  Prediction(uid=u'A10XSMW89AX9Y6', iid=u'B00DRA55DW', r_ui=5.0, est=4.173839979398416, details={u'was_impossible': False}),
#  Prediction(uid=u'A12RM5W1M4U0O4', iid=u'B007KPOZK4', r_ui=5.0, est=4.479481072300985, details={u'was_impossible': False}),
#  Prediction(uid=u'A11HUUZYFYOFAC', iid=u'B00B7PKAKC', r_ui=5.0, est=4.453326920022883, details={u'was_impossible': False}),
#  Prediction(uid=u'A108B7QO1C39JE', iid=u'B00HDRTGDK', r_ui=4.0, est=4.341925686694802, details={u'was_impossible': False}),
#  Prediction(uid=u'A13KNU0BVC4I2', iid=u'B004SJ3BCI', r_ui=5.0, est=4.171806572348293, details={u'was_impossible': False}),
#  Prediction(uid=u'A10QSQ2SISM67Z', iid=u'B007A2IOOU', r_ui=5.0, est=4.001775443476564, details={u'was_impossible': False}),
#  Prediction(uid=u'A128ZO4NM9TDN4', iid=u'B0051UP5NQ', r_ui=4.0, est=3.8044579162881744, details={u'was_impossible': False}),
#  Prediction(uid=u'A133SWO36EHQIB', iid=u'B00I8Q77Y0', r_ui=5.0, est=4.660123021996289, details={u'was_impossible': False}),
#  Prediction(uid=u'A11RWP436Q0V8J', iid=u'B008D2QRAO', r_ui=4.0, est=4.233411005260634, details={u'was_impossible': False}),
#  Prediction(uid=u'A05314842GO6XH1MTNJDE', iid=u'B0097EWK3A', r_ui=4.0, est=4.551036089815211, details={u'was_impossible': False}),
#  Prediction(uid=u'A007209714VJJNG4NW2QV', iid=u'B009KS4XRO', r_ui=4.0, est=3.9024276134284497, details={u'was_impossible': False}),
#  Prediction(uid=u'A115PPUEZ1654', iid=u'B008JGSM6G', r_ui=5.0, est=4.64160730195417, details={u'was_impossible': False}),
#  Prediction(uid=u'A13FA7RMEGBU65', iid=u'B00D74DVKM', r_ui=4.0, est=3.9340623086415087, details={u'was_impossible': False}),
#  Prediction(uid=u'A10938QNO7IYIB', iid=u'B004JZBGWI', r_ui=3.0, est=3.6572818588230107, details={u'was_impossible': False}),
#  Prediction(uid=u'A131YP1PH1FN14', iid=u'B00COVCV50', r_ui=4.0, est=4.624984182789211, details={u'was_impossible': False}),
#  Prediction(uid=u'A11TMZXPAI4G6O', iid=u'B00B2WWEFE', r_ui=5.0, est=3.832059919171641, details={u'was_impossible': False}),
#  Prediction(uid=u'A10REDSTXMOEKV', iid=u'B00CX713IG', r_ui=5.0, est=4.727429507518335, details={u'was_impossible': False}),
#  Prediction(uid=u'A12E3KAR41GDYA', iid=u'B00GXH3TGG', r_ui=5.0, est=4.356636754954252, details={u'was_impossible': False}),
#  Prediction(uid=u'A10FEJNBVLJTLM', iid=u'B00D9CNAOY', r_ui=1.0, est=3.506160164644003, details={u'was_impossible': False}),
#  Prediction(uid=u'A12YV5AWK7TKSS', iid=u'B00BS3UFCQ', r_ui=4.0, est=4.434632397719302, details={u'was_impossible': False}),
#  Prediction(uid=u'A11MKIKOOXUQK0', iid=u'B00AFCEIB0', r_ui=5.0, est=4.036863078600839, details={u'was_impossible': False}),
#  Prediction(uid=u'A11JYYUEGTFIRB', iid=u'B00IS87HYI', r_ui=3.0, est=3.6912376015202297, details={u'was_impossible': False}),
#  Prediction(uid=u'A11TF9114FSRC9', iid=u'B00BP29SAA', r_ui=5.0, est=4.0717891292703605, details={u'was_impossible': False}),
#  Prediction(uid=u'A12WDFOCQ0RT2T', iid=u'B006VXRNYG', r_ui=4.0, est=4.596665047499206, details={u'was_impossible': False}),
#  Prediction(uid=u'A138Z79GXVI1UW', iid=u'B008D2QRAO', r_ui=5.0, est=4.3162815347307575, details={u'was_impossible': False}),
#  Prediction(uid=u'A13UYQ2NFUPM7C', iid=u'B00EUCL6R0', r_ui=4.0, est=4.209149023063172, details={u'was_impossible': False}),
#  Prediction(uid=u'A117SBSBK8BESS', iid=u'B0093BM38O', r_ui=5.0, est=3.8924713782840876, details={u'was_impossible': False}),
#  Prediction(uid=u'A12SGSFD0IC1', iid=u'B004IAMM5O', r_ui=1.0, est=4.003664035996806, details={u'was_impossible': False}),
#  Prediction(uid=u'A11OP1TI0C6C76', iid=u'B004MC8CA2', r_ui=5.0, est=4.716155344326727, details={u'was_impossible': False}),
#  Prediction(uid=u'A12O1IA0C63WD', iid=u'B0097EWK3A', r_ui=5.0, est=4.285162053554038, details={u'was_impossible': False}),
#  Prediction(uid=u'A11YWHSBY47E3I', iid=u'B004QEC2EI', r_ui=5.0, est=3.952791735202098, details={u'was_impossible': False}),
#  Prediction(uid=u'A104RBWVISRIUF', iid=u'B00A4EZ3QS', r_ui=4.0, est=3.386209240060277, details={u'was_impossible': False}),
#  Prediction(uid=u'A10QM1Y3N2ND5K', iid=u'B00AR83PN4', r_ui=2.0, est=3.5149870662755953, details={u'was_impossible': False}),
#  Prediction(uid=u'A118F9CHIYAK7C', iid=u'B008XG1X18', r_ui=4.0, est=4.594185672635536, details={u'was_impossible': False}),
#  Prediction(uid=u'A112PSQ044PDF9', iid=u'B006IY163C', r_ui=1.0, est=2.638938692413384, details={u'was_impossible': False}),
#  Prediction(uid=u'A12RS3RNJNO2J4', iid=u'B00FX6ZBXC', r_ui=5.0, est=4.459855626215882, details={u'was_impossible': False}),
#  Prediction(uid=u'A11U6DLLA5JRXB', iid=u'B00ATPVA78', r_ui=5.0, est=4.341474254076623, details={u'was_impossible': False}),
#  Prediction(uid=u'A10F2EQWPB165', iid=u'B00BS3UFCQ', r_ui=5.0, est=4.610944373276334, details={u'was_impossible': False}),
#  Prediction(uid=u'A12XZMO4VY8LUE', iid=u'B0074AKEDC', r_ui=5.0, est=3.70687015234854, details={u'was_impossible': False}),
#  Prediction(uid=u'A12EJQH0DWFLX5', iid=u'B00GRVV29E', r_ui=5.0, est=4.313050581649546, details={u'was_impossible': False}),
#  Prediction(uid=u'A12AGGCDUH7JTN', iid=u'B00CTXY8RC', r_ui=3.0, est=4.09871296175714, details={u'was_impossible': False}),
#  Prediction(uid=u'A125E6B8JEABZ6', iid=u'B00INJ2P0S', r_ui=2.0, est=3.88814804919159, details={u'was_impossible': False}),
#  Prediction(uid=u'A11RMC4DI2LAGD', iid=u'B00GCT92CU', r_ui=4.0, est=4.151598660229903, details={u'was_impossible': False}),
#  Prediction(uid=u'A12DUO6XWS7JY', iid=u'B005FM77HW', r_ui=5.0, est=3.800046289138443, details={u'was_impossible': False}),
#  Prediction(uid=u'A13PBY4TA888YJ', iid=u'B009UX2YAC', r_ui=5.0, est=4.755674448386633, details={u'was_impossible': False}),
#  Prediction(uid=u'A127GFDWCYHZGX', iid=u'B0095FNJKO', r_ui=4.0, est=4.127317416214834, details={u'was_impossible': False}),
#  Prediction(uid=u'A112DRL7TW7YTH', iid=u'B006OCM0G0', r_ui=5.0, est=4.226539883422116, details={u'was_impossible': False}),
#  Prediction(uid=u'A11F6IL8DHOFEZ', iid=u'B00910Y1OQ', r_ui=4.0, est=4.378390932722844, details={u'was_impossible': False}),
#  Prediction(uid=u'A10OEBNZKX48KU', iid=u'B00AUB8GA0', r_ui=5.0, est=4.015952402192148, details={u'was_impossible': False}),
#  Prediction(uid=u'A103T4L14A5O42', iid=u'B004KAL2BC', r_ui=4.0, est=4.169411697106593, details={u'was_impossible': False}),
#  Prediction(uid=u'A12K45Q5YUNFKS', iid=u'B007OXASB2', r_ui=1.0, est=4.152846733394317, details={u'was_impossible': False}),
#  Prediction(uid=u'A13SHHYY8GGGGJ', iid=u'B00CMMR9SU', r_ui=2.0, est=4.323205508952781, details={u'was_impossible': False}),
#  Prediction(uid=u'A12B7ZMXFI6IXY', iid=u'B00AE9UYJ4', r_ui=4.0, est=4.235317770568512, details={u'was_impossible': False}),
#  Prediction(uid=u'A10D3QXJUWMIRJ', iid=u'B0067Q42BY', r_ui=5.0, est=3.46602908380643, details={u'was_impossible': False}),
#  Prediction(uid=u'A10VKCEXFKG5BW', iid=u'B006QZM73Q', r_ui=5.0, est=3.544749031727637, details={u'was_impossible': False}),
#  Prediction(uid=u'A134YH9UFZBPA2', iid=u'B00BXTTRO2', r_ui=4.0, est=3.521625522510878, details={u'was_impossible': False}),
#  Prediction(uid=u'A10096011L0LW5NMIFP6A', iid=u'B0073LHCCS', r_ui=5.0, est=4.220916798550707, details={u'was_impossible': False}),
#  Prediction(uid=u'A12RM5W1M4U0O4', iid=u'B00846GKTW', r_ui=5.0, est=4.523447654939197, details={u'was_impossible': False}),
#  Prediction(uid=u'A13DFBHBNYV5BA', iid=u'B00I8Q77Y0', r_ui=4.0, est=4.5637812458852975, details={u'was_impossible': False}),
#  Prediction(uid=u'A11TF6J0JHZ7YY', iid=u'B00AIQP9DE', r_ui=5.0, est=4.46255457209072, details={u'was_impossible': False}),
#  Prediction(uid=u'A13UWUPZQC5XVA', iid=u'B00FEMJF6O', r_ui=5.0, est=4.478320055944091, details={u'was_impossible': False}),
#  Prediction(uid=u'A10T8XGBYU7886', iid=u'B00GOZQ2E8', r_ui=5.0, est=4.30440493227178, details={u'was_impossible': False}),
#  Prediction(uid=u'A12UY65D3STDLB', iid=u'B0091REZMW', r_ui=3.0, est=3.906989649137088, details={u'was_impossible': False}),
#  Prediction(uid=u'A11BMPF18Z3JR6', iid=u'B007JPG04E', r_ui=5.0, est=4.575027921026669, details={u'was_impossible': False}),
#  Prediction(uid=u'A117RBVCW03LP0', iid=u'B00A9NXGAO', r_ui=4.0, est=4.558108717591932, details={u'was_impossible': False}),
#  Prediction(uid=u'A11AJWMFS4ZY3S', iid=u'B004VCZW60', r_ui=4.0, est=4.34297173176772, details={u'was_impossible': False}),
#  Prediction(uid=u'A10UVHE753SVH9', iid=u'B008XG1X18', r_ui=5.0, est=4.642431098789724, details={u'was_impossible': False}),
#  Prediction(uid=u'A12IVB87XJ30Y9', iid=u'B007VT07QU', r_ui=5.0, est=4.220135470745133, details={u'was_impossible': False}),
#  Prediction(uid=u'A12YV2K2A2Y1FY', iid=u'B007TBAQCK', r_ui=4.0, est=4.326603402292742, details={u'was_impossible': False}),
#  Prediction(uid=u'A134YX9UJAM20L', iid=u'B00E3BK0QQ', r_ui=5.0, est=4.389792542797387, details={u'was_impossible': False}),
#  Prediction(uid=u'A12LFNZ9RGWJZ4', iid=u'B00ED4TX2A', r_ui=4.0, est=4.070567224586435, details={u'was_impossible': False}),
#  Prediction(uid=u'A13IIP6HTFNCVT', iid=u'B007EC27QM', r_ui=4.0, est=3.9992010455342406, details={u'was_impossible': False}),
#  Prediction(uid=u'A130VLKB0O95WZ', iid=u'B006OCM13M', r_ui=5.0, est=3.2450705911891444, details={u'was_impossible': False}),
#  Prediction(uid=u'A118ZQMQRL30J4', iid=u'B009XAJI8S', r_ui=1.0, est=3.9361373294434285, details={u'was_impossible': False}),
#  Prediction(uid=u'A12B7IGY17BT73', iid=u'B00JQ8TQ1G', r_ui=5.0, est=4.353626584985954, details={u'was_impossible': False}),
#  Prediction(uid=u'A11ZBZVWFNHRT', iid=u'B006C4U9RW', r_ui=5.0, est=4.334503827251255, details={u'was_impossible': False}),
#  Prediction(uid=u'A13UN1F6F8JZ39', iid=u'B00AHUEUGS', r_ui=1.0, est=4.049450621383776, details={u'was_impossible': False}),
#  Prediction(uid=u'A10HURT1B9FM44', iid=u'B00D3MWW44', r_ui=5.0, est=4.87438203798114, details={u'was_impossible': False}),
#  Prediction(uid=u'A07343812QLONJZ8QB5N7', iid=u'B00A3HQX2Y', r_ui=5.0, est=4.337379615837899, details={u'was_impossible': False}),
#  Prediction(uid=u'A098370928I0YSRRQV0YI', iid=u'B0069G5Z9K', r_ui=1.0, est=4.511465817687845, details={u'was_impossible': False}),
#  Prediction(uid=u'A12RNPBA6RHPIG', iid=u'B008K6HN8I', r_ui=1.0, est=3.92401531296306, details={u'was_impossible': False}),
#  Prediction(uid=u'A1156XD0VU0A6H', iid=u'B009KS4XRO', r_ui=4.0, est=3.9430068403190184, details={u'was_impossible': False}),
#  Prediction(uid=u'A12MX9I47SO4BD', iid=u'B008IXP8IU', r_ui=5.0, est=4.4793530063393785, details={u'was_impossible': False}),
#  Prediction(uid=u'A12NZH66UYUNFP', iid=u'B00CJ95O2E', r_ui=4.0, est=4.0591777937200195, details={u'was_impossible': False}),
#  Prediction(uid=u'A10E6T1WNNVNWK', iid=u'B00EDEMLTW', r_ui=4.0, est=3.7366985852961125, details={u'was_impossible': False}),
#  Prediction(uid=u'A11D9WMYB2BRKU', iid=u'B00FS0VUWO', r_ui=5.0, est=3.4260259777217774, details={u'was_impossible': False}),
#  Prediction(uid=u'A10PTYA24QOBS7', iid=u'B00B4VI8MQ', r_ui=3.0, est=4.075301733996088, details={u'was_impossible': False}),
#  Prediction(uid=u'A12BB5IBP4937A', iid=u'B00785P2QC', r_ui=5.0, est=4.050613252417671, details={u'was_impossible': False}),
#  Prediction(uid=u'A12XAOIJGUKMF7', iid=u'B00E4PSG7G', r_ui=5.0, est=4.078979609636342, details={u'was_impossible': False}),
#  Prediction(uid=u'A1059SXDMUSBID', iid=u'B00CBJRTPC', r_ui=5.0, est=4.304091097580617, details={u'was_impossible': False}),
#  Prediction(uid=u'A13OOEGETGESYE', iid=u'B009ZKSPDK', r_ui=5.0, est=4.471210820340651, details={u'was_impossible': False}),
#  Prediction(uid=u'A11KWTZ5Y9WPAJ', iid=u'B006D1ONE4', r_ui=5.0, est=4.29879374116346, details={u'was_impossible': False}),
#  Prediction(uid=u'A12NVXTNPJR5AR', iid=u'B007TBAQCK', r_ui=5.0, est=3.6765208294453764, details={u'was_impossible': False}),
#  Prediction(uid=u'A1245WU35KVV2', iid=u'B008AZGWYK', r_ui=4.0, est=3.8683945467433456, details={u'was_impossible': False}),
#  Prediction(uid=u'A04023062NO3NP4XHY776', iid=u'B009WO7NQO', r_ui=5.0, est=4.425332417712782, details={u'was_impossible': False}),
#  Prediction(uid=u'A10WWXMSMNX1DR', iid=u'B00EBFKPAA', r_ui=5.0, est=4.039299066674092, details={u'was_impossible': False}),
#  Prediction(uid=u'A130CC6V8LB7GY', iid=u'B00EBQRSTK', r_ui=5.0, est=4.470489192147718, details={u'was_impossible': False}),
#  Prediction(uid=u'A12MIHSH7XDY7S', iid=u'B004FOA84A', r_ui=5.0, est=4.3299781035283145, details={u'was_impossible': False}),
#  Prediction(uid=u'A135ROW4PMH2H3', iid=u'B009LQ8X58', r_ui=5.0, est=4.373615090220938, details={u'was_impossible': False}),
#  Prediction(uid=u'A13B85HRYERCJM', iid=u'B0054JZC6E', r_ui=4.0, est=4.25059072625474, details={u'was_impossible': False}),
#  Prediction(uid=u'A11MPHKMO4RNA0', iid=u'B006R8GK2Q', r_ui=4.0, est=4.229451828739015, details={u'was_impossible': False}),
#  Prediction(uid=u'A12EJQH0DWFLX5', iid=u'B00BX42FLY', r_ui=4.0, est=4.067517733225539, details={u'was_impossible': False}),
#  Prediction(uid=u'A10GLBE652T2FT', iid=u'B00A8SPNYW', r_ui=4.0, est=3.4204791723500616, details={u'was_impossible': False}),
#  Prediction(uid=u'A11UI2KDVARMSM', iid=u'B005AKD836', r_ui=5.0, est=3.99328115757485, details={u'was_impossible': False}),
#  Prediction(uid=u'A114W37M2SD49M', iid=u'B00BPC23XO', r_ui=4.0, est=4.443569459221203, details={u'was_impossible': False}),
#  Prediction(uid=u'A11GVGGQFZDUKC', iid=u'B00JRSXIZ0', r_ui=2.0, est=4.167498578041594, details={u'was_impossible': False}),
#  Prediction(uid=u'A128PPCXUGVHJ4', iid=u'B006OBWGHO', r_ui=2.0, est=4.040041311369198, details={u'was_impossible': False}),
#  Prediction(uid=u'A10G5PUD1SL5OH', iid=u'B004QJGPNM', r_ui=5.0, est=3.7228689078929773, details={u'was_impossible': False}),
#  Prediction(uid=u'A13GJQJUHXOZF1', iid=u'B0060FHM3C', r_ui=5.0, est=4.260792223382656, details={u'was_impossible': False}),
#  Prediction(uid=u'A10VX1PY3TROIM', iid=u'B005EYWT38', r_ui=5.0, est=4.206775950966047, details={u'was_impossible': False}),
#  Prediction(uid=u'A11Y8IQNVONVK5', iid=u'B00C7TAF3Y', r_ui=5.0, est=4.840492559297783, details={u'was_impossible': False}),
#  Prediction(uid=u'A13C6NTJ3HO0FX', iid=u'B00E4PSG7G', r_ui=3.0, est=4.248829932807875, details={u'was_impossible': False}),
#  Prediction(uid=u'A12EZ42BB09D5R', iid=u'B004T2QZL8', r_ui=5.0, est=3.994850733796681, details={u'was_impossible': False}),
#  Prediction(uid=u'A1090T7CEVPXES', iid=u'B009HHX414', r_ui=1.0, est=3.4139877746290903, details={u'was_impossible': False}),
#  Prediction(uid=u'A094182421MQPOGPC3LC1', iid=u'B00EOUGFNS', r_ui=5.0, est=4.016482605911633, details={u'was_impossible': False}),
#  Prediction(uid=u'A11FYK1Q9YI31N', iid=u'B00FB13Y74', r_ui=5.0, est=3.5449164172218564, details={u'was_impossible': False}),
#  Prediction(uid=u'A10WLJ0MJ9Q7LX', iid=u'B00B4VI8MQ', r_ui=3.0, est=4.267725927457768, details={u'was_impossible': False}),
#  Prediction(uid=u'A13CTCYGTQHBUT', iid=u'B00EHKJ60E', r_ui=4.0, est=3.7751381560063413, details={u'was_impossible': False}),
#  Prediction(uid=u'A10DWTBXCHNF51', iid=u'B004SJ3BCI', r_ui=5.0, est=4.235600471765741, details={u'was_impossible': False}),
#  Prediction(uid=u'A11FOXF953S37P', iid=u'B00998UF9U', r_ui=2.0, est=3.8927512375124858, details={u'was_impossible': False}),
#  Prediction(uid=u'A12G5HFO74HTHF', iid=u'B0086700CM', r_ui=5.0, est=5, details={u'was_impossible': False}),
#  Prediction(uid=u'A10EOCQIYSMI6Y', iid=u'B008BJQCCM', r_ui=5.0, est=4.2247972247695795, details={u'was_impossible': False}),
#  Prediction(uid=u'A12NIMGZ4LWUU8', iid=u'B009EEFTMC', r_ui=3.0, est=3.3933111151686886, details={u'was_impossible': False}),
#  Prediction(uid=u'A12906AFDCR5BP', iid=u'B00FGFVMGA', r_ui=5.0, est=4.290583506806407, details={u'was_impossible': False}),
#  Prediction(uid=u'A12ISN624IFGU4', iid=u'B007NACZPI', r_ui=5.0, est=3.9598325390171474, details={u'was_impossible': False}),
#  Prediction(uid=u'A1385EU8VXNY92', iid=u'B004R13U6Y', r_ui=5.0, est=4.4150084956098965, details={u'was_impossible': False}),
#  Prediction(uid=u'A10PTYA24QOBS7', iid=u'B00785P2QC', r_ui=5.0, est=4.060517084631815, details={u'was_impossible': False}),
#  Prediction(uid=u'A12GBGF9ILMP2Z', iid=u'B008GXHOFW', r_ui=4.0, est=3.41236565816151, details={u'was_impossible': False}),
#  Prediction(uid=u'A12UTTE80IPQB2', iid=u'B008JGSM6G', r_ui=5.0, est=4.320770040139722, details={u'was_impossible': False}),
#  Prediction(uid=u'A12XJB1UHAENEK', iid=u'B004HGK6FW', r_ui=5.0, est=4.405260708609109, details={u'was_impossible': False}),
#  Prediction(uid=u'A12SJLFUF6SQUH', iid=u'B00A4KVFLY', r_ui=4.0, est=3.882164750728541, details={u'was_impossible': False}),
#  Prediction(uid=u'A11FOKDWHJ38NN', iid=u'B004GISARW', r_ui=5.0, est=4.170169683174537, details={u'was_impossible': False}),
#  Prediction(uid=u'A138ND2OX3HF24', iid=u'B00H343YNQ', r_ui=5.0, est=4.492428513926972, details={u'was_impossible': False}),
#  Prediction(uid=u'A1294DUM5G775U', iid=u'B00APKDEH6', r_ui=5.0, est=4.143319700397538, details={u'was_impossible': False}),
#  Prediction(uid=u'A12YS2AV8SH2I2', iid=u'B007SYWFRM', r_ui=2.0, est=4.493148675401071, details={u'was_impossible': False}),
#  Prediction(uid=u'A1154WMDBSFRJI', iid=u'B0064X7FVE', r_ui=2.0, est=3.813437686258235, details={u'was_impossible': False}),
#  Prediction(uid=u'A11DQ5DOJX5IN', iid=u'B00CFNDUIY', r_ui=5.0, est=4.324802008853229, details={u'was_impossible': False}),
#  Prediction(uid=u'A13NJ8IZWG5R7P', iid=u'B00689PMD2', r_ui=3.0, est=2.974264446528598, details={u'was_impossible': False}),
#  Prediction(uid=u'A139K7V6YN5QY8', iid=u'B00APKROYK', r_ui=4.0, est=3.9548993428793335, details={u'was_impossible': False}),
#  Prediction(uid=u'A1396KK8YE9D1I', iid=u'B00821NZ74', r_ui=4.0, est=4.2894377135168344, details={u'was_impossible': False}),
#  Prediction(uid=u'A127GLJ4NQOL26', iid=u'B006RXD2I6', r_ui=3.0, est=4.580637244889728, details={u'was_impossible': False}),
#  Prediction(uid=u'A13KNU0BVC4I2', iid=u'B0087HT36U', r_ui=5.0, est=4.251317638463314, details={u'was_impossible': False}),
#  Prediction(uid=u'A100VWQDTPCP7K', iid=u'B00AM1EPB2', r_ui=4.0, est=4.067920352317104, details={u'was_impossible': False}),
#  Prediction(uid=u'A13KHCB7NGJD5T', iid=u'B00BX42FLY', r_ui=4.0, est=3.883711961302551, details={u'was_impossible': False}),
#  Prediction(uid=u'A06040392DD4RUEKFX1IQ', iid=u'B00BT1SL50', r_ui=4.0, est=3.9185625831015947, details={u'was_impossible': False}),
#  Prediction(uid=u'A11HCEZ4DU3XKY', iid=u'B00992CF6W', r_ui=5.0, est=3.9714194878583515, details={u'was_impossible': False}),
#  Prediction(uid=u'A100KNKZ1AO4ZI', iid=u'B0090WZZ9A', r_ui=5.0, est=3.6646624792150493, details={u'was_impossible': False}),
#  Prediction(uid=u'A12Y4YFNY9LVX0', iid=u'B009C7ZQM4', r_ui=5.0, est=4.89707121331653, details={u'was_impossible': False}),
#  Prediction(uid=u'A10YFWYM9672WS', iid=u'B007NACZPI', r_ui=4.0, est=3.9154111629299213, details={u'was_impossible': False}),
#  Prediction(uid=u'A11KZNTR3AZ2HI', iid=u'B009ZKSPDK', r_ui=5.0, est=4.530999816196722, details={u'was_impossible': False}),
#  Prediction(uid=u'A118ZQMQRL30J4', iid=u'B0066WJLU6', r_ui=5.0, est=3.4199047875015762, details={u'was_impossible': False}),
#  Prediction(uid=u'A1365G6LT8LN2W', iid=u'B00CRFAAYC', r_ui=5.0, est=4.262141760130085, details={u'was_impossible': False}),
#  Prediction(uid=u'A110KV2T5LVMRD', iid=u'B00881VLCE', r_ui=5.0, est=4.131088362241609, details={u'was_impossible': False}),
#  Prediction(uid=u'A10M3V9SOAOB55', iid=u'B00BWBHIUG', r_ui=5.0, est=3.5117517108404344, details={u'was_impossible': False}),
#  Prediction(uid=u'A12LUFY3M72TQB', iid=u'B009XAJI8S', r_ui=3.0, est=3.946374756158839, details={u'was_impossible': False}),
#  Prediction(uid=u'A13RINJH57HENT', iid=u'B004HXHVZ8', r_ui=5.0, est=4.442949261152521, details={u'was_impossible': False}),
#  Prediction(uid=u'A11A93OQEW456H', iid=u'B0086700CM', r_ui=5.0, est=4.996773359615047, details={u'was_impossible': False}),
#  Prediction(uid=u'A13UHAKJ3MXKQF', iid=u'B00KWVZ750', r_ui=5.0, est=4.326815914185917, details={u'was_impossible': False}),
#  Prediction(uid=u'A10MDBF6K01VT', iid=u'B00G5LQ5MU', r_ui=5.0, est=4.269282552988173, details={u'was_impossible': False}),
#  Prediction(uid=u'A10869GOB1JQUF', iid=u'B00CTQ6SIG', r_ui=5.0, est=4.818742223784243, details={u'was_impossible': False}),
#  Prediction(uid=u'A0726851LE6YEJK0LM9L', iid=u'B00AKL1XPU', r_ui=5.0, est=4.163819824298378, details={u'was_impossible': False}),
#  Prediction(uid=u'A10WO0XY362KEY', iid=u'B004HE5TAG', r_ui=5.0, est=3.7382584637980663, details={u'was_impossible': False}),
#  Prediction(uid=u'A10REK3XHCU8HT', iid=u'B005KN7NQ6', r_ui=5.0, est=3.990120613696797, details={u'was_impossible': False}),
#  Prediction(uid=u'A10F38UBZB45R5', iid=u'B004LZF2LW', r_ui=3.0, est=4.215669996667224, details={u'was_impossible': False}),
#  Prediction(uid=u'A10XGJ55PVUFOK', iid=u'B00AR1AUAW', r_ui=4.0, est=4.078865643377971, details={u'was_impossible': False}),
#  Prediction(uid=u'A13NYITAFLF36M', iid=u'B008L1A68Q', r_ui=5.0, est=3.997633687101904, details={u'was_impossible': False}),
#  Prediction(uid=u'A12E3F65U2WP4T', iid=u'B0097EWK3A', r_ui=5.0, est=4.87517422437123, details={u'was_impossible': False}),
#  Prediction(uid=u'A10APFU4SBMAM1', iid=u'B00CO6TOBY', r_ui=2.0, est=3.760332164018432, details={u'was_impossible': False}),
#  Prediction(uid=u'A13NCZ6GFX3KYY', iid=u'B00H0BGCJK', r_ui=1.0, est=4.322833079975606, details={u'was_impossible': False}),
#  Prediction(uid=u'A102XPQQLIOTRZ', iid=u'B00DD1F0VC', r_ui=5.0, est=4.388711110607277, details={u'was_impossible': False}),
#  Prediction(uid=u'A12V0P7QIM2MZY', iid=u'B00HGJ18C2', r_ui=4.0, est=3.7471958554087554, details={u'was_impossible': False}),
#  Prediction(uid=u'A10SGQOVL1C4Z6', iid=u'B00COVCV50', r_ui=5.0, est=4.523901178399474, details={u'was_impossible': False}),
#  Prediction(uid=u'A13V87NIQ2LVBC', iid=u'B0063IH60K', r_ui=4.0, est=4.205976324018081, details={u'was_impossible': False}),
#  Prediction(uid=u'A1220P5YJ07YVK', iid=u'B009O2XY12', r_ui=5.0, est=3.664380238603119, details={u'was_impossible': False}),
#  Prediction(uid=u'A13UVLA11U65MC', iid=u'B00G5LQ5MU', r_ui=3.0, est=3.7852384105329984, details={u'was_impossible': False}),
#  Prediction(uid=u'A13V4H17BGPPMM', iid=u'B00JVZ0DQG', r_ui=4.0, est=4.5442058844283455, details={u'was_impossible': False}),
#  Prediction(uid=u'A11PHBTHSZFZZ5', iid=u'B005ZFOOE8', r_ui=5.0, est=4.505594951444453, details={u'was_impossible': False}),
#  Prediction(uid=u'A12DB856Q57Z12', iid=u'B009ZHQLHA', r_ui=5.0, est=3.4867741904711917, details={u'was_impossible': False}),
#  Prediction(uid=u'A11S5UDE14JMHW', iid=u'B007PT3QOQ', r_ui=3.0, est=3.030557630320133, details={u'was_impossible': False}),
#  Prediction(uid=u'A12U6CX0KUGR8T', iid=u'B006RM6JCI', r_ui=4.0, est=3.9682959578587558, details={u'was_impossible': False}),
#  Prediction(uid=u'A11B2627XDGRS5', iid=u'B007HGMVIE', r_ui=4.0, est=3.685688675899662, details={u'was_impossible': False}),
#  Prediction(uid=u'A113FWTT3WBMJX', iid=u'B0070Z89CY', r_ui=5.0, est=3.7034313003834622, details={u'was_impossible': False}),
#  Prediction(uid=u'A13LQ3QUJCIK13', iid=u'B009ZXRC9A', r_ui=5.0, est=4.173973323762212, details={u'was_impossible': False}),
#  Prediction(uid=u'A11H6S0AQI7HBF', iid=u'B0067Q4DPE', r_ui=5.0, est=4.557603732196952, details={u'was_impossible': False}),
#  Prediction(uid=u'A10A1FOXXG9OJJ', iid=u'B004VMUS9G', r_ui=4.0, est=4.40133847319801, details={u'was_impossible': False}),
#  Prediction(uid=u'A10I7FJJDJG5UH', iid=u'B00AA0TJO8', r_ui=2.0, est=4.109598513622866, details={u'was_impossible': False}),
#  Prediction(uid=u'A123PSO9MJG70I', iid=u'B008OD6QYE', r_ui=5.0, est=4.264829292221658, details={u'was_impossible': False}),
#  Prediction(uid=u'A10L3Z0WNJCYKI', iid=u'B004DLPXAO', r_ui=5.0, est=3.8929079152250443, details={u'was_impossible': False}),
#  Prediction(uid=u'A01341905GWNB6HMUPJF', iid=u'B00DS86XPM', r_ui=5.0, est=4.707897250104788, details={u'was_impossible': False}),
#  Prediction(uid=u'A12UE00VH7D20N', iid=u'B00AREIAI8', r_ui=5.0, est=4.587768776535717, details={u'was_impossible': False}),
#  Prediction(uid=u'A116NIW2AMINOE', iid=u'B00E5GJ7QS', r_ui=4.0, est=4.256667418292327, details={u'was_impossible': False}),
#  Prediction(uid=u'A108YVYGHOVXBF', iid=u'B00BX736EG', r_ui=5.0, est=4.400458651336747, details={u'was_impossible': False}),
#  Prediction(uid=u'A102YVT656CXUB', iid=u'B008AZGWYK', r_ui=5.0, est=3.864956809501995, details={u'was_impossible': False}),
#  Prediction(uid=u'A1029ESOR657OQ', iid=u'B008J4K6KI', r_ui=5.0, est=4.387564599368719, details={u'was_impossible': False}),
#  Prediction(uid=u'A10RV0FGPT0AYX', iid=u'B004UCO0FA', r_ui=5.0, est=4.719476447331844, details={u'was_impossible': False}),
#  Prediction(uid=u'A10QUNEBYKDB9I', iid=u'B008171UVM', r_ui=5.0, est=3.6867497852096314, details={u'was_impossible': False}),
#  Prediction(uid=u'A13BQPM78URBZ8', iid=u'B00BTL5YMI', r_ui=5.0, est=3.7795823694510466, details={u'was_impossible': False}),
#  Prediction(uid=u'A11XD6YP7V7W3J', iid=u'B008841TP0', r_ui=1.0, est=3.381067112189813, details={u'was_impossible': False}),
#  Prediction(uid=u'A13UIEWVG5PCH1', iid=u'B0063IH60K', r_ui=5.0, est=4.726372227195613, details={u'was_impossible': False}),
#  Prediction(uid=u'A13D4M9JIPUX8B', iid=u'B0094BB4TW', r_ui=5.0, est=3.6224701165682367, details={u'was_impossible': False}),
#  Prediction(uid=u'A114LRC6WGCGT8', iid=u'B008JGSM6G', r_ui=5.0, est=4.394715293766909, details={u'was_impossible': False}),
#  Prediction(uid=u'A1043W70WOBDDP', iid=u'B009WO7NQO', r_ui=1.0, est=4.096461059198387, details={u'was_impossible': False}),
#  Prediction(uid=u'A11WYLM1S9NOZM', iid=u'B00B63HT8Q', r_ui=5.0, est=4.684277886158656, details={u'was_impossible': False}),
#  Prediction(uid=u'A1164DIX8JEH1E', iid=u'B00FAX6XQC', r_ui=5.0, est=4.002332258327764, details={u'was_impossible': False}),
#  Prediction(uid=u'A121RUQ122N54Y', iid=u'B007MFDUP8', r_ui=1.0, est=3.6052242129886953, details={u'was_impossible': False}),
#  Prediction(uid=u'A101K1EH8VRTMP', iid=u'B006OBWGHO', r_ui=1.0, est=4.208910525476884, details={u'was_impossible': False}),
#  Prediction(uid=u'A12A8LU93A132U', iid=u'B00850NK6I', r_ui=4.0, est=3.9627521816451448, details={u'was_impossible': False}),
#  Prediction(uid=u'A13IIP6HTFNCVT', iid=u'B0064QNS62', r_ui=3.0, est=4.353847402791942, details={u'was_impossible': False}),
#  Prediction(uid=u'A104KP9O6Y8BZY', iid=u'B0063HB1HU', r_ui=5.0, est=3.589328567455485, details={u'was_impossible': False}),
#  Prediction(uid=u'A07343812QLONJZ8QB5N7', iid=u'B004N8W292', r_ui=5.0, est=4.434288570136742, details={u'was_impossible': False}),
#  Prediction(uid=u'A11FMLCHMB8638', iid=u'B004DPC5Y2', r_ui=3.0, est=3.8408182991270676, details={u'was_impossible': False}),
#  Prediction(uid=u'A10ABATOE1LMSQ', iid=u'B00FDUH4WY', r_ui=2.0, est=3.3234167715030156, details={u'was_impossible': False}),
#  Prediction(uid=u'A13CWTX5T80RJO', iid=u'B008MM9630', r_ui=5.0, est=4.363930359567295, details={u'was_impossible': False}),
#  Prediction(uid=u'A13L6KDPLGUP4J', iid=u'B007Z4AKQI', r_ui=4.0, est=4.096069675505613, details={u'was_impossible': False}),
#  Prediction(uid=u'A0651747TFRIVA6RJNCP', iid=u'B009L9Z6G4', r_ui=5.0, est=4.253032767266055, details={u'was_impossible': False}),
#  Prediction(uid=u'A10FSLJ39NOZKX', iid=u'B0087HT36U', r_ui=5.0, est=4.410540706766073, details={u'was_impossible': False}),
#  Prediction(uid=u'A11KGZ5ANVI8PS', iid=u'B009S98W3Q', r_ui=5.0, est=4.643606098381218, details={u'was_impossible': False}),
#  Prediction(uid=u'A110NYYIVQ0C2P', iid=u'B00881VLCE', r_ui=5.0, est=4.175597727205889, details={u'was_impossible': False}),
#  Prediction(uid=u'A13NKVA0SRAYBA', iid=u'B004MC8CA2', r_ui=5.0, est=4.832964296506795, details={u'was_impossible': False}),
#  Prediction(uid=u'A10MVE2MEOU6XT', iid=u'B00785P2QC', r_ui=5.0, est=4.010691158589019, details={u'was_impossible': False}),
#  Prediction(uid=u'A11Q5DZ1BH8DH5', iid=u'B009KEN87O', r_ui=5.0, est=4.744941824756187, details={u'was_impossible': False}),
#  Prediction(uid=u'A12V07M64OC0UT', iid=u'B00846F1YW', r_ui=5.0, est=3.813250287616603, details={u'was_impossible': False}),
#  Prediction(uid=u'A046006938AM5SST8SS4D', iid=u'B008469DGY', r_ui=4.0, est=4.054741886380244, details={u'was_impossible': False}),
#  Prediction(uid=u'A116NIW2AMINOE', iid=u'B004ZFK600', r_ui=5.0, est=3.7071273794859207, details={u'was_impossible': False}),
#  Prediction(uid=u'A13PYJOWCGLVWO', iid=u'B006U0Y07I', r_ui=5.0, est=4.591108483189561, details={u'was_impossible': False}),
#  Prediction(uid=u'A10TL5MYMMS3IE', iid=u'B007D21OC6', r_ui=1.0, est=3.498299768484171, details={u'was_impossible': False}),
#  Prediction(uid=u'A1058F6E2VAC0K', iid=u'B009NG7R3K', r_ui=5.0, est=4.265096006145554, details={u'was_impossible': False}),
#  Prediction(uid=u'A12TOX4JLWBW4H', iid=u'B008JK6W5K', r_ui=5.0, est=4.159712207945759, details={u'was_impossible': False}),
#  Prediction(uid=u'A12L8NYKONKWGK', iid=u'B007SYWFRM', r_ui=4.0, est=4.239543195553024, details={u'was_impossible': False}),
#  Prediction(uid=u'A10IGJ5Q3Z9WIA', iid=u'B004UID2LC', r_ui=5.0, est=3.8914577133014085, details={u'was_impossible': False}),
#  Prediction(uid=u'A11HWX089BO74Q', iid=u'B00FXKHEK6', r_ui=5.0, est=4.62306317408011, details={u'was_impossible': False}),
#  Prediction(uid=u'A11YZSEN83VHQ3', iid=u'B004DPBGCO', r_ui=1.0, est=4.3614229455330245, details={u'was_impossible': False}),
#  Prediction(uid=u'A10L7SSV5YAMN5', iid=u'B00AK2RHR2', r_ui=4.0, est=4.3376274169153515, details={u'was_impossible': False}),
#  Prediction(uid=u'A12LS5ZKQ71YM1', iid=u'B007SYWFRM', r_ui=5.0, est=4.235645740927933, details={u'was_impossible': False}),
#  Prediction(uid=u'A10XLVZTOJVXQF', iid=u'B007V2UGPE', r_ui=4.0, est=4.143375050975029, details={u'was_impossible': False}),
#  Prediction(uid=u'A13SVJQZFHS237', iid=u'B00G922EA2', r_ui=5.0, est=4.759496318309715, details={u'was_impossible': False}),
#  Prediction(uid=u'A13P1GFKTJEIT', iid=u'B004N2NWT2', r_ui=4.0, est=4.011801523986762, details={u'was_impossible': False}),
#  Prediction(uid=u'A12SHN8SWUSWBS', iid=u'B00D0VZLVE', r_ui=5.0, est=4.6070181121366165, details={u'was_impossible': False}),
#  Prediction(uid=u'A102LAIS378AIA', iid=u'B004S33RRI', r_ui=1.0, est=4.058073769390125, details={u'was_impossible': False}),
#  Prediction(uid=u'A11P5FENZ75NVW', iid=u'B0058VW36U', r_ui=5.0, est=4.271466176253279, details={u'was_impossible': False}),
#  Prediction(uid=u'A107IPVOXV924A', iid=u'B00D2XD5JU', r_ui=5.0, est=4.408571579018804, details={u'was_impossible': False}),
#  Prediction(uid=u'A13TUDSG4QK0P0', iid=u'B00B2W1RSY', r_ui=1.0, est=3.758152711477149, details={u'was_impossible': False}),
#  Prediction(uid=u'A1185AD3FCA5KF', iid=u'B008JGSM6G', r_ui=5.0, est=4.678654791857179, details={u'was_impossible': False}),
#  Prediction(uid=u'A011523719HXWV9BRWPC0', iid=u'B00GCI69D6', r_ui=5.0, est=3.902430663949607, details={u'was_impossible': False}),
#  Prediction(uid=u'A1235F1613KMAJ', iid=u'B0063M22QO', r_ui=4.0, est=4.299027020683084, details={u'was_impossible': False}),
#  Prediction(uid=u'A131RAR8JJ0BJZ', iid=u'B007OXASB2', r_ui=5.0, est=3.7227369780689727, details={u'was_impossible': False}),
#  Prediction(uid=u'A10CMHQCTPWNWK', iid=u'B00DZ22QNO', r_ui=3.0, est=3.7817275648277744, details={u'was_impossible': False}),
#  Prediction(uid=u'A11Y0MBIREXH1I', iid=u'B006BDHAX0', r_ui=4.0, est=4.3451849478144835, details={u'was_impossible': False}),
#  Prediction(uid=u'A1249XBHMW5DSN', iid=u'B00700QXFE', r_ui=1.0, est=3.049787243030158, details={u'was_impossible': False}),
#  Prediction(uid=u'A11COHG3O3GP40', iid=u'B00F3W1GAS', r_ui=5.0, est=3.6888763516977727, details={u'was_impossible': False}),
#  Prediction(uid=u'A12G7F9JVQ8YCZ', iid=u'B00GOZQ2E8', r_ui=5.0, est=4.442181922888087, details={u'was_impossible': False}),
#  Prediction(uid=u'A10DM50J4D43AM', iid=u'B00DFW3818', r_ui=1.0, est=3.748934435194541, details={u'was_impossible': False}),
#  Prediction(uid=u'A11UYHKU0BAWWV', iid=u'B0060CIG0I', r_ui=5.0, est=3.8362718747962186, details={u'was_impossible': False}),
#  Prediction(uid=u'A108PAYAIU0AW8', iid=u'B0073LWEXK', r_ui=5.0, est=3.89374100803919, details={u'was_impossible': False}),
#  Prediction(uid=u'A102M7IZD1A9G0', iid=u'B007P6T52G', r_ui=2.0, est=3.893725462090943, details={u'was_impossible': False}),
#  Prediction(uid=u'A11LLBLFRE59AI', iid=u'B0086700CM', r_ui=5.0, est=4.448245477601323, details={u'was_impossible': False}),
#  Prediction(uid=u'A12G4B7N2OP81F', iid=u'B00IAQ3RJM', r_ui=5.0, est=4.71958153411804, details={u'was_impossible': False}),
#  Prediction(uid=u'A10G621VAEQUYA', iid=u'B009HKL4B8', r_ui=5.0, est=4.163438447688495, details={u'was_impossible': False}),
#  Prediction(uid=u'A112YL94W69QJS', iid=u'B00KWVZ750', r_ui=5.0, est=4.351716484972927, details={u'was_impossible': False}),
#  Prediction(uid=u'A10UU7QN4WSFYL', iid=u'B006QCMPWM', r_ui=5.0, est=4.565336035144469, details={u'was_impossible': False}),
#  Prediction(uid=u'A10TFU3UEDJFTL', iid=u'B008FRG6JO', r_ui=5.0, est=4.236306139932823, details={u'was_impossible': False}),
# ...
#  Prediction(uid=u'A12JHKQERWHDBR', iid=u'B004H6WTJI', r_ui=5.0, est=4.818793789276994, details={u'was_impossible': False}),
#  Prediction(uid=u'A12GQVS6FYXJIH', iid=u'B008Y2FRFO', r_ui=5.0, est=3.400423623232747, details={u'was_impossible': False}),
#  Prediction(uid=u'A11NSGRVDY8J84', iid=u'B00913DPW2', r_ui=3.0, est=4.01141692569957, details={u'was_impossible': False}),
#  Prediction(uid=u'A119SU7M5GUP58', iid=u'B004OG7XY2', r_ui=5.0, est=4.647283861633566, details={u'was_impossible': False}),
#  Prediction(uid=u'A13UVLA11U65MC', iid=u'B00HY9UK28', r_ui=4.0, est=3.887272859315533, details={u'was_impossible': False}),
#  Prediction(uid=u'A11VWV1OKGVD4V', iid=u'B00AE9UYJ4', r_ui=5.0, est=3.66906181999287, details={u'was_impossible': False}),
#  Prediction(uid=u'A12EQ7AFJ2J2ZP', iid=u'B0087FDS22', r_ui=5.0, est=4.123165783692388, details={u'was_impossible': False}),
#  Prediction(uid=u'A11RU2YNML78P1', iid=u'B00AMPALV6', r_ui=3.0, est=3.615226128994551, details={u'was_impossible': False}),
#  Prediction(uid=u'A139GN6GS0A2UQ', iid=u'B00BFUUMO8', r_ui=5.0, est=3.5169844118906575, details={u'was_impossible': False}),
#  Prediction(uid=u'A13ETXASMMTL6G', iid=u'B00GY0HJ4K', r_ui=4.0, est=3.9806755343805222, details={u'was_impossible': False}),
#  Prediction(uid=u'A11JNONMEB5T2H', iid=u'B007MTQ8C6', r_ui=4.0, est=3.896862360348548, details={u'was_impossible': False}),
#  Prediction(uid=u'A11X5TN04XR5QW', iid=u'B004N2NWQ0', r_ui=1.0, est=3.383732358425722, details={u'was_impossible': False}),
#  Prediction(uid=u'A114H621Y7BKXC', iid=u'B008FRFN7A', r_ui=5.0, est=4.303221794569943, details={u'was_impossible': False}),
#  Prediction(uid=u'A137IWJMQOJGUO', iid=u'B00CDBLC8S', r_ui=5.0, est=4.534313561147902, details={u'was_impossible': False}),
#  Prediction(uid=u'A12TNTPZNPQP6C', iid=u'B00ANUMR1W', r_ui=3.0, est=3.9829460459733466, details={u'was_impossible': False}),
#  Prediction(uid=u'A105GM37MWPTQW', iid=u'B007SYDYLS', r_ui=5.0, est=4.162043298762975, details={u'was_impossible': False}),
#  Prediction(uid=u'A0940656302Z7FL0Z4SFF', iid=u'B005ZFOOE8', r_ui=5.0, est=4.423944274374319, details={u'was_impossible': False}),
#  Prediction(uid=u'A13IZBGB5S4133', iid=u'B0055SWM08', r_ui=4.0, est=4.536214148391647, details={u'was_impossible': False}),
#  Prediction(uid=u'A10SY74PJCS268', iid=u'B008N02WZU', r_ui=1.0, est=3.2223154301109993, details={u'was_impossible': False}),
#  Prediction(uid=u'A138EGGPMM8JKT', iid=u'B0079Q963K', r_ui=3.0, est=4.19332960653139, details={u'was_impossible': False}),
#  Prediction(uid=u'A106XHERWNXTVK', iid=u'B00FEMJF6O', r_ui=2.0, est=4.0540083336285475, details={u'was_impossible': False}),
#  Prediction(uid=u'A11FUKRZZYDKUN', iid=u'B00ARI9CDQ', r_ui=1.0, est=3.875876973439781, details={u'was_impossible': False}),
#  Prediction(uid=u'A1245WU35KVV2', iid=u'B009O5CLZY', r_ui=5.0, est=4.106492734377804, details={u'was_impossible': False}),
#  Prediction(uid=u'A1369I5KLZZLLS', iid=u'B004HMJ5QM', r_ui=4.0, est=4.101263997403459, details={u'was_impossible': False}),
#  Prediction(uid=u'A11FOKDWHJ38NN', iid=u'B004HXHVZ8', r_ui=5.0, est=4.586076640941021, details={u'was_impossible': False}),
#  Prediction(uid=u'A132ETQPMHQ585', iid=u'B007MFFE52', r_ui=1.0, est=3.4466374922363454, details={u'was_impossible': False}),
#  Prediction(uid=u'A10GMU2T2XVQI5', iid=u'B0091REZMW', r_ui=4.0, est=4.108864003919895, details={u'was_impossible': False}),
#  Prediction(uid=u'A10MWN6JRRU4IR', iid=u'B00BNH1PF8', r_ui=4.0, est=4.297893748606997, details={u'was_impossible': False}),
#  Prediction(uid=u'A1164DIX8JEH1E', iid=u'B008Y2FRFO', r_ui=1.0, est=4.287389623775448, details={u'was_impossible': False}),
#  Prediction(uid=u'A12VEL9WMX8CH9', iid=u'B00KWVZ750', r_ui=5.0, est=4.090256858045079, details={u'was_impossible': False}),
#  Prediction(uid=u'A13B85HRYERCJM', iid=u'B005QT1KU4', r_ui=4.0, est=3.9253531921168445, details={u'was_impossible': False}),
#  Prediction(uid=u'A10Z3CFG8BKCXJ', iid=u'B0057B1C90', r_ui=1.0, est=3.839190698176135, details={u'was_impossible': False}),
#  Prediction(uid=u'A10FES2AU7AYTD', iid=u'B00A1SL8SE', r_ui=5.0, est=4.0196876420347225, details={u'was_impossible': False}),
#  Prediction(uid=u'A12KXMJ1QN6VJ5', iid=u'B00CMMR9SU', r_ui=5.0, est=4.111968959691413, details={u'was_impossible': False}),
#  Prediction(uid=u'A12HZJZGW75EME', iid=u'B00AA87JGU', r_ui=5.0, est=4.175047653905092, details={u'was_impossible': False}),
#  Prediction(uid=u'A10QKBT0TB4Z0Z', iid=u'B0051UP5NQ', r_ui=4.0, est=3.592477791016451, details={u'was_impossible': False}),
#  Prediction(uid=u'A11B4YPPUV0M2V', iid=u'B0066T8OH0', r_ui=5.0, est=4.044720868198237, details={u'was_impossible': False}),
#  Prediction(uid=u'A13CX5BZ60WC7V', iid=u'B0086700CM', r_ui=5.0, est=4.545289361717555, details={u'was_impossible': False}),
#  Prediction(uid=u'A114WJF60BDREY', iid=u'B006RM6JCI', r_ui=5.0, est=4.316093174633607, details={u'was_impossible': False}),
#  Prediction(uid=u'A138420BCWCYPB', iid=u'B00BR4QNJ0', r_ui=4.0, est=3.9345930294367655, details={u'was_impossible': False}),
#  Prediction(uid=u'A10XM8K89AP4GE', iid=u'B00CHSPB8Y', r_ui=5.0, est=3.7553646627445256, details={u'was_impossible': False}),
#  Prediction(uid=u'A11O7CW8KQ1ED9', iid=u'B00I8Q77Y0', r_ui=5.0, est=4.54360234449822, details={u'was_impossible': False}),
#  Prediction(uid=u'A11RWP436Q0V8J', iid=u'B0067Q4DPE', r_ui=5.0, est=4.286554194981315, details={u'was_impossible': False}),
#  Prediction(uid=u'A11022OXR7JFOG', iid=u'B008KPB8P8', r_ui=2.0, est=3.8476790266435836, details={u'was_impossible': False}),
#  Prediction(uid=u'A122VZH3859I6V', iid=u'B007KPT2N4', r_ui=5.0, est=3.8581812160079583, details={u'was_impossible': False}),
#  Prediction(uid=u'A12BDQUE67KQ3G', iid=u'B008Y7SMQU', r_ui=5.0, est=3.9212935670136124, details={u'was_impossible': False}),
#  Prediction(uid=u'A131CRIH83FS0Q', iid=u'B0055DL1G4', r_ui=1.0, est=3.1453107740339785, details={u'was_impossible': False}),
#  Prediction(uid=u'A10CSKLJ7YSC2A', iid=u'B00DUOO4GE', r_ui=5.0, est=4.054832631148347, details={u'was_impossible': False}),
#  Prediction(uid=u'A121KXLT6YNMVD', iid=u'B009G9KFQ0', r_ui=3.0, est=4.2786109843401, details={u'was_impossible': False}),
#  Prediction(uid=u'A10389WSMBPCYR', iid=u'B00AKJTBL0', r_ui=1.0, est=4.177420002031255, details={u'was_impossible': False}),
#  Prediction(uid=u'A11OHDXPD643J8', iid=u'B00B7Y0206', r_ui=1.0, est=3.088295793820179, details={u'was_impossible': False}),
#  Prediction(uid=u'A10GLVITSITGSA', iid=u'B0054QY36C', r_ui=3.0, est=3.533365857600762, details={u'was_impossible': False}),
#  Prediction(uid=u'A11PJLQ5BJ5VEK', iid=u'B006D1ONE4', r_ui=5.0, est=4.747681501649626, details={u'was_impossible': False}),
#  Prediction(uid=u'A13DFO3LJ79XB4', iid=u'B00FAPF5U0', r_ui=5.0, est=4.115599385754511, details={u'was_impossible': False}),
#  Prediction(uid=u'A109KCRVW11AII', iid=u'B00A3NQNUU', r_ui=5.0, est=4.328742525258654, details={u'was_impossible': False}),
#  Prediction(uid=u'A11FHC117DPVZW', iid=u'B008KMAJQU', r_ui=4.0, est=4.19643263255005, details={u'was_impossible': False}),
#  Prediction(uid=u'A10P5GCN6BFUGJ', iid=u'B00FX6ZBXC', r_ui=4.0, est=4.617102293951085, details={u'was_impossible': False}),
#  Prediction(uid=u'A13ELTHFYO46N9', iid=u'B008MM9630', r_ui=5.0, est=4.407893149797627, details={u'was_impossible': False}),
#  Prediction(uid=u'A10S301PTZ98VS', iid=u'B004SRPXWQ', r_ui=2.0, est=4.294654427779571, details={u'was_impossible': False}),
#  Prediction(uid=u'A13GJQJUHXOZF1', iid=u'B008J4K6KI', r_ui=5.0, est=4.396713644798508, details={u'was_impossible': False}),
#  Prediction(uid=u'A105PL1EQUM7ZA', iid=u'B004HXHVZ8', r_ui=5.0, est=4.6393171419035095, details={u'was_impossible': False}),
#  Prediction(uid=u'A10XH4CNHU35IF', iid=u'B007NACZPI', r_ui=3.0, est=4.402102027539176, details={u'was_impossible': False}),
#  Prediction(uid=u'A131EHQI8PDIIJ', iid=u'B00H59CTW6', r_ui=5.0, est=4.349458262103809, details={u'was_impossible': False}),
#  Prediction(uid=u'A13A8HHWODEH1X', iid=u'B007PTJOV0', r_ui=5.0, est=4.771765747744187, details={u'was_impossible': False}),
#  Prediction(uid=u'A107FX6WPM7WMD', iid=u'B0062AX2DE', r_ui=5.0, est=4.534157981721115, details={u'was_impossible': False}),
#  Prediction(uid=u'A13G7VPBIVSKDK', iid=u'B00A4KVFLY', r_ui=4.0, est=3.939637938415316, details={u'was_impossible': False}),
#  Prediction(uid=u'A10TZX7XSVXB11', iid=u'B008D2QRAO', r_ui=2.0, est=4.127389932612341, details={u'was_impossible': False}),
#  Prediction(uid=u'A11VAPRE6NXHT7', iid=u'B0055ILRN6', r_ui=4.0, est=4.269560883663672, details={u'was_impossible': False}),
#  Prediction(uid=u'A12WA5YQ5IYWMC', iid=u'B00BXPQN2K', r_ui=3.0, est=4.31752033564076, details={u'was_impossible': False}),
#  Prediction(uid=u'A11IR35H8RCL4I', iid=u'B00AM1EPB2', r_ui=5.0, est=4.1035644959676, details={u'was_impossible': False}),
#  Prediction(uid=u'A0239841MAXD5RC4YPXU', iid=u'B00B49Z8TY', r_ui=5.0, est=3.8183970220885213, details={u'was_impossible': False}),
#  Prediction(uid=u'A12MF1KAO3X1JZ', iid=u'B00ADPH2YO', r_ui=5.0, est=4.179680592352691, details={u'was_impossible': False}),
#  Prediction(uid=u'A11XP4GZYX3GQE', iid=u'B0063M22QO', r_ui=4.0, est=4.390894961407303, details={u'was_impossible': False}),
#  Prediction(uid=u'A12FZ7RKYHZQ0Y', iid=u'B0064DBE9I', r_ui=4.0, est=4.334581152472879, details={u'was_impossible': False}),
#  Prediction(uid=u'A13QJUVMP5A4CE', iid=u'B00ATSAVQG', r_ui=5.0, est=4.006296057355871, details={u'was_impossible': False}),
#  Prediction(uid=u'A120VZHZBTAX11', iid=u'B00BPC23XO', r_ui=5.0, est=4.4955284511734765, details={u'was_impossible': False}),
#  Prediction(uid=u'A102HZ2AH6129C', iid=u'B00AE9UYJ4', r_ui=4.0, est=3.9910664503944275, details={u'was_impossible': False}),
#  Prediction(uid=u'A109PH5XBOGDIL', iid=u'B00B2V66VS', r_ui=5.0, est=4.320887326620075, details={u'was_impossible': False}),
#  Prediction(uid=u'A12KDPZKGRFOR', iid=u'B00992CF6W', r_ui=4.0, est=4.191690634648594, details={u'was_impossible': False}),
#  Prediction(uid=u'A122ZDYRJT6VIE', iid=u'B00F54F1G4', r_ui=5.0, est=3.787348195614454, details={u'was_impossible': False}),
#  Prediction(uid=u'A10QQ9DRBG32S3', iid=u'B008JGSM6G', r_ui=5.0, est=4.58564596397195, details={u'was_impossible': False}),
#  Prediction(uid=u'A1378ZJMWCTVT3', iid=u'B00HHBXYGM', r_ui=1.0, est=3.9583435545783905, details={u'was_impossible': False}),
#  Prediction(uid=u'A128W8SA6HMDB3', iid=u'B006BDHAX0', r_ui=5.0, est=4.4575535082112445, details={u'was_impossible': False}),
#  Prediction(uid=u'A13C6ZAVQPEVUX', iid=u'B0088QGB7Y', r_ui=5.0, est=4.109022081280029, details={u'was_impossible': False}),
#  Prediction(uid=u'A13MK5YFDHFTNX', iid=u'B006PH7WBM', r_ui=5.0, est=4.7984151733521205, details={u'was_impossible': False}),
#  Prediction(uid=u'A107D7VEC8IV7', iid=u'B004SIIBGU', r_ui=5.0, est=4.02905227876278, details={u'was_impossible': False}),
#  Prediction(uid=u'A12AE4JYFVYN6V', iid=u'B009DCOU9S', r_ui=4.0, est=4.037991718850466, details={u'was_impossible': False}),
#  Prediction(uid=u'A11X0RF20MIB1D', iid=u'B00FAPF5U0', r_ui=5.0, est=4.275063021551669, details={u'was_impossible': False}),
#  Prediction(uid=u'A1273U7GFG2FIJ', iid=u'B00HHBXYGM', r_ui=4.0, est=4.346697075444573, details={u'was_impossible': False}),
#  Prediction(uid=u'A12GIOHHJYSKN8', iid=u'B00ATSBIIG', r_ui=5.0, est=4.394451682573686, details={u'was_impossible': False}),
#  Prediction(uid=u'A10AG3O76QWLE0', iid=u'B008JK6W5K', r_ui=4.0, est=4.69034919141318, details={u'was_impossible': False}),
#  Prediction(uid=u'A11I47RIQXL2MD', iid=u'B00BJ7HA92', r_ui=3.0, est=3.554419824286896, details={u'was_impossible': False}),
#  Prediction(uid=u'A13M18P55AS9J', iid=u'B00C5J4MO4', r_ui=1.0, est=4.503869268437828, details={u'was_impossible': False}),
#  Prediction(uid=u'A11ZQ4YH59J92T', iid=u'B00I8Q77Y0', r_ui=5.0, est=4.446107389757629, details={u'was_impossible': False}),
#  Prediction(uid=u'A121WZNVG2RUA6', iid=u'B008BBB388', r_ui=5.0, est=4.062159578488868, details={u'was_impossible': False}),
#  Prediction(uid=u'A12UIUPEGCSOYJ', iid=u'B00BPC23XO', r_ui=3.0, est=4.032110768029686, details={u'was_impossible': False}),
#  Prediction(uid=u'A11UTRXMAEUDE', iid=u'B0086700CM', r_ui=5.0, est=4.77070661214872, details={u'was_impossible': False}),
#  Prediction(uid=u'A11ARZPI2V20LY', iid=u'B00HFTHXMC', r_ui=5.0, est=4.308986143010259, details={u'was_impossible': False}),
#  Prediction(uid=u'A12BKC0G03724F', iid=u'B005KN4PEE', r_ui=2.0, est=3.4921513448214108, details={u'was_impossible': False}),
#  Prediction(uid=u'A117M7EK15PX98', iid=u'B008FC58ES', r_ui=5.0, est=4.385447057956265, details={u'was_impossible': False}),
#  Prediction(uid=u'A13CTZJEIPCTGG', iid=u'B00BYG0RSE', r_ui=3.0, est=4.523757614385722, details={u'was_impossible': False}),
#  Prediction(uid=u'A11ZTKGR0SLIVM', iid=u'B00I6WBHD8', r_ui=5.0, est=4.023707365307871, details={u'was_impossible': False}),
#  Prediction(uid=u'A12PBK4DZI8UVP', iid=u'B008GU42KK', r_ui=5.0, est=4.352779212789275, details={u'was_impossible': False}),
#  Prediction(uid=u'A10Z5U9GROW4B8', iid=u'B00C7D6ZP2', r_ui=5.0, est=4.31727688980754, details={u'was_impossible': False}),
#  Prediction(uid=u'A10A4MK7ESZIG8', iid=u'B00I8Q77Y0', r_ui=5.0, est=4.448198385552828, details={u'was_impossible': False}),
#  Prediction(uid=u'A107KZSXOFEYIS', iid=u'B004LOMB2Q', r_ui=3.0, est=3.413071010558688, details={u'was_impossible': False}),
#  Prediction(uid=u'A12803CV7P2VH0', iid=u'B008183CTE', r_ui=5.0, est=4.088538354484048, details={u'was_impossible': False}),
#  Prediction(uid=u'A1312O6ZAW34CF', iid=u'B005MSJ3DK', r_ui=5.0, est=3.7937541161519337, details={u'was_impossible': False}),
#  Prediction(uid=u'A10QM1Y3N2ND5K', iid=u'B009HKL4B8', r_ui=1.0, est=4.129687113186197, details={u'was_impossible': False}),
#  Prediction(uid=u'A11UIB3Q85LBG', iid=u'B00850NK6I', r_ui=5.0, est=4.319472015333805, details={u'was_impossible': False}),
#  Prediction(uid=u'A13TYUPOI9XEJ3', iid=u'B004SBQGHS', r_ui=5.0, est=4.309125140765718, details={u'was_impossible': False}),
#  Prediction(uid=u'A111GHMLHWD8K8', iid=u'B008BM3TKM', r_ui=4.0, est=3.9778226296207784, details={u'was_impossible': False}),
#  Prediction(uid=u'A1193APURCP49W', iid=u'B007TKT2SK', r_ui=5.0, est=4.491962260612087, details={u'was_impossible': False}),
#  Prediction(uid=u'A129HMVJA9KOKZ', iid=u'B0080IOHLW', r_ui=5.0, est=4.030020449298612, details={u'was_impossible': False}),
#  Prediction(uid=u'A11TJDOKEL4R49', iid=u'B006RXD2I6', r_ui=5.0, est=4.701432821540714, details={u'was_impossible': False}),
#  Prediction(uid=u'A101WFMYQUKLQN', iid=u'B00DBER974', r_ui=5.0, est=4.2126441479258805, details={u'was_impossible': False}),
#  Prediction(uid=u'A13UWUPZQC5XVA', iid=u'B00CMF27DE', r_ui=5.0, est=4.6074895906325475, details={u'was_impossible': False}),
#  Prediction(uid=u'A128I65K3W9P4E', iid=u'B0080K98U0', r_ui=4.0, est=4.169488740148329, details={u'was_impossible': False}),
#  Prediction(uid=u'A10FBCA2RGV549', iid=u'B0085P2Z6E', r_ui=4.0, est=4.658257837530645, details={u'was_impossible': False}),
#  Prediction(uid=u'A111Q9P8UWHUGJ', iid=u'B006OP8494', r_ui=5.0, est=4.181002480322718, details={u'was_impossible': False}),
#  Prediction(uid=u'A1181NRB5DRTZF', iid=u'B00AESN8XY', r_ui=5.0, est=5, details={u'was_impossible': False}),
#  Prediction(uid=u'A1157VMNQK85W5', iid=u'B00CLVQ8GG', r_ui=3.0, est=3.9327205040404567, details={u'was_impossible': False}),
#  Prediction(uid=u'A11F27UM54FF', iid=u'B0094BB4TW', r_ui=3.0, est=3.1739930785308625, details={u'was_impossible': False}),
#  Prediction(uid=u'A09272162BT4907RW59NJ', iid=u'B008O661PK', r_ui=5.0, est=4.575037010062022, details={u'was_impossible': False}),
#  Prediction(uid=u'A1201F8RRSRE3S', iid=u'B00850NK6I', r_ui=5.0, est=3.5315036221064773, details={u'was_impossible': False}),
#  Prediction(uid=u'A10F2EQWPB165', iid=u'B0088QGB7Y', r_ui=5.0, est=4.475595379406155, details={u'was_impossible': False}),
#  Prediction(uid=u'A115SDWL5IJEQJ', iid=u'B008IXP8IU', r_ui=5.0, est=4.5715925560896755, details={u'was_impossible': False}),
#  Prediction(uid=u'A11F3QRWUZBIVW', iid=u'B00BPC23XO', r_ui=4.0, est=3.9571551449986435, details={u'was_impossible': False}),
#  ...]
